# %% [markdown]
# # Opinion Snippet Retriever
#
# This notebook **scans opinions and writes regex-based snippets** onto each `(:Case)-[:CITES_TO]->(:Case)` edge as `snippet_1`, `snippet_2`, … plus metadata (`snippet_method`, `snippet_count`, and optional `id_hit`).
#
# ---
#
# ## What this does
#
# 1. **Page through citation edges**
#    Batches over `:CITES_TO` using `id(r)` as a cursor (`BATCH_RELATIONSHIPS`).
#
# 2. **Load the citer’s opinion text**
#    Concatenates all `OpinionChunk` nodes for the source case ordered by `chunk_index`.
#
# 3. **Find “hits” in strict order (first method that hits wins):**
#    A) **`citation_pipe_first` (strict-ish)**: exact regex for the **first** element in `t.citation_pipe` (periods may be followed by an optional space; all whitespace collapsed).
#    B) **`relaxed_citation_first`**: robust relaxed regex for the **first** cite that **ignores all punctuation and whitespace** (e.g., `53 L. Ed. 2d 113` ⇔ `53 L.Ed.2d 113`, `432 U. S. 63` ⇔ `432 U.S. 63`).
#    C) **`exact_name`**: exact case-name regex (case-insensitive).
#    D) **`relaxed_name`**: tolerant case-name regex (handles punctuation/abbrev variants like `Department/Dep't/Dept.`).
#    E) **`citation_pipe_other`** (only if `search_all_citation_pipe_elements=True`): exact regex over **all remaining** `citation_pipe` elements (handles spacing like `432 U.S. 63` vs `432 U. S. 63`).
#    F) **`relaxed_citation_other`** (only if enabled): relaxed regex over **remaining** cites (punctuation/whitespace ignored).
#
#    > Once a method yields hits, **all snippets for that edge come from that same method** (no mixing).
#
# 4. **Merge overlapping hits into a single expanded snippet**
#    For each edge, hits become character windows (`APPROX_CHAR_WINDOW` total). Overlapping/touching windows are **merged** to avoid near-duplicates, then optionally **expanded to sentence boundaries** (`EXPAND_TO_SENTENCE`).
#
# 5. **“Id.” follow-on hits (optional)**
#    If `find_Id_hits=True`, after each primary hit we **scan forward** and treat `"Id."` as an additional hit **until** another case appears (detected by a `v`/`v.` pattern). If any `"Id."` is included, we set `id_hit = true`; otherwise `false`. If `find_Id_hits=False`, this step is skipped.
#
# 6. **Build snippet text**
#    From each (merged) window, extract a **character window** and optionally **compact** the text (`USE_COMPACT_SNIPPET`) to heal hyphenations, drop line-number rows, and collapse whitespace.
#
# 7. **Write back to Neo4j**
#    On each `:CITES_TO` edge we set:
#    * `snippet_1 … snippet_N` (up to `MAX_SNIPPETS_PER_EDGE`)
#    * `snippet_method ∈ {"citation_pipe_first","relaxed_citation_first","exact_name","relaxed_name","citation_pipe_other","relaxed_citation_other"}`
#    * `snippet_count` (N)
#    * `id_hit` (boolean) **only if** `find_Id_hits=True`
#    * If `force=True` (or global `CLEAR_PREVIOUS_SNIPPETS=True`), we first clear any existing `snippet_*` props.
#
# 8. **Progress & debug reporting**
#    Every `SECONDS_BETWEEN_REPORTS` seconds we print:
#    * edges processed
#    * successful edges (and breakdown by method)
#    * unsuccessful (no-hit) count
#    * total `"Id."` hits (when enabled)
#
#    Additionally, with `echo=True` the notebook prints **per-edge** debug lines:
#    * On name/other-element hits:
#      `source case → target case - {hit_type} - {#hits}`
#    * On misses:
#      `source case → target case - No hit found`
#    * When the source opinion text is missing/empty:
#      `source case → target case - No source opinion text`
#
# ---
#
# ## How to run
#
# ```python
# # Small dry run (first page)
# retrieve_all_snippets(
#     batch_size=50,
#     echo=True,
#     force=True,                           # overwrite existing snippet_* props
#     search_all_citation_pipe_elements=False,  # only first element of citation_pipe
#     find_Id_hits=False                    # skip "Id." follow-on scanning
# )
#
# # Full run with broader reporter-cite search + Id. detection
# retrieve_all_snippets(
#     echo=True,
#     force=True,
#     search_all_citation_pipe_elements=True,   # search remaining citation_pipe elements as LAST resort
#     find_Id_hits=True
# )
#
# # Quiet run, keep existing snippet_* (no overwrite)
# retrieve_all_snippets(
#     echo=False,
#     force=False,
#     search_all_citation_pipe_elements=False,
#     find_Id_hits=False
# )
# ```
#
# **Parameter notes**
#
# * `force`:
#
#   * `True` → clear/overwrite any existing `snippet_*` before writing
#   * `False` → keep existing `snippet_*`
#   * `None` → use global `CLEAR_PREVIOUS_SNIPPETS`
# * `search_all_citation_pipe_elements`:
#
#   * `False` (default) → search **only the first** `citation_pipe` element
#   * `True` → after name strategies fail, search **remaining** `citation_pipe` elements (exact, then relaxed)
# * `find_Id_hits`:
#
#   * `False` (default) → no `"Id."` scanning
#   * `True` → scan forward for `"Id."` before the next case (`v`/`v.`); set `id_hit` accordingly
#
# ---
#
# ## Key tunables
#
# * **Batching:** `BATCH_RELATIONSHIPS` (edges per page)
# * **Snippets per edge:** `MAX_SNIPPETS_PER_EDGE`
# * **Snippet windowing:** `APPROX_CHAR_WINDOW`, `EXPAND_TO_SENTENCE`, `USE_COMPACT_SNIPPET`
# * **Overwrite behavior:** `CLEAR_PREVIOUS_SNIPPETS` (used when `force=None`)
# * **Logging cadence:** `SECONDS_BETWEEN_REPORTS`
#
# ---
#
# ## Properties written on `:CITES_TO`
#
# * `snippet_1 … snippet_N` (text)
# * `snippet_method` (string)
# * `snippet_count` (int)
# * `id_hit` (bool; **only** if `find_Id_hits=True`)
#
# ---
#
# ## Environment & paths
#
# * **SageMaker/local project folder:** set `PROJECT_DIR` (optional).
# * **Credentials:** `.env` loaded from `ENV_PATH` (default `"../.env"`). Required keys:
#
#   * `NEO4J_URI` (e.g., `neo4j+s://<host>`)
#   * `NEO4J_USERNAME`
#   * `NEO4J_PASSWORD`
#   * `NEO4J_DATABASE` (optional; defaults to `"neo4j"`)
#
# > Install dependencies with `pip install neo4j python-dotenv pandas` (SageMaker: install into the active kernel).
#
# ---
#
# ## Assumptions
#
# * Graph contains `Case`, `OpinionChunk`, and `:CITES_TO`.
#   `OpinionChunk` has `case_id`, `chunk_index`, `text`.
# * Target cases have `t.citation_pipe` populated (pipe/semicolon-separated reporter cites).
#
# ---
#
# ## Troubleshooting
#
# * **Few/no hits:** verify `t.citation_pipe` values; rely on relaxed citation matching; optionally enable `search_all_citation_pipe_elements=True`.
# * **Near-duplicate snippets:** merging is automatic; consider increasing `APPROX_CHAR_WINDOW` for dense clusters.
# * **Unexpected `"Id."` behavior:** `"Id."` scanning is forward-only until a `v`/`v.`; enable `find_Id_hits=True` to set and observe `id_hit`.
# * **Connection errors:** confirm `NEO4J_URI` reachability and `.env` path (`ENV_PATH`).

# %%
# !pip install neo4j
# Out:
# Requirement already satisfied: neo4j in /opt/conda/lib/python3.12/site-packages (6.0.3)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.12/site-packages (from neo4j) (2024.2)

# %%
# ---------- imports ----------
import os, re, time, pathlib, logging
from typing import List, Dict, Any, Tuple, Optional

import pandas as pd  # (handy for ad-hoc checks / CSVs if you add later)
from neo4j import GraphDatabase
from dotenv import load_dotenv

# =========================
# Optional: project directory
# =========================
PROJECT_DIR = ""  # e.g., "/home/ec2-user/SageMaker/edge-classifier"
if PROJECT_DIR:
    os.makedirs(PROJECT_DIR, exist_ok=True)
    os.chdir(PROJECT_DIR)
    print(f"Working directory set to: {os.getcwd()}")
else:
    print(f"Working in current directory: {os.getcwd()}")

# =========================
# .env loading
# =========================
ENV_PATH = "../.env"
if not os.path.exists(ENV_PATH):
    print(f"Warning: .env not found at {ENV_PATH}. Make sure your Neo4j creds are available in environment.")
load_dotenv(ENV_PATH, override=True)

# Suppress very noisy Neo4j notifications in console
for _n in ("neo4j", "neo4j.notifications", "neo4j.work.simple"):
    logging.getLogger(_n).setLevel(logging.ERROR)

# =========================
# ENV / CONFIG
# =========================
def _clean_env(v: Optional[str]) -> Optional[str]:
    if v is None:
        return None
    v = v.strip().strip('"').strip("'").strip()
    return v or None

NEO4J_URI       = _clean_env(os.getenv("NEO4J_URI"))
NEO4J_USERNAME  = _clean_env(os.getenv("NEO4J_USERNAME"))
NEO4J_PASSWORD  = _clean_env(os.getenv("NEO4J_PASSWORD"))
NEO4J_DATABASE  = _clean_env(os.getenv("NEO4J_DATABASE")) or "neo4j"

if not NEO4J_URI:
    raise RuntimeError("Missing NEO4J_URI. Set it in .env (e.g., NEO4J_URI=neo4j+s://<host>).")
if not (NEO4J_USERNAME and NEO4J_PASSWORD):
    raise RuntimeError("Missing NEO4J_USERNAME or NEO4J_PASSWORD. Set them in .env.")
# Out:
# Working in current directory: /home/sagemaker-user/Snippet Retriever

# %%
import os, re, time, pathlib, logging
from typing import List, Dict, Any, Tuple, Optional

import pandas as pd 
from neo4j import GraphDatabase
from dotenv import load_dotenv

ENV_PATH = "../.env"
if not os.path.exists(ENV_PATH):
    print(f"Warning: .env not found at {ENV_PATH}. Make sure your Neo4j creds are available in environment.")
load_dotenv(ENV_PATH, override=True)

# Suppress very noisy Neo4j notifications in console
for _n in ("neo4j", "neo4j.notifications", "neo4j.work.simple"):
    logging.getLogger(_n).setLevel(logging.ERROR)

# =========================
# ENV / CONFIG
# =========================
def _clean_env(v: Optional[str]) -> Optional[str]:
    if v is None:
        return None
    v = v.strip().strip('"').strip("'").strip()
    return v or None

NEO4J_URI       = _clean_env(os.getenv("NEO4J_URI"))
NEO4J_USERNAME  = _clean_env(os.getenv("NEO4J_USERNAME"))
NEO4J_PASSWORD  = _clean_env(os.getenv("NEO4J_PASSWORD"))
NEO4J_DATABASE  = _clean_env(os.getenv("NEO4J_DATABASE")) or "neo4j"

# %% [markdown]
# ## Tunables

# %%
# =========================
# Tunables
# =========================
BATCH_RELATIONSHIPS     = 250      # :CITES_TO per page
MAX_SNIPPETS_PER_EDGE   = 10       # hard cap of snippets stored per edge
APPROX_CHAR_WINDOW      = 1200     # total chars (≈ half on each side)
EXPAND_TO_SENTENCE      = True     # widen to sentence boundaries
USE_COMPACT_SNIPPET     = True     # heal hyphenations, drop line numbers, collapse spaces
SECONDS_BETWEEN_REPORTS = 5        # periodic progress print
CLEAR_PREVIOUS_SNIPPETS = True     # default behavior; overridden by 'force' param

# %% [markdown]
# ## Cypher Queries

# %%
# =========================
# Cypher Queries
# =========================
Q_PAGE_REL = """
MATCH (s:Case)-[r:CITES_TO]->(t:Case)
WHERE id(r) > $after_id
RETURN id(r) AS rel_id,
       s.id AS src_id, coalesce(s.name,'') AS src_name,
       t.id AS tgt_id, coalesce(t.name,'') AS tgt_name,
       t.citation_pipe AS tgt_cite
ORDER BY rel_id
LIMIT $limit
"""

Q_GET_CHUNKS_FOR_CASE = """
MATCH (oc:OpinionChunk {case_id:$case_id})
RETURN oc.chunk_index AS chunk_index, oc.text AS text
ORDER BY oc.chunk_index
"""

# %%
def _mk_clear_snippets_cypher(max_snips:int) -> str:
    assigns = []
    for i in range(1, max_snips+1):
        assigns.append(f"r.snippet_{i} = NULL")
    assigns.append("r.snippet_method = NULL")
    assigns.append("r.snippet_count  = 0")
    assigns.append("r.`Id. hit?` = NULL")
    return " MATCH (src:Case {id:$src_id})-[r:CITES_TO]->(t:Case {id:$tgt_id}) SET " + ", ".join(assigns) + " RETURN 1 as ok"

Q_WRITE_SNIPPETS_BASE = """
MATCH (src:Case {id:$src_id})-[r:CITES_TO]->(t:Case {id:$tgt_id})
SET r.snippet_method = $snippet_method,
    r.snippet_count  = $snippet_count,
    r.`Id. hit?`     = $id_hit
SET r += $snippet_map
RETURN r.snippet_count AS snippet_count
"""

# =========================
# Regex helpers
# =========================
_ABBREV_ALTS = {
    "county": r"(County|Cnty\.?|Cty\.?)",
    "city": r"(City|Cty\.?)",
    "department": r"(Department|Dep't|Dept\.?|Dep’t)",
    "corporation": r"(Corporation|Corp\.?)",
    "incorporated": r"(Incorporated|Inc\.?)",
    "limited": r"(Limited|Ltd\.?)",
    "company": r"(Company|Co\.?)",
    "association": r"(Association|Ass'n|Assn\.?)",
    "commission": r"(Commission|Comm'n|Commn\.?)",
    "board": r"(Board|Bd\.?)",
    "authority": r"(Authority|Auth\.?)",
    "saint": r"(Saint|St\.?)",
    "mount": r"(Mount|Mt\.?)",
}

def compile_name_regex_exact(case_name: str) -> re.Pattern:
    escaped = re.escape(case_name.strip())
    escaped = re.sub(r"\\\s+", r"\\s+", escaped)
    return re.compile(rf"(?i)\b{escaped}\b")

def _token_to_relaxed(tok: str) -> str:
    base = tok.strip().strip(",.;:")
    key = base.lower().replace("’", "'").replace("–","-").replace("—","-")
    if key in _ABBREV_ALTS:
        return _ABBREV_ALTS[key]
    esc = re.escape(base)
    esc = re.sub(r'\\\.', r'\\.?', esc)
    return esc

def make_relaxed_case_name_regex(tgt_name: str) -> re.Pattern:
    m = re.split(r'\s+v\.?\s+', tgt_name, flags=re.IGNORECASE, maxsplit=1)
    if len(m) == 2:
        left, right = m[0], m[1]
    else:
        left, right = tgt_name, ""
    right = re.sub(r',\s*[A-Za-z][A-Za-z.]*\s*$', '', right).strip()

    def party_to_regex(party: str) -> str:
        tokens = re.split(r'\s+', party.strip())
        parts = [_token_to_relaxed(t) for t in tokens if t]
        return r'(?:\s+|,\s*)'.join(parts)

    left_re  = party_to_regex(left)  if left  else ""
    right_re = party_to_regex(right) if right else ""
    if left_re and right_re:
        pat = rf"(?i)\b{left_re}\s+v\.?\s+{right_re}(?:,\s*[A-Za-z][A-Za-z.]+)?\b"
    else:
        side = left_re or right_re or re.escape(tgt_name)
        pat = rf"(?i)\b{side}(?:,\s*[A-Za-z][A-Za-z.]+)?\b"

    try:
        return re.compile(pat)
    except re.error:
        return compile_name_regex_exact(tgt_name)

def compile_citation_regex(cite: str) -> re.Pattern:
    """
    Strict(ish) citation: keeps periods but allows optional single space after them and collapses whitespace.
    Good for exact matches like '261 A.D.2d 890'.
    """
    s = cite.strip()
    s = re.escape(s)
    s = re.sub(r'\\\s+', r'\\s*', s)      # any whitespace => \s*
    s = s.replace(r'\.', r'\. ?')         # period + optional space
    return re.compile(rf"(?i){s}")

def compile_relaxed_citation_regex(cite: str) -> re.Pattern:
    """
    Robust relaxed citation: ignore ALL punctuation and whitespace.
    Works for '53 L. Ed. 2d 113' vs '53 L.Ed.2d 113' and '432 U. S. 63' vs '432 U.S. 63'.
    Strategy:
      - Strip everything except A–Z / a–z / 0–9 from the target cite to form 'base'
      - Build a regex that allows arbitrary punctuation/space between EVERY character
        in base when searching the opinion text.
    """
    base = re.sub(r'[^A-Za-z0-9]+', '', cite or '')
    if not base or len(base) < 3:
        return compile_citation_regex(cite or '')
    # Allow ANY mix of punctuation/space (incl. non-breaking) between chars
    sep = r'[\s\.\,\-–—;:\(\)\[\]/\u00A0]*'
    parts = [re.escape(ch) for ch in base]
    pat = r'(?i)' + sep.join(parts)
    return re.compile(pat)

def split_citation_pipe(citation_pipe: Optional[str]) -> List[str]:
    if not citation_pipe:
        return []
    return [p.strip() for p in re.split(r'[;|]+', citation_pipe) if p.strip()]

# =========================
# Text & snippet helpers
# =========================
_SENT_SPLIT_RE = re.compile(r'(?<=[.!?])\s+(?=[A-Z(“"\'\[])')

def _split_sentences_with_spans(text: str) -> List[Tuple[int,int,str]]:
    spans: List[Tuple[int,int,str]] = []
    start = 0
    n = len(text)
    for m in _SENT_SPLIT_RE.finditer(text):
        end = m.start()
        if end > start:
            spans.append((start, end, text[start:end]))
        start = m.end()
    if start < n:
        spans.append((start, n, text[start:]))
    return spans

def compact_snippet(text: str) -> str:
    if not text:
        return text
    s = text.replace("\r", "\n").replace("\x0c", " ")
    # heal hyphenation across line breaks
    s = re.sub(r'(\w)-\s*\n\s*(\w)', r'\1\2', s)
    # drop bare line-number rows
    lines = []
    for ln in s.splitlines():
        if re.match(r'^\s*\d{1,3}\s*$', ln):
            continue
        lines.append(ln)
    s = "\n".join(lines)
    s = re.sub(r'\s+', ' ', s).strip()
    s = re.sub(r'\s+([,.;:!?])', r'\1', s)
    return s

def _expand_bounds_to_sentences(text: str, L: int, R: int) -> Tuple[int,int]:
    if not EXPAND_TO_SENTENCE or not text:
        return L, R
    sents = _split_sentences_with_spans(text)
    if not sents:
        return L, R
    n = len(text)
    L = max(0, min(L, n)); R = max(0, min(R, n))
    if L >= R:
        return L, R
    li = next((i for i,(sa,sb,_) in enumerate(sents) if sa <= L < sb), None)
    ri = next((i for i,(sa,sb,_) in enumerate(sents) if sa <= max(0,R-1) < sb), None)
    if li is not None: L = sents[li][0]
    if ri is not None: R = sents[ri][1]
    return L, R

def _extract_by_bounds(text: str, L: int, R: int) -> str:
    if R <= L:
        return ""
    L, R = _expand_bounds_to_sentences(text, L, R)
    snippet = text[L:R].strip()
    return compact_snippet(snippet) if USE_COMPACT_SNIPPET else snippet

# =========================
# Hit finding helpers (first element vs other elements)
# =========================
def _collect_hits_citation_first_exact(full_text: str, citation_pipe: Optional[str]) -> List[Tuple[int,int]]:
    cites = split_citation_pipe(citation_pipe)
    if not cites:
        return []
    pat = compile_citation_regex(cites[0])
    return [(m.start(), m.end()) for m in pat.finditer(full_text)]

def _collect_hits_citation_first_relaxed(full_text: str, citation_pipe: Optional[str]) -> List[Tuple[int,int]]:
    cites = split_citation_pipe(citation_pipe)
    if not cites:
        return []
    pat = compile_relaxed_citation_regex(cites[0])
    return [(m.start(), m.end()) for m in pat.finditer(full_text)]

def _collect_hits_citation_other_exact(full_text: str, citation_pipe: Optional[str]) -> List[Tuple[int,int]]:
    cites = split_citation_pipe(citation_pipe)
    if not cites or len(cites) < 2:
        return []
    spans: List[Tuple[int,int]] = []
    for cite in cites[1:]:
        pat = compile_citation_regex(cite)
        for m in pat.finditer(full_text):
            spans.append((m.start(), m.end()))
    spans.sort()
    return spans

def _collect_hits_citation_other_relaxed(full_text: str, citation_pipe: Optional[str]) -> List[Tuple[int,int]]:
    cites = split_citation_pipe(citation_pipe)
    if not cites or len(cites) < 2:
        return []
    spans: List[Tuple[int,int]] = []
    for cite in cites[1:]:
        pat = compile_relaxed_citation_regex(cite)
        for m in pat.finditer(full_text):
            spans.append((m.start(), m.end()))
    spans.sort()
    return spans

def _collect_hits_exact_name(full_text: str, tgt_name:str) -> List[Tuple[int,int]]:
    if not tgt_name:
        return []
    pat = compile_name_regex_exact(tgt_name)
    return [(m.start(), m.end()) for m in pat.finditer(full_text)]

def _collect_hits_relaxed_name(full_text: str, tgt_name:str) -> List[Tuple[int,int]]:
    if not tgt_name:
        return []
    pat = make_relaxed_case_name_regex(tgt_name)
    return [(m.start(), m.end()) for m in pat.finditer(full_text)]

_ID_RE   = re.compile(r'\bId\.\b')
_VTOK_RE = re.compile(r'\bv\.?\b')

def _collect_following_id_hits(full_text: str, start_pos: int) -> List[Tuple[int,int]]:
    """
    From start_pos, collect ALL 'Id.' spans that occur BEFORE the next 'v'/'v.' token.
    """
    out = []
    cur = start_pos
    n = len(full_text)
    while cur < n:
        m_v  = _VTOK_RE.search(full_text, cur)
        m_id = _ID_RE.search(full_text, cur)
        if not m_id:
            break
        if m_v and (m_v.start() <= m_id.start()):
            break  # hit a new 'v' before the next Id.
        out.append((m_id.start(), m_id.end()))
        cur = m_id.end() + 1
    return out

def _merge_hit_windows(text_len: int, spans: List[Tuple[int,int]], total_chars:int) -> List[Tuple[int,int]]:
    """
    Convert raw hit spans to [L,R] windows and MERGE overlapping/touching windows.
    """
    if not spans:
        return []
    half = max(1, total_chars // 2)
    windows = []
    for a,b in spans:
        L = max(0, a - half)
        R = min(text_len, b + half)
        windows.append((L,R))
    windows.sort()
    merged = []
    curL, curR = windows[0]
    for L,R in windows[1:]:
        if L <= curR:
            curR = max(curR, R)
        else:
            merged.append((curL, curR))
            curL, curR = L, R
    merged.append((curL, curR))
    return merged

# =========================
# Per-edge retrieval
# =========================
def retrieve_snippets_for_edge(session, row: Dict[str,Any], *,
                               search_all_citation_pipe_elements: bool,
                               find_Id_hits: bool,
                               echo: bool=False) -> Dict[str,Any]:
    """
    Returns dict with:
      status: 'ok'|'no_source_chunks'|'no_hit'
      method: one of:
        'citation_pipe_first', 'relaxed_citation_first',
        'exact_name', 'relaxed_name',
        'citation_pipe_other', 'relaxed_citation_other'
      snippets: List[str]
      id_hit: bool
      hit_count: int
    """
    src_id   = row["src_id"]
    src_name = row.get("src_name") or ""
    tgt_name = row["tgt_name"] or ""
    tgt_cite = row.get("tgt_cite") or ""

    chunks = session.run(Q_GET_CHUNKS_FOR_CASE, {"case_id": src_id}).data()
    if not chunks:
        return {"status":"no_source_chunks","method":None,"snippets":[], "id_hit": False, "hit_count": 0}

    full_text = "".join(ch.get("text") or "" for ch in chunks)
    if not full_text.strip():
        return {"status":"no_source_chunks","method":None,"snippets":[], "id_hit": False, "hit_count": 0}

    # a) first-element exact citation
    spans = _collect_hits_citation_first_exact(full_text, tgt_cite)
    method = None
    if spans:
        method = "citation_pipe_first"
    else:
        # b) first-element relaxed citation
        spans = _collect_hits_citation_first_relaxed(full_text, tgt_cite)
        if spans:
            method = "relaxed_citation_first"
        else:
            # c) exact name
            spans = _collect_hits_exact_name(full_text, tgt_name)
            if spans:
                method = "exact_name"
                if echo:
                    print(f"{src_name} -> {tgt_name} - exact_name - {len(spans)}")
            else:
                # d) relaxed name
                spans = _collect_hits_relaxed_name(full_text, tgt_name)
                if spans:
                    method = "relaxed_name"
                    if echo:
                        print(f"{src_name} -> {tgt_name} - relaxed_name - {len(spans)}")
                else:
                    # e) other-elements exact (only if enabled)
                    spans = []
                    if search_all_citation_pipe_elements:
                        spans = _collect_hits_citation_other_exact(full_text, tgt_cite)
                        if spans:
                            method = "citation_pipe_other"
                            if echo:
                                print(f"{src_name} -> {tgt_name} - citation_pipe_other_elements - {len(spans)}")
                        else:
                            # f) other-elements relaxed (only if enabled)
                            spans = _collect_hits_citation_other_relaxed(full_text, tgt_cite)
                            if spans:
                                method = "relaxed_citation_other"
                                if echo:
                                    print(f"{src_name} -> {tgt_name} - relaxed_citation_pipe_other_elements - {len(spans)}")

    if not spans:
        return {"status":"no_hit","method":None,"snippets":[], "id_hit": False, "hit_count": 0}

    # Optional: add 'Id.' follow-up hits that occur BEFORE next 'v' token from each original hit
    id_hit_found = False
    if find_Id_hits:
        id_spans = []
        for (a,b) in spans:
            id_spans.extend(_collect_following_id_hits(full_text, b))
        if id_spans:
            id_hit_found = True
            spans.extend(id_spans)
            spans.sort()

    # Merge windows BEFORE extracting text to avoid overlapping snippets
    merged_windows = _merge_hit_windows(len(full_text), spans, total_chars=APPROX_CHAR_WINDOW)

    # Extract snippets up to cap
    snippets: List[str] = []
    for (L,R) in merged_windows[:MAX_SNIPPETS_PER_EDGE]:
        snip = _extract_by_bounds(full_text, L, R)
        if snip:
            snippets.append(snip)

    return {"status":"ok","method":method,"snippets":snippets, "id_hit": id_hit_found, "hit_count": len(spans)}

# =========================
# Write helper
# =========================
def write_snippets(session, src_id:int, tgt_id:int, method:str, snippets:List[str], *,
                   id_hit: bool,
                   clear_previous:bool=True):
    if clear_previous:
        cy = _mk_clear_snippets_cypher(max_snips=MAX_SNIPPETS_PER_EDGE)
        session.run(cy, {"src_id": src_id, "tgt_id": tgt_id}).consume()

    snip_map = {f"snippet_{i+1}": s for i, s in enumerate(snippets)}
    session.run(
        Q_WRITE_SNIPPETS_BASE,
        {
            "src_id": src_id,
            "tgt_id": tgt_id,
            "snippet_method": method,
            "snippet_count": len(snippets),
            "id_hit": bool(id_hit),
            "snippet_map": snip_map,
        }
    ).consume()

# =========================
# Driver
# =========================
def retrieve_all_snippets(*,
                          batch_size:int = BATCH_RELATIONSHIPS,
                          echo:bool = True,
                          force: Optional[bool] = None,
                          search_all_citation_pipe_elements: bool = False,
                          find_Id_hits: bool = False):
    """
    force:
        - True  -> clear previous snippet_* before writing (overwrite)
        - False -> keep existing snippet_* (only write if needed)
        - None  -> use global CLEAR_PREVIOUS_SNIPPETS
    search_all_citation_pipe_elements:
        - False (default) -> only search FIRST element of citation_pipe
        - True            -> after name strategies, also search OTHER elements (exact then relaxed)
    find_Id_hits:
        - False (default) -> do not scan 'Id.' follow-ups
        - True            -> add 'Id.' hits occurring before the next 'v'/'v.' token after a hit
    """
    clear_previous_effective = CLEAR_PREVIOUS_SNIPPETS if (force is None) else bool(force)

    driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
    try:
        session = driver.session(database=NEO4J_DATABASE)
    except TypeError:
        session = driver.session()

    # counters
    processed = 0
    success_total = 0
    success_by_method = {
        "citation_pipe_first": 0,
        "relaxed_citation_first": 0,
        "exact_name": 0,
        "relaxed_name": 0,
        "citation_pipe_other": 0,
        "relaxed_citation_other": 0
    }
    unsuccessful = 0
    id_hit_total = 0

    last_report = time.time()
    after = -1

    if echo:
        print("Starting Opinion Snippet Retriever…")
        print(f"  · clear_previous_snippets = {clear_previous_effective}")
        print(f"  · search_all_citation_pipe_elements = {search_all_citation_pipe_elements}")
        print(f"  · find_Id_hits = {find_Id_hits}")

    with session as s:
        while True:
            rels = s.run(Q_PAGE_REL, {"after_id": after, "limit": batch_size}).data()
            if not rels:
                break

            for row in rels:
                res = retrieve_snippets_for_edge(
                    s, row,
                    search_all_citation_pipe_elements=search_all_citation_pipe_elements,
                    find_Id_hits=find_Id_hits,
                    echo=echo  # enable edge-level debug prints per your request
                )
                if res["status"] == "ok" and res["snippets"]:
                    success_total += 1
                    if res["method"] in success_by_method:
                        success_by_method[res["method"]] += 1
                    if res.get("id_hit"): id_hit_total += 1

                    write_snippets(
                        s,
                        src_id=row["src_id"],
                        tgt_id=row["tgt_id"],
                        method=res["method"],
                        snippets=res["snippets"],
                        id_hit=res.get("id_hit", False),
                        clear_previous=clear_previous_effective
                    )
                else:
                    unsuccessful += 1
                    if echo:
                        src_nm = row.get("src_name", "")
                        tgt_nm = row.get("tgt_name", "")
                        if res["status"] == "no_hit":
                            print(f"{src_nm} -> {tgt_nm} - No hit found")
                        elif res["status"] == "no_source_chunks":
                            print(f"{src_nm} -> {tgt_nm} - No source opinion text")


                processed += 1
                after = row["rel_id"]

                # periodic report every N seconds
                now = time.time()
                if echo and (now - last_report) >= SECONDS_BETWEEN_REPORTS:
                    print(
                        f"[progress] edges processed: {processed} | "
                        f"success: {success_total} "
                        f"(first_exact:{success_by_method['citation_pipe_first']}, "
                        f"first_relaxed:{success_by_method['relaxed_citation_first']}, "
                        f"exact_name:{success_by_method['exact_name']}, "
                        f"relaxed_name:{success_by_method['relaxed_name']}, "
                        f"other_exact:{success_by_method['citation_pipe_other']}, "
                        f"other_relaxed:{success_by_method['relaxed_citation_other']}) | "
                        f"unsuccessful: {unsuccessful} | "
                        f"\"Id.\" hits: {id_hit_total}"
                    )
                    last_report = now

    # final summary
    if echo:
        print("\n=== Final Summary ===")
        print(f"Edges processed: {processed}")
        print(f"Successful (hit found): {success_total}")
        print("  · By method → "
              f"first_exact: {success_by_method['citation_pipe_first']}, "
              f"first_relaxed: {success_by_method['relaxed_citation_first']}, "
              f"exact_name: {success_by_method['exact_name']}, "
              f"relaxed_name: {success_by_method['relaxed_name']}, "
              f"other_exact: {success_by_method['citation_pipe_other']}, "
              f"other_relaxed: {success_by_method['relaxed_citation_other']}")
        print(f"Unsuccessful (no hit / no source): {unsuccessful}")
        print(f"\"Id.\" hits recorded: {id_hit_total}")

# %%
# =========================
# Run
# =========================
retrieve_all_snippets(
    force=True,
    echo=True,
    find_Id_hits=False,
    search_all_citation_pipe_elements=True
)
# Out:
# Starting Opinion Snippet Retriever…
#   · clear_previous_snippets = True
#   · search_all_citation_pipe_elements = True
#   · find_Id_hits = False
# Alexander v. Choate -> Southeastern Community College v. Davis - exact_name - 3
# Olmstead v. L.C. -> Southeastern Community College v. Davis - exact_name - 1
# Olmstead v. L.C. -> Alexander v. Choate - exact_name - 1
# Singh v. George Washington University School of Medicine & Health Sciences -> Southeastern Community College v. Davis - citation_pipe_other_elements - 1
# [progress] edges processed: 27 | success: 27 (first_exact:23, first_relaxed:0, exact_name:3, relaxed_name:0, other_exact:1, other_relaxed:0) | unsuccessful: 0 | "Id." hits: 0
# Keane, Judith v. Sears Roebuck -> US Airways, Inc. v. Barnett - exact_name - 1
# State of Hawaii v. Usedu -> Christensen v. Harris County - relaxed_name - 1
# Daniel Lopez v. Catalina Channel Express, Inc. -> US Airways, Inc. v. Barnett - citation_pipe_other_elements - 1
# Felicia Pugliese v. State-Operated School District of The City of Newark -> Dial v. DEPT. OF COM. AFFAIRS - citation_pipe_other_elements - 1
# Niece v. Fitzner -> Robert T. McGregor v. Louisiana State University Board of Supervisors - No hit found
# [progress] edges processed: 70 | success: 69 (first_exact:61, first_relaxed:0, exact_name:4, relaxed_name:1, other_exact:3, other_relaxed:0) | unsuccessful: 1 | "Id." hits: 0
# Hampton v. Utah Department of Corrections -> US Airways, Inc. v. Barnett - exact_name - 1
# Equal Employment Opportunity Commission v. C.R. England, Inc. -> US Airways, Inc. v. Barnett - citation_pipe_other_elements - 1
# [progress] edges processed: 110 | success: 109 (first_exact:99, first_relaxed:0, exact_name:5, relaxed_name:1, other_exact:4, other_relaxed:0) | unsuccessful: 1 | "Id." hits: 0
# United States v. Agrawal -> Coors Brewing Co. v. MENDEZ-TORRES - No hit found
# Exby-Stolley v. Board of County Commissioners -> US Airways, Inc. v. Barnett - exact_name - 1
# Muscogee (Creek) Nation v. Pruitt -> Bell Atlantic Corp. v. Twombly - exact_name - 1
# Frame v. City of Arlington -> Olmstead v. L.C. - relaxed_name - 2
# Barber Ex Rel. Barber v. Colorado Dept. of Revenue -> US Airways, Inc. v. Barnett - citation_pipe_other_elements - 1
# American Council of the Blind v. Paulson -> US Airways, Inc. v. Barnett - citation_pipe_other_elements - 1
# Aubrey v. Koppes -> US Airways, Inc. v. Barnett - exact_name - 2
# Natofsky v. City of New York -> Federal Express Corp. v. Holowecki - citation_pipe_other_elements - 1
# Lewis v. Humboldt Acquisition Corp., Inc. -> Federal Express Corp. v. Holowecki - citation_pipe_other_elements - 1
# [progress] edges processed: 151 | success: 149 (first_exact:131, first_relaxed:0, exact_name:8, relaxed_name:2, other_exact:8, other_relaxed:0) | unsuccessful: 2 | "Id." hits: 0
# Paul Boyle v. City of Pell City -> Bell Atlantic Corp. v. Twombly - citation_pipe_other_elements - 2
# Village of Riverdale v. Allied Waste Transportation, Inc. -> People v. Keeven - exact_name - 2
# County of Lake v. Fox Waterway Agency -> City of Highland Park v. County of Cook - exact_name - 1
# Lake County Public Building Commission v. City of Waukegan -> City of Highland Park v. County of Cook - exact_name - 1
# Román-Oliveras v. Puerto Rico Electric Power Authority -> Bell Atlantic Corp. v. Twombly - citation_pipe_other_elements - 1
# Robert Wellman, Jr. v. Butler Area School District -> Booth v. Churner - exact_name - 1
# Smith v. Mensinger -> Booth v. Churner - exact_name - 1
# [progress] edges processed: 193 | success: 191 (first_exact:166, first_relaxed:0, exact_name:13, relaxed_name:2, other_exact:10, other_relaxed:0) | unsuccessful: 2 | "Id." hits: 0
# Buon v. Spindler -> Bell Atlantic Corp. v. Twombly - citation_pipe_other_elements - 1
# Natalie Slaughter v. Des Moines University College of Osteopathic Medicine -> US Airways, Inc. v. Barnett - citation_pipe_other_elements - 3
# Peninsula Regional Medical Center v. Adkins -> US Airways, Inc. v. Barnett - citation_pipe_other_elements - 1
# Bledsoe v. Palm Beach County Soil -> Consolidated Rail Corporation v. Darrone - relaxed_name - 1
# [progress] edges processed: 235 | success: 233 (first_exact:204, first_relaxed:0, exact_name:13, relaxed_name:3, other_exact:13, other_relaxed:0) | unsuccessful: 2 | "Id." hits: 0
# Mary Jo C. v. New York State and Local Retirement System et ano. -> Olmstead v. L.C. - relaxed_name - 1
# Ghulam Ali v. Michael Regan -> Olmstead v. L.C. - relaxed_name - 1
# Mays, Maxcene v. Principi, Anthony J. -> US Airways, Inc. v. Barnett - citation_pipe_other_elements - 1
# US Airways, Inc. v. Barnett -> Olmstead v. L.C. - citation_pipe_other_elements - 1
# Patricia Y. Mayers v. United Independent School District -> Crawford v. Metropolitan Government of Nashville and Davidson Cty. - citation_pipe_other_elements - 1
# [progress] edges processed: 275 | success: 273 (first_exact:239, first_relaxed:0, exact_name:13, relaxed_name:5, other_exact:16, other_relaxed:0) | unsuccessful: 2 | "Id." hits: 0
# Brown v. Dist. of Columbia -> Olmstead v. L.C. - relaxed_name - 7
# [progress] edges processed: 317 | success: 315 (first_exact:280, first_relaxed:0, exact_name:13, relaxed_name:6, other_exact:16, other_relaxed:0) | unsuccessful: 2 | "Id." hits: 0
# Joseph Allen, IV v. Brown Advisory, LLC -> Bell Atlantic Corp. v. Twombly - citation_pipe_other_elements - 1
# Savignac v. Jones Day -> Bell Atlantic Corp. v. Twombly - citation_pipe_other_elements - 1
# Lebahn v. National Farmers Union Uniform Pension Plan -> Bell Atlantic Corp. v. Twombly - citation_pipe_other_elements - 2
# Kaleena Bullington v. Bedford Cty., Tenn. -> Bell Atlantic Corp. v. Twombly - citation_pipe_other_elements - 1
# [progress] edges processed: 359 | success: 357 (first_exact:318, first_relaxed:0, exact_name:13, relaxed_name:6, other_exact:20, other_relaxed:0) | unsuccessful: 2 | "Id." hits: 0
# Johnson v. Wayside Property, Inc. -> Booth v. Churner - citation_pipe_other_elements - 1
# [progress] edges processed: 402 | success: 400 (first_exact:360, first_relaxed:0, exact_name:13, relaxed_name:6, other_exact:21, other_relaxed:0) | unsuccessful: 2 | "Id." hits: 0
# Palao v. Fel-Pro., Inc. -> Paula S. Skorup v. Modern Door Corporation - No hit found
# Jihad Adbul-Mumit v. Alexandria Hyundai, LLC -> Bell Atlantic Corp. v. Twombly - exact_name - 1
# Rodriguez v. Conagra Grocery Prod -> Rodriguez v. Conagra Grocery Products Co. - relaxed_name - 1
# Austin v. City of Pasadena -> Bell Atlantic Corp. v. Twombly - citation_pipe_other_elements - 1
# EEOC v. Amego, Inc. -> Sidney Abbott v. Randon Bragdon, D.M.D. - citation_pipe_other_elements - 3
# [progress] edges processed: 445 | success: 442 (first_exact:398, first_relaxed:0, exact_name:14, relaxed_name:7, other_exact:23, other_relaxed:0) | unsuccessful: 3 | "Id." hits: 0
# [progress] edges processed: 488 | success: 485 (first_exact:441, first_relaxed:0, exact_name:14, relaxed_name:7, other_exact:23, other_relaxed:0) | unsuccessful: 3 | "Id." hits: 0
# BAUER v. United States -> Wal-Mart Stores, Inc. v. Dukes - exact_name - 1
# Barber Lines A/s v. M/v Donau Maru -> Dees v. Austin Travis County Mental Health & Mental Retardation - No hit found
# [progress] edges processed: 529 | success: 525 (first_exact:480, first_relaxed:0, exact_name:15, relaxed_name:7, other_exact:23, other_relaxed:0) | unsuccessful: 4 | "Id." hits: 0
# Terrell v. Industrial Commission -> Midwest Air Filters Pacific, Inc. v. Finn. - citation_pipe_other_elements - 1
# Berlin State Bank v. Nelson -> Tisch Auto Supply Co. v. Nelson - exact_name - 1
# Helen Weyer v. Twentieth Century Fox Film Corporation -> Olmstead v. L.C. - relaxed_name - 2
# [progress] edges processed: 571 | success: 567 (first_exact:517, first_relaxed:2, exact_name:16, relaxed_name:8, other_exact:24, other_relaxed:0) | unsuccessful: 4 | "Id." hits: 0
# Floyd v. Office of Representative Sheila Jackson Lee -> Bell Atlantic Corp. v. Twombly - citation_pipe_other_elements - 1
# RCCH Trios Health, LLC, V. Department of Health -> Brown v. Scott Paper Worldwide Co. - relaxed_name - 1
# Jose L. Birrueta v. Department of Labor and Industries -> Brown v. Scott Paper Worldwide Co. - relaxed_name - 1
# Conboy v. State -> Jensen v. State, Department of Labor & Industry - No hit found
# Bryant Woods Inn Inc v. Howard County MD -> Southeastern Community College v. Davis - exact_name - 1
# [progress] edges processed: 614 | success: 609 (first_exact:554, first_relaxed:3, exact_name:17, relaxed_name:10, other_exact:25, other_relaxed:0) | unsuccessful: 5 | "Id." hits: 0
# Noah S. Bunker, Paul Carrell, Everett Brew Houston, Jr., W. Andrew Buchholz, Scott J. Leighty, Jad L. Davis, and Holly Clause v. Tracy D. Strandhagen -> Carey v. Piphus - citation_pipe_other_elements - 2
# Kimel v. State of FL Bd. of Regents -> Blatchford v. Native Village of Noatak - exact_name - 1
# Swearnigen-El v. Cook County Sheriff's Department -> Federal Express Corp. v. Holowecki - exact_name - 1
# [progress] edges processed: 655 | success: 650 (first_exact:592, first_relaxed:3, exact_name:19, relaxed_name:10, other_exact:26, other_relaxed:0) | unsuccessful: 5 | "Id." hits: 0
# Suellen Klossner v. IADU Table Mound MHP, LLC -> Southeastern Community College v. Davis - citation_pipe_other_elements - 1
# Andrea Schmitt v. Kaiser Foundation Health Plan -> Alexander v. Choate - exact_name - 1
# United States v. Cafaro -> Bowe v. Colgate-Palmolive Company - No hit found
# Michael Lane v. BFI Waste Systems -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# Kenneth E. Lloyd v. Hardin County, IA -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 2
# Renee Lange v. City of Oconto -> Olmstead v. L.C. - relaxed_name - 1
# [progress] edges processed: 698 | success: 692 (first_exact:629, first_relaxed:3, exact_name:20, relaxed_name:11, other_exact:29, other_relaxed:0) | unsuccessful: 6 | "Id." hits: 0
# Ohio State Bar Assn. v. Johnson -> Columbus Bar Assn. v. Elsass - exact_name - 1
# Disciplinary Counsel v. Zingarelli -> Columbus Bar Assn. v. Elsass - exact_name - 2
# C.O. v. Portland Public Schools -> Southeastern Community College v. Davis - citation_pipe_other_elements - 1
# [progress] edges processed: 741 | success: 735 (first_exact:669, first_relaxed:3, exact_name:22, relaxed_name:11, other_exact:30, other_relaxed:0) | unsuccessful: 6 | "Id." hits: 0
# Christopher Templin v. Independence Blue Cross -> Farrar v. Hobby - exact_name - 1
# Turner v. District of Columbia office of Human Rights -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# Janet Kotaska v. Federal Express Corporation -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# Janet Kotaska v. Federal Express Corporation -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# Marvin D.W. Voeltz v. Arctic Cat, Inc. -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# Miko Thomas v. JBS Green Bay, Inc. -> Bell Atlantic Corp. v. Twombly - exact_name - 1
# [progress] edges processed: 782 | success: 776 (first_exact:704, first_relaxed:3, exact_name:24, relaxed_name:11, other_exact:34, other_relaxed:0) | unsuccessful: 6 | "Id." hits: 0
# McCloskey v. Mueller -> Coggeshall v. Massachusetts Board of Registration of Psychologists - No hit found
# Williams v. MTA Bus Co. -> Christensen v. Harris County - exact_name - 1
# [progress] edges processed: 825 | success: 818 (first_exact:745, first_relaxed:3, exact_name:25, relaxed_name:11, other_exact:34, other_relaxed:0) | unsuccessful: 7 | "Id." hits: 0
# Baxter v. Wisconsin Department of Natural Resources -> Southeastern Community College v. Davis - exact_name - 1
# Jose Montanez v. Paula Price -> Alexander v. Choate - exact_name - 1
# [progress] edges processed: 868 | success: 861 (first_exact:786, first_relaxed:3, exact_name:27, relaxed_name:11, other_exact:34, other_relaxed:0) | unsuccessful: 7 | "Id." hits: 0
# Safe Streets Alliance v. Hickenlooper -> Bell Atlantic Corp. v. Twombly - citation_pipe_other_elements - 1
# Equal Employment Opportunity Commission v. Siouxland Oral Maxillofacial Surgery Associates, L.L.P. -> Farrar v. Hobby - exact_name - 1
# [progress] edges processed: 911 | success: 904 (first_exact:827, first_relaxed:3, exact_name:28, relaxed_name:11, other_exact:35, other_relaxed:0) | unsuccessful: 7 | "Id." hits: 0
# State of Washington v. Pablo Adiel Munoz-Hernandez -> Brownfield v. City of Yakima - exact_name - 1
# In Re the Detention Of: B.R. -> Brownfield v. City of Yakima - exact_name - 1
# Susan Liese v. Indian River County Hospital District -> Southeastern Community College v. Davis - citation_pipe_other_elements - 1
# Susan Liese v. Indian River County Hospital District -> Southeastern Community College v. Davis - citation_pipe_other_elements - 1
# Hovannisian v. City of Fresno -> City of Culver City v. Cohen - exact_name - 1
# [progress] edges processed: 953 | success: 946 (first_exact:864, first_relaxed:3, exact_name:31, relaxed_name:11, other_exact:37, other_relaxed:0) | unsuccessful: 7 | "Id." hits: 0
# Rodd Wagner v. Gallup, Inc. -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# Jones v. District of Columbia -> Bell Atlantic Corp. v. Twombly - citation_pipe_other_elements - 1
# Hamilton v. City of Washington, District of Columbia -> Bell Atlantic Corp. v. Twombly - citation_pipe_other_elements - 1
# Sabeta v. Baptist Hospital of Miami, Inc. -> Shotz v. City of Plantation, FL - relaxed_name - 1
# [progress] edges processed: 995 | success: 988 (first_exact:901, first_relaxed:4, exact_name:31, relaxed_name:12, other_exact:40, other_relaxed:0) | unsuccessful: 7 | "Id." hits: 0
# Kimberly Arrington v. Bill Fuller -> Carey v. Piphus - exact_name - 1
# Groesch v. City of Springfield, Ill. -> Czarniecki v. City of Chicago - exact_name - 1
# Chandler v. City of Dallas -> Southeastern Community College v. Davis - exact_name - 1
# Jerremy Dyer v. Ventra Sandusky -> Christensen v. Harris County - relaxed_name - 1
# Demyanovich v. Cadon Plating & Coatings, L.L.C. -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# St. Johnsbury Academy v. St. Johnsbury School District -> Southeastern Community College v. Davis - exact_name - 1
# [progress] edges processed: 1036 | success: 1029 (first_exact:936, first_relaxed:4, exact_name:35, relaxed_name:13, other_exact:41, other_relaxed:0) | unsuccessful: 7 | "Id." hits: 0
# Paula McAllister v. Innovation Ventures, LLC -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# Paula McAllister v. Innovation Ventures, LLC -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# Stanley v. City of Stanford -> Cleveland v. Policy Management Systems Corp. - relaxed_name - 2
# Lee v. Spoden -> International Union, United Mine Workers v. Bagwell - citation_pipe_other_elements - 1
# Lee v. Spoden -> International Union, United Mine Workers v. Bagwell - citation_pipe_other_elements - 1
# Estate of Hackler v. Hackler -> International Union, United Mine Workers v. Bagwell - citation_pipe_other_elements - 1
# [progress] edges processed: 1078 | success: 1071 (first_exact:972, first_relaxed:4, exact_name:35, relaxed_name:14, other_exact:46, other_relaxed:0) | unsuccessful: 7 | "Id." hits: 0
# Alliance to Save the Mattaponi v. Virginia Marine Resources Commissin -> International Union, United Mine Workers v. Bagwell - citation_pipe_other_elements - 1
# Mattaponi Indian Tribe v. VIRGINIA MARINE RESOURCES COMMISSION -> International Union, United Mine Workers v. Bagwell - citation_pipe_other_elements - 1
# Commonwealth v. Karn -> International Union, United Mine Workers v. Bagwell - exact_name - 1
# Ricardo Torres v. Precision Indus., Inc. -> Ticor Title Insurance v. Brown - citation_pipe_other_elements - 1
# Brown v. Government of the District of Columbia -> Wal-Mart Stores, Inc. v. Dukes - exact_name - 1
# Peter G. Milne, P.C., Peter G. Milne, Individually, and Healy, Milne & Associates, P.C. v. Val Ryan and Joy Ryan -> Wal-Mart Stores, Inc. v. Dukes - exact_name - 1
# Johnson v. Meriter Health Services Employee Retirement Plan -> Wal-Mart Stores, Inc. v. Dukes - exact_name - 1
# Beer v. United States -> Wal-Mart Stores, Inc. v. Dukes - exact_name - 1
# Bonnie Peltier v. Charter Day School, Inc. -> National Collegiate Athletic Assn. v. Smith - citation_pipe_other_elements - 1
# Bonnie Peltier v. Charter Day School, Inc. -> National Collegiate Athletic Assn. v. Smith - citation_pipe_other_elements - 1
# [progress] edges processed: 1120 | success: 1113 (first_exact:1004, first_relaxed:4, exact_name:40, relaxed_name:14, other_exact:51, other_relaxed:0) | unsuccessful: 7 | "Id." hits: 0
# Loya v. Sebelius -> Southeastern Community College v. Davis - citation_pipe_other_elements - 1
# [progress] edges processed: 1163 | success: 1156 (first_exact:1046, first_relaxed:4, exact_name:40, relaxed_name:14, other_exact:52, other_relaxed:0) | unsuccessful: 7 | "Id." hits: 0
# Benjamin Kohn v. State Bar of California -> Blatchford v. Native Village of Noatak - citation_pipe_other_elements - 2
# Traveka Stanley, Reginald Burrell, Charlie Gray, Jermaine Pringle, and Ranquel Smith v. Kay Ivey, Governor of Alabama, and John Hamm, Commissioner of the Alabama Department of Corrections, in their official capacities -> Carey v. Piphus - exact_name - 2
# W.M.M. v. Trump -> Carey v. Piphus - exact_name - 1
# Make the Road New York v. Noem -> Carey v. Piphus - exact_name - 1
# KLEO AG v. Rivada Networks, Inc. -> Carey v. Piphus - exact_name - 1
# Jacqueline Sterling v. Southlake Nautilus Health & Racquett Club, Incorpo -> Carey v. Piphus - exact_name - 1
# Jacqueline Sterling v. Southlake Nautilus Health & Racquett Club, Incorpo -> Carey v. Piphus - exact_name - 1
# Deshawn Gervin v. Pamela Florence -> Carey v. Piphus - exact_name - 1
# A.A.R.P. v. Trump -> Carey v. Piphus - exact_name - 1
# Parent Father Doe and Parent Mother Doe, Individually on their own behalf and as Parents and Next Friend for Minor Doe v. Western Dubuque Community School District, Jessica Pape, Dan Butler, and Scott Firzlaff, in their Official Capacities -> Carey v. Piphus - exact_name - 1
# Z&R Cab, LLC v. Philadelphia Parking Authority -> Carey v. Piphus - exact_name - 1
# Happel v. Guilford Cnty. Bd. of Educ. -> Carey v. Piphus - exact_name - 1
# David Ermold v. Kim Davis -> Carey v. Piphus - exact_name - 1
# Blake Stewardson v. Christopher Titus -> Carey v. Piphus - exact_name - 1
# Blake Stewardson v. Christopher Titus -> Carey v. Piphus - exact_name - 1
# Blake Stewardson v. Christopher Titus -> Carey v. Piphus - exact_name - 1
# Blake Stewardson v. Christopher Titus -> Carey v. Piphus - exact_name - 1
# Shawn Sheltra v. Jay Christensen -> Carey v. Piphus - exact_name - 1
# Inova Health Care Services, for Inova Fairfax Hospital and Its Department, Life With Cancer v. Omni Shoreham Corporation -> Carey v. Piphus - exact_name - 1
# Wilson v. Midland County -> Carey v. Piphus - exact_name - 1
# [progress] edges processed: 1205 | success: 1198 (first_exact:1068, first_relaxed:4, exact_name:59, relaxed_name:14, other_exact:53, other_relaxed:0) | unsuccessful: 7 | "Id." hits: 0
# [progress] edges processed: 1248 | success: 1241 (first_exact:1111, first_relaxed:4, exact_name:59, relaxed_name:14, other_exact:53, other_relaxed:0) | unsuccessful: 7 | "Id." hits: 0
# Coolbaugh v. La State -> Alexander v. Choate - exact_name - 1
# Michael Rinehart v. Kris Weitzell -> Bell Atlantic Corp. v. Twombly - citation_pipe_other_elements - 1
# Ronen Halpern v. Wake Forest University -> Southeastern Community College v. Davis - citation_pipe_other_elements - 1
# [progress] edges processed: 1291 | success: 1284 (first_exact:1151, first_relaxed:4, exact_name:60, relaxed_name:14, other_exact:55, other_relaxed:0) | unsuccessful: 7 | "Id." hits: 0
# Austin v. Town of Farmington -> Christensen v. Harris County - relaxed_name - 1
# Dean v. University at Buffalo School of Medicine and Biomedical Sciences -> Southeastern Community College v. Davis - citation_pipe_other_elements - 1
# 1546-Cv -> Southeastern Community College v. Davis - citation_pipe_other_elements - 1
# Laughlin v. Holder -> Bell Atlantic Corp. v. Twombly - citation_pipe_other_elements - 1
# Olivia Neal v. East Carolina University -> Southeastern Community College v. Davis - citation_pipe_other_elements - 1
# [progress] edges processed: 1334 | success: 1327 (first_exact:1189, first_relaxed:4, exact_name:60, relaxed_name:15, other_exact:59, other_relaxed:0) | unsuccessful: 7 | "Id." hits: 0
# Garrity v. United Airlines, Inc. -> Southeastern Community College v. Davis - exact_name - 1
# Dennis J. Pickens v. Soo Line RR Co. -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# Nyzier Fourqurean v. NCAA -> National Collegiate Athletic Assn. v. Smith - citation_pipe_other_elements - 1
# Jennifer Oldham v. Penn State University -> National Collegiate Athletic Assn. v. Smith - citation_pipe_other_elements - 1
# Ralph Johnson v. The National Collegiate Athletic Association -> National Collegiate Athletic Assn. v. Smith - citation_pipe_other_elements - 1
# Ralph Johnson v. The National Collegiate Athletic Association -> National Collegiate Athletic Assn. v. Smith - citation_pipe_other_elements - 1
# Bergdahl v. United States -> National Collegiate Athletic Assn. v. Smith - citation_pipe_other_elements - 1
# Donna Buettner-Hartsoe v. Baltimore Lutheran High School Association -> National Collegiate Athletic Assn. v. Smith - citation_pipe_other_elements - 1
# The Religious Sisters of Mercy v. Xavier Becerra -> National Collegiate Athletic Assn. v. Smith - citation_pipe_other_elements - 1
# Timothy Moxley v. The Ohio State University -> National Collegiate Athletic Assn. v. Smith - citation_pipe_other_elements - 1
# Bonnie Peltier v. Charter Day School, Inc. -> National Collegiate Athletic Assn. v. Smith - citation_pipe_other_elements - 1
# Bonnie Peltier v. Charter Day School, Inc. -> National Collegiate Athletic Assn. v. Smith - citation_pipe_other_elements - 1
# Bonnie Peltier v. Charter Day School, Inc. -> National Collegiate Athletic Assn. v. Smith - citation_pipe_other_elements - 1
# Sex Segregation in Youth Rodeo Events Under Title IX Regulations -> National Collegiate Athletic Assn. v. Smith - citation_pipe_other_elements - 1
# Jane Doe v. Univ. of Ky. -> National Collegiate Athletic Assn. v. Smith - citation_pipe_other_elements - 1
# Peter Deppe v. NCAA -> National Collegiate Athletic Assn. v. Smith - citation_pipe_other_elements - 1
# Caterpillar Financial Services Corporation v. Venequip Machinery Sales Corporation -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# Jamie Snethen v. Missouri State Board of Nursing -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# Local No 499, Bd of Trustees v. Art Iron, Inc. -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# Highland v. NexPoint -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# Jeanne Johnson v. City of Kansas City, Missouri -> Cleveland v. Policy Management Systems Corp. - relaxed_name - 1
# Mera v. Barr -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# Yazzie v. National Organization for Women -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# Pratik Pandharipande, M.D. v. FSD Corporation -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# G.C. v. Division of Medical Assistance and Health Services (084417) (Statewide) -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# DotConnectAfrica Trust v. Internet Corp. for Assigned Names & Nos. -> Cleveland v. Policy Management Systems Corp. - relaxed_name - 1
# Thompson v. Gold Medal Bakery, Inc. -> Cleveland v. Policy Management Systems Corp. - relaxed_name - 1
# Angel Cartagena v. Allie Lovell -> Southeastern Community College v. Davis - citation_pipe_other_elements - 1
# Rodney Baker v. Bentonville School District -> Southeastern Community College v. Davis - citation_pipe_other_elements - 1
# State of South Carolina v. United States Army Corps of Engineers -> Southeastern Community College v. Davis - citation_pipe_other_elements - 1
# Thomas v. District of Columbia -> Southeastern Community College v. Davis - citation_pipe_other_elements - 1
# [progress] edges processed: 1376 | success: 1369 (first_exact:1200, first_relaxed:4, exact_name:61, relaxed_name:18, other_exact:86, other_relaxed:0) | unsuccessful: 7 | "Id." hits: 0
# J.Q.R. v. District of Columbia Government -> Southeastern Community College v. Davis - citation_pipe_other_elements - 1
# Emilio Torres v. Salvatore Vitale -> Southeastern Community College v. Davis - citation_pipe_other_elements - 1
# Bannister v. United States Parole Commission -> Southeastern Community College v. Davis - exact_name - 1
# Phyllis Davis v. Echo Valley Condominium Ass'n -> Southeastern Community College v. Davis - citation_pipe_other_elements - 1
# Bannister v. United States Parole Commission -> Southeastern Community College v. Davis - citation_pipe_other_elements - 1
# Linda Reed v. Columbia St. Mary's Hospital -> Southeastern Community College v. Davis - citation_pipe_other_elements - 1
# Linda Reed v. Columbia St. Mary's Hospital -> Southeastern Community College v. Davis - citation_pipe_other_elements - 1
# Ray v. Hidden Harbour Assn., Inc. -> Southeastern Community College v. Davis - exact_name - 1
# James Raymond King v. Missouri American Water Co. -> Cleveland v. Policy Management Systems Corp. - relaxed_name - 2
# Derek Waskul v. Washtenaw Cnty. Community Mental Health -> Alexander v. Choate - exact_name - 1
# Cohon Ex Rel. Bass v. NEW MEXICO DEPT. OF HEALTH -> Southeastern Community College v. Davis - citation_pipe_other_elements - 1
# League of California Cities v. FCC -> Christensen v. Harris County - exact_name - 1
# Loper Bright Enterprises v. Raimondo -> Adams Fruit Co. v. Barrett - exact_name - 1
# Winifredo Herrera v. Cathay Pacific Airways Limited -> Christensen v. Harris County - exact_name - 1
# Winifredo Herrera v. Cathay Pacific Airways Limited -> Christensen v. Harris County - exact_name - 1
# Center for Biological Diversity v. U.S. Fish and Wildlife Service -> Christensen v. Harris County - relaxed_name - 1
# United States v. Vargas -> Christensen v. Harris County - exact_name - 1
# Ilai Koonwaiyou v. Antony Blinken -> Christensen v. Harris County - exact_name - 1
# David Thompson v. Regions Security Services, Inc -> Christensen v. Harris County - exact_name - 1
# Roberts v. Genting -> Christensen v. Harris County - exact_name - 1
# Sanofi Aventis US LLC v. United States HHS -> Christensen v. Harris County - relaxed_name - 1
# Doll v. Goodman -> Christensen v. Harris County - relaxed_name - 1
# Oztimurlenk, R.N. v. United States -> Christensen v. Harris County - relaxed_name - 1
# Khamidova v. Blinken -> Christensen v. Harris County - exact_name - 1
# Anmed Health v. Azar -> Christensen v. Harris County - relaxed_name - 1
# Jorge Rivera Vega v. Merrick Garland -> Christensen v. Harris County - relaxed_name - 1
# Djie v. Garland -> Christensen v. Harris County - relaxed_name - 1
# Anita Martin v. Petersen Health Operations -> Adams Fruit Co. v. Barrett - citation_pipe_other_elements - 1
# [progress] edges processed: 1419 | success: 1412 (first_exact:1214, first_relaxed:5, exact_name:73, relaxed_name:26, other_exact:94, other_relaxed:0) | unsuccessful: 7 | "Id." hits: 0
# Lorrie Ann Horner, by and Through Her Father Nfr Haskel Horner Jennifer Baker, by and Through Her Father Nfr Douglas Baker Juliana Brown, by and Through Her Father Nfr Michael Brown Angella Chaffin, by and Through Her Father Nfr Dale Chaffin Tracy Dotson, by and Through Her Father Nfr Sherman Dotson Jacqueline Elston, by and Through Her Father Joseph Elston Amy Hacker, by and Through Her Father Nfr Chris Hacker Elizabeth Suzanne Hartlage, an Adult Kelly Johnson, by and Through Her Father Nfr Charles Johnson Mary Christine Whitelock, an Adult, Leslie Burgett, by and Through Her Father Nfr Billy Burgett Barrie Wagers, by and Through Her Father Nfr Lyde Wagers v. Kentucky High School Athletic Association Kentucky State Board for Elementary and Secondary Education -> Alexander v. Choate - relaxed_name - 1
# New Concepts for Living Inc v. NLRB -> Adams Fruit Co. v. Barrett - exact_name - 1
# Eugene Westmoreland v. Latoya Hughes -> Booth v. Churner - exact_name - 1
# Kingdom v. Trump -> Booth v. Churner - exact_name - 1
# Taylor v. Trump -> Booth v. Churner - exact_name - 1
# Gray Television, Inc. v. Federal Communications Commission -> Booth v. Churner - exact_name - 1
# Williams v. Reed -> Booth v. Churner - exact_name - 1
# Toby Doyle v. City of Bauxite, Arkansas; Bill Shryock; And Mayor Eddie Jones, Individually and in His Official Capacity as the Mayor of Bauxite, Arkansas -> Booth v. Churner - exact_name - 1
# Doe v. McHenry -> Booth v. Churner - exact_name - 1
# Henry Jones v. Amanda Lamb -> Booth v. Churner - exact_name - 1
# United States v. Rivera -> Booth v. Churner - exact_name - 1
# John Kalu v. Spaulding -> Booth v. Churner - exact_name - 1
# Estrada v. Smart -> Booth v. Churner - exact_name - 1
# Kyle Brandon Richards v. Thomas Perttu -> Booth v. Churner - exact_name - 1
# Kaboni Savage v. DOJ -> Booth v. Churner - exact_name - 1
# Chisom v. State of Louisiana -> Booth v. Churner - exact_name - 1
# John Smith v. Jeremy Andrews -> Booth v. Churner - exact_name - 1
# Jaquetta Coopwood v. Wayne County, Mich. -> Booth v. Churner - exact_name - 1
# Matthew Griffin v. Nadine Bryant -> Booth v. Churner - exact_name - 1
# Huskey v. Jones -> Booth v. Churner - exact_name - 1
# [progress] edges processed: 1462 | success: 1455 (first_exact:1237, first_relaxed:5, exact_name:92, relaxed_name:27, other_exact:94, other_relaxed:0) | unsuccessful: 7 | "Id." hits: 0
# Steven J Wilcox v. Damian Wheatley -> Booth v. Churner - relaxed_name - 1
# Benson v. St. Joseph Regional Health Center -> Ahrens v. Perot Systems Corp. - No hit found
# Thompson v. North Amer Stainless -> Christensen v. Harris County - exact_name - 1
# Edward Reynolds v. Phillips & Temro -> Cleveland v. Policy Management Systems Corp. - relaxed_name - 1
# [progress] edges processed: 1505 | success: 1497 (first_exact:1276, first_relaxed:5, exact_name:93, relaxed_name:29, other_exact:94, other_relaxed:0) | unsuccessful: 8 | "Id." hits: 0
# Patrick Butler v. Village of Round Lake Police D -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# Johnson, Gordon R. v. ExxonMobil Corp -> Cleveland v. Policy Management Systems Corp. - relaxed_name - 1
# Escamilla, Nicholas v. Jungwirth, Eugene -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# Center for Special Needs Trust Administration, Inc. v. Olson -> Alexander v. Choate - exact_name - 1
# Bartolomeo v. Plymouth County -> Alexander v. Choate - exact_name - 1
# Patton v. Quality Enterprises, LLC -> US Airways, Inc. v. Barnett - exact_name - 1
# [progress] edges processed: 1548 | success: 1540 (first_exact:1313, first_relaxed:5, exact_name:96, relaxed_name:30, other_exact:96, other_relaxed:0) | unsuccessful: 8 | "Id." hits: 0
# Prairie Rivers Network v. Dynegy Midwest Generation, LLC -> Bell Atlantic Corp. v. Twombly - citation_pipe_other_elements - 1
# In re Delaware Public Schools Litigation -> Bell Atlantic Corp. v. Twombly - citation_pipe_other_elements - 1
# [progress] edges processed: 1591 | success: 1583 (first_exact:1354, first_relaxed:5, exact_name:96, relaxed_name:30, other_exact:98, other_relaxed:0) | unsuccessful: 8 | "Id." hits: 0
# Eric Washington v. Indiana High School Athletic Association, Incorporated -> Southeastern Community College v. Davis - exact_name - 2
# Charley Nicole Martin v. Jacob Elijah Callender -> Arneson v. Arneson - exact_name - 1
# Doucette v. Jacobs -> Alexander v. Choate - exact_name - 1
# Buie v. Berrien -> Bell Atlantic Corp. v. Twombly - citation_pipe_other_elements - 1
# Linda Ash v. Anderson Merchandisers, LLC -> Bell Atlantic Corp. v. Twombly - citation_pipe_other_elements - 1
# [progress] edges processed: 1634 | success: 1626 (first_exact:1390, first_relaxed:7, exact_name:99, relaxed_name:30, other_exact:100, other_relaxed:0) | unsuccessful: 8 | "Id." hits: 0
# Obrey v. Johnson -> Cooper v. Federal Reserve Bank of Richmond - citation_pipe_other_elements - 1
# [progress] edges processed: 1677 | success: 1669 (first_exact:1432, first_relaxed:7, exact_name:99, relaxed_name:30, other_exact:101, other_relaxed:0) | unsuccessful: 8 | "Id." hits: 0
# Webster Williams, III v. Michael Carvajal -> Booth v. Churner - citation_pipe_other_elements - 1
# [progress] edges processed: 1720 | success: 1712 (first_exact:1474, first_relaxed:7, exact_name:99, relaxed_name:30, other_exact:102, other_relaxed:0) | unsuccessful: 8 | "Id." hits: 0
# Jahinnslerth Orozco v. Merrick Garland -> Consolidated Rail Corporation v. Darrone - relaxed_name - 1
# T. S. v. Heart of CarDon, LLC -> Consolidated Rail Corporation v. Darrone - citation_pipe_other_elements - 1
# Donald Trump v. Mazars USA, LLP -> Consolidated Rail Corporation v. Darrone - citation_pipe_other_elements - 1
# Elouise Cobell v. Sally Jewell -> Consolidated Rail Corporation v. Darrone - relaxed_name - 1
# D.L. v. Baltimore City Board of School Commissioners -> Consolidated Rail Corporation v. Darrone - citation_pipe_other_elements - 1
# John Doe v. The Salvation Army in the United States -> Consolidated Rail Corporation v. Darrone - citation_pipe_other_elements - 1
# Middlebrooks v. Godwin Corporation -> Consolidated Rail Corporation v. Darrone - citation_pipe_other_elements - 1
# Epic Systems Corp. v. Lewis -> Adams Fruit Co. v. Barrett - exact_name - 1
# [progress] edges processed: 1762 | success: 1754 (first_exact:1508, first_relaxed:7, exact_name:100, relaxed_name:32, other_exact:107, other_relaxed:0) | unsuccessful: 8 | "Id." hits: 0
# Stephanie Carlson v. CSX Transportation, Incorpora -> Bell Atlantic Corp. v. Twombly - exact_name - 1
# Mary Casna v. City Loves Park IL -> Carey v. Piphus - exact_name - 1
# Congress v. McWilliams -> US Airways, Inc. v. Barnett - citation_pipe_other_elements - 1
# Dennis Speerly v. General Motors, LLC -> Cooper v. Federal Reserve Bank of Richmond - citation_pipe_other_elements - 1
# Pappas v. Metropolitan Police Department of the District of Columbia -> Cooper v. Federal Reserve Bank of Richmond - exact_name - 1
# Steele v. United States -> Cooper v. Federal Reserve Bank of Richmond - exact_name - 1
# Lee Williams v. Tech Mahindra Americas Inc -> Cooper v. Federal Reserve Bank of Richmond - citation_pipe_other_elements - 1
# Broidy Capital Management LLC v. Nicolas Muzin -> Cooper v. Federal Reserve Bank of Richmond - citation_pipe_other_elements - 1
# Hunter Doster v. Frank Kendall -> Cooper v. Federal Reserve Bank of Richmond - citation_pipe_other_elements - 1
# Irma Allen v. Ollies Bargain Outlet Inc -> Cooper v. Federal Reserve Bank of Richmond - citation_pipe_other_elements - 1
# Viking River Cruises, Inc. v. Moriana -> Cooper v. Federal Reserve Bank of Richmond - exact_name - 1
# Michael Molock v. Whole Foods Market, Inc. -> Cooper v. Federal Reserve Bank of Richmond - exact_name - 1
# Nina Flecha v. Medicredit, Incorporated -> Cooper v. Federal Reserve Bank of Richmond - citation_pipe_other_elements - 1
# Harris County Hospital District// Cross-Appellants,Public Utility Commission of Texas and Southwestern Bell Telephone Company D/B/A AT&T Texas v. Public Utility Commission of Texas and Southwestern Bell Telephone Company D/B/A AT&T Texas// Cross-Appellee, Harris County Hospital District -> Cooper v. Federal Reserve Bank of Richmond - citation_pipe_other_elements - 1
# John Calon v. Bank of America Corporation -> Cooper v. Federal Reserve Bank of Richmond - citation_pipe_other_elements - 1
# [progress] edges processed: 1805 | success: 1797 (first_exact:1536, first_relaxed:7, exact_name:106, relaxed_name:32, other_exact:116, other_relaxed:0) | unsuccessful: 8 | "Id." hits: 0
# Conley F. Monk, Jr. v. Robert L. Wilkie -> Cooper v. Federal Reserve Bank of Richmond - citation_pipe_other_elements - 1
# Campbell v. Natl Railroad Pass -> Cooper v. Federal Reserve Bank of Richmond - citation_pipe_other_elements - 1
# California State Teachers' Retirement System v. Alvarez -> Cooper v. Federal Reserve Bank of Richmond - exact_name - 1
# DL v. District of Columbia -> Cooper v. Federal Reserve Bank of Richmond - exact_name - 1
# Abella Owners' Association v. MI Windows & Doors, Inc. -> Cooper v. Federal Reserve Bank of Richmond - citation_pipe_other_elements - 1
# Suzanne Wolf v. Riverport Insurance Company -> Bell Atlantic Corp. v. Twombly - exact_name - 1
# Gordon Gamm v. Sanderson Farms, Inc. -> Bell Atlantic Corp. v. Twombly - citation_pipe_other_elements - 1
# [progress] edges processed: 1848 | success: 1840 (first_exact:1572, first_relaxed:7, exact_name:109, relaxed_name:32, other_exact:120, other_relaxed:0) | unsuccessful: 8 | "Id." hits: 0
# Ames v. Ohio Department of Youth Services -> Desert Palace, Inc. v. Costa - exact_name - 1
# Y.A. v. Hamtramck Pub. Schs. -> Board of Trustees of Univ. of Ala. v. Garrett - citation_pipe_other_elements - 1
# Osborne v. Baxter Healthcare Corp. -> US Airways, Inc. v. Barnett - citation_pipe_other_elements - 1
# Barbara Boose v. Tri-County Metropolitan Transp -> Olmstead v. L.C. - citation_pipe_other_elements - 1
# Mathis v. United States Parole Commission -> Alexander v. Choate - exact_name - 1
# Angelo Binno v. The American Bar Association -> Bell Atlantic Corp. v. Twombly - citation_pipe_other_elements - 1
# Bonnette v. Shinseki -> Bell Atlantic Corp. v. Twombly - citation_pipe_other_elements - 1
# Patricia Watson v. Secretary of Labor -> Christensen v. Harris County - relaxed_name - 1
# [progress] edges processed: 1891 | success: 1883 (first_exact:1607, first_relaxed:7, exact_name:111, relaxed_name:33, other_exact:125, other_relaxed:0) | unsuccessful: 8 | "Id." hits: 0
# Forest Guardians v. Dombeck -> Austin v. Owens-Brockway Glass Container, Inc. - citation_pipe_other_elements - 1
# Chopra v. Display Producers, Inc. -> Austin v. Owens-Brockway Glass Container, Inc. - relaxed_name - 1
# Skokomish Indian Tribe v. Federal Energy Regulatory Commission -> Austin v. Owens-Brockway Glass Container, Inc. - citation_pipe_other_elements - 1
# Alaska Wildlife Alliance v. Jensen -> Austin v. Owens-Brockway Glass Container, Inc. - citation_pipe_other_elements - 1
# Key v. Aurora Housing Authority -> Carey v. Piphus - exact_name - 1
# Del Marcelle v. Brown County Corp. -> Bell Atlantic Corp. v. Twombly - exact_name - 1
# Artus v. Gramercy Towers Condominium Assn. -> Villa De Las Palmas Homeowners Ass'n v. Terifaj - citation_pipe_other_elements - 1
# Untitled California Attorney General Opinion -> Villa De Las Palmas Homeowners Ass'n v. Terifaj - citation_pipe_other_elements - 1
# Champir, LLC v. Fairbanks Ranch Assn. -> Villa De Las Palmas Homeowners Ass'n v. Terifaj - citation_pipe_other_elements - 1
# Smart Corner Owners Assn. v. CJUF Smart Corner LLC -> Villa De Las Palmas Homeowners Ass'n v. Terifaj - citation_pipe_other_elements - 1
# Eith v. Ketelhut -> Villa De Las Palmas Homeowners Ass'n v. Terifaj - citation_pipe_other_elements - 1
# Branches Neighborhood Corp. v. CalAtlantic Group, Inc. -> Villa De Las Palmas Homeowners Ass'n v. Terifaj - citation_pipe_other_elements - 1
# Rancho Mirage Country Club Homeowners Ass'n v. Hazelbaker -> Villa De Las Palmas Homeowners Ass'n v. Terifaj - citation_pipe_other_elements - 1
# City of Santa Maria v. Adam -> Villa De Las Palmas Homeowners Ass'n v. Terifaj - citation_pipe_other_elements - 1
# Almanor Lakeside Villas Owners Ass'n. v. Carson -> Villa De Las Palmas Homeowners Ass'n v. Terifaj - citation_pipe_other_elements - 1
# [progress] edges processed: 1934 | success: 1926 (first_exact:1635, first_relaxed:7, exact_name:113, relaxed_name:34, other_exact:137, other_relaxed:0) | unsuccessful: 8 | "Id." hits: 0
# Pohle v. Supreme Court of the United States Bar -> Board of Trustees of Univ. of Ala. v. Garrett - citation_pipe_other_elements - 1
# Dylan Brandt v. Tim Griffin -> Board of Trustees of Univ. of Ala. v. Garrett - citation_pipe_other_elements - 2
# White Hat v. Murrill -> Board of Trustees of Univ. of Ala. v. Garrett - citation_pipe_other_elements - 1
# A. J. T. v. Osseo Area Schools, Independent School Dist. No. 279 -> Alexander v. Choate - exact_name - 1
# Commcan, Inc., and Others v. Charlie Baker, in His Official Capacity as Governor of the Commonwealth of Massachusetts -> Garcia v. Dep't of Hous. & Cmty. Dev. - citation_pipe_other_elements - 1
# United States v. Blodgett -> Board of Trustees of Univ. of Ala. v. Garrett - citation_pipe_other_elements - 1
# The People v. Jose Aviles -> Board of Trustees of Univ. of Ala. v. Garrett - relaxed_citation_pipe_other_elements - 1
# Isaacs v. Dartmouth-Hitchcock -> Consolidated Rail Corporation v. Darrone - relaxed_name - 1
# Isaacs v. Dartmouth-Hitchcock  -> Consolidated Rail Corporation v. Darrone - relaxed_name - 1
# Moorer v. Baptist Memorial Health Care System -> Carey v. Piphus - exact_name - 1
# [progress] edges processed: 1977 | success: 1969 (first_exact:1668, first_relaxed:7, exact_name:115, relaxed_name:36, other_exact:142, other_relaxed:1) | unsuccessful: 8 | "Id." hits: 0
# Kimberly Slomcenski v. Citibank, N.A. -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 2
# Horner Ex Rel. Horner v. Kentucky High School Athletic Ass'n -> Consolidated Rail Corporation v. Darrone - relaxed_name - 1
# [progress] edges processed: 2018 | success: 2010 (first_exact:1707, first_relaxed:7, exact_name:115, relaxed_name:37, other_exact:143, other_relaxed:1) | unsuccessful: 8 | "Id." hits: 0
# Yassin Aref v. Loretta Lynch -> Carey v. Piphus - exact_name - 1
# Jaros v. Illinois Department of Corrections -> Alexander v. Choate - exact_name - 1
# Calhoun, Tyrone v. DeTella, George -> Carey v. Piphus - exact_name - 1
# Ian Dawes v. Hans Walker -> Carey v. Piphus - exact_name - 1
# Barbour, Adam v. WMATA -> National Collegiate Athletic Assn. v. Smith - citation_pipe_other_elements - 1
# [progress] edges processed: 2061 | success: 2053 (first_exact:1745, first_relaxed:7, exact_name:119, relaxed_name:37, other_exact:144, other_relaxed:1) | unsuccessful: 8 | "Id." hits: 0
# Bush v. United States -> Carey v. Piphus - exact_name - 1
# Lightspeed Media Corporation v. Anthony Smith -> International Union, United Mine Workers v. Bagwell - citation_pipe_other_elements - 1
# Evans v. First Mount Vernon, Ila -> Bell Atlantic Corp. v. Twombly - exact_name - 1
# [progress] edges processed: 2104 | success: 2096 (first_exact:1783, first_relaxed:9, exact_name:121, relaxed_name:37, other_exact:145, other_relaxed:1) | unsuccessful: 8 | "Id." hits: 0
# Health and Hospital Corporation of Marion Cty. v. Talevski -> Carey v. Piphus - exact_name - 1
# Health and Hospital Corporation of Marion Cty. v. Talevski -> Carey v. Piphus - exact_name - 1
# Red Barn Motors, Inc. v. NextGear Capital, Inc. -> Wal-Mart Stores, Inc. v. Dukes - exact_name - 1
# Red Barn Motors, Inc. v. NextGear Capital, Inc. -> Wal-Mart Stores, Inc. v. Dukes - exact_name - 1
# Stuart Ex Rel. Situated v. State Farm Fire & Cas. Co. -> Wal-Mart Stores, Inc. v. Dukes - exact_name - 1
# In Re State Farm Fire & Casualty Co. -> Wal-Mart Stores, Inc. v. Dukes - exact_name - 1
# Rudy Webb v. Exxon Mobil Corporation -> Wal-Mart Stores, Inc. v. Dukes - exact_name - 1
# Williams v. Phila Housing Auth -> Southeastern Community College v. Davis - citation_pipe_other_elements - 1
# Hare v. David S. Brown Enterprises -> Desert Palace, Inc. v. Costa - exact_name - 1
# Aldrin Gomez-Martinez v. the State of Florida -> Desert Palace, Inc. v. Costa - exact_name - 1
# State v. Dunn -> Desert Palace, Inc. v. Costa - exact_name - 1
# [progress] edges processed: 2147 | success: 2139 (first_exact:1815, first_relaxed:9, exact_name:131, relaxed_name:37, other_exact:146, other_relaxed:1) | unsuccessful: 8 | "Id." hits: 0
# Brown v. Dickey -> Desert Palace, Inc. v. Costa - exact_name - 1
# Daphne Berry v. Crestwood Healthcare LP -> Desert Palace, Inc. v. Costa - exact_name - 1
# In Re: JPMorgan Chase & Company -> Desert Palace, Inc. v. Costa - exact_name - 1
# Minter v. District of Columbia -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# Pannoni v. Board of Trustees, Browning School District No. 9 -> US Airways, Inc. v. Barnett - citation_pipe_other_elements - 2
# Juan Albino v. Lee Baca -> Booth v. Churner - exact_name - 1
# Olive Oil, L.L.C. v. Cleveland Elec. Illum. Co. -> Berge v. Columbus Community Cable Access - exact_name - 1
# Westfield Ins. Co. v. Chapel Elec. Co., L.L.C. -> Berge v. Columbus Community Cable Access - exact_name - 1
# Russell v. Cooley Dickinson Hospital, Inc. -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 2
# Sullivan v. Raytheon Company -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# Griggs v. Hardwick Knitted Fabrics, Inc. -> Cleveland v. Policy Management Systems Corp. - relaxed_name - 2
# [progress] edges processed: 2190 | success: 2182 (first_exact:1847, first_relaxed:9, exact_name:137, relaxed_name:38, other_exact:150, other_relaxed:1) | unsuccessful: 8 | "Id." hits: 0
# Nutton v. Sunset Station, Inc. -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# Boyer v. United States -> Christensen v. Harris County - relaxed_name - 1
# Fleming v. Yuma Regional Medica -> Consolidated Rail Corporation v. Darrone - relaxed_name - 1
# [progress] edges processed: 2233 | success: 2225 (first_exact:1886, first_relaxed:10, exact_name:137, relaxed_name:40, other_exact:151, other_relaxed:1) | unsuccessful: 8 | "Id." hits: 0
# Kiman v. New Hampshire Department of Corrections -> Thompson v. State of Colorado - No hit found
# Mark Robinson v. Superintendent Rockview SCI -> Booth v. Churner - exact_name - 1
# Fred Dalton Brooks v. Warden -> Carey v. Piphus - exact_name - 1
# Duncan, Jimmy L. v. WMATA -> Swanks v. Washington Metropolitan Area Transit Authority - No hit found
# McIver v. Carter -> Bell Atlantic Corp. v. Twombly - citation_pipe_other_elements - 1
# Paul Mik, Jr. v. Fed. Home Loan Mortg. Corp. -> Northwest Airlines, Inc. v. Transport Workers Union - citation_pipe_other_elements - 1
# Solomon v. St. Joseph Hosp. -> Adams Fruit Co. v. Barrett - exact_name - 1
# Gustafson, M. v. Springfield 282 A.3d 739 -> Adams Fruit Co. v. Barrett - exact_name - 1
# Jonathan Corbett v. TSA -> Adams Fruit Co. v. Barrett - exact_name - 1
# Gun Owners of America, Inc. v. Merrick B. Garland -> Adams Fruit Co. v. Barrett - exact_name - 1
# Estate of Joseph Maglioli v. Alliance HC Holdings, LLC -> Adams Fruit Co. v. Barrett - exact_name - 1
# Willie Goffney, Jr. v. Xavier Becerra -> Adams Fruit Co. v. Barrett - exact_name - 1
# [progress] edges processed: 2276 | success: 2266 (first_exact:1916, first_relaxed:11, exact_name:145, relaxed_name:40, other_exact:153, other_relaxed:1) | unsuccessful: 10 | "Id." hits: 0
# Sierra Club v. EPA -> Adams Fruit Co. v. Barrett - exact_name - 1
# Comm. Overseeing Action for Lumber Int'l Trade Investigations or Negotiations v. United States -> Adams Fruit Co. v. Barrett - exact_name - 1
# Allegheny Defense Project v. FERC -> Adams Fruit Co. v. Barrett - exact_name - 2
# New York Stock Exchange LLC v. SEC -> Adams Fruit Co. v. Barrett - exact_name - 1
# Commonwealth of Pennsylvania v. President United States -> Adams Fruit Co. v. Barrett - citation_pipe_other_elements - 1
# Smith v. Berryhill -> Adams Fruit Co. v. Barrett - exact_name - 1
# Natural Resources Defense Council v. National Highway Traffic Safety -> Adams Fruit Co. v. Barrett - citation_pipe_other_elements - 1
# Luke v. State of Texas -> Alexander v. Choate - exact_name - 1
# Cropp v. Larimer County, Colorado -> Alexander v. Choate - exact_name - 1
# K. M. v. Tustin Unified School District -> Alexander v. Choate - exact_name - 1
# Carleton v. Commonwealth -> Southeastern Community College v. Davis - exact_name - 1
# Longval v. O'Toole -> Cooper v. Federal Reserve Bank of Richmond - exact_name - 1
# Eldridge v. D.C. DHS -> Olmstead v. L.C. - relaxed_name - 1
# ...
# Snell v. Neville -> Cleveland v. Policy Management Systems Corp. - relaxed_name - 1
# Mary Jo C. v. New York State and Local Retirement System et ano. -> Consolidated Rail Corporation v. Darrone - citation_pipe_other_elements - 1
# United States v. City of New York -> Cooper v. Federal Reserve Bank of Richmond - citation_pipe_other_elements - 2
# Wilkerson v. Shinseki -> Southeastern Community College v. Davis - citation_pipe_other_elements - 1
# [progress] edges processed: 9835 | success: 9784 (first_exact:8994, first_relaxed:37, exact_name:332, relaxed_name:85, other_exact:333, other_relaxed:3) | unsuccessful: 51 | "Id." hits: 0
# Citizens Bank, N.A. v. -> Wal-Mart Stores, Inc. v. Dukes - exact_name - 1
# [progress] edges processed: 9878 | success: 9827 (first_exact:9035, first_relaxed:38, exact_name:333, relaxed_name:85, other_exact:333, other_relaxed:3) | unsuccessful: 51 | "Id." hits: 0
# In Re: JPMorgan Chase & Company -> Epic Systems Corp. v. Lewis - exact_name - 1
# Thomas Anderson v. UAL -> Baldwin County Welcome Center v. Brown - citation_pipe_other_elements - 1
# [progress] edges processed: 9921 | success: 9870 (first_exact:9076, first_relaxed:38, exact_name:334, relaxed_name:85, other_exact:334, other_relaxed:3) | unsuccessful: 51 | "Id." hits: 0
# Johnson v. Meriter Health Services Employee Retirement Plan -> Ticor Title Insurance v. Brown - citation_pipe_other_elements - 1
# Wal-Mart Stores, Inc. v. Dukes -> Cooper v. Federal Reserve Bank of Richmond - exact_name - 1
# Haddad v. Wal-Mart Stores, Inc. -> Desert Palace, Inc. v. Costa - exact_name - 1
# [progress] edges processed: 9966 | success: 9915 (first_exact:9118, first_relaxed:38, exact_name:336, relaxed_name:85, other_exact:335, other_relaxed:3) | unsuccessful: 51 | "Id." hits: 0
# [progress] edges processed: 10009 | success: 9958 (first_exact:9161, first_relaxed:38, exact_name:336, relaxed_name:85, other_exact:335, other_relaxed:3) | unsuccessful: 51 | "Id." hits: 0
# Sullivan v. NH DOC -> Amer Bus Assn v. Slater, Rodney E. - No hit found
# Thomas Anderson v. UAL -> Baldwin County Welcome Center v. Brown - citation_pipe_other_elements - 1
# [progress] edges processed: 10054 | success: 10002 (first_exact:9203, first_relaxed:39, exact_name:336, relaxed_name:85, other_exact:336, other_relaxed:3) | unsuccessful: 52 | "Id." hits: 0
# Zuzanna Juris v. Inamed Corporation -> Ticor Title Insurance v. Brown - citation_pipe_other_elements - 4
# Flowers v. So Regn Physn Svcs -> Carey v. Piphus - exact_name - 1
# Exby-Stolley v. Board of County Commissioners -> Christensen v. Harris County - relaxed_name - 1
# Exby-Stolley v. Board of County Commissioners -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# Michael Argenyi v. Creighton University -> Consolidated Rail Corporation v. Darrone - citation_pipe_other_elements - 1
# Wal-Mart Stores, Inc. v. Dukes -> Cooper v. Federal Reserve Bank of Richmond - exact_name - 1
# Lonberg v. City of Riverside -> Southeastern Community College v. Davis - citation_pipe_other_elements - 1
# [progress] edges processed: 10098 | success: 10046 (first_exact:9239, first_relaxed:40, exact_name:338, relaxed_name:86, other_exact:340, other_relaxed:3) | unsuccessful: 52 | "Id." hits: 0
# Frame v. City of Arlington -> Alexander v. Choate - exact_name - 3
# Glenn Gates v. Rohm & Haas Co -> Wal-Mart Stores, Inc. v. Dukes - citation_pipe_other_elements - 2
# [progress] edges processed: 10142 | success: 10090 (first_exact:9281, first_relaxed:40, exact_name:339, relaxed_name:86, other_exact:341, other_relaxed:3) | unsuccessful: 52 | "Id." hits: 0
# U.S. v. Syphers -> Amer Bus Assn v. Slater, Rodney E. - No hit found
# Gadway v. Univ. of Toledo -> Baldwin County Welcome Center v. Brown - citation_pipe_other_elements - 1
# T.W. v. Board of Law Examiners -> National Collegiate Athletic Assn. v. Smith - citation_pipe_other_elements - 1
# Zuzanna Juris v. Inamed Corporation -> Ticor Title Insurance v. Brown - citation_pipe_other_elements - 4
# Sabo v. United States -> Christensen v. Harris County - exact_name - 1
# Aubrey v. Koppes -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# Wal-Mart Stores, Inc. v. Dukes -> Cooper v. Federal Reserve Bank of Richmond - exact_name - 1
# [progress] edges processed: 10186 | success: 10133 (first_exact:9318, first_relaxed:40, exact_name:341, relaxed_name:86, other_exact:345, other_relaxed:3) | unsuccessful: 53 | "Id." hits: 0
# Barber Ex Rel. Barber v. Colorado Dept. of Revenue -> Alexander v. Choate - exact_name - 3
# [progress] edges processed: 10230 | success: 10177 (first_exact:9361, first_relaxed:40, exact_name:342, relaxed_name:86, other_exact:345, other_relaxed:3) | unsuccessful: 53 | "Id." hits: 0
# Solar Energy Indus. Ass'n. v. United States -> Baldwin County Welcome Center v. Brown - citation_pipe_other_elements - 1
# Lois Sharer v. State of Oregon -> National Collegiate Athletic Assn. v. Smith - citation_pipe_other_elements - 1
# Beer v. United States -> Ticor Title Insurance v. Brown - citation_pipe_other_elements - 1
# Acevedo-Garcia v. Vera-Monroig -> Carey v. Piphus - exact_name - 1
# American Council of the Blind v. Paulson -> Southeastern Community College v. Davis - citation_pipe_other_elements - 2
# [progress] edges processed: 10274 | success: 10221 (first_exact:9400, first_relaxed:40, exact_name:343, relaxed_name:86, other_exact:349, other_relaxed:3) | unsuccessful: 53 | "Id." hits: 0
# American Council of the Blind v. Paulson -> Alexander v. Choate - exact_name - 1
# IBM Corporation v. Criado -> Dichner v. Liberty Travel - exact_name - 1
# [progress] edges processed: 10318 | success: 10265 (first_exact:9442, first_relaxed:40, exact_name:345, relaxed_name:86, other_exact:349, other_relaxed:3) | unsuccessful: 53 | "Id." hits: 0
# State v. Winter -> State v. Winter - citation_pipe_other_elements - 1
# Wanda St. Andrie v. Singing River Health System -> Baldwin County Welcome Center v. Brown - citation_pipe_other_elements - 1
# Acevedo-Garcia v. Vera-Monroig -> Carey v. Piphus - exact_name - 1
# Ellis v. J.R.'s Country Stores, Inc. -> Christensen v. Harris County - relaxed_name - 1
# Paul Boyle v. City of Pell City -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 2
# Currie v. Group Insurance Co -> Consolidated Rail Corporation v. Darrone - citation_pipe_other_elements - 1
# Oztimurlenk, R.N. v. United States -> Cooper v. Federal Reserve Bank of Richmond - citation_pipe_other_elements - 1
# [progress] edges processed: 10362 | success: 10309 (first_exact:9479, first_relaxed:40, exact_name:346, relaxed_name:87, other_exact:354, other_relaxed:3) | unsuccessful: 53 | "Id." hits: 0
# Michael Fisher v. Nissan N.A., Inc. -> US Airways, Inc. v. Barnett - citation_pipe_other_elements - 1
# Montgomery v. District of Columbia -> Alexander v. Choate - exact_name - 1
# Criado v. IBM Corporation -> Dichner v. Liberty Travel - exact_name - 1
# Wal-Mart Stores, Inc. v. Dukes -> Ticor Title Insurance v. Brown - citation_pipe_other_elements - 1
# [progress] edges processed: 10404 | success: 10351 (first_exact:9517, first_relaxed:40, exact_name:348, relaxed_name:87, other_exact:356, other_relaxed:3) | unsuccessful: 53 | "Id." hits: 0
# Donnika Ivy v. Michael Williams -> Christensen v. Harris County - relaxed_name - 1
# Delores Frazier-White v. David Gee -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# Natalie Slaughter v. Des Moines University College of Osteopathic Medicine -> Southeastern Community College v. Davis - citation_pipe_other_elements - 2
# Davoll v. Webb -> Alexander v. Choate - exact_name - 2
# [progress] edges processed: 10448 | success: 10395 (first_exact:9557, first_relaxed:40, exact_name:349, relaxed_name:88, other_exact:358, other_relaxed:3) | unsuccessful: 53 | "Id." hits: 0
# Wal-Mart Stores, Inc. v. Dukes -> Ticor Title Insurance v. Brown - citation_pipe_other_elements - 1
# Brigham v. Frontier Airlines -> US Airways, Inc. v. Barnett - exact_name - 1
# [progress] edges processed: 10492 | success: 10439 (first_exact:9598, first_relaxed:41, exact_name:350, relaxed_name:88, other_exact:359, other_relaxed:3) | unsuccessful: 53 | "Id." hits: 0
# Wal-Mart Stores, Inc. v. Dukes -> Ticor Title Insurance v. Brown - citation_pipe_other_elements - 1
# Erica Betts v. Costco Wholesale Corporation -> Carey v. Piphus - exact_name - 2
# Adkins v. Peninsula Regional Medical Center -> US Airways, Inc. v. Barnett - citation_pipe_other_elements - 1
# [progress] edges processed: 10536 | success: 10483 (first_exact:9639, first_relaxed:41, exact_name:351, relaxed_name:88, other_exact:361, other_relaxed:3) | unsuccessful: 53 | "Id." hits: 0
# Gustav Buchholz v. Meyer Njus Tanick, PA -> Carey v. Piphus - exact_name - 1
# T.W. v. Board of Law Examiners -> Consolidated Rail Corporation v. Darrone - citation_pipe_other_elements - 1
# National Federation of the Blind v. Linda Lamone -> US Airways, Inc. v. Barnett - citation_pipe_other_elements - 1
# [progress] edges processed: 10581 | success: 10528 (first_exact:9681, first_relaxed:41, exact_name:352, relaxed_name:88, other_exact:363, other_relaxed:3) | unsuccessful: 53 | "Id." hits: 0
# Perry Hopman v. Union Pacific Railroad -> Alexander v. Choate - exact_name - 1
# Lois Sharer v. State of Oregon -> Consolidated Rail Corporation v. Darrone - relaxed_name - 1
# Ali v. Pruitt -> US Airways, Inc. v. Barnett - citation_pipe_other_elements - 1
# Pierce v. District of Columbia -> Alexander v. Choate - exact_name - 3
# Dichner v. Liberty Travel -> Equal Employment Opportunity Commission v. Amego, Inc. - No hit found
# [progress] edges processed: 10626 | success: 10572 (first_exact:9721, first_relaxed:41, exact_name:354, relaxed_name:89, other_exact:364, other_relaxed:3) | unsuccessful: 54 | "Id." hits: 0
# Farris v. Shinseki -> Baldwin County Welcome Center v. Brown - exact_name - 1
# Pierce v. District of Columbia -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# Haybarger v. Lawrence Cty Adult -> Consolidated Rail Corporation v. Darrone - citation_pipe_other_elements - 1
# Smith v. Midland Brake, Inc. -> Southeastern Community College v. Davis - exact_name - 2
# Sunny Anthony v. Trax International Corp. -> US Airways, Inc. v. Barnett - exact_name - 1
# Michael Argenyi v. Creighton University -> Alexander v. Choate - exact_name - 1
# Keckler v. Meridian Security Insurance Co. -> General Housewares Corp. v. National Surety Corp. - No hit found
# [progress] edges processed: 10671 | success: 10616 (first_exact:9759, first_relaxed:41, exact_name:358, relaxed_name:89, other_exact:366, other_relaxed:3) | unsuccessful: 55 | "Id." hits: 0
# McFadden v. Washington Metropolitan Area Transit Authority -> US Airways, Inc. v. Barnett - citation_pipe_other_elements - 1
# Smith v. Midland Brake, Inc. -> Alexander v. Choate - exact_name - 1
# Pioneer Centres Holding Co. Employee Stock Ownership Plan & Trust v. Alerus Financial, N.A. -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# Alexander v. Choate -> Consolidated Rail Corporation v. Darrone - exact_name - 4
# McBride v. BIC Consumer Products Manufacturing Company, Inc. -> US Airways, Inc. v. Barnett - citation_pipe_other_elements - 2
# [progress] edges processed: 10715 | success: 10660 (first_exact:9798, first_relaxed:41, exact_name:360, relaxed_name:89, other_exact:369, other_relaxed:3) | unsuccessful: 55 | "Id." hits: 0
# STEPHEN B. CORN, M.D. v. BRIGHAM AND WOMEN'S HOSPITAL & Others -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# Goodwin Ex Rel. Estate of Lunnin v. C.N.J., Inc. -> Consolidated Rail Corporation v. Darrone - citation_pipe_other_elements - 1
# McDonald's v. Robertson -> Ticor Title Insurance v. Brown - citation_pipe_other_elements - 2
# Gallipo v. City of Rutland -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# Parker v. Universidad De Puerto Rico -> Consolidated Rail Corporation v. Darrone - relaxed_name - 1
# Brien Hill v. Associates for Renewal in Education -> US Airways, Inc. v. Barnett - citation_pipe_other_elements - 1
# Lawson, John v. CSX Transportation -> Cleveland v. Policy Management Systems Corp. - relaxed_name - 1
# [progress] edges processed: 10759 | success: 10704 (first_exact:9835, first_relaxed:41, exact_name:360, relaxed_name:91, other_exact:374, other_relaxed:3) | unsuccessful: 55 | "Id." hits: 0
# John Lawson, Sr. v. Csx Transportation, Incorporated -> Cleveland v. Policy Management Systems Corp. - relaxed_name - 1
# Pendleton v. Jefferson Local School District -> Consolidated Rail Corporation v. Darrone - exact_name - 1
# Kathleen Fowler v. AT&T Inc -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# Santos v. McDonough -> Consolidated Rail Corporation v. Darrone - relaxed_name - 1
# Schrader v. Fred A. Ray, M.D., P.C. -> Consolidated Rail Corporation v. Darrone - citation_pipe_other_elements - 1
# Lorrie Ann Horner, by and Through Her Father Nfr Haskel Horner Jennifer Baker, by and Through Her Father Nfr Douglas Baker Juliana Brown, by and Through Her Father Nfr Michael Brown Angella Chaffin, by and Through Her Father Nfr Dale Chaffin Tracy Dotson, by and Through Her Father Nfr Sherman Dotson Jacqueline Elston, by and Through Her Father Joseph Elston Amy Hacker, by and Through Her Father Nfr Chris Hacker Elizabeth Suzanne Hartlage, an Adult Kelly Johnson, by and Through Her Father Nfr Charles Johnson Mary Christine Whitelock, an Adult, Leslie Burgett, by and Through Her Father Nfr Billy Burgett Barrie Wagers, by and Through Her Father Nfr Lyde Wagers v. Kentucky High School Athletic Association Kentucky State Board for Elementary and Secondary Education -> Consolidated Rail Corporation v. Darrone - relaxed_name - 1
# [progress] edges processed: 10803 | success: 10748 (first_exact:9872, first_relaxed:42, exact_name:361, relaxed_name:94, other_exact:376, other_relaxed:3) | unsuccessful: 55 | "Id." hits: 0
# Zenaida Garc A-Ayala v. Lederle Parenterals, Inc. -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# Opinion No. -> Southeastern Community College v. Davis - exact_name - 1
# Garcia-Ayala v. Lederle Parentals -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# Neil Basta v. Novant Health Incorporated -> Alexander v. Choate - exact_name - 1
# Rodney Koon v. State of North Carolina -> Alexander v. Choate - exact_name - 1
# Sunny Anthony v. Trax International Corp. -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# National Federation of the Blind v. Linda Lamone -> Alexander v. Choate - exact_name - 1
# Pena v. Honeywell International, Inc. -> Cleveland v. Policy Management Systems Corp. - relaxed_name - 1
# Helen Weyer v. Twentieth Century Fox Film Corporation -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# Woodman v. Runyon -> Southeastern Community College v. Davis - exact_name - 1
# Samuel Scudder v. Dolgencorp -> Cleveland v. Policy Management Systems Corp. - citation_pipe_other_elements - 1
# EEOC v. Amego, Inc. -> Southeastern Community College v. Davis - citation_pipe_other_elements - 1
# Helen Weyer v. Twentieth Century Fox Film Corporation -> Alexander v. Choate - exact_name - 2
# [progress] edges processed: 10847 | success: 10792 (first_exact:9903, first_relaxed:42, exact_name:367, relaxed_name:95, other_exact:382, other_relaxed:3) | unsuccessful: 55 | "Id." hits: 0
# Kirola v. City of San Francisco -> Alexander v. Choate - exact_name - 1
# Helen Weyer v. Twentieth Century Fox Film Corporation -> Southeastern Community College v. Davis - exact_name - 1
#
# === Final Summary ===
# Edges processed: 10866
# Successful (hit found): 10811
#   · By method → first_exact: 9920, first_relaxed: 42, exact_name: 369, relaxed_name: 95, other_exact: 382, other_relaxed: 3
# Unsuccessful (no hit / no source): 55
# "Id." hits recorded: 0
