# %% [markdown]
# ---
#
# # Case Opinion Summarization
#
# This notebook writes a **single-paragraph opinion summary** to each `(:Case).opinion_summary` using **Amazon Bedrock – `mistral.mistral-7b-instruct-v0:2`**.
# It uses the **Mistral v0.2 tokenizer** locally (no model weights downloaded) for **token-accurate chunking** and calls Bedrock for generation.
#
# ---
#
# ## What the pipeline does
#
# 1. **Loads env & connects to Neo4j**
#    Requires `.env` with `NEO4J_URI`, `NEO4J_USERNAME`, `NEO4J_PASSWORD`, `NEO4J_DATABASE`.
#
# 2. **Uses Bedrock for generation (no GPU needed locally)**
#    Invokes `mistral.mistral-7b-instruct-v0:2` via `boto3` in the configured AWS Region.
#
# 3. **Token-based chunking with Mistral tokenizer**
#
#    * Downloads only the **tokenizer** (`mistralai/Mistral-7B-Instruct-v0.2`).
#    * Splits long opinions into parts of ≤ **context_tokens − overhead − output_reserve**, with **80-token overlap**.
#
# 4. **Fetches and compacts opinion text**
#
#    * If chunked: `(:Case)-[:HAS_OPINION_CHUNK]->(:OpinionChunk)` ordered by `chunk_index`.
#    * Else: inline `c.opinion_text`.
#    * Cleans hyphenations, line-number stubs, and collapses whitespace.
#
# 5. **Summarizes each part, then merges**
#    Rubric: parties’ key arguments (≤6 sentences), court conclusion (≤3 sentences), major statutes (≤3 laws).
#    Post-processing trims “Here’s a summary…” fluff and ends with proper punctuation.
#
# 6. **Writes back to Neo4j**
#    Only `c.opinion_summary` is written (one paragraph). Final console shows a run summary.
#
# ---
#
# ## What you’ll see in the logs
#
# For each case:
#
# ```
# - Case <CASE_ID> — <Case Name>
#     · opinion too long → split into <K> parts (<= <max_ctx_tokens> tokens each)
#       - finished part 1/<K>
#       - finished part 2/<K>
#       ...
#     · wrote opinion_summary
# ```
#
# If the opinion fits:
#
# ```
# - Case <CASE_ID> — <Case Name>
#     · wrote opinion_summary
# ```
#
# Skips:
#
# ```
# - Case <CASE_ID> — <Case Name>
#     · SKIP (no opinion text)
# ```
#
# or
#
# ```
# - Case <CASE_ID> — <Case Name>
#     · SKIP (already summarized; force=False)
# ```
#
# End of run:
#
# ```
# === Summary ===
# LLM backend: Bedrock Mistral (mistral.mistral-7b-instruct-v0:2, region=<REGION>)
# Processed: <N> | Wrote: <M> | Skipped-existing: <A> | Skipped-empty: <B> | Chunked cases: <C>
# Elapsed: <minutes> min
# ```
#
# ---
#
# ## How to run (SageMaker Studio / Notebook Instance)
#
# 1. **AWS prerequisites**
#
#    * Bedrock access in your account/region (`bedrock:InvokeModel`).
#    * Network egress to Bedrock (public internet access or proper VPC endpoints).
#    * IAM execution role attached to the notebook with Bedrock permissions.
#
# 2. **Project setup**
#
#    * Place a `.env` file (Neo4j creds) at project root or update the path.
#    * Ensure your graph has `Case`, optional `OpinionChunk`, and relationships as described.
#
# 3. **Run the notebook cells top-to-bottom**
#    The notebook will fetch the tokenizer automatically and then call Bedrock for text generation.
#
# ---
#
# ## The `summarize(...)` function
#
# **Signature (defaults):**
#
# ```python
# summarize(
#     max_new_tokens=500,      # generation cap per Bedrock call
#     min_out_tokens=200,      # best-effort minimum (post-processing)
#     batch_cases=60,          # cases queried per Neo4j page
#     echo=True,               # per-case logging
#     force=False              # re-summarize even if opinion_summary exists
# )
# ```
#
# **Behavior:**
#
# * Computes a conservative **token budget** based on Mistral v0.2 context, subtracting overhead and output reserve.
# * Splits with **token overlap (80)** to preserve context across parts.
# * Summarizes each part via Bedrock, merges, and writes `c.opinion_summary`.
#
# ---
#
# ## Assumptions & Notes
#
# * **Tokenizer only** is downloaded from Hugging Face; all generation happens in Bedrock.
# * Neo4j driver is configured to **suppress `DEPRECATION` notifications** (hides the `id()` warning); driver loggers are also set to `ERROR` as a fallback.
# * If many cases are very long, expect a handful of parts per case rather than many tiny chunks (token-aware splitting).
#
# ---
#
# ## Troubleshooting
#
# * **AccessDenied / Model not enabled** → Verify Bedrock access for `mistral.mistral-7b-instruct-v0:2` in your Region.
# * **Networking** → If running in a VPC-only notebook, confirm NAT or Bedrock VPC endpoints.
# * **Neo4j auth / TLS** → Check `.env` values and URI scheme (`neo4j+s://` for TLS).
# * **Throughput** → Increase `batch_cases` for faster DB paging; lower it if your DB is small/slow.
#
# ---

# %%
# !pip install neo4j
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: neo4j in /opt/conda/lib/python3.12/site-packages (6.0.3)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.12/site-packages (from neo4j) (2024.2)

# %%
import os, re, time, pathlib, datetime as dt, json, logging
from typing import Optional, Dict, Any, List

import boto3
from dotenv import load_dotenv
from neo4j import GraphDatabase
from neo4j.exceptions import SessionExpired, ServiceUnavailable
from transformers import AutoTokenizer

# =========================
# Configuration
# =========================
BEDROCK_REGION   = os.getenv("BEDROCK_REGION", "us-east-1")
BEDROCK_MODEL_ID = "mistral.mistral-7b-instruct-v0:2"

# Neo4j connection
load_dotenv("../.env")
NEO4J_URI      = os.getenv("NEO4J_URI")
NEO4J_USERNAME = os.getenv("NEO4J_USERNAME")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")
NEO4J_DATABASE = os.getenv("NEO4J_DATABASE", "neo4j")

# Silence noisy driver logs as a fallback (in case notification suppression
# below isn't supported by your driver/server combo)
for _name in ("neo4j", "neo4j.notifications", "neo4j.work.simple"):
    logging.getLogger(_name).setLevel(logging.ERROR)

# %% [markdown]
# ## Summary Prompt

# %%
SUMMARY_SYSTEM_PROMPT = """You are a legal assistant specializing in writing court case briefs.
Summarize the case by outlining the key arguments of both parties (max 6 sentences),
the court's conclusion (max 3 sentences) and the major statute law being applied (max 3 laws).
Do NOT repeat the instructions or case text. Output only one paragraph of case summary.

Example output:
'The plaintiff (the Clinic) argued that Bill 39-02 was enacted due to community hostility toward methadone clinics, violating Title II of the ADA and substantive due process rights.
The Defendant (Baltimore County) argued there was insufficient evidence that it regarded the Clinic's patients as disabled and challenged the district court's rulings and remedies.
The Fourth Circuit held that a reasonable jury could differ on whether the County regarded patients as disabled. It affirmed parts of the due process verdict but vacated the injunction. The case was affirmed in part, reversed in part, vacated in part, and remanded.
Major statute law applied: Title II of the Americans with Disabilities Act (42 U.S.C. § 12131 et seq.) and Substantive Due Process (Fourteenth Amendment)'
"""

USER_SUMMARY_PROMPT = """Summarize the case below by outlining the key arguments of both parties (max 6 sentences),
the court's conclusion (max 3 sentences) and the major statute law being applied (max 3 laws).
Case Name: {case_name}
Case Context:
{case_context}
"""

def _inst(system_text: str, user_text: str) -> str:
    return f"<s>[INST]{system_text}\n{user_text}[/INST]"

# %% [markdown]
# ## Cypher Queries

# %%
# =========================
# Cypher Queries
# =========================
Q_PAGE_CASES = """
MATCH (c:Case)
WHERE id(c) > $after_id
RETURN id(c) AS nid,
       c.id AS case_id,
       coalesce(c.name, '') AS case_name,
       coalesce(c.opinion_summary, '') AS existing_summary
ORDER BY nid
LIMIT $limit
"""

Q_GET_CHUNKS = """
MATCH (c:Case {id:$case_id})-[:HAS_OPINION_CHUNK]->(oc:OpinionChunk)
RETURN oc.text AS text
ORDER BY oc.chunk_index
"""

Q_GET_INLINE = "MATCH (c:Case {id:$case_id}) RETURN c.opinion_text AS text"

Q_WRITE_SUMMARY = "MATCH (c:Case {id:$case_id}) SET c.opinion_summary = $summary RETURN c.id AS case_id"

# %% [markdown]
# ## Cleaning Functions

# %%
# =========================
# Cleaning & small utils
# =========================
LEADING_FLUFF_RE = re.compile(
    r"^\s*(certainly[, ]+)?(here(?:’|')?s|here is)\s+(a|the)\s+summary\s*[:\-–—]*\s*",
    re.IGNORECASE,
)
REDACTION_RE = re.compile(
    r"\b(portions of (?:the )?(?:document|legal document) have been redacted|redacted pursuant to)\b",
    re.IGNORECASE
)
_SENT_END_RE = re.compile(r'[.?!](?:["”\'\)\]]+)?')

def _strip_leading_fluff(text: str) -> str:
    return LEADING_FLUFF_RE.sub("", text).strip()

def _finalize_sentence(text: str) -> str:
    s = text.strip()
    last = None
    for m in _SENT_END_RE.finditer(s):
        last = m
    if last:
        s = s[: last.end()].rstrip()
    if not s or s[-1] not in ".!?":
        s = s.rstrip() + "."
    return s

def _compact(text: str) -> str:
    if not text:
        return text
    s = text.replace("\r", "\n").replace("\x0c", " ")
    s = re.sub(r'(\w)-\s*\n\s*(\w)', r'\1\2', s)
    lines = []
    for ln in s.splitlines():
        if re.match(r'^\s*\d{1,3}\s*$', ln):
            continue
        lines.append(ln)
    s = "\n".join(lines)
    s = re.sub(r'\s+', ' ', s).strip()
    s = re.sub(r'\s+([,.;:!?])', r'\1', s)
    return s

def _ordinal(n: int) -> str:
    return ["first","second","third","fourth","fifth","sixth","seventh","eighth","ninth","tenth"][n-1] if 1<=n<=10 else f"{n}th"

# %% [markdown]
# ## Token-based chunking

# %%
# =========================
# Token-based chunking (Mistral tokenizer)
# =========================
# We only download the tokenizer; no model weights are fetched.
_MISTRAL_TOKENIZER_ID = "mistralai/Mistral-7B-Instruct-v0.2"
_tokenizer = AutoTokenizer.from_pretrained(_MISTRAL_TOKENIZER_ID, use_fast=True)

def _split_text_by_tokens(tokenizer, text: str, max_tokens: int, overlap: int = 50) -> List[str]:
    ids = tokenizer(text, add_special_tokens=False)["input_ids"]
    if len(ids) <= max_tokens:
        return [text]
    parts: List[str] = []
    step = max(1, max_tokens - overlap)
    for start in range(0, len(ids), step):
        end = min(len(ids), start + max_tokens)
        chunk_ids = ids[start:end]
        part = tokenizer.decode(chunk_ids, skip_special_tokens=True)
        parts.append(_compact(part))
        if end == len(ids):
            break
    return parts

def _mistral_max_ctx_tokens(max_new_tokens: int) -> int:
    """
    Conservative context calculator for Mistral 7B Instruct v0.2 (~32k context).
    Reserve some tokens for formatting + output.
    """
    model_max = getattr(_tokenizer, "model_max_length", 32000)
    if model_max is None or model_max > 1_000_000_000:
        model_max = 32000
    overhead = 512
    reserve_out = max_new_tokens + 64
    return max(1024, model_max - overhead - reserve_out)

# %%
# =========================
# Bedrock client (lazy)
# =========================
_bedrock_client = None
def _get_bedrock_client():
    global _bedrock_client
    if _bedrock_client is None:
        _bedrock_client = boto3.client("bedrock-runtime", region_name=BEDROCK_REGION)
    return _bedrock_client

# %%
def summarize(
    *,
    max_new_tokens: int = 500,
    min_out_tokens: int = 200,   # best-effort (post-gen; unused but kept for API)
    batch_cases: int = 60,
    echo: bool = True,
    force: bool = False,
):
    """
    Summarizes each Case node into c.opinion_summary using Amazon Bedrock
    model 'mistral.mistral-7b-instruct-v0:2'.

    If a Neo4j connection error (SessionExpired / ServiceUnavailable / OSError)
    occurs for a given case, that case (and the remainder of that batch) are
    skipped and processing continues with a fresh session on the next batch.
    """
    client = _get_bedrock_client()

    # Build chunker based on tokens
    max_ctx_tokens = _mistral_max_ctx_tokens(max_new_tokens)

    def _split_context(opinion_text: str) -> List[str]:
        return _split_text_by_tokens(
            _tokenizer,
            opinion_text,
            max_tokens=max_ctx_tokens,
            overlap=80,
        )

    def _gen_chunk(case_name: str, chunk_text: str) -> str:
        user = USER_SUMMARY_PROMPT.format(
            case_name=case_name,
            case_context=chunk_text,
        )
        formatted_prompt = _inst(SUMMARY_SYSTEM_PROMPT, user)

        payload = {
            "prompt": formatted_prompt,
            "max_tokens": max_new_tokens,
            "temperature": 0,
        }
        resp = client.invoke_model(
            modelId=BEDROCK_MODEL_ID,
            body=json.dumps(payload),
            contentType="application/json",
            accept="application/json",
        )
        body = json.loads(resp["body"].read())
        text = body["outputs"][0]["text"]
        text = re.sub(r"\s+", " ", text).strip()
        text = _strip_leading_fluff(text)

        if REDACTION_RE.search(text):
            text = re.sub(REDACTION_RE, "", text).strip()
        return _finalize_sentence(text)

    # ---- Neo4j driver ----
    driver = GraphDatabase.driver(
        NEO4J_URI,
        auth=(NEO4J_USERNAME, NEO4J_PASSWORD),
    )

    # Try to disable only DEPRECATION notifications (cleaner logs)
    session_kwargs: Dict[str, Any] = {"database": NEO4J_DATABASE}
    try:
        from neo4j.notifications import NotificationDisabledCategory

        session_kwargs["notifications_disabled_categories"] = [
            NotificationDisabledCategory.DEPRECATION
        ]
    except Exception:
        # Older driver versions may not support this; ignore
        pass

    processed = wrote = sk_empty = 0
    skipped_existing = 0
    chunked_cases = 0
    after_id = -1
    t0 = time.time()
    done = False

    try:
        while not done:
            # Open a fresh session for each batch
            with driver.session(**session_kwargs) as s:
                session_had_error = False

                # --- Fetch next batch of cases ---
                try:
                    batch = s.run(
                        Q_PAGE_CASES,
                        {"after_id": after_id, "limit": batch_cases},
                    ).data()
                except (SessionExpired, ServiceUnavailable, OSError) as e:
                    session_had_error = True
                    if echo:
                        print(
                            f"\nConnection error while paging cases after id {after_id}: {e}"
                        )
                        print("    · Skipping this batch and retrying with a new session.")
                    # Go back to the top of the while loop, new session next time
                    continue

                if not batch:
                    if echo:
                        print("Done. No more cases.")
                    done = True
                    continue

                if echo:
                    print(f"\nBatch after internal id {after_id}: {len(batch)} case(s)")

                # --- Process each case in the batch ---
                for row in batch:
                    nid = row["nid"]
                    case_id = row["case_id"]
                    case_name = row["case_name"] or ""
                    existing = (row.get("existing_summary") or "").strip()
                    after_id = nid  # important for paging

                    # Skip if already summarized (unless force=True)
                    if (not force) and existing:
                        skipped_existing += 1
                        processed += 1
                        if echo:
                            print(
                                f"- Case {case_id} — {case_name[:90] or '[no name]'}"
                            )
                            print("    · SKIP (already summarized; force=False)")
                        continue

                    # --- Read opinion text from Neo4j (with error handling) ---
                    try:
                        rows = s.run(
                            Q_GET_CHUNKS, {"case_id": case_id}
                        ).data()
                    except (SessionExpired, ServiceUnavailable, OSError) as e:
                        session_had_error = True
                        if echo:
                            print(
                                f"- Case {case_id} — {case_name[:90] or '[no name]'}"
                            )
                            print(
                                f"    · SKIP (Neo4j read error while getting chunks: {e})"
                            )
                            print("    · Will reopen session for remaining cases.")
                        # Break out of this batch; new session next loop
                        break

                    if rows:
                        parts_raw = [
                            _compact((r.get("text") or ""))
                            for r in rows
                            if (r.get("text") or "").strip()
                        ]
                        opinion_text = "\n\n".join(parts_raw)
                    else:
                        # Need inline text; may also fail
                        try:
                            r = s.run(
                                Q_GET_INLINE, {"case_id": case_id}
                            ).single()
                        except (SessionExpired, ServiceUnavailable, OSError) as e:
                            session_had_error = True
                            if echo:
                                print(
                                    f"- Case {case_id} — {case_name[:90] or '[no name]'}"
                                )
                                print(
                                    f"    · SKIP (Neo4j read error while getting inline text: {e})"
                                )
                                print("    · Will reopen session for remaining cases.")
                            break

                        raw = (r["text"] or "") if r and r.get("text") else ""
                        opinion_text = _compact(raw) if raw else ""

                    if not opinion_text:
                        sk_empty += 1
                        processed += 1
                        if echo:
                            print(
                                f"- Case {case_id} — {case_name[:90] or '[no name]'}"
                            )
                            print("    · SKIP (no opinion text)")
                        continue

                    if echo:
                        print(
                            f"- Case {case_id} — {case_name[:90] or '[no name]'}"
                        )

                    # --- Token-based chunking ---
                    parts = _split_context(opinion_text)
                    if len(parts) > 1 and echo:
                        chunked_cases += 1
                        print(
                            f"    · opinion too long → split into {len(parts)} parts "
                            f"(<= {max_ctx_tokens} tokens each)"
                        )

                    # --- Summarize all parts (LLM only; no Neo4j calls) ---
                    part_summaries: List[str] = []
                    for idx, ctx in enumerate(parts, 1):
                        psum = _gen_chunk(case_name, ctx)
                        part_summaries.append(psum)
                        if echo and len(parts) > 1:
                            print(f"      - finished part {idx}/{len(parts)}")

                    # Merge partial summaries
                    if len(part_summaries) == 1:
                        merged_summary = part_summaries[0]
                    else:
                        merged_lines = []
                        for i, ps in enumerate(part_summaries, 1):
                            tag = _ordinal(i)
                            merged_lines.append(
                                f"The {tag} part of the opinion text is summarized as follows:\n{ps}"
                            )
                        merged_summary = "\n\n".join(merged_lines).strip()

                    # --- Write summary back to Neo4j (with error handling) ---
                    try:
                        s.run(
                            Q_WRITE_SUMMARY,
                            {"case_id": case_id, "summary": merged_summary},
                        )
                    except (SessionExpired, ServiceUnavailable, OSError) as e:
                        session_had_error = True
                        if echo:
                            print(
                                f"    · SKIP (Neo4j write error on case {case_id}: {e})"
                            )
                            print(
                                "    · This case summary may not have been saved; "
                                "reopening session for remaining cases."
                            )
                        # Do not count as wrote; break out to reopen session
                        break

                    wrote += 1
                    processed += 1
                    if echo:
                        print("    · wrote opinion_summary")

                # End for row in batch

                if session_had_error:
                    # We broke out of the for-loop due to a connection error.
                    # Outer while-loop will open a new session and continue from
                    # the current `after_id` (effectively skipping this case).
                    continue

        # End while not done

    finally:
        driver.close()

    dt_sec = time.time() - t0
    print("\n=== Summary ===")
    print(
        f"LLM backend: Bedrock Mistral ({BEDROCK_MODEL_ID}, region={BEDROCK_REGION})"
    )
    print(
        "Processed: {p} | Wrote: {w} | "
        "Skipped-existing: {se} | Skipped-empty: {sk} | Chunked cases: {cc}".format(
            p=processed,
            w=wrote,
            se=skipped_existing,
            sk=sk_empty,
            cc=chunked_cases,
        )
    )
    print(f"Elapsed: {dt_sec/60:.1f} min")

# %%
# =========================
# Example usage
# =========================
summarize(force=False, batch_cases=60, max_new_tokens=500, min_out_tokens=200)
# Out:
# Batch after internal id -1: 60 case(s)
# - Case 187059 — Singh v. George Washington University School of Medicine & Health Sciences
#     · SKIP (already summarized; force=False)
# - Case 2349194 — Napreljac v. John Q. Hammons Hotels, Inc.
#     · SKIP (already summarized; force=False)
# - Case 3039638 — Raymond Battle v. UPS
#     · SKIP (already summarized; force=False)
# - Case 793399 — Raymond Battle, Plaintiff-Appellee/cross-Appellant v. United Parcel Service, Inc., Defenda
#     · SKIP (already summarized; force=False)
# - Case 2450784 — Gretillat v. Care Initiatives
#     · SKIP (already summarized; force=False)
# - Case 2567088 — Shape v. Barnes County, ND
#     · SKIP (already summarized; force=False)
# - Case 2998138 — Keane, Judith v. Sears Roebuck
#     · SKIP (already summarized; force=False)
# - Case 791297 — Equal Employment Opportunity Commission, and Judith Keane, Intervening v. Sears, Roebuck &
#     · SKIP (already summarized; force=False)
# - Case 2408258 — Burrell v. Cummins Great Plains, Inc.
#     · SKIP (already summarized; force=False)
# - Case 2151911 — Bodenstab v. County of Cook
#     · SKIP (already summarized; force=False)
# - Case 2994830 — Amadio, Thomas v. Ford Motor Company
#     · SKIP (already summarized; force=False)
# - Case 771887 — Thomas Amadio v. Ford Motor Company
#     · SKIP (already summarized; force=False)
# - Case 2994586 — Webb v. Clyde L. Choate Mental Health & Development Center
#     · SKIP (already summarized; force=False)
# - Case 770924 — Webb v. Choate
#     · SKIP (already summarized; force=False)
# - Case 2994134 — Rehling, Donald v. City of Chicago
#     · SKIP (already summarized; force=False)
# - Case 768159 — Donald Rehling v. The City of Chicago, a Municipal Corporation
#     · SKIP (already summarized; force=False)
# - Case 2307248 — Swartz v. McDonald's Corp.
#     · SKIP (already summarized; force=False)
# - Case 2424551 — Kiphart v. Saturn Corp.
#     · SKIP (already summarized; force=False)
# - Case 2578522 — Salmon v. West Clark Community Schools
#     · SKIP (already summarized; force=False)
# - Case 2341728 — Thompson v. Dot Foods, Inc.
#     · SKIP (already summarized; force=False)
# - Case 1476570 — Disability Advocates, Inc. v. Paterson
#     · SKIP (already summarized; force=False)
# - Case 2522878 — Davis v. Flexman
#     · SKIP (already summarized; force=False)
# - Case 2489057 — Brown v. Stone
#     · SKIP (already summarized; force=False)
# - Case 8206303 — The Evangelical Lutheran Good Samaritan Society v. Tara Rowland
#     · SKIP (already summarized; force=False)
# - Case 8206280 — The Evangelical Lutheran Good Samaritan Society v. Tara Rowland
#     · SKIP (already summarized; force=False)
# - Case 7804835 — State of Hawaii v. Usedu
#     · SKIP (already summarized; force=False)
# - Case 4563970 — Daniel Lopez v. Catalina Channel Express, Inc.
#     · SKIP (already summarized; force=False)
# - Case 3006508 — Edward O'bannon, Jr. v. Ncaa
#     · SKIP (already summarized; force=False)
# - Case 9817378 — Arc of Washington State Inc. v. Braddock
#     · SKIP (already summarized; force=False)
# - Case 2801734 — Felicia Pugliese v. State-Operated School District of The City of Newark
#     · SKIP (already summarized; force=False)
# - Case 2298810 — Lasky v. BOROUGH OF HIGHTSTOWN
#     · SKIP (already summarized; force=False)
# - Case 1990876 — Estate of Nicolas v. Ocean Plaza Condominium Ass'n, Inc.
#     · SKIP (already summarized; force=False)
# - Case 1959926 — Hampton v. Dept. of Corrections
#     · SKIP (already summarized; force=False)
# - Case 1964855 — Franek v. Tomahawk Lake Resort
#     · SKIP (already summarized; force=False)
# - Case 2339899 — Fowler v. Borough of Westville
#     · SKIP (already summarized; force=False)
# - Case 1456733 — YOURMAN BY & THROUGH YOURMAN v. People's SEC. Life Ins. Co.
#     · SKIP (already summarized; force=False)
# - Case 1446728 — Waterfront Commission v. Construction & Marine Equipment Co.
#     · SKIP (already summarized; force=False)
# - Case 1523451 — F & W ASSOCIATES v. County of Somerset
#     · SKIP (already summarized; force=False)
# - Case 8710836 — Greene v. Brentwood Union Free School District
#     · SKIP (already summarized; force=False)
# - Case 8701982 — Weisbecker v. Sayville Union Free School District
#     · SKIP (already summarized; force=False)
# - Case 7239228 — Atencio v. United States Postal Service
#     · SKIP (already summarized; force=False)
# - Case 2468988 — Lundy v. Town of Brighton
#     · SKIP (already summarized; force=False)
# - Case 2484021 — Bielski v. Green
#     · SKIP (already summarized; force=False)
# - Case 2304185 — King v. Town of Wallkill
#     · SKIP (already summarized; force=False)
# - Case 2287088 — Hoehn v. International Security Services & Investigations, Inc.
#     · SKIP (already summarized; force=False)
# - Case 8423201 — Lalla v. Consolidated Edison Co.
#     · SKIP (already summarized; force=False)
# - Case 2568051 — Dollinger v. State Insurance Fund
#     · SKIP (already summarized; force=False)
# - Case 1592895 — Niece v. Fitzner
#     · SKIP (already summarized; force=False)
# - Case 9492290 — Scot L. Zimmerman v. State of Oregon Department of Justice
#     · SKIP (already summarized; force=False)
# - Case 10843512 — Rebecca Adeyanju v. Foot and Ankle Associates of Maine, P.A.
#     · SKIP (already summarized; force=False)
# - Case 4689989 — Snell v. Neville
#     · SKIP (already summarized; force=False)
# - Case 7238494 — Morissette v. Cote Corp.
#     · SKIP (already summarized; force=False)
# - Case 1457513 — Lewis v. Zilog, Inc.
#     · SKIP (already summarized; force=False)
# - Case 2271135 — Whillock v. Delta Air Lines, Inc.
#     · SKIP (already summarized; force=False)
# - Case 2159729 — Ethridge v. State of Ala.
#     · SKIP (already summarized; force=False)
# - Case 10842070 — Way v. City of Missouri City
#     · SKIP (already summarized; force=False)
# - Case 11095257 — In the Matter of the Estate of Noel Elbert Obert, Deceased: Michael Peterson, of the Estat
#     · SKIP (already summarized; force=False)
# - Case 7250798 — Kitchen v. BASF
#     · SKIP (already summarized; force=False)
# - Case 7242964 — Weed v. Sidewinder Drilling, Inc.
#     · SKIP (already summarized; force=False)
# - Case 4106873 — Franklin Collection Service, Inc. v. Gwenlyn M. Collins
#     · SKIP (already summarized; force=False)
#
# Batch after internal id 59: 60 case(s)
# - Case 7238534 — Caldwell v. KHOU-TV & Gannett Co.
#     · SKIP (already summarized; force=False)
# - Case 4071577 — Harris County Hospital District v. William Parker
#     · SKIP (already summarized; force=False)
# - Case 8313756 — Stratton Corp. v. Engelberth Construction, Inc.
#     · SKIP (already summarized; force=False)
# - Case 2797965 — Stratton Corp. and Intrawest Stratton Development Corp. v. Engleberth Construction, Inc. v
#     · SKIP (already summarized; force=False)
# - Case 7236664 — Thomas v. Beaumont Independent School District
#     · SKIP (already summarized; force=False)
# - Case 2759857 — Equal Employment Opportunity Commission v. LHC Group, Inc.
#     · SKIP (already summarized; force=False)
# - Case 2723521 — Allen Thompson v. City of Waco, Texas
#     · SKIP (already summarized; force=False)
# - Case 903605 — Kartes v. Kartes
#     · SKIP (already summarized; force=False)
# - Case 8707467 — Bennett v. Dallas Independent School District
#     · SKIP (already summarized; force=False)
# - Case 8706985 — Guerrero v. Total Renal Care, Inc.
#     · SKIP (already summarized; force=False)
# - Case 820047 — Milton v. Texas Department of Criminal Justice
#     · SKIP (already summarized; force=False)
# - Case 8698851 — Quick v. Vistacare, Inc.
#     · SKIP (already summarized; force=False)
# - Case 8695945 — Molina v. DSI Renal, Inc.
#     · SKIP (already summarized; force=False)
# - Case 2474100 — Dick v. J.B. Hunt Transport, Inc.
#     · SKIP (already summarized; force=False)
# - Case 2626011 — People v. Wood
#     · SKIP (already summarized; force=False)
# - Case 3003606 — Renae Ekstrand v. School District of Somerset
#     · SKIP (already summarized; force=False)
# - Case 1267171 — Ekstrand v. School District of Somerset
#     · SKIP (already summarized; force=False)
# - Case 9906564 — Hampton v. Utah Department of Corrections
#     · SKIP (already summarized; force=False)
# - Case 9324549 — Maughan v. United State Department of Justice
#     · SKIP (already summarized; force=False)
# - Case 1042637 — Equal Employment Opportunity Commission v. Abercrombie & Fitch Stores, Inc.
#     · SKIP (already summarized; force=False)
# - Case 215941 — Equal Employment Opportunity Commission v. C.R. England, Inc.
#     · SKIP (already summarized; force=False)
# - Case 2472981 — West v. New Mexico Taxation & Revenue Department
#     · SKIP (already summarized; force=False)
# - Case 2473877 — Obermeyer v. Vilsack
#     · SKIP (already summarized; force=False)
# - Case 147655 — Wilkerson v. Shinseki
#     · SKIP (already summarized; force=False)
# - Case 1457246 — Bergman v. Paulson
#     · SKIP (already summarized; force=False)
# - Case 1466923 — Norden v. Samper
#     · SKIP (already summarized; force=False)
# - Case 2418603 — Hahn Ex Rel. Barta v. Linn County, IA
#     · SKIP (already summarized; force=False)
# - Case 1883312 — Randolph v. Rodgers
#     · SKIP (already summarized; force=False)
# - Case 2487895 — Badlam v. Reynolds Metals Co.
#     · SKIP (already summarized; force=False)
# - Case 2414903 — Nunnery v. Elgin Joliet Eastern Railway Co.
#     · SKIP (already summarized; force=False)
# - Case 8994013 — Flanigan v. International Brotherhood of Teamsters
#     · SKIP (already summarized; force=False)
# - Case 567186 — Flanigan v. Ups
#     · SKIP (already summarized; force=False)
# - Case 1407224 — Baltzer v. City of Sun Prairie/Police Department
#     · SKIP (already summarized; force=False)
# - Case 1302864 — Glamann v. St. Paul Fire & Marine Insurance
#     · SKIP (already summarized; force=False)
# - Case 3025030 — Sarnowski v. Air Brooke Limousine
#     · SKIP (already summarized; force=False)
# - Case 769160 — Alfred F. Marinelli v. City of Erie, Pennsylvania
#     · SKIP (already summarized; force=False)
# - Case 765245 — Katherine L. Taylor v. Phoenixville School District
#     · SKIP (already summarized; force=False)
# - Case 1657453 — Taylor v. Phoenixville School District
#     · SKIP (already summarized; force=False)
# - Case 751106 — Dennis E. Gaul v. Lucent Technologies Inc. John Does 1-100 Jane Does 1-100 Abc Corp. Xyz C
#     · SKIP (already summarized; force=False)
# - Case 11102008 — In the Matter of the Necessity for the Hospitalization of Rabi R.
#     · SKIP (already summarized; force=False)
# - Case 11102041 — Jayda Roman v. Cleveland Karren
#     · SKIP (already summarized; force=False)
# - Case 4370367 — Saffir v. Wheeler
#     · SKIP (already summarized; force=False)
# - Case 2293502 — Stone v. Sangamon County Sheriff's Department
#     · SKIP (already summarized; force=False)
# - Case 752893 — Richard Baulos and Stanley Schneider v. Roadway Express, Inc.
#     · SKIP (already summarized; force=False)
# - Case 2471625 — Barnes v. Zaccari
#     · SKIP (already summarized; force=False)
# - Case 2448607 — Lawson v. Plantation General Hospital, L.P.
#     · SKIP (already summarized; force=False)
# - Case 2448476 — Richardson v. Honda Manufacturing of Alabama, LLC
#     · SKIP (already summarized; force=False)
# - Case 2353008 — Bennett v. Nissan North America, Inc.
#     · SKIP (already summarized; force=False)
# - Case 1458208 — Castro-Medina v. Procter & Gamble Commercial Co.
#     · SKIP (already summarized; force=False)
# - Case 2574610 — Smith v. Wynfield Development Co., Inc.
#     · SKIP (already summarized; force=False)
# - Case 2455596 — Brandon v. Lockheed Martin Aeronautical Systems
#     · SKIP (already summarized; force=False)
# - Case 2463704 — Roberts v. Rayonier, Inc.
#     · SKIP (already summarized; force=False)
# - Case 9520187 — United States v. Agrawal
#     · SKIP (already summarized; force=False)
# - Case 798922 — Coors Brewing Company v. Mendez-Torres
#     · SKIP (already summarized; force=False)
# - Case 4581355 — Exby-Stolley v. Board of County Commissioners
#     · SKIP (already summarized; force=False)
# - Case 2658390 — ['YOUNG v. DISTRICT OF COLUMBIA HOUSING AUTHORITY']
#     · SKIP (already summarized; force=False)
# - Case 803653 — Cinnamon Hills Youth Crisis Center, Inc. v. Saint George City
#     · SKIP (already summarized; force=False)
# - Case 2301074 — Stoney v. Maple Shade Tp.
#     · SKIP (already summarized; force=False)
# - Case 623760 — Muscogee (Creek) Nation v. Pruitt
#     · SKIP (already summarized; force=False)
# - Case 613680 — Frame v. City of Arlington
#     · SKIP (already summarized; force=False)
#
# Batch after internal id 119: 60 case(s)
# - Case 2478221 — Brown v. County of Nassau
#     · SKIP (already summarized; force=False)
# - Case 3049958 — American Ass'n of People With Disabilities Ex Rel. O'Connor v. Harris
#     · SKIP (already summarized; force=False)
# - Case 146255 — AMERICAN ASS'N OF PEOPLE WITH DISAB. v. Harris
#     · SKIP (already summarized; force=False)
# - Case 173170 — Chamber of Commerce of United States v. Edmondson
#     · SKIP (already summarized; force=False)
# - Case 208064 — Military Order of the Purple Heart v. Secretary of Veterans Affairs
#     · SKIP (already summarized; force=False)
# - Case 3064828 — Lonberg v. City of Riverside
#     · SKIP (already summarized; force=False)
# - Case 9572143 — Lonberg v. City of Riverside
#     · SKIP (already summarized; force=False)
# - Case 172041 — Barber Ex Rel. Barber v. Colorado Dept. of Revenue
#     · SKIP (already summarized; force=False)
# - Case 1902575 — Hughes v. Colorado Department of Corrections
#     · SKIP (already summarized; force=False)
# - Case 1718407 — Covington v. McNEESE STATE UNIVERSITY
#     · SKIP (already summarized; force=False)
# - Case 2308148 — Huezo v. Los Angeles Community College District
#     · SKIP (already summarized; force=False)
# - Case 187155 — American Council of the Blind v. Paulson
#     · SKIP (already summarized; force=False)
# - Case 8751304 — Californians for Disability Rights, Inc. v. California Department of Transportation
#     · SKIP (already summarized; force=False)
# - Case 2413193 — Schorr v. Borough of Lemoyne
#     · SKIP (already summarized; force=False)
# - Case 7230795 — National Federation of the Blind v. Scribd Inc.
#     · SKIP (already summarized; force=False)
# - Case 6453045 — Shedlock v. Department of Correction
#     · SKIP (already summarized; force=False)
# - Case 4566930 — Aubrey v. Koppes
#     · SKIP (already summarized; force=False)
# - Case 4367056 — Bekkem v. Wilkie
#     · SKIP (already summarized; force=False)
# - Case 867786 — Koessel v. Sublette County Sheriff's Department
#     · SKIP (already summarized; force=False)
# - Case 676486 — David Atkins v. Ken Salazar, Secretary
#     · SKIP (already summarized; force=False)
# - Case 7223716 — Jenkins v. City of San Antonio Fire Department
#     · SKIP (already summarized; force=False)
# - Case 1448351 — Houston v. Army Fleet Services, L.L.C.
#     · SKIP (already summarized; force=False)
# - Case 2407245 — Taylor v. County Bancshares, Inc.
#     · SKIP (already summarized; force=False)
# - Case 2418784 — Eber v. Harris County Hospital District
#     · SKIP (already summarized; force=False)
# - Case 8415394 — Natofsky v. City Of New York
#     · SKIP (already summarized; force=False)
# - Case 4388666 — Natofsky v. City of New York
#     · SKIP (already summarized; force=False)
# - Case 4106643 — Prescott-Harris v. McHugh
#     · SKIP (already summarized; force=False)
# - Case 2708565 — Eric Huang v. Continental Casualty Company
#     · SKIP (already summarized; force=False)
# - Case 801002 — Lewis v. Humboldt Acquisition Corp., Inc.
#     · SKIP (already summarized; force=False)
# - Case 61643 — Pinkerton v. Spellings
#     · SKIP (already summarized; force=False)
# - Case 8411090 — Pinkerton v. U.S. Department of Education
#     · SKIP (already summarized; force=False)
# - Case 53880 — Pinkerton v. Spellings
#     · SKIP (already summarized; force=False)
# - Case 2332665 — Valentine v. Standard & Poor's
#     · SKIP (already summarized; force=False)
# - Case 746251 — Kevin J. Gilday v. Mecosta County
#     · SKIP (already summarized; force=False)
# - Case 2400182 — Adams v. Rochester General Hospital
#     · SKIP (already summarized; force=False)
# - Case 2490986 — Warmsley v. New York City Transit Authority
#     · SKIP (already summarized; force=False)
# - Case 8408373 — Allen v. Pacific Bell
#     · SKIP (already summarized; force=False)
# - Case 784117 — No. 02-55721
#     · SKIP (already summarized; force=False)
# - Case 4309231 — Alaska State Commission for Human Rights v. Anderson
#     · SKIP (already summarized; force=False)
# - Case 4257748 — Schack v. Schack
#     · SKIP (already summarized; force=False)
# - Case 4119191 — Burnett v. Government Employee Insurance Company
#     · SKIP (already summarized; force=False)
# - Case 2924446 — City of Hooper Bay v. Bunyan
#     · SKIP (already summarized; force=False)
# - Case 2674728 — Pralle v. Milwicz
#     · SKIP (already summarized; force=False)
# - Case 2673161 — Pralle v. Milwicz
#     · SKIP (already summarized; force=False)
# - Case 2461960 — Monzulla v. Voorhees Concrete Cutting
#     · SKIP (already summarized; force=False)
# - Case 2422677 — Helpin v. Trustees of the University of Pennsylvania
#     · SKIP (already summarized; force=False)
# - Case 2512220 — Sowinski v. Walker
#     · SKIP (already summarized; force=False)
# - Case 2622088 — State Farm Mutual Automobile Insurance Co. v. Dowdy
#     · SKIP (already summarized; force=False)
# - Case 2600380 — Alaskans for a Common Language, Inc. v. Kritz
#     · SKIP (already summarized; force=False)
# - Case 2517869 — State v. Pease
#     · SKIP (already summarized; force=False)
# - Case 852590 — Smith v. Toney
#     · SKIP (already summarized; force=False)
# - Case 1052718 — Marc Eskin v. Alice B. Bartee
#     · SKIP (already summarized; force=False)
# - Case 2639607 — Colbert v. Moomba Sports, Inc.
#     · SKIP (already summarized; force=False)
# - Case 2510359 — Alex v. State
#     · SKIP (already summarized; force=False)
# - Case 2576177 — Cummins, Inc. v. Nelson
#     · SKIP (already summarized; force=False)
# - Case 2533739 — State Farm Mutual Automobile Insurance Co. v. Dowdy
#     · SKIP (already summarized; force=False)
# - Case 2629723 — Reich v. Cominco Alaska, Inc.
#     · SKIP (already summarized; force=False)
# - Case 2519679 — Hammock v. State
#     · SKIP (already summarized; force=False)
# - Case 4295856 — Charles Edward Ctr. v. Sec'y, Dep't of Homeland Sec., Customs & Border Prot. Agency
#     · SKIP (already summarized; force=False)
# - Case 4194851 — Paul Boyle v. City of Pell City
#     · SKIP (already summarized; force=False)
#
# Batch after internal id 179: 60 case(s)
# - Case 3192126 — Delores Frazier-White v. David Gee
#     · SKIP (already summarized; force=False)
# - Case 2151759 — Verna v. Public Health Trust of Miami-Dade County
#     · SKIP (already summarized; force=False)
# - Case 9941701 — Jennifer Akridge v. Alfa Mutual Insurance Company
#     · SKIP (already summarized; force=False)
# - Case 4454477 — Tesone v. Empire Marketing Strategies
#     · SKIP (already summarized; force=False)
# - Case 2475759 — Vazquez v. MUNICIPALITY OF JUNCOS
#     · SKIP (already summarized; force=False)
# - Case 2455339 — Garavito v. City of Tampa
#     · SKIP (already summarized; force=False)
# - Case 1686267 — Moore v. Hillsborough County Board of County Commissioners
#     · SKIP (already summarized; force=False)
# - Case 4349223 — Sinapi v. RI Board of Bar Examiners
#     · SKIP (already summarized; force=False)
# - Case 4019153 — Sabo v. United States
#     · SKIP (already summarized; force=False)
# - Case 7233328 — Lloyd v. Birkman
#     · SKIP (already summarized; force=False)
# - Case 8714075 — Agoh v. Hyatt Corp.
#     · SKIP (already summarized; force=False)
# - Case 2385735 — Williamson v. American National Insurance Company
#     · SKIP (already summarized; force=False)
# - Case 2174894 — Nolan v. ARKEMA, INC.
#     · SKIP (already summarized; force=False)
# - Case 3140062 — State Bank of Waterloo v. City of Waterloo
#     · SKIP (already summarized; force=False)
# - Case 2047002 — Village of Riverdale v. Allied Waste Transportation, Inc.
#     · SKIP (already summarized; force=False)
# - Case 2115215 — County of Lake v. Fox Waterway Agency
#     · SKIP (already summarized; force=False)
# - Case 2034700 — City of Joliet v. Snyder
#     · SKIP (already summarized; force=False)
# - Case 3139754 — County of Cook v. Village of Rosemont
#     · SKIP (already summarized; force=False)
# - Case 2065753 — Lake County Public Building Commission v. City of Waukegan
#     · SKIP (already summarized; force=False)
# - Case 1992984 — City of Evanston v. Regional Transportation Authority
#     · SKIP (already summarized; force=False)
# - Case 2091201 — Village of Oak Brook v. County of Du Page
#     · SKIP (already summarized; force=False)
# - Case 2080501 — Sadat v. American Motors Corp.
#     · SKIP (already summarized; force=False)
# - Case 2222634 — Clement v. O'MALLEY
#     · SKIP (already summarized; force=False)
# - Case 2061898 — People v. Keeven
#     · SKIP (already summarized; force=False)
# - Case 4105275 — United States Equal Employment Opportunity Commission v. St. Joseph's Hospital, Inc.
#     · SKIP (already summarized; force=False)
# - Case 2524376 — Hare v. Potter
#     · SKIP (already summarized; force=False)
# - Case 2521420 — Webster Greenthumb Co. v. Fulton County, Ga.
#     · SKIP (already summarized; force=False)
# - Case 6343078 — Montgomery v. District of Columbia
#     · SKIP (already summarized; force=False)
# - Case 223577 — Román-Oliveras v. Puerto Rico Electric Power Authority
#     · SKIP (already summarized; force=False)
# - Case 2185841 — Paulone v. City of Frederick
#     · SKIP (already summarized; force=False)
# - Case 4227888 — Robert Wellman, Jr. v. Butler Area School District
#     · SKIP (already summarized; force=False)
# - Case 3012250 — Smith v. Mensinger
#     · SKIP (already summarized; force=False)
# - Case 778006 — Smith v. Mensinger
#     · SKIP (already summarized; force=False)
# - Case 7013984 — Lovell v. Chandler
#     · SKIP (already summarized; force=False)
# - Case 779154 — RICHARD K. LOVELL v. SUSAN CHANDLER, IN HER OFFICIAL CAPACITY AS THE DIRECTOR OF THE DEPAR
#     · SKIP (already summarized; force=False)
# - Case 6107721 — McClain v. Kissler
#     · SKIP (already summarized; force=False)
# - Case 5665415 — Heritage Residential Care, Inc. v. Division of Labor Standards Enforcement
#     · SKIP (already summarized; force=False)
# - Case 2255370 — Gutierrez v. G & M OIL COMPANY, INC.
#     · SKIP (already summarized; force=False)
# - Case 2255853 — Jhaveri v. Teitelbaum
#     · SKIP (already summarized; force=False)
# - Case 2568337 — Luttrell v. Runyon
#     · SKIP (already summarized; force=False)
# - Case 1657347 — Persons v. Runyon
#     · SKIP (already summarized; force=False)
# - Case 717553 — Kenneth C. Antol v. William J. Perry, Secretary Department of Defense, (Defense Logistics
#     · SKIP (already summarized; force=False)
# - Case 787765 — Federal Trade Commission v. Garvey
#     · SKIP (already summarized; force=False)
# - Case 8413465 — Rodriguez v. Village Green Realty, Inc.
#     · SKIP (already summarized; force=False)
# - Case 2655295 — Estate of Lance v. Lewisville Independent School District
#     · SKIP (already summarized; force=False)
# - Case 9386374 — Buon v. Spindler
#     · SKIP (already summarized; force=False)
# - Case 4384521 — Natalie Slaughter v. Des Moines University College of Osteopathic Medicine
#     · SKIP (already summarized; force=False)
# - Case 7246018 — Smith v. N. Shore-Long Island Jewish Health Sys.
#     · SKIP (already summarized; force=False)
# - Case 7242452 — Fox v. Costco Wholesale Corp.
#     · SKIP (already summarized; force=False)
# - Case 7242265 — Granica v. Town of Hamburg
#     · SKIP (already summarized; force=False)
# - Case 7241917 — Dugger v. Stephen F. Austin State University
#     · SKIP (already summarized; force=False)
# - Case 7239615 — Adduci v. Yankee Gas Services Co.
#     · SKIP (already summarized; force=False)
# - Case 4675588 — Unrein v. PHC-Fort Morgan
#     · SKIP (already summarized; force=False)
# - Case 3207173 — Peninsula Regional Medical Center v. Adkins
#     · SKIP (already summarized; force=False)
# - Case 3207088 — Adair v. City of Muskogee
#     · SKIP (already summarized; force=False)
# - Case 2792880 — Equal Employment Opportunity Commission v. Ford Motor Co.
#     · SKIP (already summarized; force=False)
# - Case 2780464 — Hawkins v. Schwan's Home Service, Inc.
#     · SKIP (already summarized; force=False)
# - Case 807663 — Robert v. Board of County Commissioners
#     · SKIP (already summarized; force=False)
# - Case 803980 — Equal Employment Opportunity Commission v. Picture People, Inc.
#     · SKIP (already summarized; force=False)
# - Case 615207 — Colon-Fontanez v. Municipality of San Juan
#     · SKIP (already summarized; force=False)
#
# Batch after internal id 239: 60 case(s)
# - Case 172638 — Hennagir v. Utah Department of Corrections
#     · SKIP (already summarized; force=False)
# - Case 1266139 — Hennagir v. UTAH DEPT. OF CORRECTIONS
#     · SKIP (already summarized; force=False)
# - Case 2520866 — Key v. Grayson
#     · SKIP (already summarized; force=False)
# - Case 9849187 — Reno v. Baird
#     · SKIP (already summarized; force=False)
# - Case 9975443 — Cory v. Stewart
#     · SKIP (already summarized; force=False)
# - Case 2567469 — Brettler v. Purdue University
#     · SKIP (already summarized; force=False)
# - Case 158744 — Davoll v. Webb
#     · SKIP (already summarized; force=False)
# - Case 2491278 — Patterson v. Illinois, Department of Corrections
#     · SKIP (already summarized; force=False)
# - Case 2338276 — Alberti v. City & County of San Francisco Sheriff's Department
#     · SKIP (already summarized; force=False)
# - Case 750163 — Mark Bledsoe v. Palm Beach County Soil and Water Conservation District, Board of County Co
#     · SKIP (already summarized; force=False)
# - Case 72566 — Bledsoe v. Palm Beach County Soil
#     · SKIP (already summarized; force=False)
# - Case 72565 — Bledsoe v. Palm Beach County Soil
#     · SKIP (already summarized; force=False)
# - Case 1989568 — Zimmerman v. State of Oregon Department of Justice
#     · SKIP (already summarized; force=False)
# - Case 9556725 — Tafolla v. Heilig
#     · SKIP (already summarized; force=False)
# - Case 7797140 — Dansie v. Union Pacific Railroad
#     · SKIP (already summarized; force=False)
# - Case 2517591 — Hutson v. COVIDIEN, INC.
#     · SKIP (already summarized; force=False)
# - Case 2313929 — Coleman v. Blue Cross Blue Shield of Kan.
#     · SKIP (already summarized; force=False)
# - Case 2334590 — Chavez v. Qwest, Inc.
#     · SKIP (already summarized; force=False)
# - Case 2371995 — Ottenberg's Bakers, Inc. v. District of Columbia Commission on Human Rights
#     · SKIP (already summarized; force=False)
# - Case 2427422 — Gomez v. Laidlaw Transit, Inc.
#     · SKIP (already summarized; force=False)
# - Case 2473839 — Equal Employment Opportunity Commission v. Hibbing Taconite Co.
#     · SKIP (already summarized; force=False)
# - Case 2436149 — Galvan v. City of Bryan, Tex.
#     · SKIP (already summarized; force=False)
# - Case 1528293 — Rivera v. Heyman
#     · SKIP (already summarized; force=False)
# - Case 736905 — Sidney Abbott v. Randon Bragdon, D.M.D.
#     · SKIP (already summarized; force=False)
# - Case 1872619 — Geuss v. Pfizer, Inc.
#     · SKIP (already summarized; force=False)
# - Case 7246706 — U.S. Underwriters Ins. Co. v. Itg Dev. Grp., LLC
#     · SKIP (already summarized; force=False)
# - Case 7246784 — Siuzdak v. Sessions
#     · SKIP (already summarized; force=False)
# - Case 10830082 — Tudor v. Whitehall Central School District
#     · SKIP (already summarized; force=False)
# - Case 10732244 — Yerdon v. Poitras
#     · SKIP (already summarized; force=False)
# - Case 9987913 — Woods v. Centro of Oneida, Inc.
#     · SKIP (already summarized; force=False)
# - Case 7243544 — Hulett v. City of Syracuse
#     · SKIP (already summarized; force=False)
# - Case 7226402 — Van Velzor v. City of Burleson
#     · SKIP (already summarized; force=False)
# - Case 8712451 — Brooklyn Center for Independence of the Disabled v. Bloomberg
#     · SKIP (already summarized; force=False)
# - Case 816224 — Mary Jo C. v. New York State and Local Retirement System et ano.
#     · SKIP (already summarized; force=False)
# - Case 2517364 — Hart v. Ridge Tool Co.
#     · SKIP (already summarized; force=False)
# - Case 10502330 — Ghulam Ali v. Michael Regan
#     · SKIP (already summarized; force=False)
# - Case 7086108 — Garcia v. Dep't of Hous. & Cmty. Dev.
#     · SKIP (already summarized; force=False)
# - Case 7246343 — Marshall v. N.Y.S. Pub. High Sch. Athletic Ass'n, Inc.
#     · SKIP (already summarized; force=False)
# - Case 8414144 — Wright v. New York State Department of Corrections
#     · SKIP (already summarized; force=False)
# - Case 4020118 — Wright v. New York State Dep't of Corr. & Cmty. Supervision
#     · SKIP (already summarized; force=False)
# - Case 11132954 — Jay Pemberton v. Bell's Brewery, Inc.
#     · SKIP (already summarized; force=False)
# - Case 9896355 — Mia Bennett v. Hurley Medical Center
#     · SKIP (already summarized; force=False)
# - Case 748781 — Helen R. Bloom v. Bexar County, Texas
#     · SKIP (already summarized; force=False)
# - Case 2346944 — Innovative Health Systems, Inc. v. City of White Plains
#     · SKIP (already summarized; force=False)
# - Case 2356371 — Irby v. Sumnicht
#     · SKIP (already summarized; force=False)
# - Case 1668691 — Riley v. Vilsack
#     · SKIP (already summarized; force=False)
# - Case 2396034 — Clayborne v. Potter
#     · SKIP (already summarized; force=False)
# - Case 2995874 — Mays, Maxcene v. Principi, Anthony J.
#     · SKIP (already summarized; force=False)
# - Case 778931 — Maxcene Mays v. Anthony J. Principi, Secretary of Veterans Affairs
#     · SKIP (already summarized; force=False)
# - Case 118500 — US Airways, Inc. v. Barnett
#     · SKIP (already summarized; force=False)
# - Case 2429616 — Felix v. New York City Transit Authority
#     · SKIP (already summarized; force=False)
# - Case 8712418 — Massachusetts Institute of Technology v. Research, Development & Technical Employees Union
#     · SKIP (already summarized; force=False)
# - Case 203052 — Curran v. Cousins
#     · SKIP (already summarized; force=False)
# - Case 2573665 — Ragan v. JEFFBOAT, LLC
#     · SKIP (already summarized; force=False)
# - Case 1760726 — Burton v. Commonwealth
#     · SKIP (already summarized; force=False)
# - Case 1396139 — Bloxam v. Berg
#     · SKIP (already summarized; force=False)
# - Case 1692282 — Brown v. Commonwealth
#     · SKIP (already summarized; force=False)
# - Case 2100511 — Bowling v. Lexington-Fayette Urban County Government
#     · SKIP (already summarized; force=False)
# - Case 1874198 — Ernst v. Commonwealth
#     · SKIP (already summarized; force=False)
# - Case 1353107 — Davis v. Commonwealth
#     · SKIP (already summarized; force=False)
#
# Batch after internal id 299: 60 case(s)
# - Case 2276112 — Sherroan v. Commonwealth
#     · SKIP (already summarized; force=False)
# - Case 1440288 — Brooks v. Lexington-Fayette Urban County Housing Authority
#     · SKIP (already summarized; force=False)
# - Case 2343191 — St. Clair v. Commonwealth
#     · SKIP (already summarized; force=False)
# - Case 1652120 — Thomas v. Greenview Hospital, Inc.
#     · SKIP (already summarized; force=False)
# - Case 11063458 — Patricia Y. Mayers v. United Independent School District
#     · SKIP (already summarized; force=False)
# - Case 11052367 — Strife v. AISD
#     · SKIP (already summarized; force=False)
# - Case 10499542 — Barron v. United States
#     · SKIP (already summarized; force=False)
# - Case 9453044 — Mueck v. La Grange Acquisitions
#     · SKIP (already summarized; force=False)
# - Case 9410601 — Mueck v. La Grange Acquisitions
#     · SKIP (already summarized; force=False)
# - Case 9402882 — Donna Harmon v. Texas Southern University
#     · SKIP (already summarized; force=False)
# - Case 9396117 — Perry Hopman v. Union Pacific Railroad
#     · SKIP (already summarized; force=False)
# - Case 9888021 — Michael Nall v. BNSF Railway Company
#     · SKIP (already summarized; force=False)
# - Case 6108206 — Diamond Offshore Servs. Ltd. v. Williams
#     · SKIP (already summarized; force=False)
# - Case 4150999 — United States v. Monsalvatge
#     · SKIP (already summarized; force=False)
# - Case 891505 — Estate of Lajeuenesse v. UNM Bd. of Regents
#     · SKIP (already summarized; force=False)
# - Case 1656419 — Eckman v. Moore
#     · SKIP (already summarized; force=False)
# - Case 864673 — Walter W. Eckman v. Linda Michelle Moore
#     · SKIP (already summarized; force=False)
# - Case 864363 — Walter W. Eckman v. Linda Michelle Moore
#     · SKIP (already summarized; force=False)
# - Case 2414664 — Colon Ex Rel. Molina v. Bic USA, Inc.
#     · SKIP (already summarized; force=False)
# - Case 8729288 — BD v. DeBuono
#     · SKIP (already summarized; force=False)
# - Case 1075597 — Sears v. Metro Nashville Airport
#     · SKIP (already summarized; force=False)
# - Case 726657 — Peggy Neece v. Internal Revenue Service
#     · SKIP (already summarized; force=False)
# - Case 153907 — Neece v. Internal Revenue Service
#     · SKIP (already summarized; force=False)
# - Case 710103 — Medite Of New Mexico, Inc., Petitioner, v. National Labor Relations Board
#     · SKIP (already summarized; force=False)
# - Case 2344024 — Schiavo v. Owens-Corning Fiberglas
#     · SKIP (already summarized; force=False)
# - Case 604927 — Calandro v. First Community Bank And Trust Company Of Lone Grove
#     · SKIP (already summarized; force=False)
# - Case 595275 — 37 Fed. R. Evid. Serv. 225, prod.liab.rep. (Cch) P 13,373 Four Corners Helicopters, Inc.,
#     · SKIP (already summarized; force=False)
# - Case 566776 — Richard Paul DENISON, Plaintiff-Appellee, v. SWACO GEOLOGRAPH COMPANY, Defendant-Appellant
#     · SKIP (already summarized; force=False)
# - Case 566775 — David Polys and Marcia Polys v. Trans-Colorado Airlines, Inc.
#     · SKIP (already summarized; force=False)
# - Case 557435 — 32 Fed. R. Evid. Serv. 513, prod.liab.rep.(cch)p 12,760 Danny Quinton, Doing Business as Q
#     · SKIP (already summarized; force=False)
# - Case 556628 — Mcewen v. City Of Norman
#     · SKIP (already summarized; force=False)
# - Case 11163581 — Cote v. NH College, et al.
#     · SKIP (already summarized; force=False)
# - Case 11107735 — Jordan Watkins v. Brij Mohan
#     · SKIP (already summarized; force=False)
# - Case 11068416 — Thomas Anderson v. UAL
#     · SKIP (already summarized; force=False)
# - Case 11067791 — Thomas Anderson v. UAL
#     · SKIP (already summarized; force=False)
# - Case 11064112 — Gadway v. Univ. of Toledo
#     · SKIP (already summarized; force=False)
# - Case 11038010 — Solar Energy Indus. Ass'n. v. United States
#     · SKIP (already summarized; force=False)
# - Case 11095591 — Wanda St. Andrie v. Singing River Health System
#     · SKIP (already summarized; force=False)
# - Case 7237355 — Wilder v. United States Department of Veterans Affairs
#     · SKIP (already summarized; force=False)
# - Case 8679473 — Farmer v. D & O Contractors, Inc.
#     · SKIP (already summarized; force=False)
# - Case 8498999 — O'Cheskey v. CitiGroup Global Markets, Inc. (In re American Housing Foundation)
#     · SKIP (already summarized; force=False)
# - Case 7232125 — Adkins v. Atria Senior Living, Inc.
#     · SKIP (already summarized; force=False)
# - Case 7231560 — Simmons v. Methodist Hospitals
#     · SKIP (already summarized; force=False)
# - Case 8497932 — U.S. Bank, N.A. v. Smith (In re Smith)
#     · SKIP (already summarized; force=False)
# - Case 7236570 — Garcia v. Penske Logistics, LLC
#     · SKIP (already summarized; force=False)
# - Case 8714694 — Stewart Information Services Corp. v. Great American Insurance
#     · SKIP (already summarized; force=False)
# - Case 617865 — Us Bank National Association v. Smf Energy Corporation
#     · SKIP (already summarized; force=False)
# - Case 617053 — Farris v. Shinseki
#     · SKIP (already summarized; force=False)
# - Case 2468183 — McClendon v. Bronx County District Attorneys Office
#     · SKIP (already summarized; force=False)
# - Case 2475063 — Farris v. SHINSEKI
#     · SKIP (already summarized; force=False)
# - Case 2542119 — Barbosa v. Continuum Health Partners, Inc.
#     · SKIP (already summarized; force=False)
# - Case 1439565 — Flight v. Gloeckler
#     · SKIP (already summarized; force=False)
# - Case 6330219 — Jeanne King v. Steward Trumbull Mem. Hosp.
#     · SKIP (already summarized; force=False)
# - Case 4510923 — Michael Fisher v. Nissan N.A., Inc.
#     · SKIP (already summarized; force=False)
# - Case 7240600 — Equal Employment Opportunity Commission v. Methodist Hospitals of Dallas
#     · SKIP (already summarized; force=False)
# - Case 1100931 — Epica v. Swiss Bank Corp.(overseas) Sa
#     · SKIP (already summarized; force=False)
# - Case 4414370 — Brown v. Dist. of Columbia
#     · SKIP (already summarized; force=False)
# - Case 2924443 — Pierce v. District of Columbia
#     · SKIP (already summarized; force=False)
# - Case 815354 — Michael Argenyi v. Creighton University
#     · SKIP (already summarized; force=False)
# - Case 7109673 — Brock v. Lucky Stores, Inc.
#     · SKIP (already summarized; force=False)
#
# Batch after internal id 359: 60 case(s)
# - Case 1834428 — Boelman v. Manson State Bank
#     · SKIP (already summarized; force=False)
# - Case 2528823 — In Re Estate of Matthews
#     · SKIP (already summarized; force=False)
# - Case 2441960 — Harding v. CIANBRO CORPORATION
#     · SKIP (already summarized; force=False)
# - Case 23944 — Flowers v. So Regn Physn Svcs
#     · SKIP (already summarized; force=False)
# - Case 772924 — Sandra Spragis Flowers v. Southern Regional Physician Services Inc.
#     · SKIP (already summarized; force=False)
# - Case 73689 — Bruce v. City of Gainesville, GA
#     · SKIP (already summarized; force=False)
# - Case 73688 — Bruce v. City of Gainesville, GA
#     · SKIP (already summarized; force=False)
# - Case 156111 — Smith v. Midland Brake, Inc.
#     · SKIP (already summarized; force=False)
# - Case 1401810 — Andress v. National Pizza Co. Intern., Inc.
#     · SKIP (already summarized; force=False)
# - Case 1535490 — In Re Leslie Fay Companies, Inc.
#     · SKIP (already summarized; force=False)
# - Case 1581667 — Guckenberger v. Boston University
#     · SKIP (already summarized; force=False)
# - Case 1446759 — Soileau v. Guilford of Maine, Inc.
#     · SKIP (already summarized; force=False)
# - Case 2477324 — Leavitt v. SW & B Construction Co.
#     · SKIP (already summarized; force=False)
# - Case 4533330 — Lopez-Lopez v. The Robinson School
#     · SKIP (already summarized; force=False)
# - Case 8713160 — Doherty v. Donahoe
#     · SKIP (already summarized; force=False)
# - Case 8712419 — Akerson v. Pritzker
#     · SKIP (already summarized; force=False)
# - Case 11109111 — Kathryn Downey v. Earl Johnson and Massachusetts Department of State Police
#     · SKIP (already summarized; force=False)
# - Case 8692803 — Palmquist v. Shinseki
#     · SKIP (already summarized; force=False)
# - Case 2438907 — Lakshman v. University of Maine System
#     · SKIP (already summarized; force=False)
# - Case 200760 — Acevedo-Garcia v. Vera-Monroig
#     · SKIP (already summarized; force=False)
# - Case 200604 — Acevedo-Garcia v. Vera-Monroig
#     · SKIP (already summarized; force=False)
# - Case 9940794 — Taquila Monroe v. Board of Regents of the University System of Georgia
#     · SKIP (already summarized; force=False)
# - Case 2774268 — Sakari Jarvela v. Crete Carrier Corporation
#     · SKIP (already summarized; force=False)
# - Case 2679055 — Sakari Jarvela v. Crete Carrier Corporation
#     · SKIP (already summarized; force=False)
# - Case 1679363 — Mendiola v. Vision Hospitality
#     · SKIP (already summarized; force=False)
# - Case 2445461 — Stockton v. a World of Hope Childcare Learning Center
#     · SKIP (already summarized; force=False)
# - Case 2490474 — Price v. Facility Management Group, Inc.
#     · SKIP (already summarized; force=False)
# - Case 2518179 — Musarra v. Vineyards Development Corp.
#     · SKIP (already summarized; force=False)
# - Case 10516940 — Rae v. Woburn Public Schools
#     · SKIP (already summarized; force=False)
# - Case 2430478 — Dorsett v. Sandoz, Inc.
#     · SKIP (already summarized; force=False)
# - Case 2539976 — Skinner v. Salem School District
#     · SKIP (already summarized; force=False)
# - Case 777650 — Valjeanne Currie v. Group Insurance Commission
#     · SKIP (already summarized; force=False)
# - Case 199901 — Currie v. Group Insurance Co
#     · SKIP (already summarized; force=False)
# - Case 11163303 — Skinner v. Salem School District
#     · SKIP (already summarized; force=False)
# - Case 8746651 — Dehoyos v. Allstate Corp.
#     · SKIP (already summarized; force=False)
# - Case 8731702 — Macarz v. Transworld Systems, Inc.
#     · SKIP (already summarized; force=False)
# - Case 7246301 — Gonzalez v. Cnty. of Merced
#     · SKIP (already summarized; force=False)
# - Case 11099971 — Curwen v. District of Columbia International School
#     · SKIP (already summarized; force=False)
# - Case 10558545 — EEOC v. Wal-Mart Stores East, L.P.
#     · SKIP (already summarized; force=False)
# - Case 10547452 — EEOC v. Wal-Mart Stores East, L.P.
#     · SKIP (already summarized; force=False)
# - Case 4583916 — Brad Sandefur v. Thomas Dart
#     · SKIP (already summarized; force=False)
# - Case 4583814 — Brad Sandefur v. Thomas Dart
#     · SKIP (already summarized; force=False)
# - Case 4583789 — Brad Sandefur v. Thomas Dart
#     · SKIP (already summarized; force=False)
# - Case 4565422 — Mark Mlsna v. Union Pacific Railroad Compan
#     · SKIP (already summarized; force=False)
# - Case 4565392 — Mark Mlsna v. Union Pacific Railroad Compan
#     · SKIP (already summarized; force=False)
# - Case 4404705 — Michael Booth v. Nissan N. Am., Inc.
#     · SKIP (already summarized; force=False)
# - Case 4166342 — Sherlyn Brown v. Milwaukee Board of School Dire
#     · SKIP (already summarized; force=False)
# - Case 4154171 — Rittelmeyer v. Univ. of N. Carolina at Chapel Hill
#     · SKIP (already summarized; force=False)
# - Case 7242440 — Boadi v. Center for Human Development, Inc.
#     · SKIP (already summarized; force=False)
# - Case 5287048 — Datar v. National Oilwell Varco, L.P.
#     · SKIP (already summarized; force=False)
# - Case 7241598 — Ravel v. Hewlett-Packard Enterprise, Inc.
#     · SKIP (already summarized; force=False)
# - Case 4034583 — Eymarde Lawler v. Peoria School District No. 150
#     · SKIP (already summarized; force=False)
# - Case 4034085 — Rozsavolgyi v. City of Aurora
#     · SKIP (already summarized; force=False)
# - Case 2485868 — Acevedo v. City of Philadelphia
#     · SKIP (already summarized; force=False)
# - Case 3897673 — Opinion No.
#     · SKIP (already summarized; force=False)
# - Case 1530903 — Martin v. PGA Tour, Inc.
#     · SKIP (already summarized; force=False)
# - Case 1694340 — The Florida Bar v. Clement
#     · SKIP (already summarized; force=False)
# - Case 1388627 — Champ v. Baltimore County
#     · SKIP (already summarized; force=False)
# - Case 2573611 — Equal Employment Opportunity Commission v. United Parcel Services, Inc.
#     · SKIP (already summarized; force=False)
# - Case 757053 — Kelvin Washington v. Hca Health Services of Texas, Inc., Doing Business as Hca Spring Bran
#     · SKIP (already summarized; force=False)
#
# Batch after internal id 419: 60 case(s)
# - Case 1710293 — Chmielewski v. Xermac, Inc
#     · SKIP (already summarized; force=False)
# - Case 155597 — Sutton v. United Air Lines, Inc.
#     · SKIP (already summarized; force=False)
# - Case 1971255 — Sicard v. City of Sioux City
#     · SKIP (already summarized; force=False)
# - Case 2097124 — Murphy v. United Parcel Service, Inc.
#     · SKIP (already summarized; force=False)
# - Case 2131399 — Ferguson v. Western Carolina Regional Sewer Authority
#     · SKIP (already summarized; force=False)
# - Case 1670980 — Christopher v. Laidlaw Transit Inc.
#     · SKIP (already summarized; force=False)
# - Case 808268 — Elwell v. Oklahoma, Ex Rel. Board of Regents
#     · SKIP (already summarized; force=False)
# - Case 2528323 — Sworn v. Western New York Children's Psychiatric Center
#     · SKIP (already summarized; force=False)
# - Case 2576016 — Parkinson v. Goord
#     · SKIP (already summarized; force=False)
# - Case 1989577 — Raines v. State of Florida
#     · SKIP (already summarized; force=False)
# - Case 1381501 — Fennell v. Simmons
#     · SKIP (already summarized; force=False)
# - Case 1529911 — McDonald v. Com. of Mass.
#     · SKIP (already summarized; force=False)
# - Case 6554433 — Joseph Allen, IV v. Brown Advisory, LLC
#     · SKIP (already summarized; force=False)
# - Case 4031580 — Marylee Arrigo v. Link Stop, Inc.
#     · SKIP (already summarized; force=False)
# - Case 9365563 — Brigham v. Frontier Airlines
#     · SKIP (already summarized; force=False)
# - Case 2822033 — Adkins v. Peninsula Regional Medical Center
#     · SKIP (already summarized; force=False)
# - Case 613272 — Helm v. Kansas
#     · SKIP (already summarized; force=False)
# - Case 10848883 — Double Eagle Alloys v. Hooper
#     · SKIP (already summarized; force=False)
# - Case 10804682 — Alcala v. Ortega
#     · SKIP (already summarized; force=False)
# - Case 10609951 — In re: Overstock Securities
#     · SKIP (already summarized; force=False)
# - Case 10467531 — Grange Insurance Association v. Reson Woods
#     · SKIP (already summarized; force=False)
# - Case 9963884 — Johnson v. City of Cheyenne
#     · SKIP (already summarized; force=False)
# - Case 9912570 — Lindsay v. Denver Public Schools
#     · SKIP (already summarized; force=False)
# - Case 6335030 — SEC v. GenAudio Inc.
#     · SKIP (already summarized; force=False)
# - Case 4563151 — Savignac v. Jones Day
#     · SKIP (already summarized; force=False)
# - Case 4419355 — Eaton v. Pacheco
#     · SKIP (already summarized; force=False)
# - Case 4262621 — Hall v. Conoco Inc.
#     · SKIP (already summarized; force=False)
# - Case 4174486 — Pioneer Centres Holding Co. Employee Stock Ownership Plan & Trust v. Alerus Financial, N.A
#     · SKIP (already summarized; force=False)
# - Case 4014574 — Lebahn v. National Farmers Union Uniform Pension Plan
#     · SKIP (already summarized; force=False)
# - Case 8678159 — Jordan v. Dillion Companies
#     · SKIP (already summarized; force=False)
# - Case 2810842 — Cook v. Rockwell International Corp.
#     · SKIP (already summarized; force=False)
# - Case 7230929 — Chacon v. Brigham & Women's Hospital
#     · SKIP (already summarized; force=False)
# - Case 2784715 — Ellis v. J.R.'s Country Stores, Inc.
#     · SKIP (already summarized; force=False)
# - Case 2754507 — Ward v. Jewell
#     · SKIP (already summarized; force=False)
# - Case 2685760 — Dalpiaz v. Carbon County, Utah
#     · SKIP (already summarized; force=False)
# - Case 6985844 — Botosan v. Paul McNally Realty
#     · SKIP (already summarized; force=False)
# - Case 769197 — Botosan v. Mcnally Realty
#     · SKIP (already summarized; force=False)
# - Case 11162435 — R. Lacey Colligan v. Mary Hitchcock Memorial Hospital, et al.
#     · SKIP (already summarized; force=False)
# - Case 2568985 — Hill v. Shell Oil Co.
#     · SKIP (already summarized; force=False)
# - Case 2311759 — Botosan v. Fitzhugh
#     · SKIP (already summarized; force=False)
# - Case 11160393 — Tanner v. Wal-Mart
#     · SKIP (already summarized; force=False)
# - Case 627358 — Charles E. Little, Jr. v. Federal Bureau of Investigation Joseph v. Corless John Doe Willi
#     · SKIP (already summarized; force=False)
# - Case 4315243 — Kaleena Bullington v. Bedford Cty., Tenn.
#     · SKIP (already summarized; force=False)
# - Case 2706857 — Virginia Homes, Ltd. v. Goldman
#     · SKIP (already summarized; force=False)
# - Case 628999 — Robert T. McGregor v. Louisiana State University Board of Supervisors
#     · SKIP (already summarized; force=False)
# - Case 537035 — Mary Ann Carter RENNIE, Plaintiff-Appellant, v. H. Lawrence GARRETT III, Secretary of the
#     · SKIP (already summarized; force=False)
# - Case 1891049 — Shrout v. Black Clawson Co.
#     · SKIP (already summarized; force=False)
# - Case 499095 — James R. Harris v. William E. Brock, Secretary of Labor, United States Department of Labor
#     · SKIP (already summarized; force=False)
# - Case 2361577 — Lowery v. WMC-TV
#     · SKIP (already summarized; force=False)
# - Case 1888890 — Janikowski v. Bendix Co.
#     · SKIP (already summarized; force=False)
# - Case 446821 — Gardner v. Morris
#     · SKIP (already summarized; force=False)
# - Case 2126677 — Fussell v. Georgia Ports Authority
#     · SKIP (already summarized; force=False)
# - Case 161862 — Goodwin v. General Motors Corp.
#     · SKIP (already summarized; force=False)
# - Case 160386 — Amro v. Boeing Company
#     · SKIP (already summarized; force=False)
# - Case 214280 — Coates v. Powell
# ...
#     · wrote opinion_summary
# - Case 391150 — Richard Davis v. Robert H. Fendler
#     · wrote opinion_summary
# - Case 9256950 — Davis v. Florida Power & Light Co.
#     · wrote opinion_summary
# - Case 9816747 — Davis v. Francis Howell School District
#     · wrote opinion_summary
# - Case 4345705 — Cornwell v. Microsoft Corp.
#     · wrote opinion_summary
# - Case 2502199 — Mediatek, Inc. v. Sanyo Electric Co. Ltd.
#     · wrote opinion_summary
# - Case 5490870 — Flo & Eddie, Inc. v. Sirius XM Radio, Inc.
#     · wrote opinion_summary
# - Case 110104 — Southeastern Community College v. Davis
#     · wrote opinion_summary
# - Case 2967010 — Davis v. Virginia Commonwealth University
#     · wrote opinion_summary
# - Case 7252687 — Vargas v. Viacom International, Inc.
#     · wrote opinion_summary
# - Case 445265 — James M. Day v. Wayne County Board of Auditors, Wayne County Civil Service Commission, Cou
#     · wrote opinion_summary
# - Case 6936021 — DeBoer v. Mellon Mortgage Co.
#     · wrote opinion_summary
# - Case 9163729 — DeBord v. Board of Education of the Ferguson-Florissant School District
#     · wrote opinion_summary
# - Case 9297855 — People v. DeCamp
#     · wrote opinion_summary
# - Case 203989 — DeCaro v. Hasbro, Inc.
#     · wrote opinion_summary
# - Case 6966415 — DePaoli v. Abbott Laboratories
#     · wrote opinion_summary
# - Case 2960604 — Robert DeRosa v. National Envelope Corporation
#     · wrote opinion_summary
# - Case 4668175 — Int'l Techs. Mktg., Inc. v. Verint Sys., Ltd.
#     · wrote opinion_summary
# - Case 284387 — Moses Arthur Dean and Willie J. Matthews v. Mr. And Mrs. Donald Ashling
#     · wrote opinion_summary
# - Case 4855679 — Rodriguez v. Thompson
#     · wrote opinion_summary
# - Case 9491114 — Stacy L. Deane v. Pocono Medical Center
#     · wrote opinion_summary
# - Case 4067659 — Elness Swenson Graham Architects, Inc.// RLJ II-C Austin Air, LP RLJ II-C Austin Air Lesse
#     · opinion too long → split into 5 parts (<= 30924 tokens each)
#       - finished part 1/5
#       - finished part 2/5
#       - finished part 3/5
#       - finished part 4/5
#       - finished part 5/5
#     · wrote opinion_summary
# - Case 1964682 — Debra P. v. Turlington
#     · wrote opinion_summary
# - Case 1639116 — Decker v. University of Houston
#     · wrote opinion_summary
# - Case 8709422 — Dees v. Austin Travis County Mental Health & Mental Retardation
#     · wrote opinion_summary
# - Case 2358077 — Deily v. Waste Management of Allentown
#     · wrote opinion_summary
# - Case 9036766 — DelCostello v. International Brotherhood of Teamsters
#     · wrote opinion_summary
# - Case 3207320 — Danny Delaval v. PTech Drilling Tubulars, LLC
#     · wrote opinion_summary
# - Case 9428116 — Delaware State College v. Ricks
#     · wrote opinion_summary
#
# Batch after internal id 4105: 60 case(s)
# - Case 773891 — David Demshki v. Richard Monteith Anthony Whitehurst Steven Sloan Heidi Arno Monteith for
#     · wrote opinion_summary
# - Case 725053 — Dennin v. Connecticut Interscholastic Athletic Conference
#     · wrote opinion_summary
# - Case 769358 — Richard W. Deppe v. United Airlines
#     · wrote opinion_summary
# - Case 1782030 — DeRouen v. Audirsch
#     · wrote opinion_summary
# - Case 775435 — Nicholas Devito v. Chicago Park District
#     · wrote opinion_summary
# - Case 9634423 — Dewitt v. Proctor Hospital
#     · wrote opinion_summary
# - Case 1878815 — Diaz v. Pan American World Airways, Inc.
#     · wrote opinion_summary
# - Case 2576900 — Puerto Rico American Insurance v. Burgos
#     · wrote opinion_summary
# - Case 2971892 — Dillery v. Sandusky
#     · wrote opinion_summary
# - Case 162420 — Dilley v. Supervalu, Inc.
#     · wrote opinion_summary
# - Case 8729001 — Coalition of Montanans Concerned with Disabilities, Inc. v. Gallatin Airport Authority
#     · wrote opinion_summary
# - Case 626818 — Disability Advocates, Inc. v. New York Coalition for Quality Assisted
#     · wrote opinion_summary
# - Case 1241128 — Disability Rights Wisconsin, Inc. v. Walworth County Board of Supervisors
#     · wrote opinion_summary
# - Case 469371 — Disabled In Action Of Pennsylvania v. Pierce
#     · wrote opinion_summary
# - Case 9440551 — Disabled in Action v. Southeastern Pennsylvania Transportation Authority
#     · wrote opinion_summary
# - Case 769623 — Robert J. Disanto v. McGraw Inc./platt's Division
#     · wrote opinion_summary
# - Case 9208700 — Discovery House, Inc. v. Consolidated City of Indianapolis
#     · wrote opinion_summary
# - Case 7216793 — Discovery House, Inc. v. Consolidated City
#     · wrote opinion_summary
# - Case 4314323 — King v. Miami Cnty. Ohio Bd. of Cnty. Commissioners (In Re Children's Home County Ditch)
#     · wrote opinion_summary
# - Case 8394504 — Doak v. Johnson
#     · wrote opinion_summary
# - Case 9168414 — City of Omaha v. Doane
#     · wrote opinion_summary
# - Case 6970654 — Doe v. Pfrommer
#     · wrote opinion_summary
# - Case 2994219 — EEOC v. IN Bell
#     · wrote opinion_summary
# - Case 769162 — Equal Employment Opportunity Commission v. Stowe-Pharr Mills, Incorporated, D/B/A Pharr Ya
#     · wrote opinion_summary
# - Case 2967215 — EEOC v. Stowe-Pharr Mills
#     · wrote opinion_summary
# - Case 74383 — Earl v. Mervyns, Inc.
#     · wrote opinion_summary
# - Case 678816 — Easley v. Snider
#     · wrote opinion_summary
# - Case 172399 — Ellenberg v. New Mexico Military Institute
#     · wrote opinion_summary
# - Case 2264649 — Emery v. Caravan of Dreams, Inc.
#     · wrote opinion_summary
# - Case 8408266 — Estades-Negroni v. Associates Corp. of North America
#     · wrote opinion_summary
# - Case 112798 — Farrar v. Hobby
#     · wrote opinion_summary
# - Case 145827 — Federal Express Corp. v. Holowecki
#     · wrote opinion_summary
# - Case 668232 — Reginald D. Fedro v. Janet Reno, 1 Attorney General of the United States
#     · wrote opinion_summary
# - Case 766776 — Donna Feldman v. American Memorial Life Insurance Company, Formerly Known as Prairie State
#     · wrote opinion_summary
# - Case 3013755 — Fiscus v. Wal Mart Stores Inc
#     · wrote opinion_summary
# - Case 765810 — Ellen Fjellestad v. Pizza Hut of America, Inc.
#     · wrote opinion_summary
# - Case 185038 — Flemmings, Virginia v. Howard University
#     · wrote opinion_summary
# - Case 472579 — Louis P. Forrisi v. Otis R. Bowen
#     · wrote opinion_summary
# - Case 785830 — Robin Fortyune v. American Multi-Cinema, Inc.
#     · wrote opinion_summary
# - Case 773361 — Jane M. Foster v. Time Warner Entertainment Company, L.P.
#     · wrote opinion_summary
# - Case 23584 — Giles v. General Electric Co.
#     · wrote opinion_summary
# - Case 180298 — Gomez-Gonzalez v. Rural Opportunities, Inc.
#     · wrote opinion_summary
# - Case 722406 — Gonzales v. Garner Food Services, Inc.
#     · wrote opinion_summary
# - Case 8474901 — Graves v. Finch Pruyn & Co.
#     · wrote opinion_summary
# - Case 747612 — Jay Lawrence Halperin v. Abacus Technology Corporation
#     · wrote opinion_summary
# - Case 1765886 — Hicks v. Dothan City Board of Education
#     · wrote opinion_summary
# - Case 198690 — Higgins v. New Balance Athletic Shoe, Inc.
#     · wrote opinion_summary
# - Case 73889 — Hilburn v. Murata Electronics
#     · wrote opinion_summary
# - Case 1875320 — Hinneberg v. Big Stone County Housing & Redevelopment Authority
#     · wrote opinion_summary
# - Case 1395491 — Hogue v. MQS Inspection, Inc.
#     · wrote opinion_summary
# - Case 2531860 — White v. Boehringer Mannheim Corp.
#     · wrote opinion_summary
# - Case 9910566 — Hurd, Jr. v. District of Columbia
#     · wrote opinion_summary
# - Case 202298 — Iverson v. City of Boston
#     · wrote opinion_summary
# - Case 8695918 — A.M. ex rel. J.M. v. NYC Department of Education
#     · wrote opinion_summary
# - Case 74407 — Jang v. United Technologies Corp.
#     · wrote opinion_summary
# - Case 448906 — Thomas Jasany v. United States Postal Service
#     · wrote opinion_summary
# - Case 737439 — Robert Johnson v. American Chamber of Commerce Publishers, Inc., Doing Business as Apland
#     · wrote opinion_summary
# - Case 11919 — Johnson v. Gambrinus Company
#     · wrote opinion_summary
# - Case 784068 — Anna Lea Justice v. Pike County Board of Education and Frank Welch
#     · wrote opinion_summary
# - Case 2969427 — Kennedy v. Superior Printing
#     · wrote opinion_summary
#
# Batch after internal id 4165: 60 case(s)
# - Case 2367431 — Kilroy v. Husson College
#     · wrote opinion_summary
# - Case 516984 — Kohl v. Woodhaven Learning Center
#     · wrote opinion_summary
# - Case 1524939 — Kuehl v. Wal-Mart Stores, Inc.
#     · wrote opinion_summary
# - Case 1903094 — Demahy v. Wyeth Inc.
#     · wrote opinion_summary
# - Case 789284 — Rodney Kupstas v. City of Greenwood
#     · wrote opinion_summary
# - Case 1881083 — Lee v. Trustees of Dartmouth College
#     · wrote opinion_summary
# - Case 1368804 — Little v. Federal Bureau of Investigation
#     · wrote opinion_summary
# - Case 17666 — Loulseged v. Akzo Nobel Inc.
#     · wrote opinion_summary
# - Case 2814810 — Cheryl Phipps v. Wal-Mart Stores, Inc.
#     · wrote opinion_summary
# - Case 542407 — Lussier v. Dugger
#     · wrote opinion_summary
# - Case 706928 — Beth Lyons v. The Legal Aid Society
#     · wrote opinion_summary
# - Case 2510668 — MX Group, Inc. v. City of Covington
#     · wrote opinion_summary
# - Case 626311 — MacFarlan v. IVY HILL SNF, LLC
#     · wrote opinion_summary
# - Case 1894955 — MacZaczyj v. State of NY
#     · wrote opinion_summary
# - Case 1685958 — Mannell v. American Tobacco Co.
#     · wrote opinion_summary
# - Case 1388338 — Mason v. Correctional Medical Services, Inc.
#     · wrote opinion_summary
# - Case 2594077 — Mayberry v. Von Valtier
#     · wrote opinion_summary
# - Case 1449887 — McFadden v. Ballard, Spahr, Andrews, & Ingersoll, LLP
#     · wrote opinion_summary
# - Case 1608773 — McGill v. Callear
#     · wrote opinion_summary
# - Case 442153 — Walter D. McGuinness v. United States Postal Service, Felix J. Jackson, and A.A. Winslow,
#     · wrote opinion_summary
# - Case 1747334 — Merry v. A. Sulka & Co., Ltd.
#     · wrote opinion_summary
# - Case 12943 — Miller v. Public Storage Management, Inc.
#     · wrote opinion_summary
# - Case 781578 — Candice E. Mitchell v. Iowa Protection and Advocacy Services, Inc. Sylvia Piper
#     · wrote opinion_summary
# - Case 7016750 — Molski v. Gleich
#     · wrote opinion_summary
# - Case 765674 — Steaphanie Moore v. Payless Shoe Source, Inc.
#     · wrote opinion_summary
# - Case 2596549 — Motzkin v. Trustees of Boston University
#     · wrote opinion_summary
# - Case 202377 — Mulloy v. Acushnet Company
#     · wrote opinion_summary
# - Case 3033664 — Robert K. Murphey v. City of Minneapolis
#     · wrote opinion_summary
# - Case 1556729 — Mustafa v. Clark County School District
#     · wrote opinion_summary
# - Case 2763475 — Myers v. Knight Protective Service, Inc.
#     · wrote opinion_summary
# - Case 1768817 — Nisperos v. Buck
#     · wrote opinion_summary
# - Case 118315 — Olmstead v. L.C.
#     · wrote opinion_summary
# - Case 72412 — Onishea v. Hopper
#     · wrote opinion_summary
# - Case 790278 — Christopher M. Opsteen v. Keller Structures, Inc.
#     · wrote opinion_summary
# - Case 1379360 — Oxford House, Inc. v. Township of Cherry Hill
#     · wrote opinion_summary
# - Case 769651 — David Pals v. Schepel Buick & Gmc Truck, Inc.
#     · wrote opinion_summary
# - Case 6985123 — Parker v. Columbia Pictures Industries
#     · wrote opinion_summary
# - Case 655315 — Mary Tuck v. Hca Health Services of Tennessee, Inc., D/B/A Donelson Hospital
#     · wrote opinion_summary
# - Case 1523043 — Pinnock v. International House of Pancakes Franchisee
#     · wrote opinion_summary
# - Case 2414074 — Woods v. Wills
#     · opinion too long → split into 2 parts (<= 30924 tokens each)
#       - finished part 1/2
#       - finished part 2/2
#     · wrote opinion_summary
# - Case 165831 — Praseuth v. Rubbermaid, Inc.
#     · wrote opinion_summary
# - Case 2154224 — Pushkin v. Regents of University of Colorado
#     · wrote opinion_summary
# - Case 199356 — Reed v. Lepage Bakeries, Inc.
#     · wrote opinion_summary
# - Case 2316860 — Maryland Commission on Human Relations v. Mayor of Baltimore
#     · wrote opinion_summary
# - Case 7016607 — Richard S. v. Department of Developmental Services of the State of California
#     · wrote opinion_summary
# - Case 1396791 — Ricks v. Xerox Corp.
#     · wrote opinion_summary
# - Case 10679 — Riel v. Elect Data System
#     · wrote opinion_summary
# - Case 786444 — Ristrom v. Asbestos Workers Local 34 Joint Apprentice Committee
#     · wrote opinion_summary
# - Case 169751 — Robertson v. Las Animas County Sheriff's Department
#     · wrote opinion_summary
# - Case 2490409 — Rodriguez v. City of New York
#     · wrote opinion_summary
# - Case 1361849 — Rodriguez v. Westhab, Inc.
#     · wrote opinion_summary
# - Case 769625 — Susan Rogers v. New York University
#     · wrote opinion_summary
# - Case 790496 — Daniel P. Rooney v. Koch Air, LLC
#     · wrote opinion_summary
# - Case 2352100 — Rothman v. Emory University
#     · wrote opinion_summary
# - Case 198940 — Santiago Clemente v. Executive Airlines
#     · wrote opinion_summary
# - Case 2999028 — Scheerer, Scott E. v. Potter, James E.
#     · wrote opinion_summary
# - Case 2357933 — Arline v. School Bd. of Nassau County
#     · wrote opinion_summary
# - Case 1399445 — Schroedel v. New York University Medical Center
#     · wrote opinion_summary
# - Case 1944012 — Sharrow v. Bailey
#     · wrote opinion_summary
# - Case 768059 — Arthur Joseph Sheehan v. James Marr, Police Chief, City of Gloucester
#     · wrote opinion_summary
#
# Batch after internal id 4225: 26 case(s)
# - Case 768355 — Staceen M. Sinkler v. Midwest Property Management Limited Partnership
#     · wrote opinion_summary
# - Case 3050407 — Skaff v. Meridien North America Beverly Hills, LLC
#     · wrote opinion_summary
# - Case 757342 — Paula S. Skorup v. Modern Door Corporation
#     · wrote opinion_summary
# - Case 1038160 — Jacqlyn Smith v. Clark County School District
#     · wrote opinion_summary
# - Case 28753 — Soledad v. United States Department of Treasury
#     · wrote opinion_summary
# - Case 186677 — Spinelli, Gianpaola v. Goss, Porter
#     · wrote opinion_summary
# - Case 411442 — Joseph L. Stutts, Jr. v. S. David Freeman, as Chairman of the Board of Directors of the Te
#     · wrote opinion_summary
# - Case 184891 — Swanks v. Washington Metropolitan Area Transit Authority
#     · wrote opinion_summary
# - Case 2577172 — Taylor v. Phoenixville School District
#     · wrote opinion_summary
# - Case 186091 — Taylor, Carolyn v. Small, Lawrence M.
#     · wrote opinion_summary
# - Case 715667 — John Teahan v. Metro-North Commuter Railroad Company
#     · wrote opinion_summary
# - Case 1687227 — Thomas by and Through Thomas v. Davidson Academy
#     · wrote opinion_summary
# - Case 161423 — Thompson v. State of Colorado
#     · wrote opinion_summary
# - Case 517701 — Larry THORNHILL, Plaintiff/Appellant, v. John O. MARSH, Jr., Secretary of the Department o
#     · wrote opinion_summary
# - Case 730859 — John R. Turco v. Hoechst Celanese Corporation, Hoechst Celanese Chemical Group, Inc.
#     · wrote opinion_summary
# - Case 1395009 — Valdez v. Albuquerque Public Schools
#     · wrote opinion_summary
# - Case 1521361 — Wallace v. Town of Stratford Board of Education
#     · wrote opinion_summary
# - Case 6984727 — Weyer v. Twentieth Century Fox Film Corp.
#     · wrote opinion_summary
# - Case 729953 — Williams v. Channel Master Satellite Systems
#     · wrote opinion_summary
# - Case 786911 — Dewey Michael Williams v. London Utility Commission
#     · wrote opinion_summary
# - Case 787450 — Edward R. Williams Angelynne Williams, H/w v. Philadelphia Housing Authority Police Depart
#     · wrote opinion_summary
# - Case 737029 — Lynda L. Willis v. Conopco, Inc., A.K.A. Lever Brothers Company, A.K.A. Unilever
#     · wrote opinion_summary
# - Case 1354826 — Willnerd v. First National Nebraska, Inc.
#     · wrote opinion_summary
# - Case 1395125 — Wood v. County of Alameda
#     · wrote opinion_summary
# - Case 543624 — Zamlen v. City of Cleveland
#     · wrote opinion_summary
# - Case 1469322 — De La Torres v. Bolger
#     · wrote opinion_summary
# Done. No more cases.
#
# === Summary ===
# LLM backend: Bedrock Mistral (mistral.mistral-7b-instruct-v0:2, region=us-east-1)
# Processed: 4251 | Wrote: 386 | Skipped-existing: 3865 | Skipped-empty: 0 | Chunked cases: 10
# Elapsed: 56.1 min
