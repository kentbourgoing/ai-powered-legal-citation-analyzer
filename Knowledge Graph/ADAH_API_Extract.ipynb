# %% [markdown]
# # ADAH Dataset Construction Pipeline
#
# ## Purpose
#
# This notebook/script builds a unified ADAH dataset by:
#
# 1. Extracting **clean ADA case names** from a PDF (ADAH handbook).
# 2. Calling the **CourtListener API** to:
#
#    * Download **ADAH “seed” cases** by name.
#    * Download **cases cited by those ADAH cases**.
#    * Download **cases that cite ADAH cases**.
# 3. **Inferring jurisdictions** from `court_citation_string`.
# 4. Tagging each case with a **`Citing_Relationship`** label:
#
#    * `adah`
#    * `cited_by_adah`
#    * `citing_adah`
# 5. **Deduplicating** by case ID and exporting combined JSONs locally and to **S3**.
#
# ---
#
# ## 1. Extracting clean case names from the ADAH PDF
#
# ### `read_pdf_content(pdf_path)`
#
# * Ensures the PDF exists.
# * Installs `pypdf` if needed.
# * Reads each page with `pypdf.PdfReader`.
# * Splits text into lines and strips whitespace.
# * Handles **hanging indents**:
#
#   * If the next line is indented, it is concatenated with the current line to rebuild broken case names.
# * Returns a **list of processed text lines**.
#
# ### `normalize_case_name(name)`
#
# Normalizes raw case-name text:
#
# * Unifies `vs.`, `vs`, `v.`, `v` → `" v "`.
# * Normalizes dash characters.
# * Removes control characters and non-alphanumeric punctuation (keeps letters, digits, `&`, `-`, spaces).
# * Collapses multiple spaces to one.
# * Returns a clean, trimmed string.
#
# ### `parse_case_name_only(pdf_path, min_name_length=5)`
#
# Extracts **only case names** from the PDF:
#
# 1. Calls `read_pdf_content(pdf_path)` to get lines.
# 2. Uses patterns:
#
#    * `v_pattern` → lines containing `v.` or `vs.`
#    * `in_re_pattern` → lines starting with `in re` or `ex parte`.
# 3. Strips **citations and references**:
#
#    * Parenthetical citations `( ... )`
#    * Page references like `904H`, `911M1`
#    * Volume citations like `123 U.S. 456`
#    * Westlaw cites `2019 WL 123456`
#    * Leftover numeric page references.
# 4. Normalizes the line with `normalize_case_name`.
# 5. Keeps it if:
#
#    * Length ≥ `min_name_length`, and
#    * Contains `" v "` or starts with `"in re"` / `"ex parte"`.
#
# Results:
#
# * Returns a **sorted, unique list** of clean case names.
# * Saves them to `./datasets/ada_case_names_only.txt`.
# * Prints the first 20 names and the total count.
#
# ---
#
# ## 2. Building the initial ADAH case set via CourtListener
#
# You load the extracted case names:
#
# ```python
# with open("ada_case_names_only.txt", "r") as f:
#     ada_case_names = [line.strip() for line in f.readlines()]
# ```
#
# ### `safe_json_get(url, headers=None, retries=3, delay=1)`
#
# Safe wrapper for `requests.get`:
#
# * Handles:
#
#   * HTTP errors
#   * Network errors
#   * JSON decode errors
# * On **429 (Too Many Requests)**:
#
#   * Waits (`delay` seconds, exponential backoff).
#   * Retries up to `retries` times.
# * Returns parsed JSON or `None`.
#
# ### `get_best_opinion_text(opinion_data)`
#
# Chooses the **best available opinion text** from a CourtListener opinion object:
#
# Priority order:
#
# 1. `plain_text` (no parsing needed)
# 2. `html_with_citations`
# 3. `html`
# 4. `html_lawbox`
# 5. `xml_harvard`
# 6. `html_columbia`
# 7. `html_anon_2020`
#
# * For XML (`xml_harvard`), uses `BeautifulSoup(..., "xml")`.
# * For HTML, uses `BeautifulSoup(..., "html.parser")`.
# * Returns **plain text opinion** or `""` if nothing available.
#
# ### `adah_api_extract(ada_case_names)`
#
# Given a list of case names (queries):
#
# 1. For each `query`:
#
#    * Calls `https://www.courtlistener.com/api/rest/v4/search/?q={query}` using `safe_json_get`.
#    * Takes the **first result**.
#    * If there is an associated opinion:
#
#      * Reads the first opinion ID.
#      * Calls `/api/rest/v4/opinions/{opinion_id}/` via `safe_json_get`.
#      * Extracts opinion text using `get_best_opinion_text`.
#    * Builds a **flat `case` dict** with:
#
#      * `ID` (opinion ID)
#      * `absolute_url`
#      * `date_filed`
#      * `case_name`, `case_full_name`
#      * `docker_number`, court metadata, attorney, judge, `panel_names`
#      * `citation`, `lexisCite`, `neutralCite`
#      * `cite_to` (list of cited opinion IDs)
#      * `opinion_type`
#      * `opinion`
#      * `page_count`
#
# 2. Returns a **DataFrame** `adah_df` with one row per case.
#
# ### Batching ADA case-name queries
#
# #### `batch_list(lst, n_batches)`
#
# Utility to split a list into roughly equal sublists:
#
# ```python
# k, m = divmod(len(lst), n_batches)
# return [lst[i*k + min(i, m):(i+1)*k + min(i+1, m)] for i in range(n_batches)]
# ```
#
# Usage:
#
# ```python
# adah_batches = batch_list(ada_case_names, 3)
# headers = {"Authorization": "Token <YOUR_TOKEN>"}
#
# for i in range(len(adah_batches)):
#     batch_df = adah_api_extract(adah_batches[i])
#     batch_df.to_json(f"adah_batch{i+1}.json", orient="records", indent=4)
#     time.sleep(3700)  # long pause to avoid rate limiting
# ```
#
# Then:
#
# * Combine `adah_batch*.json` with `glob` and `pd.concat` into a single DataFrame.
# * Save the final list of records as `adah.json`.
#
# ---
#
# ## 3. Optional JSON field normalization
#
# ### `convert_json_to_list_format(data)`
#
# Normalizes the structure of a list of case dictionaries so that:
#
# * Some fields remain **single strings**:
#
#   * e.g., `ID`, `absolute_url`, `date_files`, `case_name`, `case_full_name`, `court`, etc.
# * All other fields are converted to **lists of strings**.
#
# Rules:
#
# * If key in `single_string_fields`:
#
#   * Ensure a single string (cast ints/floats to str, handle `None`).
# * Otherwise:
#
#   * If value is a list → convert each element to `str`.
#   * If scalar → wrap in a single-element list of strings.
#   * If `None` → empty list.
#   * Else → `[str(value)]`.
#
# Returns a new list with consistent value types.
#
# ---
#
# ## 4. Extracting cases **cited by** ADAH cases
#
# First, load `adah.json`:
#
# ```python
# with open("./datasets/adah.json", "r", encoding="utf-8") as f:
#     adah_cases = json.load(f)
# ```
#
# Collect all cited opinion IDs:
#
# ```python
# cited_id_list = []
# for case in adah_cases:
#     if isinstance(case['cite_to'], list):
#         cited_id_list = cited_id_list + case['cite_to']
# unique_cited_id_list = list(set(cited_id_list))
# ```
#
# ### `safe_api_call(url, headers=None, timeout=30)`
#
# Improved safe API helper:
#
# * Adds explicit `timeout`.
# * On 429:
#
#   * Logs a message.
#   * Sleeps for **1 hour**.
#   * Retries once.
# * Handles other HTTP errors, timeouts, and request exceptions.
# * Returns JSON or `None`.
#
# ### `extract_single_case(opinion_id, headers=None)`
#
# Given a **single opinion ID**:
#
# 1. Fetch opinion data from `/opinions/{opinion_id}/`.
#
# 2. Use `cluster` URL in the opinion to fetch cluster data.
#
# 3. Take `case_name` from the cluster object (skip if missing).
#
# 4. Run a search on `/search/?q={case_name}` to get richer metadata.
#
# 5. Use `get_best_opinion_text` on the original opinion.
#
# 6. Build a **case dict**:
#
#    * `ID` (opinion_id)
#    * `absolute_url`, `case_name`, `case_full_name`
#    * `court`, `court_citation_string`
#    * `attorney`, `judge`, `panel_names`
#    * `cite_to`, `opinion_type`, `opinion`
#
# 7. Returns the case dict or `None`.
#
# ### `process_by_batch_new(case_ids, batch_size=10, headers=None, output_dir="./datasets/")`
#
# Batch processor for large sets of opinion IDs:
#
# * Logs start, total cases, and number of batches.
# * For each batch:
#
#   * Slices `case_ids` into a batch of size `batch_size`.
#   * Loops through each ID and calls `extract_single_case`.
#   * Tracks successes and failures.
#   * Saves batch results to `case_cited_batch_{batch_num}.json`.
#   * Prints batch time and total time so far.
#   * Adds a small delay between batches.
# * At the end:
#
#   * Prints total success rate, average time per case.
#   * Returns a **DataFrame** of all extracted cases.
#
# Usage example:
#
# ```python
# case_id_list = unique_cited_id_list[1669:16001] + unique_cited_id_list[17317:]
# headers = {"Authorization": "Token <YOUR_TOKEN>"}
#
# result_df = process_by_batch_new(
#     case_id_list,
#     batch_size=1000,
#     headers=headers,
#     output_dir="./datasets/"
# )
# ```
#
# Then you can combine `case_cited_batch_*.json` into a single DataFrame and export if needed.
#
# ---
#
# ## 5. Extracting cases that **cite** ADAH cases
#
# ### `cases_cited_by_id(adah_opinion_ids, headers=None, batch_num=1)`
#
# Given a list of **ADAH opinion IDs**:
#
# 1. For each `target_opinion_id`:
#
#    * Calls `/search/?q=cites:{target_opinion_id}` to find cases that **cite** this opinion.
#    * Skips results without opinions.
#    * For each result:
#
#      * Takes the first opinion ID.
#      * Confirms that `target_opinion_id` is in its `cites` list.
#      * Calls `/opinions/{opinion_id}/` and extracts text with `get_best_opinion_text`.
#      * Builds a case dict with:
#
#        * IDs, URLs, filing date
#        * `case_name`, `case_full_name`
#        * `docketNumber`
#        * court metadata, attorney, judge, panel_names
#        * citation fields, `cite_to`, `opinion_type`, `opinion`, `page_count`.
#
# 2. Appends all cases to a list and saves to `case_citing_adah_batch_{batch_num}.json`.
#
# 3. Returns a DataFrame of the batch.
#
# Batching:
#
# ```python
# unique_adah_ids = list(set(adah_id_list))
# adah_batches = batch_list(unique_adah_ids, 6)
#
# headers = {"Authorization": "Token <YOUR_TOKEN>"}
#
# for i in range(len(adah_batches)):
#     batch_df = cases_cited_by_id(adah_batches[i], headers, batch_num=i+1)
#     batch_df.to_csv(f"case_citing_adah_batch_{i+1}.csv", index=False)
#     time.sleep(3700)
# ```
#
# Then:
#
# * Combine `case_citing_adah_batch_*.json` into one DataFrame.
# * Save as `case_citing_adah.json`.
#
# ---
#
# ## 6. Inferring jurisdictions from court citations
#
# You first download **full ADAH set** from S3:
#
# ```python
# s3 = boto3.client('s3')
# bucket = 'capstone-project-legal-citation'
# key = 'datasets/full_adah_set.json'
#
# response = s3.get_object(Bucket=bucket, Key=key)
# adah_full = json.loads(response['Body'].read().decode('utf-8'))
# ```
#
# ### `infer_jurisdiction(court_citation)`
#
# Maps `court_citation_string` to a **jurisdiction name** used later for court-level assignment. Returns one of many specific strings (e.g., `"U.S. Court of Appeals for the Ninth Circuit"`, `"California Supreme Court"`) or `"Unknown"`.
#
# It uses several maps:
#
# * `supreme_map` → Federal Supreme Court (SCOTUS).
# * `circuit_map` → Federal Courts of Appeals (1st Cir., 2d Cir., etc.).
# * `district_patterns` → District Courts (N.D. Cal., D. Mass., etc.) via regex.
# * `special_map` → Special federal courts and tribunals (Tax Ct., OLC, etc.).
# * `state_map` → State abbreviations (Cal., N.Y., Tex., etc.); distinguishes:
#
#   * `"Ct. App."` → `"{State} Court of Appeal"`
#   * `"Supreme Ct."` → `"{State} Supreme Court"`
#   * else → just the state name.
#
# Usage:
#
# ```python
# for case in adah_full:
#     court_citation = case.get("court_citation_string", "")
#     case["jurisdiction_inferred"] = infer_jurisdiction(court_citation)
# ```
#
# You then:
#
# * Collect cases where `jurisdiction_inferred == 'Unknown'`.
# * Inspect missing citation strings with `value_counts`.
# * Save the enriched dataset:
#
# ```python
# output_path = './datasets/combined/adah_cases_full.json'
# with open(output_path, 'w', encoding="utf-8") as f:
#     json.dump(adah_full, f, ensure_ascii=False, indent=2)
# ```
#
# ---
#
# ## 7. Tagging relationships and building combined ADAH sets
#
# ### Combine ADAH and cases that **cite** ADAH
#
# ```python
# with open('citing_adah_new.json', 'r', encoding='utf-8') as f:
#     citing_adah = json.load(f)
# with open('adah.json', 'r', encoding='utf-8') as f:
#     adah = json.load(f)
#
# # Add inferred jurisdiction to both sets
# for case in citing_adah:
#     case["jurisdiction_inferred"] = infer_jurisdiction(case.get("court_citation_string", ""))
# for case in adah:
#     case["jurisdiction_inferred"] = infer_jurisdiction(case.get("court_citation_string", ""))
#
# # Tag relationships
# for case in adah:
#     case['Citing_Relationship'] = 'adah'
# for case in citing_adah:
#     case['Citing_Relationship'] = 'citing_adah'
# ```
#
# Convert to DataFrames, concatenate, and deduplicate by `ID`:
#
# ```python
# citing_adah_df = pd.DataFrame(citing_adah)
# adah_df = pd.DataFrame(adah)
#
# combined = pd.concat([citing_adah_df, adah_df], ignore_index=True)
# combined_df = combined.drop_duplicates(subset=['ID'])
# combined_df.to_json('full_adah_set.json', orient='records', indent=2)
# ```
#
# ### Combine `adah`, `cited_by_adah`, and `citing_adah` with labels
#
# 1. Read **all cases cited by ADAH** (`case_cited_batch_*.json`) and combine them into `cited_by_adah`.
#
# 2. Load:
#
#    * `adah.json` (seed ADAH cases)
#    * `case_citing_adah.json` (citers)
#
# 3. Tag relationship types:
#
# ```python
# for case in cited_by_adah:
#     case["Citing_Relationship"] = "cited_by_adah"
# for case in citing_adah:
#     case["Citing_Relationship"] = "citing_adah"
# for case in adah:
#     case["Citing_Relationship"] = "adah"
# ```
#
# 4. Save `cited_by_adah` separately:
#
# ```python
# cited_output_path = './datasets/combined/cited_by_adah.json'
# with open(cited_output_path, 'w', encoding="utf-8") as f:
#     json.dump(cited_by_adah, f, ensure_ascii=False, indent=2)
# ```
#
# 5. Build a **fully combined, deduplicated** dataset:
#
# ```python
# combined = adah + cited_by_adah + citing_adah
#
# unique_cases = {}
# for case in combined:
#     case_id = case.get("ID")
#     if case_id not in unique_cases:
#         unique_cases[case_id] = case
#
# deduped_list = list(unique_cases.values())
#
# output_path = './datasets/combined/adah_cases_combined.json'
# with open(output_path, 'w', encoding="utf-8") as f:
#     json.dump(deduped_list, f, ensure_ascii=False, indent=2)
# ```
#
# ---
#
# ## 8. Uploading datasets to S3
#
# Uses SageMaker’s `Session.upload_data`:
#
# ```python
# import sagemaker
# session = sagemaker.Session()
#
# files = [
#     'adah_cases_full',  # etc.
# ]
# bucket = 'capstone-project-legal-citation'
# prefix = 'datasets'
#
# for file_name in files:
#     local_path = f'./datasets/combined/{file_name}.json'
#     s3_uri = session.upload_data(path=local_path, bucket=bucket, key_prefix=prefix)
#
# print(f"Uploaded to: {s3_uri}")
# ```
#
# This pushes the local JSONs (e.g., `adah_cases_full.json`) to your S3 bucket under `datasets/`.
#
# ---
#
# ## Typical workflow
#
# 1. **Extract clean ADA case names** from the ADAH PDF:
#
#    * `parse_case_name_only("datasets/ADAH.pdf")`
#    * Save to `ada_case_names_only.txt`.
#
# 2. **Fetch ADAH seed cases** from CourtListener:
#
#    * Batch `ada_case_names` with `batch_list`.
#    * Run `adah_api_extract` per batch.
#    * Combine to `adah.json`.
#
# 3. **Fetch cases cited by ADAH**:
#
#    * Build `unique_cited_id_list` from `adah.json`.
#    * Run `process_by_batch_new` on those IDs.
#    * Combine `case_cited_batch_*.json` to a single dataset.
#
# 4. **Fetch cases that cite ADAH**:
#
#    * Build unique ADAH opinion IDs.
#    * Run `cases_cited_by_id` in batches.
#    * Combine outputs to `case_citing_adah.json`.
#
# 5. **Infer jurisdictions** for all cases using `infer_jurisdiction`.
#
# 6. **Tag `Citing_Relationship`** for:
#
#    * ADAH seed cases → `adah`
#    * Cases cited by ADAH → `cited_by_adah`
#    * Cases citing ADAH → `citing_adah`
#
# 7. **Deduplicate by `ID`** and export:
#
#    * `full_adah_set.json`
#    * `adah_cases_full.json`
#    * `adah_cases_combined.json`
#
# 8. **Upload** final JSONs to S3 for downstream processing (e.g., Neo4j, json→csv converter).

# %%
import re
import os
import subprocess
import sys
import requests
from bs4 import BeautifulSoup
from bs4 import XMLParsedAsHTMLWarning
import warnings
import pandas as pd
import numpy as np
import time
import json
import pprint

import math
from datetime import datetime, timedelta
import glob

# %% [markdown]
# ## Extract Case names and normalize

# %%
def read_pdf_content(pdf_path: str) -> list:
    """
    Read PDF content and extract text lines.

    Args:
        pdf_path (str): Path to the PDF file

    Returns:
        list: List of text lines from the PDF

    Raises:
        FileNotFoundError: If PDF file doesn't exist
        RuntimeError: If PDF reading fails
    """
    # Check if file exists
    if not os.path.exists(pdf_path):
        raise FileNotFoundError(f"PDF file not found: {pdf_path}")

    # Import PDF processing library
    try:
        import pypdf
    except ImportError:
        print("Installing pypdf...")
        subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "pypdf"])
        import pypdf

    # Read PDF and extract text lines, handling two-column layout and hanging indents
    try:
        reader = pypdf.PdfReader(pdf_path)
        all_lines = []

        for page in reader.pages:
            text = page.extract_text() or ""
            page_lines = [line.strip() for line in text.splitlines() if line.strip()]
            all_lines.extend(page_lines)

        # Process lines to handle hanging indents and concatenate multi-line case names
        processed_lines = []
        i = 0

        while i < len(all_lines):
            current_line = all_lines[i]

            # Check if the next line is a hanging indent (starts with spaces or is indented)
            if (i + 1 < len(all_lines) and
                all_lines[i + 1] and
                (all_lines[i + 1].startswith(' ') or
                 len(all_lines[i + 1]) - len(all_lines[i + 1].lstrip()) > 0)):

                # Concatenate the hanging line with the current line
                next_line = all_lines[i + 1].strip()
                concatenated_line = f"{current_line} {next_line}"
                processed_lines.append(concatenated_line)
                i += 2  # Skip the next line since we've concatenated it
            else:
                processed_lines.append(current_line)
                i += 1

        return processed_lines

    except Exception as e:
        raise RuntimeError(f"Error reading PDF file: {e}")

# %%
def normalize_case_name(name: str) -> str:
    """(As you already have) Normalizes variations of v., spaces, punctuation, etc."""
    if not name or not isinstance(name, str):
        return ""
    name = re.sub(r"\bvs\.?\b", " v ", name, flags=re.IGNORECASE)
    name = re.sub(r"\bv\.?\b", " v ", name, flags=re.IGNORECASE)
    name = re.sub(r"[\u2010-\u2015]", "-", name)
    name = re.sub(r"[\t\r\n]+", " ", name)
    name = re.sub(r"[^A-Za-z0-9&\-\s]+", "", name)
    name = re.sub(r"\s+", " ", name)
    return name.strip()

# %%
def parse_case_name_only(pdf_path: str, min_name_length: int = 5) -> list:
    """
    Parse case names only from PDF, normalize them, and remove all citations and references.

    This function focuses solely on extracting clean, normalized case names without any
    citations, page numbers, or other references.

    Args:
        pdf_path (str): Path to the PDF file
        min_name_length (int): Minimum length for valid case names (default: 5)

    Returns:
        list: List of clean, normalized case names found in the PDF

    Example:
        >>> case_names = parse_case_name_only("datasets/ADAH.pdf")
        >>> print(f"Found {len(case_names)} clean case names")
    """
    print(f"Parsing case names only from {pdf_path}...")

    # Step 1: Read PDF content
    lines = read_pdf_content(pdf_path)

    # Compile regex patterns for case name detection
    v_pattern = re.compile(r"\b(v\.?|vs\.)\b", re.IGNORECASE)
    in_re_pattern = re.compile(r"^\s*(in\s+re|ex\s+parte)\b", re.IGNORECASE)

    # Pattern to remove citations and references
    citation_pattern = re.compile(r"\(([^)]+)\)")
    page_ref_pattern = re.compile(r"\b\d{1,4}[a-zA-Z]?\d*\b")  # Page references like "904H", "911M1"
    volume_page_pattern = re.compile(r"\b\d{1,3}\s+[A-Za-z\.]+\s+\d{1,4}")  # Volume citations
    westlaw_pattern = re.compile(r"\b\d{4}\s+WL\s+\d+\b")  # Westlaw citations

    case_names = set()

    for line in lines:
        # Look for lines that contain case name patterns
        if (v_pattern.search(line) or in_re_pattern.search(line)):

            # Remove citations within parentheses
            clean_line = citation_pattern.sub("", line)

            # Remove page references (like "904H", "911M1")
            clean_line = page_ref_pattern.sub("", clean_line)

            # Remove volume citations (like "123 U.S. 456")
            clean_line = volume_page_pattern.sub("", clean_line)

            # Remove Westlaw citations
            clean_line = westlaw_pattern.sub("", clean_line)

            # Remove common reference patterns
            clean_line = re.sub(r"\b\d{1,3}\s+[A-Za-z\.]+\s+\d{1,4}(?:\s*[,\.]\s*\d+)*\b", "", clean_line)

            # Remove standalone numbers that might be page references
            clean_line = re.sub(r"\b\d{1,4}[a-zA-Z]?\d*\b", "", clean_line)

            # Normalize the case name
            normalized = normalize_case_name(clean_line)

            # Validate it's a proper case name
            if (len(normalized) >= min_name_length and
                (" v " in normalized or
                 normalized.startswith("in re") or
                 normalized.startswith("ex parte"))):
                case_names.add(normalized)

    result = sorted(list(case_names))
    print(f"Extracted {len(result)} clean case names from {pdf_path}")

    return result

# %%
# !ls -l
# Out:
# total 72
# -rw-r--r-- 1 sagemaker-user users 69768 Oct  5 23:54 ADAH_API_Extract_Simran.ipynb
# drwxr-xr-x 2 sagemaker-user users    39 Oct  5 23:53 dataset

# %%
# Test the new parse_case_name_only function
pdf_path = "./datasets/ADAH.pdf"
clean_case_names = parse_case_name_only(pdf_path)

print(f"\nFirst 20 clean case names:")
print("=" * 50)
for i, name in enumerate(clean_case_names[:20]):
    print(f"{i+1:2d}. {name}")

print(f"\nTotal clean case names: {len(clean_case_names)}")

# Save clean case names to file
output_file = "./datasets/ada_case_names_only.txt"
with open(output_file, 'w', encoding='utf-8') as f:
    for name in clean_case_names:
        f.write(f"{name}\n")

print(f"\n✓ Clean case names saved to: {output_file}")
# Out:
# Parsing case names only from ./datasets/ADAH.pdf...
# Installing pypdf...
# Extracted 2858 clean case names from ./datasets/ADAH.pdf
#
# First 20 clean case names:
# ==================================================
#  1. & School v EEOC H
#  2. A Helping Hand LLC v Baltimore County
#  3. A Society Without A Name v Virginia
#  4. ABC v XYZ Corp L
#  5. AC ex rel JC v Shelby County Board of
#  6. ACPA v ONeill D
#  7. AIDS Inc v Abrams
#  8. AKA v Washington Hospital Center
#  9. ALPA v ONeill D
# 10. AT & T Mobility LLC v Concepcion
# 11. Abbasi v Hertzfeld & Rubin A
# 12. Abbott v Bragdon C
# 13. Abdul Wali v Coughlin B
# 14. Aberman v J Abouchar & Sons Inc
# 15. Aberman v J Abouchar & Sons Inc No
# 16. Ability Center of Greater Toledo v City of
# 17. Abilt v Central Intelligence Agency
# 18. Abner v Kansas City Southern Railroad
# 19. Abrahams v MTA Long Island Bus
# 20. Access Now Inc v Southwest Airlines Co
#
# Total clean case names: 2858
#
# ✓ Clean case names saved to: ada_case_names_only.txt

# %%
# Example list of ADA cases
with open("ada_case_names_only.txt", "r") as f:
    ada_case_names = [line.strip() for line in f.readlines()]

# %% [markdown]
# ## Extract cases using API call

# %%
def safe_json_get(url, headers=None, retries=3, delay=1):
    """Fetch URL and return JSON safely; handles HTTP errors, JSON decode errors, retries on 429"""
    for attempt in range(retries):
        try:
            response = requests.get(url, headers=headers)
            response.raise_for_status()
            return response.json()
        except requests.exceptions.HTTPError as e:
            if response.status_code == 429:  # Too Many Requests
                print(f"429 Too Many Requests. Waiting {delay} sec before retrying...")
                time.sleep(delay)
                delay *= 2  # exponential backoff
            else:
                print(f"HTTP error for URL {url}: {e}")
                break
        except requests.exceptions.RequestException as e:
            print(f"Request error for URL {url}: {e}")
            break
        except ValueError as e:  # JSONDecodeError
            print(f"JSON decode error for URL {url}: {e}")
            break
    return None


################################################################################

# Suppress XML-as-HTML warnings
warnings.filterwarnings("ignore", category=XMLParsedAsHTMLWarning)

def get_best_opinion_text(opinion_data):
    """Selecting the best opinion text from CourtListener opinion data"""
    options = [
        "plain_text",
        "html_with_citations",
        "html",
        "html_lawbox",
        "xml_harvard",
        "html_columbia",
        "html_anon_2020"
    ]

    for field in options:
        text = opinion_data.get(field)
        if text and text.strip():
            if field == "plain_text":
                # already plain text, no parsing needed
                return text
            elif field == "xml_harvard":
                # use XML parser for XML content
                text = BeautifulSoup(text, "xml").get_text(" ", strip=True)
            else:
                # use HTML parser for other HTML fields
                text = BeautifulSoup(text, "html.parser").get_text(" ", strip=True)
            return text

    return ""  # nothing found



################################################################################

def adah_api_extract(ada_case_names):
    """Extracting ADAH Cases"""
    adah_cases = []

    for query in ada_case_names:
        url = f"https://www.courtlistener.com/api/rest/v4/search/?q={query}"
        response = safe_json_get(url, headers=headers)
        if not response or not response.get("results"):
            print(f"No results for: {query}")
            continue

        result = response["results"][0]
        if not result.get("opinions"):
            print(f"No opinions for: {query}")
            continue

        # Extract opinion ID and fetch opinion safely
        opinion_id = result['opinions'][0]['id']
        opinion_api_url = f"https://www.courtlistener.com/api/rest/v4/opinions/{opinion_id}/"
        opinion_data = safe_json_get(opinion_api_url, headers=headers)
        if not opinion_data:
            print(f"Failed to fetch opinion {opinion_id}")
            continue
        # some case are in in plain text, some are in HTML
        # creating priotization
        opinion_text = get_best_opinion_text(opinion_data)
        page_count = opinion_data.get('page_count')


        # extract keys
        case = {
            "ID": result['opinions'][0]['id'],
            "absolute_url":result.get("absolute_url"),
            "date_filed":result.get("dateFiled"),
            "case_name":result.get("caseName"),
            "case_full_name":result.get("caseNameFull"),
            "docker_number": result.get('docketNumber'),
            "court_id": result.get('court_id'),
            "court": result.get("court"),
            "court_citation_string": result.get("court_citation_string"),
            "court_jurisdiction": result.get("court_jurisdiction"),
            "attorney": result.get('attorney'),
            "judge": result.get('judge'),
            "panel_names": result.get('panel_names'),
            "citation": result.get('citation'),
            "lexisCite": result.get('lexisCite'),
            "neutralCite": result.get('neutralCite'),
            "cite_to": result['opinions'][0]['cites'],
            "opinion_type": result['opinions'][0]['type'],
            "opinion": opinion_text,
            "page_count": page_count
        }

        adah_cases.append(case)

    # output_path = f"adah_cases_sample_{sample_size}.json"
    # with open(output_path, "w", encoding="utf-8") as f:
    #     json.dump(adah_cases, f, ensure_ascii=False, indent=2)

    adah_df = pd.DataFrame(adah_cases)
    return adah_df

# %%
def batch_list(lst, n_batches):
    """
    Split a list into n_batches roughly equal chunks.
    """
    k, m = divmod(len(lst), n_batches)
    return [lst[i*k + min(i, m):(i+1)*k + min(i+1, m)] for i in range(n_batches)]

# Split into 6 batches
adah_batches = batch_list(ada_case_names, 3)

headers = {"Authorization": "Token e8c44d881eb22e19247756b1d38c2c9469085ff1"}

for i in range(len(adah_batches)):

  print(f"Starting Batch: {i+1}")
  batch_id = adah_batches[i]
  batch_df = adah_api_extract(batch_id)
  print(f"Batch {i+1} has a shape of:{batch_df.shape}")
  batch_df.to_json(f"adah_batch{i+1}.json", orient="records", indent=4)
  print(f"Saved batch {i+1} to adah_batch_{i+1}.json")

  time.sleep(3700)



all_files = glob.glob("adah_batch*.json")

# Read and concatenate them into a single DataFrame
df = pd.concat((pd.read_json(f, orient="records") for f in all_files), ignore_index=True)

print(f"Final Dataframe shape: {df.shape}")

output_path = "adah.json"

# Convert DataFrame to list of dictionaries
records = df.to_dict(orient="records")

print()

with open(output_path, "w", encoding="utf-8") as f:
    json.dump(records, f, ensure_ascii=False, indent=2)
# Out:
# Final Dataframe shape: (2681, 20)

# %%
adah_df
# Out:
#         ID                                       absolute_url  date_filed  \
# 0  1024999  /opinion/1024999/a-helping-hand-llc-v-baltimor...  2008-02-12
#
#                                      case_name  \
# 0  A HELPING HAND, LLC v. Baltimore County, MD
#
#                                       case_full_name docker_number court_id  \
# 0  A HELPING HAND, LLC, a Maryland Corporate Enti...       06-2026      ca4
#
#                                      court court_citation_string  \
# 0  Court of Appeals for the Fourth Circuit              4th Cir.
#
#   court_jurisdiction                                           attorney  \
# 0               None  ARGUED: Jeffrey Grant Cook, Paul M. Mayhew, Ba...
#
#                                        judge  \
# 0  Motz, Duncan, Brinkema, Eastern, Virginia
#
#                                      panel_names  \
# 0  [Allyson Kay Duncan, Diana Jane Gribbon Motz]
#
#                                             citation  \
# 0  [515 F.3d 356, 20 Am. Disabilities Cas. (BNA) ...
#
#                    lexisCite neutralCite  \
# 0  2008 U.S. App. LEXIS 3092
#
#                                              cite_to      opinion_type  \
# 0  [100934, 101297, 104381, 105040, 109301, 10967...  combined-opinion
#
#                                              opinion  page_count
# 0                               PUBLISHED\n\nUNIT...          26

# %%
def convert_json_to_list_format(data):
    """
    Convert JSON data so that each key contains either a single string or a list of strings.
    Specific fields are kept as single strings, while others are converted to lists.

    Args:
        data: List of dictionaries with mixed value types

    Returns:
        List of dictionaries where values are either single strings or lists of strings
    """
    # Fields that should remain as single strings
    single_string_fields = {
        'ID', 'absolute_url', 'date_files', 'case_name', 'case_full_name',
        'court', 'court_citation_string', 'opinion_type', 'opinion'
    }

    converted_data = []

    for case in data:
        converted_case = {}

        for key, value in case.items():
            if key in single_string_fields:
                # Keep these fields as single strings
                if isinstance(value, (int, float)):
                    converted_case[key] = str(value)
                elif isinstance(value, str):
                    converted_case[key] = value
                elif value is None:
                    converted_case[key] = ""
                else:
                    converted_case[key] = str(value)
            else:
                # Convert other fields to lists
                if isinstance(value, list):
                    # If it's already a list, convert each element to string
                    converted_case[key] = [str(item) for item in value]
                elif isinstance(value, (int, float)):
                    # Convert numbers to strings and wrap in list
                    converted_case[key] = [str(value)]
                elif isinstance(value, str):
                    # Convert string to list with single element
                    converted_case[key] = [value]
                elif value is None:
                    # Handle None values as empty list
                    converted_case[key] = []
                else:
                    # For any other type, convert to string and wrap in list
                    converted_case[key] = [str(value)]

        converted_data.append(converted_case)

    return converted_data

# # Test the updated function
# with open("./github/w210/datasets/adah_cases_sample_5.json", "r", encoding="utf-8") as f:
#     original_data = json.load(f)

# Convert the data
# converted_data = convert_json_to_list_format(original_data)

# Uncomment to save the converted dataset in JSON format
# output_path = f"./github/w210/datasets/adah_cases_sample_{sample_size}.json"
# with open(output_path, "w", encoding="utf-8") as f:
#     json.dump(converted_data, f, ensure_ascii=False, indent=2)

# %% [markdown]
# ## Extract cases cited by ADAH cases

# %%
with open("./datasets/adah.json", "r", encoding="utf-8") as f:
    adah_cases = json.load(f)

# Fixed version - Load JSON properly
print(f"Loaded {len(adah_cases)} cases")
print(f"First case keys: {list(adah_cases[0].keys())}")
print(f"First case type: {type(adah_cases[0])}")
# Out:
# Loaded 2805 cases
# First case keys: ['ID', 'absolute_url', 'date_files', 'case_name', 'case_full_name', 'court', 'court_citation_string', 'attorney', 'judge', 'panel_names', 'cite_to', 'opinion_type', 'opinion']
# First case type: <class 'dict'>

# %%
# Get all the cited ids
cited_id_list = []

for case in adah_cases:
    if isinstance(case['cite_to'], list):
        cited_id_list = cited_id_list + case['cite_to']
unique_cited_id_list = list(set(cited_id_list))

print(len(unique_cited_id_list))
# Out:
# 27475

# %%
import time
import math
import pandas as pd
import json
import requests

def safe_api_call(url, headers=None, timeout=30):
    """
    Make API call with timeout and proper error handling
    Handles 429 errors by pausing for one hour
    """
    try:
        response = requests.get(url, headers=headers, timeout=timeout)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.HTTPError as e:
        if response.status_code == 429:  # Too Many Requests
            print(f"🚫 Rate limit exceeded (429) for: {url}")
            print(f"⏳ Pausing for 1 hour before continuing...")
            time.sleep(3600)  # Wait for 1 hour
            print(f"✅ Resume after 1 hour pause")
            # Retry the request after the pause
            try:
                response = requests.get(url, headers=headers, timeout=timeout)
                response.raise_for_status()
                return response.json()
            except Exception as retry_e:
                print(f"❌ Request still failed after pause for {url}: {retry_e}")
                return None
        else:
            print(f"❌ HTTP error for {url}: {e}")
            return None
    except requests.exceptions.Timeout:
        print(f"⏰ Timeout after {timeout}s for: {url}")
        return None
    except requests.exceptions.RequestException as e:
        print(f"❌ Request error for {url}: {e}")
        return None
    except Exception as e:
        print(f"❌ Unexpected error for {url}: {e}")
        return None
###################################################################################################

def extract_single_case(opinion_id, headers=None):
    """
    Extract a single case by opinion ID with timeout handling
    """
    try:
        # Step 1: Get opinion data
        opinion_url = f"https://www.courtlistener.com/api/rest/v4/opinions/{opinion_id}/"
        opinion_data = safe_api_call(opinion_url, headers, timeout=30)

        if not opinion_data:
            return None

        # Step 2: Get cluster data
        cluster_url = opinion_data.get("cluster")
        if not cluster_url:
            return None

        cluster_data = safe_api_call(cluster_url, headers, timeout=30)
        if not cluster_data:
            return None

        case_name = cluster_data.get("case_name", "")
        if not case_name:
            return None

        # Step 3: Search for case details
        search_url = f"https://www.courtlistener.com/api/rest/v4/search/?q={case_name}"
        search_data = safe_api_call(search_url, headers, timeout=30)

        if not search_data or not search_data.get("results"):
            return None

        search_result = search_data["results"][0]

        # Extract opinion text
        opinion_text = get_best_opinion_text(opinion_data)

        # Build case record
        case = {
            "ID": opinion_id,
            "absolute_url": search_result.get("absolute_url"),
            "case_name": case_name,
            "case_full_name": search_result.get("caseNameFull"),
            "court": search_result.get("court"),
            "court_citation_string": search_result.get("court_citation_string"),
            "attorney": search_result.get('attorney'),
            "judge": search_result.get('judge'),
            "panel_names": search_result.get('panel_names'),
            "cite_to": search_result['opinions'][0]['cites'],
            "opinion_type": search_result['opinions'][0]['type'],
            "opinion": opinion_text
        }

        return case

    except Exception as e:
        print(f"❌ Error processing case {opinion_id}: {e}")
        return None

# %%
def process_by_batch_new(case_ids, batch_size=10, headers=None, output_dir="./datasets/"):
    """
    NEW: Process cases in batches with proper timeout handling and progress reporting
    """
    print("🚀 STARTING NEW BATCH PROCESSING")
    print("=" * 60)

    total_cases = len(case_ids)
    total_batches = math.ceil(total_cases / batch_size)

    print(f"📊 Processing {total_cases} cases in {total_batches} batches of {batch_size}")
    print(f"💾 Output directory: {output_dir}")
    print()

    all_cases = []
    start_time = time.time()

    # Process each batch
    for batch_num in range(total_batches):
        batch_start_time = time.time()

        # Get batch case IDs
        start_idx = batch_num * batch_size
        end_idx = min(start_idx + batch_size, total_cases)
        batch_case_ids = case_ids[start_idx:end_idx]

        print(f"📦 BATCH {batch_num + 1}/{total_batches}")
        print(f"   Processing cases: {batch_case_ids}")

        batch_cases = []
        successful_cases = 0

        # Process each case in the batch
        for i, case_id in enumerate(batch_case_ids):
            print(f"   🔄 Case {i+1}/{len(batch_case_ids)}: ID {case_id}")

            case_data = extract_single_case(case_id, headers)

            if case_data:
                batch_cases.append(case_data)
                successful_cases += 1
                print(f"   ✅ Success: {case_data['case_name']}")
            else:
                print(f"   ❌ Failed: ID {case_id}")

        # Save batch results
        output_path = f"{output_dir}case_cited_batch_{batch_num + 1}.json"
        with open(output_path, "w", encoding="utf-8") as f:
            json.dump(batch_cases, f, ensure_ascii=False, indent=2)

        all_cases.extend(batch_cases)

        # Calculate timing
        batch_time = time.time() - batch_start_time
        total_time = time.time() - start_time

        # Progress report
        print(f"   📈 Batch {batch_num + 1} completed:")
        print(f"      ✅ Successful: {successful_cases}/{len(batch_case_ids)} cases")
        print(f"      ⏱️  Batch time: {batch_time:.1f}s")
        print(f"      ⏱️  Total time: {total_time/60:.1f} minutes")
        print(f"      💾 Saved to: {output_path}")

        if batch_num < total_batches - 1:
            print(f"   ⏳ Waiting 2 seconds before next batch...")
            time.sleep(2)  # Short delay between batches

        print()

    # Final summary
    total_time = time.time() - start_time
    success_rate = len(all_cases) / total_cases * 100

    print("🎉 EXTRACTION COMPLETE!")
    print("=" * 60)
    print(f"📊 Total cases processed: {total_cases}")
    print(f"✅ Successfully extracted: {len(all_cases)}")
    print(f"❌ Failed extractions: {total_cases - len(all_cases)}")
    print(f"📈 Success rate: {success_rate:.1f}%")
    print(f"⏱️  Total time: {total_time/60:.1f} minutes")
    print(f"📊 Average time per case: {total_time/total_cases:.1f} seconds")
    print(f"💾 All batches saved to: {output_dir}")

    return pd.DataFrame(all_cases)

# %%
case_id_list = unique_cited_id_list[1669:16001] + unique_cited_id_list[17317:]
print(len(case_id_list))
# Out:
# 24490

# %%
headers = {"Authorization": "Token db39287c2b23954a0fda2c32fe8f0813db323385"}
result_df = process_by_batch_new(
    case_id_list,
    batch_size=1000,
    headers=headers,
    output_dir="./datasets/"
)
# Out:
# 🚀 STARTING NEW BATCH PROCESSING
# ============================================================
# 📊 Processing 24490 cases in 25 batches of 1000
# 💾 Output directory: ./datasets/
#
# 📦 BATCH 1/25
#    Processing cases: [6430154, 794064, 1973719, 1449432, 794092, 794093, 794103, 1580541, 1580545, 794117, 794123, 400907, 794125, 1449485, 7698, 1449491, 1973782, 400919, 7707, 400923, 400927, 1318433, 7719, 663081, 794154, 1711660, 7728, 794164, 663099, 7740, 2104899, 6430276, 1449541, 532042, 794187, 663115, 532047, 663126, 532058, 269915, 663136, 794210, 794215, 8920681, 401006, 1449583, 401024, 6430350, 532116, 794261, 401048, 794266, 2498210, 532132, 9707173, 794277, 401062, 794280, 532138, 2105010, 2629301, 794298, 7869, 6823618, 2367173, 7877, 11149010, 794324, 794334, 1973982, 7904, 794342, 794359, 1580799, 6430471, 794377, 1449740, 1449745, 794387, 3940117, 794414, 794420, 2367290, 2498372, 3940166, 794439, 11149127, 794441, 1580876, 794453, 794458, 1449818, 6430558, 6430566, 794475, 794482, 1711987, 1187709, 794496, 1449865, 270228, 2105238, 1580952, 8089, 1187742, 2629538, 8099, 1187755, 794543, 794544, 6037430, 1449914, 1580987, 1712064, 2367431, 794568, 1581003, 794572, 2629580, 2367436, 3416024, 794586, 1449946, 794588, 1449950, 1187815, 794604, 794607, 794612, 794615, 1449979, 794637, 1974293, 2367511, 2367522, 532516, 794672, 794677, 532536, 270396, 1450049, 2498626, 2367555, 1450053, 794698, 794707, 8659028, 8277, 2498646, 8278, 8282, 3940444, 2367587, 532584, 794729, 8659052, 794736, 794740, 8659066, 1581194, 663691, 794767, 1450133, 1843349, 1974424, 663711, 663715, 2105510, 2105515, 2367668, 663735, 794817, 9576643, 794826, 663755, 1188044, 663760, 2105558, 663767, 663774, 8416, 8425, 8426, 794859, 1450217, 663789, 794863, 2105584, 1843446, 794874, 8449, 532740, 1581318, 794896, 532764, 794911, 1450272, 794913, 794914, 2629925, 1712422, 1581350, 8659254, 2105662, 8659269, 1974598, 794951, 1450313, 1450314, 8659287, 532825, 794978, 6431077, 11149677, 6431093, 532856, 532860, 1450365, 8586, 2498955, 1581455, 8592, 795025, 795027, 1319315, 8598, 1712535, 8600, 8604, 795042, 8659366, 8615, 3154350, 6431156, 8659392, 795078, 8659399, 1450450, 1057237, 532960, 795111, 1843687, 11149802, 795114, 795117, 1319405, 664051, 8659445, 532981, 795129, 795140, 2630151, 664078, 664084, 8659482, 795163, 533023, 795169, 664099, 2105896, 664109, 2630193, 2368052, 11149878, 6431289, 664123, 795196, 795206, 664147, 2105944, 1581657, 664159, 5775967, 1581667, 664169, 1581675, 1712748, 8659565, 795248, 8659576, 2630266, 1974920, 795284, 8862, 795294, 1581730, 11149990, 402089, 795307, 2499246, 6431408, 795314, 795316, 5907139, 795332, 2106054, 1843916, 795345, 795355, 8659676, 795358, 1581792, 402146, 795371, 402156, 1450733, 8659696, 1319672, 795392, 402178, 402194, 1057558, 1057569, 2368291, 9002, 9006, 1450801, 9010, 795441, 8659764, 6431538, 795446, 9052982, 1450809, 1057596, 9024, 9029, 795465, 11150153, 1450834, 2368346, 1057627, 795484, 8659809, 1057635, 3941220, 1188714, 2368363, 1581931, 795499, 795505, 1844093, 1450881, 1057666, 2106255, 402321, 1057682, 2630547, 9184149, 3679127, 402334, 6955935, 11150248, 2106281, 1057709, 795566, 1975213, 795570, 1450945, 402374, 1713098, 795599, 8791001, 1975265, 795621, 1844204, 795644, 2106367, 795656, 2237451, 2106380, 795662, 402450, 795669, 1582107, 402459, 1057821, 664624, 1057841, 9267, 2106420, 1057847, 9277, 664638, 795716, 664647, 9291, 9292, 664652, 795726, 1451093, 402519, 533593, 664667, 795741, 795747, 533603, 7218276, 664676, 795751, 2499688, 664679, 1057899, 664683, 2499693, 664686, 795759, 1188976, 1451125, 1975417, 402559, 2761877, 795805, 11150494, 664740, 2368680, 664745, 664746, 795819, 1189036, 2237613, 1057977, 795839, 5645504, 795846, 1451217, 3941598, 1058023, 9448, 9455, 664816, 795897, 9469, 1189125, 795912, 2237708, 533773, 1713432, 7218458, 795939, 533796, 2368804, 2499880, 1058090, 9516, 1713453, 795949, 9521, 2106679, 6825273, 795965, 533826, 795974, 664904, 1189194, 664910, 271696, 664912, 533842, 533854, 1320290, 664930, 6956390, 533863, 1189228, 7218543, 664944, 1320318, 796030, 2631047, 2368905, 2368911, 2631065, 1058201, 1058205, 1320356, 2368934 ...
#    🔄 Case 1/1000: ID 6430154
#    ✅ Success: Gorham v. Moor
#    🔄 Case 2/1000: ID 794064
#    ❌ Failed: ID 794064
#    🔄 Case 3/1000: ID 1973719
#    ✅ Success: In Re McDermott
#    🔄 Case 4/1000: ID 1449432
#    ✅ Success: Dennis Joslin Co., LLC v. Johnson
#    🔄 Case 5/1000: ID 794092
#    ✅ Success: Chicago United Industries, Ltd. v. City of Chicago
#    🔄 Case 6/1000: ID 794093
#    ✅ Success: Evan S. Hull v. Stoughton Trailers, LLC
#    🔄 Case 7/1000: ID 794103
#    ✅ Success: Kathy J. Smith v. John E. Potter, Postmaster General of the United States
#    🔄 Case 8/1000: ID 1580541
#    ✅ Success: State v. Sims
#    🔄 Case 9/1000: ID 1580545
#    ✅ Success: In Re Rangel
#    🔄 Case 10/1000: ID 794117
#    ✅ Success: Tammy Powell v. Yellow Book Usa, Inc. Victoria Kreutz
#    🔄 Case 11/1000: ID 794123
#    ✅ Success: Stephen Cordry, Doing Business as Cordry Mobile Homes v. Vanderbilt Mortgage & Finance, Inc., 21st Mortgage Corporation v. Stephen Cordry
#    🔄 Case 12/1000: ID 400907
#    ✅ Success: Roy Export Company Establishment Of Vaduz, Liechtenstein v. Columbia Broadcasting System, Inc.
#    🔄 Case 13/1000: ID 794125
#    ✅ Success: United States v. Christopher Ray Plouffe
#    🔄 Case 14/1000: ID 1449485
#    ✅ Success: Perez v. Pappas
#    🔄 Case 15/1000: ID 7698
#    ✅ Success: McCallum Highlands, Ltd. v. Washington Capital Dus, Inc.
#    🔄 Case 16/1000: ID 1449491
#    ✅ Success: Burns v. McGraw-Hill Broadcasting Co., Inc.
#    🔄 Case 17/1000: ID 1973782
#    ✅ Success: Boynton Cab Co. v. Department of Industry, Labor & Human Relations
#    🔄 Case 18/1000: ID 400919
#    ❌ Failed: ID 400919
#    🔄 Case 19/1000: ID 7707
#    ✅ Success: Tacon Mechanical Contractors, Inc. v. Aetna Casualty & Surety Co.
#    🔄 Case 20/1000: ID 400923
#    ✅ Success: The Dow Chemical Company, Intervening v. Dr. James R. Allen and John Van Miller, and James P. Wachtendonk, Intervening
#    🔄 Case 21/1000: ID 400927
#    ✅ Success: Halet v. Wend Investment Co.
#    🔄 Case 22/1000: ID 1318433
#    ✅ Success: Hall v. FRUEHAUF CORPORATION
#    🔄 Case 23/1000: ID 7719
#    ✅ Success: Weaver v. Amoco Production Co.
#    🔄 Case 24/1000: ID 663081
#    ✅ Success: Thomas Conway, Plaintiff-Appellee-Cross-Appellant v. Icahn & Co., Inc., Defendant-Appellant-Cross-Appellee
#    🔄 Case 25/1000: ID 794154
#    ✅ Success: The Delaware Nation v. Commonwealth Of Pennsylvania
#    🔄 Case 26/1000: ID 1711660
#    ✅ Success: Van Baale v. City of Des Moines
#    🔄 Case 27/1000: ID 7728
#    ✅ Success: Lakoski v. James
#    🔄 Case 28/1000: ID 794164
#    ✅ Success: Edward Yashenko v. Harrah's Nc Casino Company, LLC
#    🔄 Case 29/1000: ID 663099
#    ✅ Success: Mildred Prunty v. Arkansas Freightways, Inc., and Chuck Baugh
#    🔄 Case 30/1000: ID 7740
#    ✅ Success: Manuel v. Westlake Polymers Corp.
#    🔄 Case 31/1000: ID 2104899
#    ✅ Success: Knapp v. Potamkin Motors Corp.
#    🔄 Case 32/1000: ID 6430276
#    ✅ Success: Timpany v. Handrahan
#    🔄 Case 33/1000: ID 1449541
#    ✅ Success: DeMello v. Home Escrow, Inc.
#    🔄 Case 34/1000: ID 532042
#    ✅ Success: Rosa R. v. Connelly
#    🔄 Case 35/1000: ID 794187
#    ✅ Success: Samuel Scaife v. Cook County, Michael F. Sheahan, Randy Pietrowski
#    🔄 Case 36/1000: ID 663115
#    ✅ Success: Jordan v. Indiana High School Athletic Association
#    🔄 Case 37/1000: ID 532047
# ❌ HTTP error for https://www.courtlistener.com/api/rest/v4/search/?q=The Clausen Company v. Dynatron/bondo Corporation: 500 Server Error: Internal Server Error for url: https://www.courtlistener.com/api/rest/v4/search/?q=The%20Clausen%20Company%20v.%20Dynatron/bondo%20Corporation
#    ❌ Failed: ID 532047
#    🔄 Case 38/1000: ID 663126
#    ✅ Success: Robert Flieger v. Paul K. Delo, Superintendent
#    🔄 Case 39/1000: ID 532058
#    ✅ Success: Illinois Central Gulf Railroad Company, Cross-Appellee v. International Paper Company, Cross-Appellant
#    🔄 Case 40/1000: ID 269915
#    ✅ Success: L. G. Simon, Doing Business as Simon Electric Company v. Maryland Casualty Company
#    🔄 Case 41/1000: ID 663136
#    ✅ Success: Melissa Sargent v. George T. Paul Tee Tool, Inc.
#    🔄 Case 42/1000: ID 794210
#    ✅ Success: Denise R. Hite v. Vermeer Manufacturing Company Rick Leedom
#    🔄 Case 43/1000: ID 794215
#    ✅ Success: Maelynn Tenge v. Phillips Modern Ag Co. Scott Phillips, Individually and in His Official Capacity Lori Phillips, Individually
#    🔄 Case 44/1000: ID 8920681
#    ✅ Success: Gresham v. Windrush Partners, Ltd.
#    🔄 Case 45/1000: ID 401006
#    ✅ Success: Lawrence Abram Benson, D.D.S. v. Arizona State Board of Dental Examiners
#    🔄 Case 46/1000: ID 1449583
#    ✅ Success: Sexton v. Gibbs
#    🔄 Case 47/1000: ID 401024
#    ✅ Success: Halderman v. Pennhurst State School & Hospital
#    🔄 Case 48/1000: ID 6430350
#    ✅ Success: Highland Foundry Co. v. New York, New Haven, & Hartford Railroad
#    🔄 Case 49/1000: ID 532116
#    ✅ Success: Daniel Kimbro, Plaintiff-Appellant/cross-Appellee v. Atlantic Richfield Company, Defendant-Appellee/cross-Appellant
#    🔄 Case 50/1000: ID 794261
# ❌ HTTP error for https://www.courtlistener.com/api/rest/v4/search/?q=In Re: Eagle-Picher Industries, Inc., Debtor. Caradon Doors and Windows, Inc. v. Eagle-Picher Industries, Inc., Movant-Appellant: 500 Server Error: Internal Server Error for url: https://www.courtlistener.com/api/rest/v4/search/?q=In%20Re:%20Eagle-Picher%20Industries,%20Inc.,%20Debtor.%20Caradon%20Doors%20and%20Windows,%20Inc.%20v.%20Eagle-Picher%20Industries,%20Inc.,%20Movant-Appellant
#    ❌ Failed: ID 794261
#    🔄 Case 51/1000: ID 401048
#    ❌ Failed: ID 401048
#    🔄 Case 52/1000: ID 794266
#    ✅ Success: Andrews v. Du Pont De Nemours and Company
#    🔄 Case 53/1000: ID 2498210
#    ✅ Success: Velez v. Janssen Ortho LLC
#    🔄 Case 54/1000: ID 532132
#    ✅ Success: Lombardi v. Small Business Administration
#    🔄 Case 55/1000: ID 9707173
#    ✅ Success: Wiseman v. Armstrong
#    🔄 Case 56/1000: ID 794277
#    ✅ Success: Reasonover v. St. Louis County
#    🔄 Case 57/1000: ID 401062
#    ❌ Failed: ID 401062
#    🔄 Case 58/1000: ID 794280
#    ❌ Failed: ID 794280
#    🔄 Case 59/1000: ID 532138
#    ✅ Success: Tally-Ho, Inc., a Florida Corporation, Plaintiff-Counter-Defendant-Appellant v. Coast Community College District, Defendant-Counter-Plaintiff-Appellee
#    🔄 Case 60/1000: ID 2105010
#    ✅ Success: Burkhart v. Davies
#    🔄 Case 61/1000: ID 2629301
#    ✅ Success: Van Sickle v. McGraw
#    🔄 Case 62/1000: ID 794298
#    ✅ Success: Wall Data Inc. v. Los Angeles County Sheriff's Department
#    🔄 Case 63/1000: ID 7869
#    ✅ Success: Washington v. Resolution Trust Corp.
#    🔄 Case 64/1000: ID 6823618
#    ✅ Success: In re Wesslau
#    🔄 Case 65/1000: ID 2367173
#    ✅ Success: Hernandez v. City of Hartford
#    🔄 Case 66/1000: ID 7877
#    ✅ Success: Kiser v. Garrett
#    🔄 Case 67/1000: ID 11149010
#    ✅ Success: Naylor v. Cardinal Local School Dist. Bd. of Edn.
#    🔄 Case 68/1000: ID 794324
#    ✅ Success: Samuel Stallings v. Hussmann Corporation Brian Groninger
#    🔄 Case 69/1000: ID 794334
#    ✅ Success: Karla Robinson v. Geico General Insurance Company
#    🔄 Case 70/1000: ID 1973982
#    ✅ Success: Master Financial, Inc. v. DeJulio (In Re DeJulio)
#    🔄 Case 71/1000: ID 7904
#    ✅ Success: Applewhite v. Reichhold Chemicals, Inc.
#    🔄 Case 72/1000: ID 794342
#    ✅ Success: Stanford T.E. McClure Jr. v. Career Systems Development Corporation Vinnell Corporation
#    🔄 Case 73/1000: ID 794359
#    ✅ Success: Besime Kanacevic v. Immigration and Naturalization Service
#    🔄 Case 74/1000: ID 1580799
#    ✅ Success: Woodall v. Hunnicutt Construction
#    🔄 Case 75/1000: ID 6430471
#    ✅ Success: Welsh v. Milton Water Co.
#    🔄 Case 76/1000: ID 794377
#    ✅ Success: Gary Kusens, Plaintiff-Appellant/cross-Appellee v. Pascal Company, Inc., Defendants-Appellees/cross-Appellants
#    🔄 Case 77/1000: ID 1449740
#    ✅ Success: In Re Windisch
#    🔄 Case 78/1000: ID 1449745
#    ✅ Success: Carone v. Retamco Operating, Inc.
#    🔄 Case 79/1000: ID 794387
#    ❌ Failed: ID 794387
#    🔄 Case 80/1000: ID 3940117
#    ✅ Success: O'Connor v. Quintana Petroleum Co.
#    🔄 Case 81/1000: ID 794414
#    ✅ Success: Miller v. Administrative Office of the Courts
#    🔄 Case 82/1000: ID 794420
#    ✅ Success: Arthur W. Fuesting v. Zimmer, Inc.
#    🔄 Case 83/1000: ID 2367290
#    ✅ Success: Kolpas v. G.D. Searle & Co.
#    🔄 Case 84/1000: ID 2498372
#    ✅ Success: Coddington v. Adelphi University
#    🔄 Case 85/1000: ID 3940166
#    ✅ Success: Craddock v. Sunshine Bus Lines, Inc.
#    🔄 Case 86/1000: ID 794439
#    ❌ Failed: ID 794439
#    🔄 Case 87/1000: ID 11149127
#    ✅ Success: Streetsboro Edn. Assn. v. Streetsboro City School Dist. Bd. of Edn.
#    🔄 Case 88/1000: ID 794441
#    ✅ Success: Richardson v. Sugg
#    🔄 Case 89/1000: ID 1580876
#    ✅ Success: Judice v. Hospital Serv. Dist. No. 1
#    🔄 Case 90/1000: ID 794453
#    ✅ Success: Jackie Ervin Rasberry v. Rosie B. Garcia, Warden
#    🔄 Case 91/1000: ID 794458
#    ✅ Success: Falko-Gunter Falkner, Georg Holzer, and Friedrich Dorner v. Stephen C. Inglis, Michael E.G. Boursnell, and Anthony C. Minson
#    🔄 Case 92/1000: ID 1449818
#    ✅ Success: Marinhagen v. Boster, Inc.
#    🔄 Case 93/1000: ID 6430558
#    ✅ Success: Blackburn v. Boston & Northern Street Railway Co.
#    🔄 Case 94/1000: ID 6430566
#    ✅ Success: Dulligan v. Barber Asphalt Paving Co.
#    🔄 Case 95/1000: ID 794475
#    ✅ Success: Dennis Paese v. Hartford Life and Accident Insurance Company
#    🔄 Case 96/1000: ID 794482
#    ✅ Success: Surrick v. Killion
#    🔄 Case 97/1000: ID 1711987
#    ✅ Success: State Ex Rel. Rt
#    🔄 Case 98/1000: ID 1187709
#    ✅ Success: Readenour v. Marion Power Shovel
#    🔄 Case 99/1000: ID 794496
#    ✅ Success: Ahmmad Pourghoraishi v. Flying J, Incorporated, Steve Lindgren, Larry Williams, City of Gary, Indiana, Nakon Security, Incorporated
#    🔄 Case 100/1000: ID 1449865
#    ✅ Success: Bland Independent School District v. Blue
#    🔄 Case 101/1000: ID 270228
#    ✅ Success: William Merle Canaday v. United States
#    🔄 Case 102/1000: ID 2105238
#    ✅ Success: Butts v. University of Osteopathic Medicine & Health Sciences
#    🔄 Case 103/1000: ID 1580952
#    ✅ Success: Solow v. Century Assets Corp.
#    🔄 Case 104/1000: ID 8089
#    ✅ Success: Davis v. Bayless
#    🔄 Case 105/1000: ID 1187742
#    ✅ Success: Iwen v. US West Direct
#    🔄 Case 106/1000: ID 2629538
#    ✅ Success: Eastwood v. Department
#    🔄 Case 107/1000: ID 8099
#    ✅ Success: Robertson v. Plano City of Texas
#    🔄 Case 108/1000: ID 1187755
#    ✅ Success: Fukuda v. City of Angels
#    🔄 Case 109/1000: ID 794543
#    ✅ Success: Peoples v. Cca Detention Centers
#    🔄 Case 110/1000: ID 794544
#    ✅ Success: Ramon Zamora v. Elite Logistics, Inc.
#    🔄 Case 111/1000: ID 6037430
#    ✅ Success: Perry v. Pelersi
#    🔄 Case 112/1000: ID 1449914
#    ✅ Success: Independent Living Center of Southern California, Inc. v. Maxwell-Jolly
#    🔄 Case 113/1000: ID 1580987
#    ✅ Success: Osterberg v. Peca
#    🔄 Case 114/1000: ID 1712064
#    ✅ Success: Flowers v. Dempsey-Tegeler & Co.
#    🔄 Case 115/1000: ID 2367431
#    ✅ Success: Kilroy v. Husson College
#    🔄 Case 116/1000: ID 794568
#    ✅ Success: Marquita Phillips v. Quebecor World Rai Incorporated
#    🔄 Case 117/1000: ID 1581003
#    ✅ Success: Bell v. Elmhurst Chicago Stone Co.
#    🔄 Case 118/1000: ID 794572
#    ✅ Success: Paul A. Wojewski, M.D., Sara Wojewski v. Rapid City Regional Hospital, Inc. Charles Hart, M.D. Robert Glenn Allen, Jr., M.D.
#    🔄 Case 119/1000: ID 2629580
#    ✅ Success: Roby v. McKesson Corp.
#    🔄 Case 120/1000: ID 2367436
#    ✅ Success: Hoffman v. Fidelity Brokerage Services, Inc.
#    🔄 Case 121/1000: ID 3416024
#    ✅ Success: Schneiderman v. Interstate Transit Lines, Inc.
#    🔄 Case 122/1000: ID 794586
#    ✅ Success: Forest Guardians v. Mike Johanns, Secretary of Agriculture United States Forest Service
#    🔄 Case 123/1000: ID 1449946
# ❌ HTTP error for https://www.courtlistener.com/api/rest/v4/search/?q=Horizon/CMS Healthcare Corporation v. Auld: 500 Server Error: Internal Server Error for url: https://www.courtlistener.com/api/rest/v4/search/?q=Horizon/CMS%20Healthcare%20Corporation%20v.%20Auld
#    ❌ Failed: ID 1449946
#    🔄 Case 124/1000: ID 794588
#    ✅ Success: United States v. Jervis Lavern Goodrich
#    🔄 Case 125/1000: ID 1449950
#    ✅ Success: Minneapolis Taxi Owners Coalition, Inc. v. City of Minneapolis
#    🔄 Case 126/1000: ID 1187815
#    ✅ Success: Gardner v. Evans
#    🔄 Case 127/1000: ID 794604
#    ✅ Success: Healy v. City Of Chicago
#    🔄 Case 128/1000: ID 794607
#    ✅ Success: Jarrod Wagner v. Hesston Corporation Agco Corporation Agco Corporation of Delaware
#    🔄 Case 129/1000: ID 794612
#    ✅ Success: Steven A. Breitkreutz, Orville Hillis v. Cambrex Charles City, Inc., Formerly Known as Salsbury Chemicals Inc.
#    🔄 Case 130/1000: ID 794615
#    ✅ Success: Robert Carter v. Ashland, Inc. John Jennex
#    🔄 Case 131/1000: ID 1449979
#    ✅ Success: State Ex Rel. Nixon v. American Tobacco Co.
#    🔄 Case 132/1000: ID 794637
#    ❌ Failed: ID 794637
#    🔄 Case 133/1000: ID 1974293
#    ✅ Success: Smith v. UNEMPLOYMENT COMP. BD., ETC.
#    🔄 Case 134/1000: ID 2367511
#    ✅ Success: Saunders v. Horn
#    🔄 Case 135/1000: ID 2367522
#    ✅ Success: Pan American Petroleum Corporation v. Texas Pacific Coal & Oil Company
#    🔄 Case 136/1000: ID 532516
#    ✅ Success: Duty Free Shop, Inc. v. Administracion De Terrenos De Puerto Rico
#    🔄 Case 137/1000: ID 794672
#    ❌ Failed: ID 794672
#    🔄 Case 138/1000: ID 794677
#    ✅ Success: Lankford v. Sherman
#    🔄 Case 139/1000: ID 532536
#    ✅ Success: Washington Hospital v. White
#    🔄 Case 140/1000: ID 270396
#    ✅ Success: Floyd Gene Bridger v. Union Railway Company
#    🔄 Case 141/1000: ID 1450049
#    ✅ Success: In Re Static Random Access Memory (SRAM) Antitrust Litigation
#    🔄 Case 142/1000: ID 2498626
#    ✅ Success: Dorchy v. Washington Metropolitan Area Transit Authority
#    🔄 Case 143/1000: ID 2367555
#    ✅ Success: Holland v. Foley Brothers Dry Goods Company
#    🔄 Case 144/1000: ID 1450053
#    ✅ Success: Sims v. Mme. Paulette Dry Cleaners
#    🔄 Case 145/1000: ID 794698
#    ✅ Success: Conrad Gorospe Shirley Gorospe v. Commissioner of Internal Revenue
#    🔄 Case 146/1000: ID 794707
#    ✅ Success: Robert Dark v. Curry County Curry County Road Department Dan Crumley, Individually and in His Official Capacity as Curry County Roadmaster
#    🔄 Case 147/1000: ID 8659028
#    ✅ Success: Williams v. United Corp.
#    🔄 Case 148/1000: ID 8277
#    ✅ Success: Daigle v. Liberty Life Insurance
#    🔄 Case 149/1000: ID 2498646
#    ✅ Success: Manhattan Ice & Cold Storage, Inc. v. City of Manhattan
#    🔄 Case 150/1000: ID 8278
#    ✅ Success: Pedraza v. Jones
#    🔄 Case 151/1000: ID 8282
#    ✅ Success: Perez v. Federal Bureau of Investigation
#    🔄 Case 152/1000: ID 3940444
#    ✅ Success: Rippy v. Rippy
#    🔄 Case 153/1000: ID 2367587
#    ✅ Success: Almonte v. Coca-Cola Bottling Co. of New York, Inc.
#    🔄 Case 154/1000: ID 532584
#    ✅ Success: Charles A. Bane v. Richard G. Ferguson
#    🔄 Case 155/1000: ID 794729
#    ✅ Success: Yassin Muhiddin Aref, Defendant-Petitioner v. United States of America, Plaintiff-Respondent, New York Civil Liberties Union, Movant
#    🔄 Case 156/1000: ID 8659052
#    ✅ Success: Arlington Funding Services, Inc. v. Geigel
#    🔄 Case 157/1000: ID 794736
#    ✅ Success: Kathleen Buck v. The Hampton Township School District Lawrence C. Korchnak, Dr
#    🔄 Case 158/1000: ID 794740
#    ✅ Success: Cheryl P. Francis v. Booz, Allen & Hamilton, Incorporated, Reserve Officers Association, Amicus Supporting
#    🔄 Case 159/1000: ID 8659066
#    ✅ Success: In re People
#    🔄 Case 160/1000: ID 1581194
#    ✅ Success: Greenberg v. New York State
#    🔄 Case 161/1000: ID 663691
#    ✅ Success: Charles Kowal v. MCI Communications Corporation
#    🔄 Case 162/1000: ID 794767
#    ✅ Success: Donna Valentine v. City of Chicago, a Municipal Corporation, John Tominello, Mike Ditusa, and Joseph Senese
#    🔄 Case 163/1000: ID 1450133
#    ✅ Success: Akin v. Santa Clara Land Co., Ltd.
#    🔄 Case 164/1000: ID 1843349
#    ✅ Success: Stoll v. Noel
#    🔄 Case 165/1000: ID 1974424
#    ✅ Success: Rodrigues v. Miriam Hospital
#    🔄 Case 166/1000: ID 663711
#    ✅ Success: Lawshe v. Simpson
#    🔄 Case 167/1000: ID 663715
#    ✅ Success: Keiko Larez, and v. William Holcomb, and Cross-Appellee
#    🔄 Case 168/1000: ID 2105510
#    ✅ Success: Alderson v. Rockwell International Corp.
#    🔄 Case 169/1000: ID 2105515
#    ✅ Success: Federated Publications, Inc. v. Board of Trustees
#    🔄 Case 170/1000: ID 2367668
# ❌ HTTP error for https://www.courtlistener.com/api/rest/v4/search/?q=Howell v. SAM'S CLUB 8160/WAL-MART: 500 Server Error: Internal Server Error for url: https://www.courtlistener.com/api/rest/v4/search/?q=Howell%20v.%20SAM'S%20CLUB%208160/WAL-MART
#    ❌ Failed: ID 2367668
#    🔄 Case 171/1000: ID 663735
#    ✅ Success: L & A Contracting Company v. Southern Concrete Services, Inc.
#    🔄 Case 172/1000: ID 794817
#    ✅ Success: Li Hua Lin v. United States Department of Justice Alberto R. Gonzales, Attorney General
#    🔄 Case 173/1000: ID 9576643
#    ✅ Success: Marcus Bros. Textiles, Inc. v. Price Waterhouse, LLP
#    🔄 Case 174/1000: ID 794826
#    ❌ Failed: ID 794826
#    🔄 Case 175/1000: ID 663755
#    ✅ Success: James W. Richardson v. Consolidated Rail Corporation
#    🔄 Case 176/1000: ID 1188044
#    ✅ Success: Diversified Management, Inc. v. Denver Post, Inc.
#    🔄 Case 177/1000: ID 663760
#    ✅ Success: United States v. Virgil Washington
#    🔄 Case 178/1000: ID 2105558
#    ✅ Success: Phelps v. Bross
#    🔄 Case 179/1000: ID 663767
#    ✅ Success: Little Rock School District v. Pulaski County Special School District
#    🔄 Case 180/1000: ID 663774
#    ✅ Success: In Re Jack Raley Construction, Inc.
#    🔄 Case 181/1000: ID 8416
#    ✅ Success: Vander Zee v. Reno
#    🔄 Case 182/1000: ID 8425
#    ✅ Success: Vera v. Tue
#    🔄 Case 183/1000: ID 8426
#    ✅ Success: Eason v. Thaler
#    🔄 Case 184/1000: ID 794859
#    ✅ Success: John Lee Conaway v. Marvin Polk, Warden, Central Prison, Raleigh, North Carolina North Carolina Attorney General
#    🔄 Case 185/1000: ID 1450217
#    ✅ Success: Ware v. Nicklin Associates, Inc.
#    🔄 Case 186/1000: ID 663789
#    ❌ Failed: ID 663789
#    🔄 Case 187/1000: ID 794863
#    ✅ Success: United States v. Larry Jo Leeson
#    🔄 Case 188/1000: ID 2105584
#    ✅ Success: Stajos v. City of Lansing
#    🔄 Case 189/1000: ID 1843446
#    ✅ Success: Hassett v. Altai, Inc. (In Re CIS Corp.)
#    🔄 Case 190/1000: ID 794874
#    ✅ Success: Donna Randolph v. Ohio Department of Youth Services
#    🔄 Case 191/1000: ID 8449
#    ✅ Success: Oswalt v. Sara Lee Corporation
#    🔄 Case 192/1000: ID 532740
#    ✅ Success: St. Louis Fuel and Supply Company, Inc. v. Federal Energy Regulatory Commission
#    🔄 Case 193/1000: ID 1581318
#    ✅ Success: Staub v. Boeing Co.
#    🔄 Case 194/1000: ID 794896
#    ✅ Success: Rosemary Sylvester v. Sos Children's Villages Illinois, Inc.
#    🔄 Case 195/1000: ID 532764
#    ❌ Failed: ID 532764
#    🔄 Case 196/1000: ID 794911
#    ✅ Success: Lucille K. Melvin v. Car-Freshener Corporation
#    🔄 Case 197/1000: ID 1450272
#    ✅ Success: Narducci v. Moore
#    🔄 Case 198/1000: ID 794913
#    ✅ Success: James L. Spann v. Sharon Roper Lorna Bell, Assistant Nurse
#    🔄 Case 199/1000: ID 794914
#    ✅ Success: Weems v. Little Rock Police Department
#    🔄 Case 200/1000: ID 2629925
#    ✅ Success: Paule v. Santa Fe County Board of County Commissioners
#    🔄 Case 201/1000: ID 1712422
#    ✅ Success: Southland Royalty Co. v. Pan American Petroleum Corp.
#    🔄 Case 202/1000: ID 1581350
#    ✅ Success: Helmly v. Stone Container Corp.
#    🔄 Case 203/1000: ID 8659254
#    ✅ Success: Rivenburgh v. CSX Transportation
#    🔄 Case 204/1000: ID 2105662
#    ✅ Success: State Ex Rel. Goettsch v. Diacide Distributors, Inc.
#    🔄 Case 205/1000: ID 8659269
#    ✅ Success: Banks v. International Rental & Leasing Corp.
#    🔄 Case 206/1000: ID 1974598
#    ✅ Success: Tyler v. State
#    🔄 Case 207/1000: ID 794951
#    ✅ Success: Louis Vuitton Malletier v. Dooney & Bourke, Inc., Docket No. 04-4941-Cv
#    🔄 Case 208/1000: ID 1450313
#    ✅ Success: Harris v. Mills
#    🔄 Case 209/1000: ID 1450314
#    ✅ Success: W. Dow Hamm III Corp. v. Millennium Income Fund, L.L.C.
#    🔄 Case 210/1000: ID 8659287
#    ✅ Success: Simpson v. Golden
#    🔄 Case 211/1000: ID 532825
#    ✅ Success: Jerry Ellis v. Jerry Butler, L.P.N. Maximum Security Unit, Jerry Ellis v. Dr. R. Jones, Lpn B. Marks, Maximum Security Unit
#    🔄 Case 212/1000: ID 794978
#    ✅ Success: Jackie Killian v. Yorozu Automotive Tennessee, Inc.
#    🔄 Case 213/1000: ID 6431077
#    ✅ Success: Stynes v. Boston Elevated Railway Co.
#    🔄 Case 214/1000: ID 11149677
#    ✅ Success: Columbus Bar Assn. v. Schlosser
#    🔄 Case 215/1000: ID 6431093
#    ✅ Success: Montgomery Door & Sash Co. v. Atlantic Lumber Co.
#    🔄 Case 216/1000: ID 532856
#    ✅ Success: Olan Jett v. Blue Cross and Blue Shield of Alabama, Inc., Medical Expense Plan
#    🔄 Case 217/1000: ID 532860
#    ✅ Success: Azteca Milling Co. v. The United States
#    🔄 Case 218/1000: ID 1450365
#    ✅ Success: City of Everett v. Estate of Sumstad
#    🔄 Case 219/1000: ID 8586
#    ✅ Success: Augustson v. Linea Aerea Nacional-Chile S.A. (LAN-Chile)
#    🔄 Case 220/1000: ID 2498955
#    ✅ Success: Bartell v. Lohiser
#    🔄 Case 221/1000: ID 1581455
#    ✅ Success: Ostrach v. Regents of the University of California
#    🔄 Case 222/1000: ID 8592
#    ✅ Success: Doe Ex Rel. Doe v. Rains County Independent School District
#    🔄 Case 223/1000: ID 795025
#    ✅ Success: Gordon v. Frank
#    🔄 Case 224/1000: ID 795027
#    ✅ Success: Bethany Reynolds v. Ethicon Endo-Surgery, Inc. Dave Burns
#    🔄 Case 225/1000: ID 1319315
#    ✅ Success: Davidson v. City of Westminster
#    🔄 Case 226/1000: ID 8598
#    ✅ Success: Cantu v. Rocha
#    🔄 Case 227/1000: ID 1712535
#    ✅ Success: Michel v. Efferson
#    🔄 Case 228/1000: ID 8600
#    ✅ Success: Baker v. Putnal
#    🔄 Case 229/1000: ID 8604
#    ✅ Success: Aetna Casualty & Surety Co. v. Iso-Tex, Inc.
#    🔄 Case 230/1000: ID 795042
#    ✅ Success: United States v. Edward Rosenthal, United States of America v. Edward Rosenthal
#    🔄 Case 231/1000: ID 8659366
#    ✅ Success: Joseph v. Daily News Publishing Co.
#    🔄 Case 232/1000: ID 8615
#    ✅ Success: Barrera-Montenegro v. USA & Drug Enforcement Administration
#    🔄 Case 233/1000: ID 3154350
#    ✅ Success: Matter of Witkowich v. Zoning Bd. of Appeals of Town of Yorktown
#    🔄 Case 234/1000: ID 6431156
#    ✅ Success: Thomson v. Pentecost
#    🔄 Case 235/1000: ID 8659392
#    ✅ Success: Anthony v. Firstbank Virgin Islands
#    🔄 Case 236/1000: ID 795078
#    ✅ Success: Berckeley Investment Group, Ltd. v. Douglas Colkitt
#    🔄 Case 237/1000: ID 8659399
#    ✅ Success: Najawicz v. People
#    🔄 Case 238/1000: ID 1450450
#    ✅ Success: Casillas v. Daines
#    🔄 Case 239/1000: ID 1057237
#    ✅ Success: Estate of George v. Vermont League of Cities & Towns
#    🔄 Case 240/1000: ID 532960
#    ✅ Success: Securities and Exchange Commission v. First City Financial Corporation, Ltd.
#    🔄 Case 241/1000: ID 795111
#    ✅ Success: April McMillan v. Collection Professionals, Incorporated, an Illinois Corporation
#    🔄 Case 242/1000: ID 1843687
#    ✅ Success: National City Bank v. Elliott (In Re Elliott)
#    🔄 Case 243/1000: ID 11149802
# ❌ HTTP error for https://www.courtlistener.com/api/rest/v4/search/?q=State ex rel. Johnson v. Cleveland Hts./Univ. Hts. School Dist. Bd. of Edn.: 500 Server Error: Internal Server Error for url: https://www.courtlistener.com/api/rest/v4/search/?q=State%20ex%20rel.%20Johnson%20v.%20Cleveland%20Hts./Univ.%20Hts.%20School%20Dist.%20Bd.%20of%20Edn.
#    ❌ Failed: ID 11149802
#    🔄 Case 244/1000: ID 795114
#    ✅ Success: Jimmie Treadwell v. Office of the Illinois Secretary of State
#    🔄 Case 245/1000: ID 795117
#    ✅ Success: Brenda Patton v. Keystone Rv Company
#    🔄 Case 246/1000: ID 1319405
#    ✅ Success: Campbell v. General Motors Corp.
#    🔄 Case 247/1000: ID 664051
#    ✅ Success: Marc J. Anderson & Jeffrey E. Grubb v. Dennis Branen, Ross Kindestin, Ed Wisniefski
#    🔄 Case 248/1000: ID 8659445
#    ✅ Success: Simmonds v. People
#    🔄 Case 249/1000: ID 532981
#    ✅ Success: Nuclear Transport & Storage, Inc. v. United States
#    🔄 Case 250/1000: ID 795129
#    ✅ Success: Charlotte Klingler v. Director, Department Of Revenue, State Of Missouri
#    🔄 Case 251/1000: ID 795140
#    ✅ Success: Pedro Garcia-Quintero v. Alberto R. Gonzales, Attorney General
#    🔄 Case 252/1000: ID 2630151
#    ✅ Success: Alpine Lumber Co. v. Capital West National Bank
#    🔄 Case 253/1000: ID 664078
#    ✅ Success: Patsy Elaine CARMON, Plaintiff-Appellant, v. LUBRIZOL CORPORATION, Defendant-Appellee
#    🔄 Case 254/1000: ID 664084
#    ✅ Success: Kelley v. De Nemours and Company
#    🔄 Case 255/1000: ID 8659482
#    ✅ Success: Pichierri v. Crowley
#    🔄 Case 256/1000: ID 795163
#    ✅ Success: Oyenike Alaka v. Attorney General of the United States Secretary of Department of Homeland Security
#    🔄 Case 257/1000: ID 533023
#    ✅ Success: Mark Tarka v. G. Charles Franklin
#    🔄 Case 258/1000: ID 795169
#    ✅ Success: Kathleen Sanford, Individually and as Administratrix of the Estate of Michael R. Sanford v. Pamela Stiles Dennis Murphy East Penn School District
#    🔄 Case 259/1000: ID 664099
#    ✅ Success: Psi Energy, Inc. v. Exxon Coal Usa, Inc., and Exxon Corporation
#    🔄 Case 260/1000: ID 2105896
#    ✅ Success: Rehabilitative Care Systems of America v. Davis
#    🔄 Case 261/1000: ID 664109
#    ✅ Success: Stephen Eberhardt v. Jack O'Malley
#    🔄 Case 262/1000: ID 2630193
#    ✅ Success: Simek v. Tate
#    🔄 Case 263/1000: ID 2368052
#    ✅ Success: Leelanau Wine Cellars, Ltd. v. Black & Red, Inc.
#    🔄 Case 264/1000: ID 11149878
#    ✅ Success: State ex rel. Ms. Parsons Constr., Inc. v. Moyer
#    🔄 Case 265/1000: ID 6431289
#    ✅ Success: Opinion of the Justices to the Senate
#    🔄 Case 266/1000: ID 664123
#    ❌ Failed: ID 664123
#    🔄 Case 267/1000: ID 795196
#    ❌ Failed: ID 795196
#    🔄 Case 268/1000: ID 795206
#    ✅ Success: Advantage Media, L.L.C. v. City Of Eden Prairie
#    🔄 Case 269/1000: ID 664147
#    ✅ Success: Homeland Stores, Inc. v. Resolution Trust Corporation, and Bob's Super Saver, Inc.
#    🔄 Case 270/1000: ID 2105944
#    ✅ Success: AmQuip Corp. v. Cloud
#    🔄 Case 271/1000: ID 1581657
#    ✅ Success: Schneider v. South Dakota Department of Transportation
#    🔄 Case 272/1000: ID 664159
#    ✅ Success: Martha Griffith v. State of Colorado, Division of Youth Services
#    🔄 Case 273/1000: ID 5775967
#    ✅ Success: Westbury Laundromat, Inc. v. Mammina
#    🔄 Case 274/1000: ID 1581667
#    ✅ Success: Guckenberger v. Boston University
#    🔄 Case 275/1000: ID 664169
#    ❌ Failed: ID 664169
#    🔄 Case 276/1000: ID 1581675
#    ✅ Success: Nissim v. McNEIL CONSUMER PRODUCTS CO., INC.
#    🔄 Case 277/1000: ID 1712748
#    ✅ Success: Hidalgo v. Surety Savings and Loan Association
#    🔄 Case 278/1000: ID 8659565
#    ✅ Success: Bryan v. Fawkes
#    🔄 Case 279/1000: ID 795248
# ❌ HTTP error for https://www.courtlistener.com/api/rest/v4/search/?q=Gina Williams v. New York City Housing Authority, Teamsters Local 237/i.b.t, Docket No. 04-2531-Cv: 500 Server Error: Internal Server Error for url: https://www.courtlistener.com/api/rest/v4/search/?q=Gina%20Williams%20v.%20New%20York%20City%20Housing%20Authority,%20Teamsters%20Local%20237/i.b.t,%20Docket%20No.%2004-2531-Cv
#    ❌ Failed: ID 795248
#    🔄 Case 280/1000: ID 8659576
#    ✅ Success: Machado v. Yacht Haven U.S.V.I., LLC
#    🔄 Case 281/1000: ID 2630266
#    ✅ Success: Heber Light & Power Co. v. Utah Public Service Commission
#    🔄 Case 282/1000: ID 1974920
#    ✅ Success: Hurley v. Frontier Ford Motors, Inc.
#    🔄 Case 283/1000: ID 795284
#    ✅ Success: Patricia A. Daffin, on Behalf of Herself and All Others Similarly Situated v. Ford Motor Company
#    🔄 Case 284/1000: ID 8862
#    ✅ Success: United States v. Pettigrew
#    🔄 Case 285/1000: ID 795294
#    ✅ Success: Gabe Keri v. Board of Trustees of Purdue University
#    🔄 Case 286/1000: ID 1581730
#    ✅ Success: Winfrey v. City of Chicago
#    🔄 Case 287/1000: ID 11149990
#    ✅ Success: State ex rel. Youngstown v. Mahoning Cty. Bd. of Elections
#    🔄 Case 288/1000: ID 402089
#    ❌ Failed: ID 402089
#    🔄 Case 289/1000: ID 795307
#    ❌ Failed: ID 795307
#    🔄 Case 290/1000: ID 2499246
#    ✅ Success: Bram v. United States
#    🔄 Case 291/1000: ID 6431408
#    ✅ Success: Scannell v. Boston Elevated Railway Co.
#    🔄 Case 292/1000: ID 795314
# ❌ HTTP error for https://www.courtlistener.com/api/rest/v4/clusters/795314/: 502 Server Error: Bad Gateway for url: https://www.courtlistener.com/api/rest/v4/clusters/795314/
#    ❌ Failed: ID 795314
#    🔄 Case 293/1000: ID 795316
#    ✅ Success: United States v. Mary K. Edelmann
#    🔄 Case 294/1000: ID 5907139
#    ✅ Success: Corcoran v. National Union Fire Insurance
#    🔄 Case 295/1000: ID 795332
#    ❌ Failed: ID 795332
#    🔄 Case 296/1000: ID 2106054
#    ✅ Success: Pendleton v. Mills
#    🔄 Case 297/1000: ID 1843916
#    ✅ Success: In Re WA Mallory Co., Inc.
#    🔄 Case 298/1000: ID 795345
#    ✅ Success: Nippon Steel Corporation, Nkk Corporation, Kawasaki Steel Corporation, and Toyo Kohan Co., Ltd. v. United States, and Mittal Steel USA Isg Inc.
#    🔄 Case 299/1000: ID 795355
#    ✅ Success: Lerner v. Fleet Bank
#    🔄 Case 300/1000: ID 8659676
#    ✅ Success: Bertrand v. Mystic Granite & Marble, Inc.
#    🔄 Case 301/1000: ID 795358
#    ❌ Failed: ID 795358
#    🔄 Case 302/1000: ID 1581792
#    ✅ Success: Daigle v. Friendly Ice Cream Corp.
#    🔄 Case 303/1000: ID 402146
#    ❌ Failed: ID 402146
#    🔄 Case 304/1000: ID 795371
#    ✅ Success: Communities for Equity v. Michigan High School Athletic Association
#    🔄 Case 305/1000: ID 402156
#    ❌ Failed: ID 402156
#    🔄 Case 306/1000: ID 1450733
#    ✅ Success: In Re McAllen Medical Center, Inc.
#    🔄 Case 307/1000: ID 8659696
#    ✅ Success: United Corp. v. Hamed
#    🔄 Case 308/1000: ID 1319672
#    ✅ Success: Sebring v. Colver
#    🔄 Case 309/1000: ID 795392
#    ✅ Success: Linda Green v. Franklin National Bank of Minneapolis, Doing Business as Franklin Bank
#    🔄 Case 310/1000: ID 402178
#    ✅ Success: Public Power Council v. Peter Johnson
#    🔄 Case 311/1000: ID 402194
#    ✅ Success: Catherine H. Johnson MILAM, Plaintiff-Appellant, v. UNITED STATES POSTAL SERVICE, Defendant-Appellee
#    🔄 Case 312/1000: ID 1057558
#    ✅ Success: State v. Dorantes
#    🔄 Case 313/1000: ID 1057569
#    ✅ Success: Brown v. Tennessee Title Loans, Inc.
#    🔄 Case 314/1000: ID 2368291
#    ✅ Success: Clark v. Posey
#    🔄 Case 315/1000: ID 9002
#    ✅ Success: Grabowski v. Jackson County Public Defenders Office
#    🔄 Case 316/1000: ID 9006
#    ✅ Success: Scottish Heritable Trust v. Peat Marwick Main & Co.
#    🔄 Case 317/1000: ID 1450801
#    ✅ Success: Linton v. State
#    🔄 Case 318/1000: ID 9010
#    ✅ Success: Meadowbriar Home for Children, Inc. v. Gunn
#    🔄 Case 319/1000: ID 795441
# ❌ HTTP error for https://www.courtlistener.com/api/rest/v4/search/?q=Cam I, Inc. And Blue Sky Video, Inc. v. Louisville/jefferson County Metro Government: 500 Server Error: Internal Server Error for url: https://www.courtlistener.com/api/rest/v4/search/?q=Cam%20I,%20Inc.%20And%20Blue%20Sky%20Video,%20Inc.%20v.%20Louisville/jefferson%20County%20Metro%20Government
#    ❌ Failed: ID 795441
#    🔄 Case 320/1000: ID 8659764
#    ✅ Success: Marsh-Monsanto v. Clarenbach
#    🔄 Case 321/1000: ID 6431538
#    ✅ Success: John Hetherington & Sons, Ltd. v. William Firth Co.
#    🔄 Case 322/1000: ID 795446
#    ✅ Success: James W. Smoak v. Eric Hall, David Bush Jeff Phann Tim McHood Brian Brock Jerry Andrews, Lieutenant
#    🔄 Case 323/1000: ID 9052982
#    ✅ Success: American Postal Workers Union v. United States Postal Service
#    🔄 Case 324/1000: ID 1450809
#    ✅ Success: Smith v. Brown & Williamson Tobacco Corp.
#    🔄 Case 325/1000: ID 1057596
#    ✅ Success: State v. Majors
#    🔄 Case 326/1000: ID 9024
#    ✅ Success: Wallace v. Texas Tech Univ.
#    🔄 Case 327/1000: ID 9029
#    ✅ Success: Palma v. Verex Assurance, Inc.
#    🔄 Case 328/1000: ID 795465
#    ✅ Success: James T. Allen v. Timothy W. Martin, Brian Piersma and Robert Millette
#    🔄 Case 329/1000: ID 11150153
#    ✅ Success: State ex rel. OTR v. Columbus
#    🔄 Case 330/1000: ID 1450834
#    ✅ Success: Guckenberger v. Boston University
#    🔄 Case 331/1000: ID 2368346
#    ✅ Success: Capan v. Divine Providence Hospital
#    🔄 Case 332/1000: ID 1057627
#    ✅ Success: Leggett v. Duke Energy Corp.
#    🔄 Case 333/1000: ID 795484
#    ✅ Success: Davel Communications, Inc. v. Qwest Corp.
#    🔄 Case 334/1000: ID 8659809
#    ✅ Success: Gerald v. R.J. Reynolds Tobacco Co.
#    🔄 Case 335/1000: ID 1057635
#    ✅ Success: Sneed v. Board of Professional Responsibility
#    🔄 Case 336/1000: ID 3941220
#    ✅ Success: Lewis v. East Texas Finance Co.
#    🔄 Case 337/1000: ID 1188714
#    ✅ Success: Mark v. Seattle Times
#    🔄 Case 338/1000: ID 2368363
#    ✅ Success: National Federation of the Blind v. Target Corp.
#    🔄 Case 339/1000: ID 1581931
#    ✅ Success: Olson v. Synergistic Technologies Business Systems, Inc.
#    🔄 Case 340/1000: ID 795499
#    ✅ Success: Meacham v. Knolls Atomic Power Laboratory
#    🔄 Case 341/1000: ID 795505
#    ❌ Failed: ID 795505
#    🔄 Case 342/1000: ID 1844093
#    ✅ Success: Souther v. Safeco Life Insurance Co. (In Re Cooper)
#    🔄 Case 343/1000: ID 1450881
# ❌ HTTP error for https://www.courtlistener.com/api/rest/v4/search/?q=Berschauer/Phillips Construction Co. v. Seattle School District No. 1: 500 Server Error: Internal Server Error for url: https://www.courtlistener.com/api/rest/v4/search/?q=Berschauer/Phillips%20Construction%20Co.%20v.%20Seattle%20School%20District%20No.%201
#    ❌ Failed: ID 1450881
#    🔄 Case 344/1000: ID 1057666
#    ✅ Success: STATE of Tennessee v. Marcus RICHARDS
#    🔄 Case 345/1000: ID 2106255
#    ✅ Success: Spir Star Ag v. Kimich
#    🔄 Case 346/1000: ID 402321
#    ✅ Success: Debora D. Gordon v. National Youth Work Alliance
#    🔄 Case 347/1000: ID 1057682
#    ✅ Success: State v. Hanson
#    🔄 Case 348/1000: ID 2630547
#    ✅ Success: Korea Supply Co. v. Lockheed Martin Corp.
#    🔄 Case 349/1000: ID 9184149
#    ✅ Success: Florida v. J. L.
#    🔄 Case 350/1000: ID 3679127
#    ✅ Success: Wharton v. City of Greensboro
#    🔄 Case 351/1000: ID 402334
#    ✅ Success: Elmer G. Berry v. Richard Schweiker, Secretary of Health and Human Services
#    🔄 Case 352/1000: ID 6955935
#    ✅ Success: Clark v. California
#    🔄 Case 353/1000: ID 11150248
#    ✅ Success: State ex rel. SuperAmerica Group v. Licking Cty. Bd. of Elections
#    🔄 Case 354/1000: ID 2106281
#    ✅ Success: Loehr v. Ventura County Community College District
#    🔄 Case 355/1000: ID 1057709
#    ✅ Success: State v. Day
#    🔄 Case 356/1000: ID 795566
#    ✅ Success: Glenn Cassimy v. Board of Education of the Rockford Public Schools, District 205
#    🔄 Case 357/1000: ID 1975213
#    ✅ Success: Connelly v. University of Vermont & State Agricultural College
#    🔄 Case 358/1000: ID 795570
#    ✅ Success: Rashid Arraleh v. County of Ramsey Terry Zurn, Individually
#    🔄 Case 359/1000: ID 1450945
#    ✅ Success: Dominguez v. City of Council Bluffs, Iowa
#    🔄 Case 360/1000: ID 402374
#    ✅ Success: Leon G. Nichols, Rudolph J. Bystrak, Intervenors-Appellants v. Mobile Board of Realtors, Inc.
#    🔄 Case 361/1000: ID 1713098
#    ✅ Success: St. Paul Fire & Marine Ins. Co. v. Anderson
#    🔄 Case 362/1000: ID 795599
#    ❌ Failed: ID 795599
#    🔄 Case 363/1000: ID 8791001
#    ✅ Success: Grimes v. Employers Mutual Liability Insurance
#    🔄 Case 364/1000: ID 1975265
#    ✅ Success: Simmons v. Eagle Seelatsee
#    🔄 Case 365/1000: ID 795621
#    ❌ Failed: ID 795621
#    🔄 Case 366/1000: ID 1844204
#    ✅ Success: Hulme v. Barrett
#    🔄 Case 367/1000: ID 795644
#    ✅ Success: Linh Thanongsinh v. Board of Education, District U-46 and Hanan Javetz, Individually and in His Official Capacity
#    🔄 Case 368/1000: ID 2106367
#    ✅ Success: Wilson v. State
#    🔄 Case 369/1000: ID 795656
#    ✅ Success: Senty-Haugen v. Goodno
#    🔄 Case 370/1000: ID 2237451
#    ✅ Success: Anderson v. Phoenix Investment Counsel of Boston, Inc.
#    🔄 Case 371/1000: ID 2106380
#    ✅ Success: In Re Commitment of Dodson
#    🔄 Case 372/1000: ID 795662
#    ✅ Success: Shirdena M. Twymon v. Wells Fargo & Company, Doing Business as Wells Fargo Home Mortgage, Inc.
#    🔄 Case 373/1000: ID 402450
#    ✅ Success: Safeway Stores, Incorporated, Cross-Appellee v. Safeway Discount Drugs, Inc., Cross-Appellant
#    🔄 Case 374/1000: ID 795669
#    ✅ Success: Equal Employment Opportunity Commission v. Trans States Airlines
#    🔄 Case 375/1000: ID 1582107
#    ✅ Success: Lekich v. International Business MacHines Corp.
#    🔄 Case 376/1000: ID 402459
#    ✅ Success: Louis L. ANDERSON, Jr., Plaintiff-Appellant, v. SAVAGE LABORATORIES, INC., a Corporation, Defendant-Appellee
#    🔄 Case 377/1000: ID 1057821
#    ✅ Success: State v. Campbell
#    🔄 Case 378/1000: ID 664624
#    ✅ Success: Ellen Mendes v. Medtronic, Inc.
#    🔄 Case 379/1000: ID 1057841
#    ✅ Success: UT Medical Group, Inc. v. Vogt
#    🔄 Case 380/1000: ID 9267
#    ✅ Success: Brown v. CSC Logic, Inc.
#    🔄 Case 381/1000: ID 2106420
#    ✅ Success: Barratt v. Cushman & Wakefield of New Jersey, Inc.
#    🔄 Case 382/1000: ID 1057847
#    ✅ Success: State v. Berrios
#    🔄 Case 383/1000: ID 9277
#    ✅ Success: Altman Nursing, Inc. v. Clay Capital Corp.
#    🔄 Case 384/1000: ID 664638
#    ✅ Success: Brian Sheppard v. Leon Beerman, as an Individual and in His Official Capacity as Justice of the Supreme Court of the State of New York
#    🔄 Case 385/1000: ID 795716
#    ✅ Success: Equal Employment Opportunity Commission v. Watkins Motor Lines, Inc.
#    🔄 Case 386/1000: ID 664647
#    ✅ Success: In Re Trans World Airlines, Incorporated
#    🔄 Case 387/1000: ID 9291
#    ✅ Success: Texas Independent Party v. Kirk
#    🔄 Case 388/1000: ID 9292
#    ✅ Success: Rizzo v. Children's World Learning Centers, Inc.
#    🔄 Case 389/1000: ID 664652
#    ✅ Success: Darrell E. Brown v. Csx Transportation, Incorporated, a Corporation
#    🔄 Case 390/1000: ID 795726
#    ✅ Success: Teresa Tysinger v. Police Department of the City of Zanesville
#    🔄 Case 391/1000: ID 1451093
#    ✅ Success: Diaz Ex Rel. Diaz v. Feil
#    🔄 Case 392/1000: ID 402519
#    ✅ Success: Marion S. RICE, Plaintiff, Appellant, v. NEW ENGLAND COLLEGE, Defendant, Appellee
#    🔄 Case 393/1000: ID 533593
#    ✅ Success: Wilbert J. Sheets, Cross-Appellant v. Yamaha Motors Corporation, U.S.A. And Yamaha Motor Co. Ltd. Of Iwata, Japan, Cross-Appellees
#    🔄 Case 394/1000: ID 664667
#    ✅ Success: Michigan Protection and Advocacy Service, Incorporated v. Babin
#    🔄 Case 395/1000: ID 795741
#    ✅ Success: Steven L. Anders v. Waste Management of Wisconsin, Incorporated, Subsidiary, and Waste Management, Incorporated, a Parent Corporation
#    🔄 Case 396/1000: ID 795747
#    ✅ Success: Lateirra R. Sublett v. John Wiley & Sons, Inc. & Wiley Publishing, Inc.
#    🔄 Case 397/1000: ID 533603
#    ✅ Success: Wells v. Brown
#    🔄 Case 398/1000: ID 7218276
#    ✅ Success: Shapiro v. Secretary of Health & Human Services
#    🔄 Case 399/1000: ID 664676
#    ✅ Success: In the Matter of Barry Stuart Udell, Debtor-Appellee. Appeal of the Standard Carpetland Usa, Inc.
#    🔄 Case 400/1000: ID 795751
#    ✅ Success: Laura Phelan v. Cook County
#    🔄 Case 401/1000: ID 2499688
#    ✅ Success: Kirkland v. St. Elizabeth Hospital
#    🔄 Case 402/1000: ID 664679
#    ❌ Failed: ID 664679
#    🔄 Case 403/1000: ID 1057899
#    ✅ Success: CATTANO v. Bragg
#    🔄 Case 404/1000: ID 664683
#    ✅ Success: Kelvin Highsmith, Marcita Highsmith, and Joseph Villasenor v. Chrysler Credit Corporation
#    🔄 Case 405/1000: ID 2499693
#    ✅ Success: In Re Sumitomo Copper Litigation
#    🔄 Case 406/1000: ID 664686
#    ❌ Failed: ID 664686
#    🔄 Case 407/1000: ID 795759
#    ✅ Success: Reverend Gary Thompson v. Bi-State Development Agency, Doing Business as Metro
#    🔄 Case 408/1000: ID 1188976
#    ✅ Success: Nahrstedt v. Lakeside Village Condominium Assn.
#    🔄 Case 409/1000: ID 1451125
#    ✅ Success: Pele Defense Fund v. Puna Geothermal Venture
#    🔄 Case 410/1000: ID 1975417
#    ✅ Success: Hassan v. Begley
#    🔄 Case 411/1000: ID 402559
#    ✅ Success: Fed. Sec. L. Rep. P 98,643 Securities and Exchange Commission v. Washington County Utility District, Wade H. Patrick
#    🔄 Case 412/1000: ID 2761877
#    ✅ Success: Lawrence Arduini v. Igt
#    🔄 Case 413/1000: ID 795805
#    ✅ Success: Yves Gautier Edimo-Doualla v. Alberto R. Gonzales, 1
#    🔄 Case 414/1000: ID 11150494
#    ✅ Success: Disciplinary Counsel v. Koury
#    🔄 Case 415/1000: ID 664740
#    ❌ Failed: ID 664740
#    🔄 Case 416/1000: ID 2368680
#    ✅ Success: Colorado Cross-Disability Coalition v. Too (Delaware), Inc.
#    🔄 Case 417/1000: ID 664745
#    ✅ Success: Perry Fields v. Farmers Insurance Company, Inc. Government Employees Hospital Association
#    🔄 Case 418/1000: ID 664746
#    ✅ Success: Mary P. Durham v. Xerox Corporation, a New York Corporation Doing Business in the State of Oklahoma
#    🔄 Case 419/1000: ID 795819
#    ✅ Success: Brown v. Card Service Center
#    🔄 Case 420/1000: ID 1189036
#    ✅ Success: Takele v. Mayo Clinic
#    🔄 Case 421/1000: ID 2237613
#    ✅ Success: Pepsi-Cola General Bottlers, Inc. v. Woods
#    🔄 Case 422/1000: ID 1057977
#    ✅ Success: Whaley v. Perkins
#    🔄 Case 423/1000: ID 795839
#    ✅ Success: Joseph Lopez v. City of Chicago, Jennifer Delucia, James Delafont, Daniel Jacobs, and Hector Vergara
#    🔄 Case 424/1000: ID 5645504
#    ✅ Success: Adams v. Moffatt
#    🔄 Case 425/1000: ID 795846
#    ✅ Success: Pamela J. Burks v. Wisconsin Department of Transportation, Marcia L. Traska, and Mary P. Forlenza
#    🔄 Case 426/1000: ID 1451217
#    ✅ Success: ConAgra Foods, Inc. v. Draper
#    🔄 Case 427/1000: ID 3941598
#    ✅ Success: King v. Monitor Drill Company
#    🔄 Case 428/1000: ID 1058023
#    ✅ Success: Dabney v. Augusta Mut. Ins. Co.
#    🔄 Case 429/1000: ID 9448
#    ✅ Success: Jennifer Waymire v. Harris County, Texas
#    🔄 Case 430/1000: ID 9455
#    ✅ Success: Ray v. Glidden Company
#    🔄 Case 431/1000: ID 664816
#    ✅ Success: Fdic v. Adam
#    🔄 Case 432/1000: ID 795897
#    ✅ Success: Gregson Joseph v. Michael O. Leavitt, Secretary of Department of Health & Human Services, Docket No. 05-3348-Cv
#    🔄 Case 433/1000: ID 9469
#    ✅ Success: Buchanan v. City of San Antonio
#    🔄 Case 434/1000: ID 1189125
#    ✅ Success: Henderson v. PENNWALT CORPORATION
#    🔄 Case 435/1000: ID 795912
#    ✅ Success: Lois Jones v. Thomas Brennan
#    🔄 Case 436/1000: ID 2237708
#    ✅ Success: Demchuk v. Duplancich
#    🔄 Case 437/1000: ID 533773
#    ✅ Success: United States v. Willie Williams
#    🔄 Case 438/1000: ID 1713432
#    ✅ Success: Kirschke v. City of Houston
#    🔄 Case 439/1000: ID 7218458
#    ✅ Success: Isaac v. Secretary of the Department of Health & Human Services
#    🔄 Case 440/1000: ID 795939
#    ✅ Success: Nush Gjolaj v. Bureau of Citizenship and Immigration Services
#    🔄 Case 441/1000: ID 533796
#    ✅ Success: Thomas J. O'DOnnell v. United States
#    🔄 Case 442/1000: ID 2368804
#    ✅ Success: Georgetown Associates, Ltd. v. Home Federal Savings & Loan Ass'n
#    🔄 Case 443/1000: ID 2499880
#    ✅ Success: Quaak v. Dexia, S.A.
#    🔄 Case 444/1000: ID 1058090
#    ✅ Success: State v. Rice
#    🔄 Case 445/1000: ID 9516
#    ✅ Success: Clardy Manufacturing Co. v. Marine Midland Business Loans Inc.
#    🔄 Case 446/1000: ID 1713453
#    ✅ Success: Crews v. HOUSTON CTY. DEPT. OF PENSIONS & SEC.
#    🔄 Case 447/1000: ID 795949
#    ✅ Success: Bank of Louisiana v. Aetna U.S. Healthcare Inc. Aetna Life Insurance Company
#    🔄 Case 448/1000: ID 9521
#    ✅ Success: Rogers v. International Marine Terminals, Inc.
#    🔄 Case 449/1000: ID 2106679
#    ✅ Success: Woods-Pirozzi v. Nabisco Foods
#    🔄 Case 450/1000: ID 6825273
#    ✅ Success: Snowbank Enterprises, Inc. v. United States
#    🔄 Case 451/1000: ID 795965
#    ✅ Success: Ahmed Ali v. Deborah Achim, Michael Chertoff, and Alberto Gonzales, Ahmed Ali v. Alberto Gonzales
#    🔄 Case 452/1000: ID 533826
#    ✅ Success: United States v. Kojo Sababu, Jaime Delgado, and Dora Garcia
#    🔄 Case 453/1000: ID 795974
#    ❌ Failed: ID 795974
#    🔄 Case 454/1000: ID 664904
#    ❌ Failed: ID 664904
#    🔄 Case 455/1000: ID 1189194
#    ✅ Success: Blades v. DaFoe
#    🔄 Case 456/1000: ID 664910
# ❌ HTTP error for https://www.courtlistener.com/api/rest/v4/search/?q=Beverly P. Davis, Wife Of/and Willie Earl Davis v. Odeco, Inc., Murphy Exploration & Production Company, Originally Sued as Odeco, Inc.: 500 Server Error: Internal Server Error for url: https://www.courtlistener.com/api/rest/v4/search/?q=Beverly%20P.%20Davis,%20Wife%20Of/and%20Willie%20Earl%20Davis%20v.%20Odeco,%20Inc.,%20Murphy%20Exploration%20&%20Production%20Company,%20Originally%20Sued%20as%20Odeco,%20Inc.
#    ❌ Failed: ID 664910
# ...
#    🔄 Case 612/1000: ID 534561
#    ✅ Success: Wilbur Toledo, Plaintiff-Appellant/cross-Appellee v. Nobel-Sysco, Inc., Defendant-Appellee/cross-Appellant
#    🔄 Case 613/1000: ID 796705
#    ✅ Success: Sheila White v. United States Department of Housing and Urban Development
#    🔄 Case 614/1000: ID 1058849
#    ✅ Success: Taboada v. Daly Seven, Inc.
#    🔄 Case 615/1000: ID 796715
#    ✅ Success: Robert Wayne Chalfant v. Titan Distribution, Inc. Titan International, Inc.
#    🔄 Case 616/1000: ID 2369586
#    ✅ Success: Blevins Asphalt Construction Co. v. Director of Revenue
#    🔄 Case 617/1000: ID 4204598
#    ✅ Success: GRISHAM v. CITY OF OKLAHOMA CITY
#    🔄 Case 618/1000: ID 6826048
#    ✅ Success: Blue Cross & Blue Shield Ass'n v. United States
#    🔄 Case 619/1000: ID 534597
#    ✅ Success: Thais Carriere, Widow of Samuel Carriere, Iv, Individually and on Behalf of Her Minor Child v. Sears, Roebuck and Company
#    🔄 Case 620/1000: ID 796750
#    ✅ Success: Richard M. Wishkin v. John E. Potter, Postmaster General
#    🔄 Case 621/1000: ID 534610
#    ✅ Success: James B. Geitz v. John Lindsey, Dennis Bevirt and Michael Boyne
#    🔄 Case 622/1000: ID 10323
#    ✅ Success: United States v. Gray
#    🔄 Case 623/1000: ID 10328
#    ✅ Success: Dao v. Auchan Hypermarket
#    🔄 Case 624/1000: ID 403547
#    ✅ Success: Juan Santoni, Jr. v. Federal Deposit Insurance Corporation
#    🔄 Case 625/1000: ID 796772
#    ✅ Success: United States v. Brandon H. Charles
#    🔄 Case 626/1000: ID 1452132
#    ✅ Success: Pantoja v. Countrywide Home Loans, Inc.
#    🔄 Case 627/1000: ID 403573
#    ✅ Success: A. Rab Chowdhury, M.D. v. The Reading Hospital and Medical Center
#    🔄 Case 628/1000: ID 1845366
#    ✅ Success: Cooper v. Cooper (In Re Cooper)
#    🔄 Case 629/1000: ID 1190009
#    ✅ Success: Samuelson v. LaPorte Community School Corp.
#    🔄 Case 630/1000: ID 403592
#    ✅ Success: Ennis Nettles v. Louie L. Wainwright, Director, Division of Corrections, State of Florida
#    🔄 Case 631/1000: ID 403595
#    ✅ Success: National Labor Relations Board v. United Parcel Service, Inc.
#    🔄 Case 632/1000: ID 796824
#    ✅ Success: Oregon Natural Resources Council v. Allen
#    🔄 Case 633/1000: ID 1452195
#    ✅ Success: American Rockwool, Inc. v. Owens-Corning Fiberglas Corp.
#    🔄 Case 634/1000: ID 403624
#    ✅ Success: Mary A. Bart v. William C. Telford
#    🔄 Case 635/1000: ID 2369704
#    ✅ Success: Hart Holding Co. v. Drexel Burnham Lambert Inc.
#    🔄 Case 636/1000: ID 1845422
#    ✅ Success: Levy v. Runnells (In Re Landbank Equity Corp. )
#    🔄 Case 637/1000: ID 1058992
#    ✅ Success: Bentley Funding v. Sk & R Group
#    🔄 Case 638/1000: ID 1190065
#    ✅ Success: St. Luke's Hospital v. Schmaltz
#    🔄 Case 639/1000: ID 11151539
#    ✅ Success: State ex rel. The Ryant Commt. v. Lorain Cty. Bd. of Elections
#    🔄 Case 640/1000: ID 2369728
#    ✅ Success: Maher v. New Jersey Transit Rail Operations, Inc.
#    🔄 Case 641/1000: ID 1190081
#    ✅ Success: Hauter v. Zogarts
#    🔄 Case 642/1000: ID 403656
#    ✅ Success: James D. Ray v. The Tennessee Valley Authority
#    🔄 Case 643/1000: ID 796879
#    ✅ Success: Equal Employment Opportunity Commission v. Wal-Mart Stores, Inc.
#    🔄 Case 644/1000: ID 665813
#    ✅ Success: Association For Retarded Citizens Of Dallas v. Dallas County Mental Health & Mental Retardation Center Board Of Trustees
#    🔄 Case 645/1000: ID 665815
#    ❌ Failed: ID 665815
#    🔄 Case 646/1000: ID 1190112
#    ✅ Success: Jacobs v. Clark County School District
#    🔄 Case 647/1000: ID 2500834
#    ✅ Success: Natural Resources Defense Council v. Patterson
#    🔄 Case 648/1000: ID 1059043
#    ✅ Success: LOFTON RIDGE v. Norfolk Southern Ry. Co.
#    🔄 Case 649/1000: ID 403683
#    ✅ Success: Kaiser Aluminum & Chemical Sales, Inc. v. Avondale Shipyards, Inc.
#    🔄 Case 650/1000: ID 1190115
#    ✅ Success: Bailey v. USF Holland, Inc.
#    🔄 Case 651/1000: ID 665833
#    ✅ Success: Christine M. Donato v. Metropolitan Life Insurance Company
#    🔄 Case 652/1000: ID 796913
#    ✅ Success: Clemmons v. Armontrout
#    🔄 Case 653/1000: ID 403698
#    ✅ Success: Associated Photographers, Inc. v. Aetna Casualty & Surety Company, an Insurance Corporation
#    🔄 Case 654/1000: ID 403700
#    ✅ Success: Douglas James Scanlon v. Atascadero State Hospital, California Department of Mental Health
#    🔄 Case 655/1000: ID 1190133
#    ✅ Success: Filar v. Board of Educ. of City of Chicago
#    🔄 Case 656/1000: ID 796917
#    ✅ Success: Nat Levy v. Donald J. Ohl, William J. Knapp, L. David Green, and Merilyn Hamlett
#    🔄 Case 657/1000: ID 403707
#    ✅ Success: Beltran v. Meyers
#    🔄 Case 658/1000: ID 534783
#    ✅ Success: John Clark Donatelli v. National Hockey League
#    🔄 Case 659/1000: ID 10507
#    ✅ Success: Mays v. Sudderth
#    🔄 Case 660/1000: ID 10514
#    ✅ Success: Myers v. Klevenhagen
#    🔄 Case 661/1000: ID 796946
#    ✅ Success: United States v. Edison Misla-Aldarondo
#    🔄 Case 662/1000: ID 10517
#    ✅ Success: Bellaire General Hospital v. Blue Cross Blue Shield of Michigan
#    🔄 Case 663/1000: ID 403742
#    ✅ Success: Pacesetter Systems, Inc. v. Medtronic, Inc. And Med Rel Inc.
#    🔄 Case 664/1000: ID 796959
# ❌ HTTP error for https://www.courtlistener.com/api/rest/v4/search/?q=Sanford Kreisler Bask Holdings, LLC v. Glenn H. Goldberg, T/a S. Goldberg-Cust Srg Properties No. 5, Llc, Creditors-Appellees: 500 Server Error: Internal Server Error for url: https://www.courtlistener.com/api/rest/v4/search/?q=Sanford%20Kreisler%20Bask%20Holdings,%20LLC%20v.%20Glenn%20H.%20Goldberg,%20T/a%20S.%20Goldberg-Cust%20Srg%20Properties%20No.%205,%20Llc,%20Creditors-Appellees
#    ❌ Failed: ID 796959
#    🔄 Case 665/1000: ID 10529
#    ✅ Success: Williams v. Time Warner Operation, Inc.
#    🔄 Case 666/1000: ID 3942690
#    ✅ Success: Moore v. Mettauer
#    🔄 Case 667/1000: ID 796963
#    ✅ Success: Board of Education of Fayette County, Kentucky v. L.M., as Legal Guardian of T.D., a Minor L.M., on Her Own Behalf and T.D., by His Legal Guardian
#    🔄 Case 668/1000: ID 403759
#    ❌ Failed: ID 403759
#    🔄 Case 669/1000: ID 403767
#    ✅ Success: United States v. Pablo Escoboza Vega
#    🔄 Case 670/1000: ID 796987
#    ✅ Success: Lorraine Lettieri v. Equant Incorporated
#    🔄 Case 671/1000: ID 9185600
#    ✅ Success: Board of Trustees of the University of Alabama v. Garrett
#    🔄 Case 672/1000: ID 534852
#    ✅ Success: Sharon Campbell v. Ingersoll Milling MacHine Company, an Illinois Corporation, and Henry Ortland, Individually
#    🔄 Case 673/1000: ID 403788
#    ✅ Success: Clifton Powell v. Shopco Laurel Company and Robert K. Skeen
#    🔄 Case 674/1000: ID 534872
#    ✅ Success: Louis Eugene Russell v. Tom Rolfs, Superintendent
#    🔄 Case 675/1000: ID 1845593
#    ✅ Success: Dominguez v. Bucyrus-Erie Company
#    🔄 Case 676/1000: ID 403803
#    ✅ Success: Leonard S. GOFF, Plaintiff-Appellant, v. CONTINENTAL OIL COMPANY, Defendant-Appellee
#    🔄 Case 677/1000: ID 534877
#    ❌ Failed: ID 534877
#    🔄 Case 678/1000: ID 1714526
#    ✅ Success: Van Dyke v. Boswell, O'Toole, Davis & Pickering
#    🔄 Case 679/1000: ID 797031
#    ✅ Success: Heather Wilkinson v. Jacob Allen Shackelford Michelin North America, Inc.
#    🔄 Case 680/1000: ID 797038
#    ✅ Success: Davis v. City of Las Vegas
#    🔄 Case 681/1000: ID 272751
#    ✅ Success: United States v. Grover C. Bryant, Jr., Jack C. Clifton, and Dan Watson
#    🔄 Case 682/1000: ID 1583472
#    ✅ Success: O'NEIL v. Picillo
#    🔄 Case 683/1000: ID 2763127
#    ✅ Success: Granato v. Davis
#    🔄 Case 684/1000: ID 797051
#    ✅ Success: United States v. Perry Reich
#    🔄 Case 685/1000: ID 11151739
#    ✅ Success: State ex rel. Stevens v. Geauga Cty. Bd. of Elections
#    🔄 Case 686/1000: ID 797061
#    ✅ Success: El-Masri v. United States
#    🔄 Case 687/1000: ID 1452421
#    ✅ Success: Benton v. Kroger Co.
#    🔄 Case 688/1000: ID 665998
#    ✅ Success: Matter of Appletree Markets, Inc.
#    🔄 Case 689/1000: ID 403861
#    ✅ Success: Alvin DURRETT, Plaintiff-Appellee, v. JENKINS BRICKYARD, INC., Defendant-Appellant
#    🔄 Case 690/1000: ID 797086
# ❌ HTTP error for https://www.courtlistener.com/api/rest/v4/search/?q=Equal Employment Opportunity Commission Louella Rollins v. Woodmen of the World Life Insurance Society, And/or Omaha Woodmen Life Insurance Society: 500 Server Error: Internal Server Error for url: https://www.courtlistener.com/api/rest/v4/search/?q=Equal%20Employment%20Opportunity%20Commission%20Louella%20Rollins%20v.%20Woodmen%20of%20the%20World%20Life%20Insurance%20Society,%20And/or%20Omaha%20Woodmen%20Life%20Insurance%20Society
#    ❌ Failed: ID 797086
#    🔄 Case 691/1000: ID 403872
#    ❌ Failed: ID 403872
#    🔄 Case 692/1000: ID 797098
#    ✅ Success: Neama El Sayed Ramadan Gaser Hesham El Gendy v. Alberto R. Gonzales, Attorney General
#    🔄 Case 693/1000: ID 10672
#    ✅ Success: Robinson v. Global Marine Drilling Co.
#    🔄 Case 694/1000: ID 1190320
#    ✅ Success: Harney v. Speedway SuperAmerica, LLC
#    🔄 Case 695/1000: ID 10682
#    ✅ Success: Canutillo Independent School District v. National Union Fire Insurance Co. of Pittsburgh
#    🔄 Case 696/1000: ID 666044
#    ❌ Failed: ID 666044
#    🔄 Case 697/1000: ID 8923586
#    ✅ Success: Gerena-Valentin v. Koch
#    🔄 Case 698/1000: ID 2369990
#    ✅ Success: Deck v. City of Toledo
#    🔄 Case 699/1000: ID 10698
#    ✅ Success: Riley v. City of Jackson, MS
#    🔄 Case 700/1000: ID 403918
#    ✅ Success: Hurie Jones v. Orleans Parish School Board
#    🔄 Case 701/1000: ID 6171091
#    ✅ Success: Gieseking v. Urania Records, Inc.
#    🔄 Case 702/1000: ID 3942870
#    ✅ Success: Queen Insurance v. State
#    🔄 Case 703/1000: ID 1452503
#    ✅ Success: Ridings v. Riverside Medical Center
#    🔄 Case 704/1000: ID 1321438
#    ✅ Success: Laurie v. Thomas
#    🔄 Case 705/1000: ID 797154
#    ✅ Success: Lauren v. Deflaminis
#    🔄 Case 706/1000: ID 1452531
#    ✅ Success: Home Builders Ass'n v. City of Scottsdale
#    🔄 Case 707/1000: ID 797172
#    ✅ Success: Marcella Fane v. Locke Reynolds, LLP
#    🔄 Case 708/1000: ID 2238966
#    ✅ Success: Eshaghi v. Hanley Dawson Cadillac Co.
#    🔄 Case 709/1000: ID 9447929
#    ✅ Success: Marietta Page v. Telford Work
#    🔄 Case 710/1000: ID 1321469
#    ✅ Success: Cross v. Trapp
#    🔄 Case 711/1000: ID 797189
#    ✅ Success: Tejpaul S. Jogi v. Tim Voges
#    🔄 Case 712/1000: ID 1059335
#    ✅ Success: Super Fresh Food Markets of Virginia, Inc. v. Ruffin
#    🔄 Case 713/1000: ID 1583625
#    ✅ Success: In Re National Mortgage Equity Corp. Mortgage Pool Certificates Securities Litigation
#    🔄 Case 714/1000: ID 2632202
#    ✅ Success: Pangle v. Bend-LaPine School District
#    🔄 Case 715/1000: ID 797204
#    ✅ Success: Stephanie Gambini v. Total Renal Care, Inc., D/B/A Davita, Inc.
#    🔄 Case 716/1000: ID 1190434
#    ✅ Success: Heslop v. Bank of Utah
#    🔄 Case 717/1000: ID 797239
#    ✅ Success: James Dixon, Jr. v. Alberto Gonzales, United States Attorney General and Robert S. Mueller, Iii, Fbi Director
#    🔄 Case 718/1000: ID 5646906
#    ✅ Success: Strachan v. Meritor Mortgage Corp. East
#    🔄 Case 719/1000: ID 2239048
#    ✅ Success: White v. University of Massachusetts at Boston
#    🔄 Case 720/1000: ID 797259
#    ✅ Success: Equal Employment Opportunity Commission v. Schneider National, Inc.
#    🔄 Case 721/1000: ID 272977
#    ✅ Success: The New York Times Company v. Eugene Connor
#    🔄 Case 722/1000: ID 9054804
#    ✅ Success: Salcer v. Envicon Equities Corp.
#    🔄 Case 723/1000: ID 797269
#    ✅ Success: Yeng Thao v. City Of St. Paul
#    🔄 Case 724/1000: ID 797279
#    ✅ Success: Connie M. Gretillat v. Care Initiatives
#    🔄 Case 725/1000: ID 797288
#    ✅ Success: Molski v. M.J. Cable, Inc.
#    🔄 Case 726/1000: ID 1714793
#    ✅ Success: Fuller v. Local Union No. 106 of the United Brotherhood of Carpenters & Joiners
#    🔄 Case 727/1000: ID 3943019
#    ✅ Success: Henry v. Phillips
#    🔄 Case 728/1000: ID 797311
#    ✅ Success: Eugene Winkler, Gary Gersen, Timuel Black, Mary Cay Marubio, and C. Douglas Ferguson v. Robert M. Gates, Secretary of Defense
#    🔄 Case 729/1000: ID 5909127
#    ✅ Success: Suny College of Environmental Science v. State Division of Human Rights
#    🔄 Case 730/1000: ID 797320
#    ✅ Success: Daniel Shahinaj v. Alberto R. Gonzales, Attorney General of the United States of America
#    🔄 Case 731/1000: ID 797322
#    ✅ Success: Jane E. Stewart v. Independent School District No. 196
#    🔄 Case 732/1000: ID 2108043
#    ✅ Success: Mouradian v. General Electric Co.
#    🔄 Case 733/1000: ID 1714829
#    ✅ Success: Buckner Glass & Mirror Inc. v. T.A. Pritchard Co.
#    🔄 Case 734/1000: ID 797327
#    ✅ Success: Vernon E. Christensen v. Titan Distribution, Inc.
#    🔄 Case 735/1000: ID 1059483
#    ✅ Success: Simmons v. Miller
#    🔄 Case 736/1000: ID 2370209
#    ✅ Success: V.L. v. Wagner
#    🔄 Case 737/1000: ID 2501289
#    ✅ Success: Parrish v. Sollecito
#    🔄 Case 738/1000: ID 797354
#    ✅ Success: McCARTHY v. DUN & BRADSTREET CORPORATION
#    🔄 Case 739/1000: ID 797355
#    ✅ Success: Jack Ehleiter v. Grapetree Shores, Inc.
#    🔄 Case 740/1000: ID 2632366
#    ✅ Success: Computer Publications, Inc. v. Welton
#    🔄 Case 741/1000: ID 1452720
#    ✅ Success: Carondelet Health Services v. Arizona Health Care Cost Containment System Administration
#    🔄 Case 742/1000: ID 797364
#    ✅ Success: Knight v. Kirby Inland Marine Inc.
#    🔄 Case 743/1000: ID 797366
#    ✅ Success: Darrell L. Burrell v. Dr. Pepper/seven Up Bottling Group, Inc. Dr. Pepper/seven Up Bottling Group, L.P.
#    🔄 Case 744/1000: ID 1452726
#    ✅ Success: Guenin v. Sendra Corp.
#    🔄 Case 745/1000: ID 1845952
#    ✅ Success: In Re Wirmel
#    🔄 Case 746/1000: ID 797377
#    ✅ Success: Andreoli v. Gates
#    🔄 Case 747/1000: ID 10951
#    ✅ Success: Equal Employment Opportunity Commission v. Texas Instruments Inc.
#    🔄 Case 748/1000: ID 273098
#    ✅ Success: Wallach v. Lieberman
#    🔄 Case 749/1000: ID 10964
#    ✅ Success: Texas Manufactured Housing Ass'n v. Nederland
#    🔄 Case 750/1000: ID 404185
#    ✅ Success: Tom Brown v. United States Department of Interior
#    🔄 Case 751/1000: ID 1583838
#    ✅ Success: Bonfield v. AAMCO Transmissions, Inc.
#    🔄 Case 752/1000: ID 273120
#    ✅ Success: Dino DeLaurentiis Cinemato-Grafica, S.P.A. v. D-150, Inc.
#    🔄 Case 753/1000: ID 797409
#    ✅ Success: Karen Bombaci v. Journal Community Publishing Group, Inc.
#    🔄 Case 754/1000: ID 1583843
#    ✅ Success: Muller v. Stromberg Carlson Corp.
#    🔄 Case 755/1000: ID 2108133
#    ✅ Success: Akers v. Kelley Co.
#    🔄 Case 756/1000: ID 2501351
#    ✅ Success: World Wrestling Federation Entertainment, Inc. v. Big Dog Holdings, Inc.
#    🔄 Case 757/1000: ID 797416
#    ✅ Success: Deana Tipler v. Douglas County, Nebraska Robert Houston, Director of Douglas County Corrections
#    🔄 Case 758/1000: ID 797417
#    ✅ Success: Judy A. Libel v. Adventure Lands of America, Inc. John M. Krantz
#    🔄 Case 759/1000: ID 535276
#    ✅ Success: Anna G. Lewis, Cross-Appellants v. Parish of Terrebonne, Godfrey Boquet, Cross-Appellee
#    🔄 Case 760/1000: ID 2370284
#    ✅ Success: Gantler v. Stephens
#    🔄 Case 761/1000: ID 797423
#    ✅ Success: United States v. Hosvaldo Lopez
#    🔄 Case 762/1000: ID 535281
#    ✅ Success: John Junior Dayse v. George Schuldt, Chief of Police
#    🔄 Case 763/1000: ID 535282
#    ✅ Success: Nieto v. San Perlita Independent School District
#    🔄 Case 764/1000: ID 535296
#    ✅ Success: Charles Roggow v. Mineral Processing Corp., Needmore Processing Division
#    🔄 Case 765/1000: ID 535301
#    ✅ Success: Euna Fay BLAKE, Appellant, v. J.C. PENNEY CO., INC., Appellee; Euna Fay BLAKE, Appellee, v. J.C. PENNEY CO., INC., Appellant
#    🔄 Case 766/1000: ID 1059608
#    ✅ Success: Berean Law Group, P.C. v. Cox
#    🔄 Case 767/1000: ID 8792865
#    ✅ Success: Charles Labs, Inc. v. Banner
#    🔄 Case 768/1000: ID 797476
#    ✅ Success: Thomas v. Corwin
#    🔄 Case 769/1000: ID 1714991
#    ✅ Success: Rosas v. Buddies Food Store
#    🔄 Case 770/1000: ID 1321784
#    ✅ Success: Hutchens v. Hankins
#    🔄 Case 771/1000: ID 8137542
#    ✅ Success: Thayer v. City of Worcester
#    🔄 Case 772/1000: ID 797536
#    ✅ Success: Sharon MacY v. Hopkins County School Board of Education
#    🔄 Case 773/1000: ID 1059685
#    ✅ Success: Commonwealth v. Luzik
#    🔄 Case 774/1000: ID 797542
#    ✅ Success: Shirley Johnson, as Legal Guardian of Michael Gilfeather, an Incapacitated Adult v. Manitowoc Boom Trucks, Inc.
#    🔄 Case 775/1000: ID 1190761

# %% [markdown]
# ## Extract Cases Citing ADAH Cases

# %%
def cases_cited_by_id(adah_opinion_ids, headers=None, batch_num = 1):
    cases = []

    for target_opinion_id in adah_opinion_ids:
        api_url = f"https://www.courtlistener.com/api/rest/v4/search/?q=cites:{target_opinion_id}"

        response = safe_json_get(api_url, headers=headers)
        if not response or not response.get("results"):
            print(f"No results for: {target_opinion_id}")
            continue

        # Loop through each result that cites the ADAH opinion
        for result in response["results"]:
            if not result.get("opinions"):
                print(f"No opinions for: {target_opinion_id}")
                continue

            # Extract the first opinion ID (you could loop through all opinions if needed)
            opinion_id = result['opinions'][0]['id']

            if target_opinion_id in result['opinions'][0].get('cites', []):
              opinion_api_url = f"https://www.courtlistener.com/api/rest/v4/opinions/{opinion_id}/"
              opinion_data = safe_json_get(opinion_api_url, headers=headers)
              if not opinion_data:
                  print(f"Failed to fetch opinion {opinion_id}")
                  continue

              # Get best opinion text
              opinion_text = get_best_opinion_text(opinion_data)
              page_count = opinion_data.get('page_count')


              # Build case dictionary
              case = {
                    "ID": result['opinions'][0]['id'],
                    "absolute_url":result.get("absolute_url"),
                    "date_filed":result.get("dateFiled"),
                    "case_name":result.get("caseName"),
                    "case_full_name":result.get("caseNameFull"),
                    "docker_number": result.get('docketNumber'),
                    "court_id": result.get('court_id'),
                    "court": result.get("court"),
                    "court_citation_string": result.get("court_citation_string"),
                    "court_jurisdiction": result.get("court_jurisdiction"),
                    "attorney": result.get('attorney'),
                    "judge": result.get('judge'),
                    "panel_names": result.get('panel_names'),
                    "citation": result.get('citation'),
                    "lexisCite": result.get('lexisCite'),
                    "neutralCite": result.get('neutralCite'),
                    "cite_to": result['opinions'][0]['cites'],
                    "opinion_type": result['opinions'][0]['type'],
                    "opinion": opinion_text,
                    "page_count": page_count
                    }

            cases.append(case)  # append the flattened dictionary


    output_path = f"case_citing_adah_batch_{batch_num}.json"
    with open(output_path, "w", encoding="utf-8") as f:
        json.dump(cases, f, ensure_ascii=False, indent=2)

    # Convert to DataFrame after looping through all ADAH IDs
    df = pd.DataFrame(cases)
    return df

# %%
def batch_list(lst, n_batches):
    """
    Split a list into n_batches roughly equal chunks.
    """
    k, m = divmod(len(lst), n_batches)
    return [lst[i*k + min(i, m):(i+1)*k + min(i+1, m)] for i in range(n_batches)]

# Split into 6 batches
unique_adah_ids = list(set(adah_id_list))
adah_batches = batch_list(unique_adah_ids, 6)

headers = {"Authorization": "Token e8c44d881eb22e19247756b1d38c2c9469085ff1"}

for i in range(len(adah_batches)):

  print(f"Starting Batch: {i+1}")
  batch_id = adah_batches[i]
  batch_df = cases_cited_by_id(batch_id, headers, batch_num=i+1)
  print(f"Batch {i+1} has a shape of:{batch_df.shape}")
  batch_df.to_csv(f"case_citing_adah_batch_{i+1}.csv", index=False)
  print(f"Saved batch {i+1} to case_citing_adah_batch_{i+1}.csv")

  time.sleep(3700)



all_files = glob.glob("case_citing_adah_batch_*.json")

# Read and concatenate them into a single DataFrame
df = pd.concat((pd.read_json(f, orient="records") for f in all_files), ignore_index=True)

print(f"Final Dataframe shape: {df.shape}")

output_path = "case_citing_adah.json"

# Convert DataFrame to list of dictionaries
records = df.to_dict(orient="records")

print()

with open(output_path, "w", encoding="utf-8") as f:
    json.dump(records, f, ensure_ascii=False, indent=2)

# %% [markdown]
# ## Manually Label Jurisdictions
#
# The mapping follows court level as follow:
#
# ![court_level.png](attachment:3261083e-3851-487e-a8ff-87351e1a8198.png)

# %%
import boto3
import json

s3 = boto3.client('s3')

bucket = 'capstone-project-legal-citation'
key = 'datasets/full_adah_set.json'

# Download file content as text
response = s3.get_object(Bucket=bucket, Key=key)
adah_full = json.loads(response['Body'].read().decode('utf-8'))

# Inspect
print(type(adah_full))
# Out:
# <class 'list'>

# %%
adah_full[0]
# Out:
# {'ID': 2113004,
#  'absolute_url': '/opinion/2113004/hastings-v-papillion-lavista-school-district/',
#  'date_filed': '2011-01-25',
#  'case_name': 'Hastings v. Papillion-LaVista School District',
#  'case_full_name': 'Patricia K. HASTINGS, Plaintiff, v. PAPILLION-LaVISTA SCHOOL DISTRICT, School District No. 27, Defendant',
#  'docker_number': '8:10CV74',
#  'court_id': 'ned',
#  'court': 'District Court, D. Nebraska',
#  'court_citation_string': 'D. Neb.',
#  'court_jurisdiction': None,
#  'attorney': 'Robert E. O’Connor, Jr., O’Connor & Associates, Omaha, NE, for Plaintiff., Gregory H. Perry, Jeanette L. Stull, Perry, Guthery Law Firm, Lincoln, NE, for Defendant.',
#  'judge': 'Joseph F. Bataillon',
#  'panel_names': [],
#  'citation': ['780 F. Supp. 2d 958',
#   '24 Am. Disabilities Cas. (BNA) 618',
#   '2011 U.S. Dist. LEXIS 7257',
#   '2011 WL 250428'],
#  'lexisCite': '2011 U.S. Dist. LEXIS 7257',
#  'neutralCite': '',
#  'cite_to': [108153,
#   118014,
#   118470,
#   145857,
#   147194,
#   149210,
#   150068,
#   152234,
#   492085,
#   696226,
#   760518,
#   762234,
#   765564,
#   765810,
#   768645,
#   774458,
#   775171,
#   783094,
#   784000,
#   785367,
#   786444,
#   790092,
#   791934,
#   792122,
#   792754,
#   793834,
#   793842,
#   794612,
#   796715,
#   1301732,
#   1451705,
#   1454073],
#  'opinion_type': 'combined-opinion',
#  'opinion': 'MEMORANDUM AND ORDER JOSEPH F. BATAILLON, Chief Judge. This matter is before the court on the defendant’s motion for summary judgment, Filing No. 19. 1 This is an action for discrimination in employment. The plaintiff alleges that she was terminated from her position as a special education paraeducator by Papillion-La Vista School District (“the School District”) in violation of the Americans with Disabilities Act (“ADA”), 42 U.S.C. § 12101 et seq.; the Age Discrimination in Employment Act (“ADEA”), 29 U.S.C. § 621 et seq.; and the Nebraska Age discrimination in Employment Act, Neb.Rev.Stat. § 48-1001 et seq. The defendant argues that uncontroverted facts show that the plaintiff cannot establish that she was disabled as that term was defined at the time she was terminated and that she has not presented evidence sufficient to establish a prima facie case of age discrimination. I. BACKGROUND A. Facts The parties agree on the following facts. 2 The plaintiff, Patricia Hastings, was employed by the School District as a paraedueator at Papillion-LaVista High School (“PLHS”) since 2000. She was a one-on-one special education paraedueator for medically fragile students. Her job primarily involved working with students. At her annual physical in November of 2008, Hastings was given a temporary standing restriction. She then spoke to the human resoxxrces director, Ms. Mimi Goings, about it. Goings told Hastings that she could either transfer to another school or take sick leave until the restriction was lifted, but could not retxxrn to her job with the restriction. Hastings also told Goings at the meeting that she would need to take time off for doctor’s appointments in the future. Hastings asked her doctor to lift the restriction the following day. Ms. Hastings presented PLHS with a second doctor’s note dated November 14, 2008, releasing her from her standing restriction. She missed only one day of work due to *960 the standing restriction and returned to work in her job as a special education paraeducator at PLHS. Ms. Goings heard nothing more from Ms. Hastings or her doctor regarding her standing restriction or any health conditions or concerns after this. The School District was aware that Ms. Hastings had been diagnosed with cancer in 2004 and 2006. She states that the School District “was excellent” in accommodating her while she was being treated for cancer. The plaintiff acknowledges that her employee handbook mentions, and she was aware, that time off must be preapproved by an administrator. In Ms. Goings’ position as Director of Human Resources, she received regular absence and leave reports regarding paraeducators. Ms. Goings expected to see Ms. Hastings’ name on these reports after their November communications in light of Ms. Hastings’ statement that she would need to miss work for doctor’s appointments. Ms. Goings asked Kathy Weaver, a special education teacher and head of the special education department at PLHS, whether Ms. Hastings had missed work, and Ms. Weaver stated that she had. Weaver then forwarded to Goings e-mails that Hastings had sent notifying the teachers of absences for three doctor’s appointments in November. Ms. Goings then compared Hastings’ November 2008 time sheet and discovered that she had marked down that she had worked full days each day that month except for two days— November 13, which was the day she missed because of her standing restriction, and November 14, a preapproved personal day. There was no indication on her time sheet that she had missed any time for her doctor’s appointments. On December 10, 2008, Ms. Goings called a meeting with Principal Glover and Ms. Hastings to determine if Ms. Hastings had violated the district’s policies regarding leave time and time sheets. Ms. Hastings admitted that she had failed to record time that she was absent on her time sheets and that she did not get preapproval from an administrator before taking the time off. Ms. Goings terminated he ...
#  'page_count': None,
#  'jurisdiction_inferred': 'Nebraska',
#  'Citing_Relationship': 'citing_adah'}

# %%
import re

def infer_jurisdiction(court_citation):
    """
    Infers the jurisdiction and court level from a court citation string.
    Returns one of:
      - 'U.S. Court of Appeals for the Ninth Circuit'
      - 'U.S. District Court for the Northern District of California'
      - 'California Court of Appeal'
      - 'Federal'
      - 'Unknown'
    """

    if not court_citation or not isinstance(court_citation, str):
        return "Unknown"

    court_citation = court_citation.strip()

    # --- Federal Supreme and Appellate --- 1 
    supreme_map = {"SCOTUS": "Federal Supreme Court"}
    
    # --- Federal Appellate Courts (Court of Appeals) --- 2 = Court of Appeals
    circuit_map = {
        "1st Cir.": "U.S. Court of Appeals for the First Circuit",
        "2d Cir.": "U.S. Court of Appeals for the Second Circuit",
        "3d Cir.": "U.S. Court of Appeals for the Third Circuit",
        "3rd Cir.": "U.S. Court of Appeals for the Third Circuit",
        "4th Cir.": "U.S. Court of Appeals for the Fourth Circuit",
        "5th Cir.": "U.S. Court of Appeals for the Fifth Circuit",
        "6th Cir.": "U.S. Court of Appeals for the Sixth Circuit",
        "7th Cir.": "U.S. Court of Appeals for the Seventh Circuit",
        "8th Cir.": "U.S. Court of Appeals for the Eighth Circuit",
        "9th Cir.": "U.S. Court of Appeals for the Ninth Circuit",
        "10th Cir.": "U.S. Court of Appeals for the Tenth Circuit",
        "11th Cir.": "U.S. Court of Appeals for the Eleventh Circuit",
        "D.C. Cir.": "U.S. Court of Appeals for the D.C. Circuit",
        "Fed. Cir.": "U.S. Court of Appeals for the Federal Circuit",
        "Vet. App.": "U.S. Court of Appeals for Veterans Claims",
        "C.A.A.F.": "U.S. Court of Appeals for the Armed Forces",
        "A.C.C.A.": "U.S. Army Court of Criminal Appeals"
    }

    # --- Federal District/Trial Courts --- 3 = District Court 
    district_patterns = {
        r"\bN\.D\. Cal\.": "U.S. District Court for the Northern District of California",
        r"\bC\.D\. Cal\.": "U.S. District Court for the Central District of California",
        r"\bS\.D\. Cal\.": "U.S. District Court for the Southern District of California",
        r"\bE\.D\. Cal\.": "U.S. District Court for the Eastern District of California",
        r"\bD\. Mass\.": "U.S. District Court for the District of Massachusetts",
        r"\bD\. Md\.": "U.S. District Court for the District of Maryland",
        r"\bD\. Maryland": "U.S. District Court for the District of Maryland",
        r"\bM\.D\. La\.": "U.S. District Court for the Middle District of Louisiana",
        r"\bD\. Colo\.": "U.S. District Court for the District of Colorado",
        r"\bD\. Or\.": "U.S. District Court for the District of Oregon",
        r"\bD\. Haw\.": "U.S. District Court for the District of Hawaii",
        r"\bS\.D\.N\.Y\.": "U.S. District Court for the Southern District of New York",
        r"\bE\.D\.N\.Y": "U.S. District Court for the Eastern District of New York",
        r"\bD\.N\.J\.": "U.S. District Court for the District of New Jersey",
        r"\bD\.D\.C\.": "U.S. District Court for the District of Columbia",
        r"\bD\.V\.I\.": "U.S. District Court for the District of the Virgin Islands",
        r"\bE\.D\.N\.Y\.": "U.S. District Court for the Eastern District of New York",
        r"\bD\. Minnesota": "U.S. District Court for the District of Minnesota",
        r"\bM\.D\. Penn\.": "U.S. District Court for the Middle District of Pennsylvania",
        r"\bD\.C\.": "U.S. District Court for the District of Columbia"
    }

    # --- State Courts --- 4
    state_map = {
        "Ala.": "Alabama", 
        "Alaska": "Alaska", 
        "Ariz.": "Arizona", 
        "Ark.": "Arkansas",
        "Cal.": "California", 
        "Colo.": "Colorado", 
        "Conn.": "Connecticut", 
        "Del.": "Delaware",
        "Fla.": "Florida", 
        "Ga.": "Georgia", 
        "Haw.": "Hawaii", 
        "Idaho": "Idaho",
        "Ill.": "Illinois", 
        "Ind.": "Indiana", 
        "Iowa": "Iowa", 
        "Kan.": "Kansas",
        "Ky.": "Kentucky", 
        "La.": "Louisiana", 
        "Me.": "Maine", 
        "Md.": "Maryland",
        "Mass.": "Massachusetts", 
        "Mich.": "Michigan", 
        "Minn.": "Minnesota",
        "Miss.": "Mississippi", 
        "Mo.": "Missouri", 
        "Mont.": "Montana", 
        "Neb.": "Nebraska",
        "Nev.": "Nevada", 
        "N.H.": "New Hampshire", 
        "N.J.": "New Jersey", 
        "N.M.": "New Mexico",
        "N.Y.": "New York", 
        "NY": "New York",
        "N.C.": "North Carolina", 
        "N.D.": "North Dakota", 
        "Ohio": "Ohio",
        "Okla.": "Oklahoma", 
        "Or.": "Oregon", 
        "Pa.": "Pennsylvania", 
        "R.I.": "Rhode Island",
        "S.C.": "South Carolina", 
        "S.D.": "South Dakota", 
        "Tenn.": "Tennessee", 
        "Tex.": "Texas",
        "Utah": "Utah", 
        "Vt.": "Vermont", 
        "Va.": "Virginia",
        "Rockingham Cir. Ct.": "Virginia",
        "Wash.": "Washington",
        "W. Va.": "West Virginia", 
        "Wis.": "Wisconsin", 
        "Wyo.": "Wyoming",
        "V.I.": "Virgin Islands", 
        "P.R.": "Puerto Rico",
        "Guam": "Guam",
        "N. Mar. I.": "Northern Mariana Islands"
    }

    # Special Courts and administribunals 1
    special_map = {
        "Ct. Intl. Trade": "U.S. Court of International Trade",
        "Tax Ct.": "U.S. Tax Court",
        "MSPB": "Merit Systems Protection Board",
        "OLC": "Office of Legal Counsel",
        "Bankr. M.D. Penn.": "U.S. Bankruptcy Court, D of Penn",
        "BIA": "Board of Immigration Appeals",
        "A.S.B.C.A.": "Armed Services Board of Contract Appeals",
        "Fed. Cl.": "U.S. Court of Federal Claims"
    }

    # Match Federal Supreme Court
    for pattern, full_name in supreme_map.items():
        if pattern in court_citation:
            return full_name
            
    # Match Circuit Courts
    for pattern, full_name in circuit_map.items():
        if pattern in court_citation:
            return full_name

    # Match District Courts
    for pattern, full_name in district_patterns.items():
        if re.search(pattern, court_citation):
            return full_name

    # Match Specialized and Admin Tribunals Courts
    for pattern, full_name in special_map.items():
        if pattern in court_citation:
            return full_name

    # Match State Courts
    for abbr, full_name in state_map.items():
        if abbr in court_citation:
            # detect “Ct. App.” vs Supreme
            if "Ct. App." in court_citation:
                return f"{full_name} Court of Appeal"
            elif "Supreme Ct." in court_citation:
                return f"{full_name} Supreme Court"
            else:
                return full_name

    return "Unknown"

# %%
for case in adah_full:
    court_citation = case.get("court_citation_string", "")
    case["jurisdiction_inferred"] = infer_jurisdiction(court_citation)

# %%
jurisdiction_missing = []
for case in adah_full:
    if case['jurisdiction_inferred'] == 'Unknown':
        jurisdiction_missing.append(case)
len(jurisdiction_missing)
# Out:
# 25

# %%
missing_citation_str = []
for case in jurisdiction_missing:
    missing_citation_str.append(case.get("court_citation_string", ""))

print(len(missing_citation_str))
display(pd.Series(missing_citation_str).value_counts())
# Out:
# 25
#     25
# Name: count, dtype: int64

# %%
output_path = './datasets/combined/adah_cases_full.json'
with open(output_path, 'w', encoding="utf-8") as f:
    json.dump(adah_full, f, ensure_ascii=False, indent=2)

# %% [markdown]
# ### Combine cases, add jurisdiction and labels

# %%
with open('citing_adah_new.json', 'r', encoding='utf-8') as f:
    citing_adah = json.load(f)

with open('adah.json', 'r', encoding='utf-8') as f:
    adah = json.load(f)

# %%
for case in citing_adah:
    court_citation = case.get("court_citation_string", "")
    case["jurisdiction_inferred"] = infer_jurisdiction(court_citation)

# %%
for case in adah:
    court_citation = case.get("court_citation_string", "")
    case["jurisdiction_inferred"] = infer_jurisdiction(court_citation)

# %%
for case in adah:
    case['Citing_Relationship'] = 'adah'

# %%
for case in citing_adah:
    case['Citing_Relationship'] = 'citing_adah'

# %%
# Convert JSON lists (loaded with json.load) into pandas DataFrames
citing_adah_df = pd.DataFrame(citing_adah)
adah_df = pd.DataFrame(adah)

# Check shapes
print('citing_adah_df:', citing_adah_df.shape)
print('adah_df:', adah_df.shape)

# Combine them (stack rows)
combined = pd.concat([citing_adah_df, adah_df], ignore_index=True)
print('combined_df:', combined.shape)

# Drop duplicate rows
combined_df = combined.drop_duplicates(subset=['ID'])
print('combined after dedupe:', combined_df.shape)

# (Optional) Save back to JSON
combined_df.to_json('full_adah_set.json', orient='records', indent=2)
# Out:
# citing_adah_df: (13242, 22)
# adah_df: (2681, 22)
# combined_df: (15923, 22)
# combined after dedupe: (15372, 22)

# %% [markdown]
# ## Combine datasets and add "relationship" tag

# %%
folder_path = './datasets'
cited_by_adah = []

for i in range(1, 30):
    file_path = os.path.join(folder_path, f'case_cited_batch_{i}.json')
    with open(file_path, 'r') as f:
        data = json.load(f)
        cited_by_adah.extend(data)
print(f"✅ Combined {len(cited_by_adah)} JSON objects total.")
# Out:
# ✅ Combined 26025 JSON objects total.

# %%
adah_file_path = './datasets/adah.json'
with open(adah_file_path, 'r') as f:
    adah = json.load(f)

citing_adah_file_path = './datasets/case_citing_adah.json'
with open(citing_adah_file_path, 'r') as f:
    citing_adah = json.load(f)

# %%
for case in cited_by_adah:
    case["Citing_Relationship"] = "cited_by_adah"

for case in citing_adah:
    case['Citing_Relationship'] = 'citing_adah'

for case in adah:
    case['Citing_Relationship'] = 'adah'

# %%
cited_output_path = './datasets/combined/cited_by_adah.json'
with open(cited_output_path, 'w', encoding="utf-8") as f:
    json.dump(cited_by_adah, f, ensure_ascii=False, indent=2)

# adah_output_path = './datasets/combined/adah.json'
# with open(adah_output_path, 'w', encoding="utf-8") as f:
#     json.dump(adah, f, ensure_ascii=False, indent=2)

# citing_output_path = './datasets/combined/citing_adah.json'
# with open(citing_output_path, 'w', encoding="utf-8") as f:
#     json.dump(citing_adah, f, ensure_ascii=False, indent=2)

# %%
# Step 1: Combine all into one list
combined = adah + cited_by_adah + citing_adah

# Step 2: Deduplicate by case ID
unique_cases = {}
for case in combined:
    case_id = case.get("ID")
    if case_id not in unique_cases:
        unique_cases[case_id] = case  # keep the first occurrence

# Step 3: Convert back to a list
deduped_list = list(unique_cases.values())

print(f"✅ Deduplicated: {len(deduped_list)} unique cases from {len(combined)} total.")
# Out:
# ✅ Deduplicated: 38817 unique cases from 45616 total.

# %%
output_path = './datasets/combined/adah_cases_combined.json'
with open(output_path, 'w', encoding="utf-8") as f:
    json.dump(deduped_list, f, ensure_ascii=False, indent=2)

# %% [markdown]
# ## Upload to S3 bucket

# %%
import sagemaker

# Create a SageMaker session (automatically uses your IAM role)
session = sagemaker.Session()

files = [#'adah',
         #'citing_adah',
         #'cited_by_adah',
         'adah_cases_full']
bucket = 'capstone-project-legal-citation'
prefix = 'datasets'  # folder name in your bucket

# Upload to S3
for file_name in files:
    local_path = f'./datasets/combined/{file_name}.json'
    s3_uri = session.upload_data(path=local_path, bucket=bucket, key_prefix=prefix)

print(f"✅ Uploaded to: {s3_uri}")
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml
# ✅ Uploaded to: s3://capstone-project-legal-citation/datasets/adah_cases_full.json
