# %% [markdown]
# # OpinionChunk Embedding Pipeline (Titan + Neo4j)
#
# ## 1. Purpose
#
# This pipeline embeds the **`OpinionChunk`** nodes in your Neo4j knowledge graph using **Amazon Titan** embeddings, and stores the resulting vectors back on each node.
#
# Once embeddings are stored, you can:
#
# - Create a **vector index** in Neo4j.
# - Use these embeddings for **semantic search**, **GraphRAG**, and **agent tools**.
#
# ---
#
# ## 2. What the Pipeline Does (Step by Step)
#
# ### 2.1. Load configuration and connect to Neo4j
#
# - Reads environment variables from `.env`:
#   - `NEO4J_URI`
#   - `NEO4J_USERNAME`
#   - `NEO4J_PASSWORD`
#   - `NEO4J_DATABASE`
#   - `AWS_REGION` (for Bedrock)
# - Creates a Neo4j driver and verifies connectivity.
#
# **Goal:** Make sure we can read and write `OpinionChunk` nodes.
#
# ---
#
# ### 2.2. Select `OpinionChunk` nodes that need embeddings
#
# The pipeline runs a Cypher query roughly like:
#
# ```cypher
# MATCH (c:OpinionChunk)
# WHERE c.embedding IS NULL
#   AND c.text IS NOT NULL AND c.text <> ''
# RETURN id(c) AS node_id, c.text AS text
# ````
#
# * It **filters only nodes without an `embedding` property** (so we do not recompute embeddings every time).
# * It also ensures `text` is present and not empty.
# * This returns a list of `(node_id, text)` pairs.
#
# > Neo4j warnings:
# >
# > * `id(c)` is deprecated in Neo4j 5 → you can later switch to `elementId(c)` if you want.
# > * `c.embedding` “does not exist” at first → this is only a warning because the property is not created yet. It will appear once the first embeddings are written.
#
# ---
#
# ### 2.3. Batch processing
#
# The list of `OpinionChunk` nodes is processed in **batches** (for example, 32 at a time):
#
# * Split the list of nodes into batches.
# * For each batch:
#
#   * Collect the chunk texts.
#   * Call the Titan embedding function on these texts.
#   * Write the resulting vectors back to Neo4j for the corresponding nodes.
#
# This batching helps you:
#
# * Control the number of Titan calls.
# * Manage rate limits and memory usage more easily.
#
# ---
#
# ### 2.4. Embedding text with Amazon Titan
#
# The helper function (conceptually called `embed_texts_titan`) does:
#
# 1. **Loop over each text** in the batch.
#
# 2. For each text, call **Bedrock InvokeModel** with:
#
#    * `modelId = "amazon.titan-embed-text-v2:0"`
#    * JSON body like:
#
#      ```json
#      { "inputText": "the text to embed" }
#      ```
#    * Titan expects a **single string**, not an array. This is why we call Titan once per chunk instead of sending a list.
#
# 3. Parse the response and extract the embedding vector from the response payload (e.g. `payload["embedding"]`).
#
# 4. Return a list of embeddings (one per input text).
#
# **Key details:**
#
# * The Titan model returns a vector of a fixed length (for v2 it is typically **1024 dimensions**, unless you override via `embeddingConfig`).
# * These vectors must match the dimensions used in your Neo4j vector index.
#
# ---
#
# ### 2.5. Writing embeddings back to Neo4j
#
# For each batch, after we get the embeddings list:
#
# * We pair `node_id` (or `elementId`) with its embedding vector.
# * We run a Cypher write query to set:
#
# ```cypher
# MATCH (c:OpinionChunk)
# WHERE id(c) = $id                      -- or elementId(c) = $id
# SET c.embedding = $embedding
# ```
#
# This adds a new property `embedding` to each `OpinionChunk` node.
#
# After this step, some `OpinionChunk` nodes will have:
#
# * `text` (original opinion snippet).
# * `embedding` (Titan vector representation of that text).
#
# ---
#
# ### 2.6. “Force” flag logic
#
# The pipeline supports a `force` parameter:
#
# * `force = False` (default):
#
#   * Only embed nodes where `c.embedding IS NULL`.
#   * Good for incremental runs (e.g., new data, resume after a failure).
# * `force = True`:
#
#   * Ignore existing embeddings and re-embed everything.
#   * Useful when you change the model, the embedding config, or want a clean refresh.
#
# ---
#
# ### 2.7. Creating the Neo4j vector index
#
# After embeddings are written, the pipeline (or a separate step) creates a **vector index** on `OpinionChunk.embedding`, for example:
#
# ```cypher
# CREATE VECTOR INDEX chunkEmbeddings IF NOT EXISTS
# FOR (c:OpinionChunk)
# ON (c.embedding)
# OPTIONS {
#   indexConfig: {
#     `vector.dimensions`: 1024,
#     `vector.similarity_function`: 'cosine'
#   }
# };
# ```
#
# **Important:**
# The `vector.dimensions` value must match the actual embedding size returned by Titan (e.g., 1024). If you use the wrong dimension, vector queries will fail.
#
# This index is later used by retrievers / GraphRAG to:
#
# * Run **semantic similarity search** over `OpinionChunk.text`.
# * Retrieve the most relevant chunks for a user query.
#
# ---
#
# ## 3. How This Fits into the Larger System
#
# Once this pipeline has run:
#
# * Every relevant `OpinionChunk` node is enriched with an `embedding`.
# * `chunkEmbeddings` vector index is available in Neo4j.
# * You can now:
#
#   * Use **vector-based retrievers** (e.g., in Python, LangChain, or Neo4j procedures).
#   * Combine vector search with **Cypher traversal** (Vector + Cypher retrievers).
#   * Plug this into a **GraphRAG agent** that:
#
#     * Queries Neo4j by similarity.
#     * Navigates relationships (cases, citations, parties, entities).
#     * Uses an LLM (e.g., Claude) to generate answers.
#
# In short:
# This pipeline is the **embedding + indexing foundation** that makes semantic retrieval over `OpinionChunk` opinions possible.
#
# ---
#
# ## 4. Key Design Choices
#
# * **Node label:** `:OpinionChunk`
#
#   * Each node represents a chunk of legal opinion text.
# * **Embedding property:** `embedding`
#
#   * Stored directly on the node to keep graph + vector in one place.
# * **Text property:** `text`
#
#   * Source text used for embedding and later used as context for LLMs.
# * **Model:** `amazon.titan-embed-text-v2:0` via Bedrock
#
#   * Chosen to stay inside AWS (no OpenAI dependency).
# * **Index name:** `chunkEmbeddings`
#
#   * Used later by retrievers / Cypher vector queries.
#
# ---
#
# ## 5. Summary
#
# This pipeline:
#
# 1. Finds all `OpinionChunk` nodes that need embeddings.
# 2. Calls Amazon Titan for each chunk to generate an embedding vector.
# 3. Writes the embedding back to Neo4j on `OpinionChunk.embedding`.
# 4. Creates a `chunkEmbeddings` vector index for fast similarity search.
# 5. Prepares your legal-knowledge graph for **GraphRAG**, **retrievers**, and **agents** built on top of `OpinionChunk` semantic search.

# %%
! pip install neo4j python-dotenv boto3
# Out:
# Requirement already satisfied: neo4j in /opt/conda/lib/python3.12/site-packages (6.0.3)
# Requirement already satisfied: python-dotenv in /opt/conda/lib/python3.12/site-packages (1.2.1)
# Requirement already satisfied: boto3 in /opt/conda/lib/python3.12/site-packages (1.37.1)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.12/site-packages (from neo4j) (2024.2)
# Requirement already satisfied: botocore<1.38.0,>=1.37.1 in /opt/conda/lib/python3.12/site-packages (from boto3) (1.37.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /opt/conda/lib/python3.12/site-packages (from boto3) (0.11.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.12/site-packages (from botocore<1.38.0,>=1.37.1->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.12/site-packages (from botocore<1.38.0,>=1.37.1->boto3) (1.26.20)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.38.0,>=1.37.1->boto3) (1.17.0)

# %%
import os
import json
from typing import List, Dict

from neo4j import GraphDatabase
from dotenv import load_dotenv
import boto3
from math import ceil

# Load environment variables

load_dotenv("../.env", override=True)

NEO4J_URI      = os.getenv("NEO4J_URI")
NEO4J_USER     = os.getenv("NEO4J_USERNAME")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")
NEO4J_DATABASE = os.getenv("NEO4J_DATABASE") or None  # None = default

AWS_REGION     = os.getenv("AWS_REGION", "us-west-2")  # adjust to your setup

TITAN_MODEL_ID = "amazon.titan-embed-text-v2:0"
EMBEDDING_DIM  = 1024  # adjust if you configure Titan differently
INDEX_NAME     = "chunkEmbeddings"
LABEL_NAME     = "OpinionChunk"
EMBED_PROP     = "embedding"
MODEL_META     = "amazon.titan-embed-text-v2:0"

# Neo4j driver

driver = GraphDatabase.driver(
    NEO4J_URI,
    auth=(NEO4J_USER, NEO4J_PASSWORD),
)

# Optional: verify connectivity
driver.verify_connectivity()
print("Connected to Neo4j:", NEO4J_URI)
# Out:
# Connected to Neo4j: neo4j+s://df1a98d5.databases.neo4j.io

# %% [markdown]
# ## Bedrock client and embedding helper

# %%
bedrock = boto3.client("bedrock-runtime", region_name=AWS_REGION)

def embed_texts_titan(texts):
    """
    Embed a list of strings using amazon.titan-embed-text-v2:0.
    Titan expects a single string in 'inputText', so we call it once per text.
    Returns: list[list[float]]
    """
    embeddings = []

    for t in texts:
        # Basic guard
        if not t or not t.strip():
            embeddings.append([])
            continue

        body = {
            "inputText": t,
            # Optional: if you want fixed dimension and your model supports it:
            # "embeddingConfig": {"outputEmbeddingLength": EMBEDDING_DIM}
        }

        response = bedrock.invoke_model(
            modelId=TITAN_MODEL_ID,
            contentType="application/json",
            accept="application/json",
            body=json.dumps(body),
        )

        payload = json.loads(response["body"].read())

        # Titan v2 typically returns an 'embedding' field
        if "embedding" in payload:
            vec = payload["embedding"]
        # Some wrappers use 'embeddings' for multiple, keep this as a fallback
        elif "embeddings" in payload:
            vec = payload["embeddings"][0]
        else:
            raise ValueError(f"Unexpected Titan response structure: {payload}")

        embeddings.append(vec)

    return embeddings

# %% [markdown]
# ## Helper to fetch OpinionChunk nodes needing embeddings

# %%
def fetch_opinion_chunks(force: bool = False, limit: int | None = None):
    """
    Returns a list of dictionaries:
    {"node_id": <neo4j_internal_id>, "text": <chunk_text>}
    """
    if force:
        cypher = f"""
        MATCH (c:{LABEL_NAME})
        WHERE c.text IS NOT NULL AND c.text <> ''
        RETURN elementId(c) AS node_id, c.text AS text
        """
    else:
        cypher = f"""
        MATCH (c:{LABEL_NAME})
        WHERE c.{EMBED_PROP} IS NULL
          AND c.text IS NOT NULL AND c.text <> ''
        RETURN elementId(c) AS node_id, c.text AS text
        """

    if limit is not None:
        cypher += "\nLIMIT $limit"

    with driver.session(database=NEO4J_DATABASE) as session:
        result = session.run(cypher, limit=limit)
        rows = [{"node_id": r["node_id"], "text": r["text"]} for r in result]
    return rows

# %% [markdown]
# ## Write embeddings back

# %%
def write_embeddings(batch: List[Dict]):
    """
    batch: list of dicts with keys: id (int), embedding (list[float])
    """
    cypher = f"""
    UNWIND $rows AS row
    MATCH (c)
    WHERE elementId(c) = row.id
    SET c.{EMBED_PROP}       = row.embedding,
        c.embedding_model    = $model_id,
        c.embedding_dim      = $dim,
        c.embedding_updated_at = datetime()
    """

    with driver.session(database=NEO4J_DATABASE) as session:
        session.run(
            cypher,
            rows=batch,
            model_id=MODEL_META,
            dim=EMBEDDING_DIM,
        )

# %% [markdown]
# ## Main embedding pipeline

# %%
def run_embedding_pipeline(force: bool = False, batch_size: int = 32, limit: int | None = None):
    """
    force=False  -> only embed OpinionChunk nodes without embeddings.
    force=True   -> re-embed ALL OpinionChunk nodes.
    limit        -> optional limit for testing.
    """
    chunks = fetch_opinion_chunks(force=force, limit=limit)
    total = len(chunks)
    if total == 0:
        print("No OpinionChunk nodes to embed.")
        return

    print(f"Found {total} OpinionChunk nodes to embed (force={force}).")

    num_batches = ceil(total / batch_size)
    for i in range(num_batches):
        start = i * batch_size
        end   = min(start + batch_size, total)
        batch = chunks[start:end]

        texts = [row["text"] for row in batch]
        node_ids = [row["node_id"] for row in batch]

        print(f"Batch {i+1}/{num_batches} – embedding {len(texts)} chunks...")

        embeddings = embed_texts_titan(texts)

        rows_for_neo4j = [
            {"id": node_ids[j], "embedding": embeddings[j]}
            for j in range(len(node_ids))
        ]

        write_embeddings(rows_for_neo4j)

    print("Embedding pipeline completed.")

# %% [markdown]
# ## Create vector index on :OpinionChunk(embedding)

# %%
def create_vector_index():
    cypher = f"""
    CREATE VECTOR INDEX {INDEX_NAME} IF NOT EXISTS
    FOR (c:{LABEL_NAME}) ON (c.{EMBED_PROP})
    OPTIONS {{
      indexConfig: {{
        `vector.dimensions`: $dim,
        `vector.similarity_function`: 'cosine'
      }}
    }}
    """
    with driver.session(database=NEO4J_DATABASE) as session:
        session.run(cypher, dim=EMBEDDING_DIM)
    print(f"Vector index '{INDEX_NAME}' ensured on :{LABEL_NAME}({EMBED_PROP}) with dim={EMBEDDING_DIM}.")

# %% [markdown]
# ## Run Embeddings on OpinionChunks

# %%
run_embedding_pipeline(force=False, batch_size=32)
create_vector_index()
# Out:
# Received notification from DBMS server: <GqlStatusObject gql_status='01N52', status_description='warn: property key does not exist. The property `embedding` does not exist in database `neo4j`. Verify that the spelling is correct.', position=<SummaryInputPosition line=3, column=17, offset=48>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'offset': 48, 'line': 3, 'column': 17}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        MATCH (c:OpinionChunk)\n        WHERE c.embedding IS NULL\n          AND c.text IS NOT NULL AND c.text <> ''\n        RETURN elementId(c) AS node_id, c.text AS text\n        "
# Found 56347 OpinionChunk nodes to embed (force=False).
# Batch 1/1761 – embedding 32 chunks...
# Batch 2/1761 – embedding 32 chunks...
# Batch 3/1761 – embedding 32 chunks...
# Batch 4/1761 – embedding 32 chunks...
# Batch 5/1761 – embedding 32 chunks...
# Batch 6/1761 – embedding 32 chunks...
# Batch 7/1761 – embedding 32 chunks...
# Batch 8/1761 – embedding 32 chunks...
# Batch 9/1761 – embedding 32 chunks...
# Batch 10/1761 – embedding 32 chunks...
# Batch 11/1761 – embedding 32 chunks...
# Batch 12/1761 – embedding 32 chunks...
# Batch 13/1761 – embedding 32 chunks...
# Batch 14/1761 – embedding 32 chunks...
# Batch 15/1761 – embedding 32 chunks...
# Batch 16/1761 – embedding 32 chunks...
# Batch 17/1761 – embedding 32 chunks...
# Batch 18/1761 – embedding 32 chunks...
# Batch 19/1761 – embedding 32 chunks...
# Batch 20/1761 – embedding 32 chunks...
# Batch 21/1761 – embedding 32 chunks...
# Batch 22/1761 – embedding 32 chunks...
# Batch 23/1761 – embedding 32 chunks...
# Batch 24/1761 – embedding 32 chunks...
# Batch 25/1761 – embedding 32 chunks...
# Batch 26/1761 – embedding 32 chunks...
# Batch 27/1761 – embedding 32 chunks...
# Batch 28/1761 – embedding 32 chunks...
# Batch 29/1761 – embedding 32 chunks...
# Batch 30/1761 – embedding 32 chunks...
# Batch 31/1761 – embedding 32 chunks...
# Batch 32/1761 – embedding 32 chunks...
# Batch 33/1761 – embedding 32 chunks...
# Batch 34/1761 – embedding 32 chunks...
# Batch 35/1761 – embedding 32 chunks...
# Batch 36/1761 – embedding 32 chunks...
# Batch 37/1761 – embedding 32 chunks...
# Batch 38/1761 – embedding 32 chunks...
# Batch 39/1761 – embedding 32 chunks...
# Batch 40/1761 – embedding 32 chunks...
# Batch 41/1761 – embedding 32 chunks...
# Batch 42/1761 – embedding 32 chunks...
# Batch 43/1761 – embedding 32 chunks...
# Batch 44/1761 – embedding 32 chunks...
# Batch 45/1761 – embedding 32 chunks...
# Batch 46/1761 – embedding 32 chunks...
# Batch 47/1761 – embedding 32 chunks...
# Batch 48/1761 – embedding 32 chunks...
# Batch 49/1761 – embedding 32 chunks...
# Batch 50/1761 – embedding 32 chunks...
# Batch 51/1761 – embedding 32 chunks...
# Batch 52/1761 – embedding 32 chunks...
# Batch 53/1761 – embedding 32 chunks...
# Batch 54/1761 – embedding 32 chunks...
# Batch 55/1761 – embedding 32 chunks...
# Batch 56/1761 – embedding 32 chunks...
# Batch 57/1761 – embedding 32 chunks...
# Batch 58/1761 – embedding 32 chunks...
# Batch 59/1761 – embedding 32 chunks...
# Batch 60/1761 – embedding 32 chunks...
# Batch 61/1761 – embedding 32 chunks...
# Batch 62/1761 – embedding 32 chunks...
# Batch 63/1761 – embedding 32 chunks...
# Batch 64/1761 – embedding 32 chunks...
# Batch 65/1761 – embedding 32 chunks...
# Batch 66/1761 – embedding 32 chunks...
# Batch 67/1761 – embedding 32 chunks...
# Batch 68/1761 – embedding 32 chunks...
# Batch 69/1761 – embedding 32 chunks...
# Batch 70/1761 – embedding 32 chunks...
# Batch 71/1761 – embedding 32 chunks...
# Batch 72/1761 – embedding 32 chunks...
# Batch 73/1761 – embedding 32 chunks...
# Batch 74/1761 – embedding 32 chunks...
# Batch 75/1761 – embedding 32 chunks...
# Batch 76/1761 – embedding 32 chunks...
# Batch 77/1761 – embedding 32 chunks...
# Batch 78/1761 – embedding 32 chunks...
# Batch 79/1761 – embedding 32 chunks...
# Batch 80/1761 – embedding 32 chunks...
# Batch 81/1761 – embedding 32 chunks...
# Batch 82/1761 – embedding 32 chunks...
# Batch 83/1761 – embedding 32 chunks...
# Batch 84/1761 – embedding 32 chunks...
# Batch 85/1761 – embedding 32 chunks...
# Batch 86/1761 – embedding 32 chunks...
# Batch 87/1761 – embedding 32 chunks...
# Batch 88/1761 – embedding 32 chunks...
# Batch 89/1761 – embedding 32 chunks...
# Batch 90/1761 – embedding 32 chunks...
# Batch 91/1761 – embedding 32 chunks...
# Batch 92/1761 – embedding 32 chunks...
# Batch 93/1761 – embedding 32 chunks...
# Batch 94/1761 – embedding 32 chunks...
# Batch 95/1761 – embedding 32 chunks...
# Batch 96/1761 – embedding 32 chunks...
# Batch 97/1761 – embedding 32 chunks...
# Batch 98/1761 – embedding 32 chunks...
# Batch 99/1761 – embedding 32 chunks...
# Batch 100/1761 – embedding 32 chunks...
# Batch 101/1761 – embedding 32 chunks...
# Batch 102/1761 – embedding 32 chunks...
# Batch 103/1761 – embedding 32 chunks...
# Batch 104/1761 – embedding 32 chunks...
# Batch 105/1761 – embedding 32 chunks...
# Batch 106/1761 – embedding 32 chunks...
# Batch 107/1761 – embedding 32 chunks...
# Batch 108/1761 – embedding 32 chunks...
# Batch 109/1761 – embedding 32 chunks...
# Batch 110/1761 – embedding 32 chunks...
# Batch 111/1761 – embedding 32 chunks...
# Batch 112/1761 – embedding 32 chunks...
# Batch 113/1761 – embedding 32 chunks...
# Batch 114/1761 – embedding 32 chunks...
# Batch 115/1761 – embedding 32 chunks...
# Batch 116/1761 – embedding 32 chunks...
# Batch 117/1761 – embedding 32 chunks...
# Batch 118/1761 – embedding 32 chunks...
# Batch 119/1761 – embedding 32 chunks...
# Batch 120/1761 – embedding 32 chunks...
# Batch 121/1761 – embedding 32 chunks...
# Batch 122/1761 – embedding 32 chunks...
# Batch 123/1761 – embedding 32 chunks...
# Batch 124/1761 – embedding 32 chunks...
# Batch 125/1761 – embedding 32 chunks...
# Batch 126/1761 – embedding 32 chunks...
# Batch 127/1761 – embedding 32 chunks...
# Batch 128/1761 – embedding 32 chunks...
# Batch 129/1761 – embedding 32 chunks...
# Batch 130/1761 – embedding 32 chunks...
# Batch 131/1761 – embedding 32 chunks...
# Batch 132/1761 – embedding 32 chunks...
# Batch 133/1761 – embedding 32 chunks...
# Batch 134/1761 – embedding 32 chunks...
# Batch 135/1761 – embedding 32 chunks...
# Batch 136/1761 – embedding 32 chunks...
# Batch 137/1761 – embedding 32 chunks...
# Batch 138/1761 – embedding 32 chunks...
# Batch 139/1761 – embedding 32 chunks...
# Batch 140/1761 – embedding 32 chunks...
# Batch 141/1761 – embedding 32 chunks...
# Batch 142/1761 – embedding 32 chunks...
# Batch 143/1761 – embedding 32 chunks...
# Batch 144/1761 – embedding 32 chunks...
# Batch 145/1761 – embedding 32 chunks...
# Batch 146/1761 – embedding 32 chunks...
# Batch 147/1761 – embedding 32 chunks...
# Batch 148/1761 – embedding 32 chunks...
# Batch 149/1761 – embedding 32 chunks...
# Batch 150/1761 – embedding 32 chunks...
# Batch 151/1761 – embedding 32 chunks...
# Batch 152/1761 – embedding 32 chunks...
# Batch 153/1761 – embedding 32 chunks...
# Batch 154/1761 – embedding 32 chunks...
# Batch 155/1761 – embedding 32 chunks...
# Batch 156/1761 – embedding 32 chunks...
# Batch 157/1761 – embedding 32 chunks...
# Batch 158/1761 – embedding 32 chunks...
# Batch 159/1761 – embedding 32 chunks...
# Batch 160/1761 – embedding 32 chunks...
# Batch 161/1761 – embedding 32 chunks...
# Batch 162/1761 – embedding 32 chunks...
# Batch 163/1761 – embedding 32 chunks...
# Batch 164/1761 – embedding 32 chunks...
# Batch 165/1761 – embedding 32 chunks...
# Batch 166/1761 – embedding 32 chunks...
# Batch 167/1761 – embedding 32 chunks...
# Batch 168/1761 – embedding 32 chunks...
# Batch 169/1761 – embedding 32 chunks...
# Batch 170/1761 – embedding 32 chunks...
# Batch 171/1761 – embedding 32 chunks...
# Batch 172/1761 – embedding 32 chunks...
# Batch 173/1761 – embedding 32 chunks...
# Batch 174/1761 – embedding 32 chunks...
# Batch 175/1761 – embedding 32 chunks...
# Batch 176/1761 – embedding 32 chunks...
# Batch 177/1761 – embedding 32 chunks...
# Batch 178/1761 – embedding 32 chunks...
# Batch 179/1761 – embedding 32 chunks...
# Batch 180/1761 – embedding 32 chunks...
# Batch 181/1761 – embedding 32 chunks...
# Batch 182/1761 – embedding 32 chunks...
# Batch 183/1761 – embedding 32 chunks...
# Batch 184/1761 – embedding 32 chunks...
# Batch 185/1761 – embedding 32 chunks...
# Batch 186/1761 – embedding 32 chunks...
# Batch 187/1761 – embedding 32 chunks...
# Batch 188/1761 – embedding 32 chunks...
# Batch 189/1761 – embedding 32 chunks...
# Batch 190/1761 – embedding 32 chunks...
# Batch 191/1761 – embedding 32 chunks...
# Batch 192/1761 – embedding 32 chunks...
# Batch 193/1761 – embedding 32 chunks...
# Batch 194/1761 – embedding 32 chunks...
# Batch 195/1761 – embedding 32 chunks...
# Batch 196/1761 – embedding 32 chunks...
# Batch 197/1761 – embedding 32 chunks...
# Batch 198/1761 – embedding 32 chunks...
# Batch 199/1761 – embedding 32 chunks...
# Batch 200/1761 – embedding 32 chunks...
# Batch 201/1761 – embedding 32 chunks...
# Batch 202/1761 – embedding 32 chunks...
# Batch 203/1761 – embedding 32 chunks...
# Batch 204/1761 – embedding 32 chunks...
# Batch 205/1761 – embedding 32 chunks...
# Batch 206/1761 – embedding 32 chunks...
# Batch 207/1761 – embedding 32 chunks...
# Batch 208/1761 – embedding 32 chunks...
# Batch 209/1761 – embedding 32 chunks...
# Batch 210/1761 – embedding 32 chunks...
# Batch 211/1761 – embedding 32 chunks...
# Batch 212/1761 – embedding 32 chunks...
# Batch 213/1761 – embedding 32 chunks...
# Batch 214/1761 – embedding 32 chunks...
# Batch 215/1761 – embedding 32 chunks...
# Batch 216/1761 – embedding 32 chunks...
# Batch 217/1761 – embedding 32 chunks...
# Batch 218/1761 – embedding 32 chunks...
# Batch 219/1761 – embedding 32 chunks...
# Batch 220/1761 – embedding 32 chunks...
# Batch 221/1761 – embedding 32 chunks...
# Batch 222/1761 – embedding 32 chunks...
# Batch 223/1761 – embedding 32 chunks...
# Batch 224/1761 – embedding 32 chunks...
# Batch 225/1761 – embedding 32 chunks...
# Batch 226/1761 – embedding 32 chunks...
# Batch 227/1761 – embedding 32 chunks...
# Batch 228/1761 – embedding 32 chunks...
# Batch 229/1761 – embedding 32 chunks...
# Batch 230/1761 – embedding 32 chunks...
# Batch 231/1761 – embedding 32 chunks...
# Batch 232/1761 – embedding 32 chunks...
# Batch 233/1761 – embedding 32 chunks...
# Batch 234/1761 – embedding 32 chunks...
# Batch 235/1761 – embedding 32 chunks...
# Batch 236/1761 – embedding 32 chunks...
# Batch 237/1761 – embedding 32 chunks...
# Batch 238/1761 – embedding 32 chunks...
# Batch 239/1761 – embedding 32 chunks...
# Batch 240/1761 – embedding 32 chunks...
# Batch 241/1761 – embedding 32 chunks...
# Batch 242/1761 – embedding 32 chunks...
# Batch 243/1761 – embedding 32 chunks...
# Batch 244/1761 – embedding 32 chunks...
# Batch 245/1761 – embedding 32 chunks...
# Batch 246/1761 – embedding 32 chunks...
# Batch 247/1761 – embedding 32 chunks...
# Batch 248/1761 – embedding 32 chunks...
# Batch 249/1761 – embedding 32 chunks...
# Batch 250/1761 – embedding 32 chunks...
# Batch 251/1761 – embedding 32 chunks...
# Batch 252/1761 – embedding 32 chunks...
# Batch 253/1761 – embedding 32 chunks...
# Batch 254/1761 – embedding 32 chunks...
# Batch 255/1761 – embedding 32 chunks...
# Batch 256/1761 – embedding 32 chunks...
# Batch 257/1761 – embedding 32 chunks...
# Batch 258/1761 – embedding 32 chunks...
# Batch 259/1761 – embedding 32 chunks...
# Batch 260/1761 – embedding 32 chunks...
# Batch 261/1761 – embedding 32 chunks...
# Batch 262/1761 – embedding 32 chunks...
# Batch 263/1761 – embedding 32 chunks...
# Batch 264/1761 – embedding 32 chunks...
# Batch 265/1761 – embedding 32 chunks...
# Batch 266/1761 – embedding 32 chunks...
# Batch 267/1761 – embedding 32 chunks...
# Batch 268/1761 – embedding 32 chunks...
# Batch 269/1761 – embedding 32 chunks...
# Batch 270/1761 – embedding 32 chunks...
# Batch 271/1761 – embedding 32 chunks...
# Batch 272/1761 – embedding 32 chunks...
# Batch 273/1761 – embedding 32 chunks...
# Batch 274/1761 – embedding 32 chunks...
# Batch 275/1761 – embedding 32 chunks...
# Batch 276/1761 – embedding 32 chunks...
# Batch 277/1761 – embedding 32 chunks...
# Batch 278/1761 – embedding 32 chunks...
# Batch 279/1761 – embedding 32 chunks...
# Batch 280/1761 – embedding 32 chunks...
# Batch 281/1761 – embedding 32 chunks...
# Batch 282/1761 – embedding 32 chunks...
# Batch 283/1761 – embedding 32 chunks...
# Batch 284/1761 – embedding 32 chunks...
# Batch 285/1761 – embedding 32 chunks...
# Batch 286/1761 – embedding 32 chunks...
# Batch 287/1761 – embedding 32 chunks...
# Batch 288/1761 – embedding 32 chunks...
# Batch 289/1761 – embedding 32 chunks...
# Batch 290/1761 – embedding 32 chunks...
# Batch 291/1761 – embedding 32 chunks...
# Batch 292/1761 – embedding 32 chunks...
# Batch 293/1761 – embedding 32 chunks...
# Batch 294/1761 – embedding 32 chunks...
# Batch 295/1761 – embedding 32 chunks...
# Batch 296/1761 – embedding 32 chunks...
# Batch 297/1761 – embedding 32 chunks...
# Batch 298/1761 – embedding 32 chunks...
# Batch 299/1761 – embedding 32 chunks...
# Batch 300/1761 – embedding 32 chunks...
# Batch 301/1761 – embedding 32 chunks...
# Batch 302/1761 – embedding 32 chunks...
# Batch 303/1761 – embedding 32 chunks...
# Batch 304/1761 – embedding 32 chunks...
# Batch 305/1761 – embedding 32 chunks...
# Batch 306/1761 – embedding 32 chunks...
# Batch 307/1761 – embedding 32 chunks...
# Batch 308/1761 – embedding 32 chunks...
# Batch 309/1761 – embedding 32 chunks...
# Batch 310/1761 – embedding 32 chunks...
# Batch 311/1761 – embedding 32 chunks...
# Batch 312/1761 – embedding 32 chunks...
# Batch 313/1761 – embedding 32 chunks...
# Batch 314/1761 – embedding 32 chunks...
# Batch 315/1761 – embedding 32 chunks...
# Batch 316/1761 – embedding 32 chunks...
# Batch 317/1761 – embedding 32 chunks...
# Batch 318/1761 – embedding 32 chunks...
# Batch 319/1761 – embedding 32 chunks...
# Batch 320/1761 – embedding 32 chunks...
# Batch 321/1761 – embedding 32 chunks...
# Batch 322/1761 – embedding 32 chunks...
# Batch 323/1761 – embedding 32 chunks...
# Batch 324/1761 – embedding 32 chunks...
# Batch 325/1761 – embedding 32 chunks...
# Batch 326/1761 – embedding 32 chunks...
# Batch 327/1761 – embedding 32 chunks...
# Batch 328/1761 – embedding 32 chunks...
# Batch 329/1761 – embedding 32 chunks...
# Batch 330/1761 – embedding 32 chunks...
# Batch 331/1761 – embedding 32 chunks...
# Batch 332/1761 – embedding 32 chunks...
# Batch 333/1761 – embedding 32 chunks...
# Batch 334/1761 – embedding 32 chunks...
# Batch 335/1761 – embedding 32 chunks...
# Batch 336/1761 – embedding 32 chunks...
# Batch 337/1761 – embedding 32 chunks...
# Batch 338/1761 – embedding 32 chunks...
# Batch 339/1761 – embedding 32 chunks...
# Batch 340/1761 – embedding 32 chunks...
# Batch 341/1761 – embedding 32 chunks...
# Batch 342/1761 – embedding 32 chunks...
# Batch 343/1761 – embedding 32 chunks...
# Batch 344/1761 – embedding 32 chunks...
# Batch 345/1761 – embedding 32 chunks...
# Batch 346/1761 – embedding 32 chunks...
# Batch 347/1761 – embedding 32 chunks...
# Batch 348/1761 – embedding 32 chunks...
# Batch 349/1761 – embedding 32 chunks...
# Batch 350/1761 – embedding 32 chunks...
# Batch 351/1761 – embedding 32 chunks...
# Batch 352/1761 – embedding 32 chunks...
# Batch 353/1761 – embedding 32 chunks...
# Batch 354/1761 – embedding 32 chunks...
# Batch 355/1761 – embedding 32 chunks...
# Batch 356/1761 – embedding 32 chunks...
# Batch 357/1761 – embedding 32 chunks...
# Batch 358/1761 – embedding 32 chunks...
# Batch 359/1761 – embedding 32 chunks...
# Batch 360/1761 – embedding 32 chunks...
# Batch 361/1761 – embedding 32 chunks...
# Batch 362/1761 – embedding 32 chunks...
# Batch 363/1761 – embedding 32 chunks...
# Batch 364/1761 – embedding 32 chunks...
# Batch 365/1761 – embedding 32 chunks...
# Batch 366/1761 – embedding 32 chunks...
# Batch 367/1761 – embedding 32 chunks...
# Batch 368/1761 – embedding 32 chunks...
# Batch 369/1761 – embedding 32 chunks...
# Batch 370/1761 – embedding 32 chunks...
# Batch 371/1761 – embedding 32 chunks...
# Batch 372/1761 – embedding 32 chunks...
# Batch 373/1761 – embedding 32 chunks...
# Batch 374/1761 – embedding 32 chunks...
# Batch 375/1761 – embedding 32 chunks...
# Batch 376/1761 – embedding 32 chunks...
# Batch 377/1761 – embedding 32 chunks...
# Batch 378/1761 – embedding 32 chunks...
# Batch 379/1761 – embedding 32 chunks...
# Batch 380/1761 – embedding 32 chunks...
# Batch 381/1761 – embedding 32 chunks...
# Batch 382/1761 – embedding 32 chunks...
# Batch 383/1761 – embedding 32 chunks...
# Batch 384/1761 – embedding 32 chunks...
# Batch 385/1761 – embedding 32 chunks...
# Batch 386/1761 – embedding 32 chunks...
# Batch 387/1761 – embedding 32 chunks...
# Batch 388/1761 – embedding 32 chunks...
# Batch 389/1761 – embedding 32 chunks...
# Batch 390/1761 – embedding 32 chunks...
# Batch 391/1761 – embedding 32 chunks...
# Batch 392/1761 – embedding 32 chunks...
# Batch 393/1761 – embedding 32 chunks...
# Batch 394/1761 – embedding 32 chunks...
# Batch 395/1761 – embedding 32 chunks...
# Batch 396/1761 – embedding 32 chunks...
# Batch 397/1761 – embedding 32 chunks...
# Batch 398/1761 – embedding 32 chunks...
# Batch 399/1761 – embedding 32 chunks...
# Batch 400/1761 – embedding 32 chunks...
# Batch 401/1761 – embedding 32 chunks...
# Batch 402/1761 – embedding 32 chunks...
# Batch 403/1761 – embedding 32 chunks...
# Batch 404/1761 – embedding 32 chunks...
# Batch 405/1761 – embedding 32 chunks...
# Batch 406/1761 – embedding 32 chunks...
# Batch 407/1761 – embedding 32 chunks...
# Batch 408/1761 – embedding 32 chunks...
# Batch 409/1761 – embedding 32 chunks...
# Batch 410/1761 – embedding 32 chunks...
# Batch 411/1761 – embedding 32 chunks...
# Batch 412/1761 – embedding 32 chunks...
# Batch 413/1761 – embedding 32 chunks...
# Batch 414/1761 – embedding 32 chunks...
# Batch 415/1761 – embedding 32 chunks...
# Batch 416/1761 – embedding 32 chunks...
# Batch 417/1761 – embedding 32 chunks...
# Batch 418/1761 – embedding 32 chunks...
# Batch 419/1761 – embedding 32 chunks...
# Batch 420/1761 – embedding 32 chunks...
# Batch 421/1761 – embedding 32 chunks...
# Batch 422/1761 – embedding 32 chunks...
# Batch 423/1761 – embedding 32 chunks...
# Batch 424/1761 – embedding 32 chunks...
# Batch 425/1761 – embedding 32 chunks...
# Batch 426/1761 – embedding 32 chunks...
# Batch 427/1761 – embedding 32 chunks...
# Batch 428/1761 – embedding 32 chunks...
# Batch 429/1761 – embedding 32 chunks...
# Batch 430/1761 – embedding 32 chunks...
# Batch 431/1761 – embedding 32 chunks...
# Batch 432/1761 – embedding 32 chunks...
# Batch 433/1761 – embedding 32 chunks...
# Batch 434/1761 – embedding 32 chunks...
# Batch 435/1761 – embedding 32 chunks...
# Batch 436/1761 – embedding 32 chunks...
# Batch 437/1761 – embedding 32 chunks...
# Batch 438/1761 – embedding 32 chunks...
# Batch 439/1761 – embedding 32 chunks...
# Batch 440/1761 – embedding 32 chunks...
# Batch 441/1761 – embedding 32 chunks...
# Batch 442/1761 – embedding 32 chunks...
# Batch 443/1761 – embedding 32 chunks...
# Batch 444/1761 – embedding 32 chunks...
# Batch 445/1761 – embedding 32 chunks...
# Batch 446/1761 – embedding 32 chunks...
# Batch 447/1761 – embedding 32 chunks...
# Batch 448/1761 – embedding 32 chunks...
# Batch 449/1761 – embedding 32 chunks...
# Batch 450/1761 – embedding 32 chunks...
# Batch 451/1761 – embedding 32 chunks...
# Batch 452/1761 – embedding 32 chunks...
# Batch 453/1761 – embedding 32 chunks...
# Batch 454/1761 – embedding 32 chunks...
# Batch 455/1761 – embedding 32 chunks...
# Batch 456/1761 – embedding 32 chunks...
# Batch 457/1761 – embedding 32 chunks...
# Batch 458/1761 – embedding 32 chunks...
# Batch 459/1761 – embedding 32 chunks...
# Batch 460/1761 – embedding 32 chunks...
# Batch 461/1761 – embedding 32 chunks...
# Batch 462/1761 – embedding 32 chunks...
# Batch 463/1761 – embedding 32 chunks...
# Batch 464/1761 – embedding 32 chunks...
# Batch 465/1761 – embedding 32 chunks...
# Batch 466/1761 – embedding 32 chunks...
# Batch 467/1761 – embedding 32 chunks...
# Batch 468/1761 – embedding 32 chunks...
# Batch 469/1761 – embedding 32 chunks...
# Batch 470/1761 – embedding 32 chunks...
# Batch 471/1761 – embedding 32 chunks...
# Batch 472/1761 – embedding 32 chunks...
# Batch 473/1761 – embedding 32 chunks...
# Batch 474/1761 – embedding 32 chunks...
# Batch 475/1761 – embedding 32 chunks...
# Batch 476/1761 – embedding 32 chunks...
# Batch 477/1761 – embedding 32 chunks...
# Batch 478/1761 – embedding 32 chunks...
# Batch 479/1761 – embedding 32 chunks...
# Batch 480/1761 – embedding 32 chunks...
# Batch 481/1761 – embedding 32 chunks...
# Batch 482/1761 – embedding 32 chunks...
# Batch 483/1761 – embedding 32 chunks...
# Batch 484/1761 – embedding 32 chunks...
# Batch 485/1761 – embedding 32 chunks...
# Batch 486/1761 – embedding 32 chunks...
# Batch 487/1761 – embedding 32 chunks...
# Batch 488/1761 – embedding 32 chunks...
# Batch 489/1761 – embedding 32 chunks...
# Batch 490/1761 – embedding 32 chunks...
# Batch 491/1761 – embedding 32 chunks...
# Batch 492/1761 – embedding 32 chunks...
# Batch 493/1761 – embedding 32 chunks...
# Batch 494/1761 – embedding 32 chunks...
# Batch 495/1761 – embedding 32 chunks...
# Batch 496/1761 – embedding 32 chunks...
# Batch 497/1761 – embedding 32 chunks...
# Batch 498/1761 – embedding 32 chunks...
# Batch 499/1761 – embedding 32 chunks...
# Batch 500/1761 – embedding 32 chunks...
# Batch 501/1761 – embedding 32 chunks...
# Batch 502/1761 – embedding 32 chunks...
# Batch 503/1761 – embedding 32 chunks...
# Batch 504/1761 – embedding 32 chunks...
# Batch 505/1761 – embedding 32 chunks...
# Batch 506/1761 – embedding 32 chunks...
# Batch 507/1761 – embedding 32 chunks...
# Batch 508/1761 – embedding 32 chunks...
# Batch 509/1761 – embedding 32 chunks...
# Batch 510/1761 – embedding 32 chunks...
# Batch 511/1761 – embedding 32 chunks...
# Batch 512/1761 – embedding 32 chunks...
# Batch 513/1761 – embedding 32 chunks...
# Batch 514/1761 – embedding 32 chunks...
# Batch 515/1761 – embedding 32 chunks...
# Batch 516/1761 – embedding 32 chunks...
# Batch 517/1761 – embedding 32 chunks...
# Batch 518/1761 – embedding 32 chunks...
# Batch 519/1761 – embedding 32 chunks...
# Batch 520/1761 – embedding 32 chunks...
# Batch 521/1761 – embedding 32 chunks...
# Batch 522/1761 – embedding 32 chunks...
# Batch 523/1761 – embedding 32 chunks...
# Batch 524/1761 – embedding 32 chunks...
# Batch 525/1761 – embedding 32 chunks...
# Batch 526/1761 – embedding 32 chunks...
# Batch 527/1761 – embedding 32 chunks...
# Batch 528/1761 – embedding 32 chunks...
# Batch 529/1761 – embedding 32 chunks...
# Batch 530/1761 – embedding 32 chunks...
# Batch 531/1761 – embedding 32 chunks...
# Batch 532/1761 – embedding 32 chunks...
# Batch 533/1761 – embedding 32 chunks...
# Batch 534/1761 – embedding 32 chunks...
# Batch 535/1761 – embedding 32 chunks...
# Batch 536/1761 – embedding 32 chunks...
# Batch 537/1761 – embedding 32 chunks...
# Batch 538/1761 – embedding 32 chunks...
# Batch 539/1761 – embedding 32 chunks...
# Batch 540/1761 – embedding 32 chunks...
# Batch 541/1761 – embedding 32 chunks...
# Batch 542/1761 – embedding 32 chunks...
# Batch 543/1761 – embedding 32 chunks...
# Batch 544/1761 – embedding 32 chunks...
# Batch 545/1761 – embedding 32 chunks...
# Batch 546/1761 – embedding 32 chunks...
# Batch 547/1761 – embedding 32 chunks...
# Batch 548/1761 – embedding 32 chunks...
# Batch 549/1761 – embedding 32 chunks...
# Batch 550/1761 – embedding 32 chunks...
# Batch 551/1761 – embedding 32 chunks...
# Batch 552/1761 – embedding 32 chunks...
# Batch 553/1761 – embedding 32 chunks...
# Batch 554/1761 – embedding 32 chunks...
# Batch 555/1761 – embedding 32 chunks...
# Batch 556/1761 – embedding 32 chunks...
# Batch 557/1761 – embedding 32 chunks...
# Batch 558/1761 – embedding 32 chunks...
# Batch 559/1761 – embedding 32 chunks...
# Batch 560/1761 – embedding 32 chunks...
# Batch 561/1761 – embedding 32 chunks...
# Batch 562/1761 – embedding 32 chunks...
# Batch 563/1761 – embedding 32 chunks...
# Batch 564/1761 – embedding 32 chunks...
# Batch 565/1761 – embedding 32 chunks...
# Batch 566/1761 – embedding 32 chunks...
# Batch 567/1761 – embedding 32 chunks...
# Batch 568/1761 – embedding 32 chunks...
# Batch 569/1761 – embedding 32 chunks...
# Batch 570/1761 – embedding 32 chunks...
# Batch 571/1761 – embedding 32 chunks...
# Batch 572/1761 – embedding 32 chunks...
# Batch 573/1761 – embedding 32 chunks...
# Batch 574/1761 – embedding 32 chunks...
# Batch 575/1761 – embedding 32 chunks...
# Batch 576/1761 – embedding 32 chunks...
# Batch 577/1761 – embedding 32 chunks...
# Batch 578/1761 – embedding 32 chunks...
# Batch 579/1761 – embedding 32 chunks...
# Batch 580/1761 – embedding 32 chunks...
# Batch 581/1761 – embedding 32 chunks...
# Batch 582/1761 – embedding 32 chunks...
# Batch 583/1761 – embedding 32 chunks...
# Batch 584/1761 – embedding 32 chunks...
# Batch 585/1761 – embedding 32 chunks...
# Batch 586/1761 – embedding 32 chunks...
# Batch 587/1761 – embedding 32 chunks...
# Batch 588/1761 – embedding 32 chunks...
# Batch 589/1761 – embedding 32 chunks...
# Batch 590/1761 – embedding 32 chunks...
# Batch 591/1761 – embedding 32 chunks...
# Batch 592/1761 – embedding 32 chunks...
# Batch 593/1761 – embedding 32 chunks...
# Batch 594/1761 – embedding 32 chunks...
# Batch 595/1761 – embedding 32 chunks...
# Batch 596/1761 – embedding 32 chunks...
# Batch 597/1761 – embedding 32 chunks...
# Batch 598/1761 – embedding 32 chunks...
# Batch 599/1761 – embedding 32 chunks...
# Batch 600/1761 – embedding 32 chunks...
# Batch 601/1761 – embedding 32 chunks...
# Batch 602/1761 – embedding 32 chunks...
# Batch 603/1761 – embedding 32 chunks...
# Batch 604/1761 – embedding 32 chunks...
# Batch 605/1761 – embedding 32 chunks...
# Batch 606/1761 – embedding 32 chunks...
# Batch 607/1761 – embedding 32 chunks...
# Batch 608/1761 – embedding 32 chunks...
# Batch 609/1761 – embedding 32 chunks...
# Batch 610/1761 – embedding 32 chunks...
# Batch 611/1761 – embedding 32 chunks...
# Batch 612/1761 – embedding 32 chunks...
# Batch 613/1761 – embedding 32 chunks...
# Batch 614/1761 – embedding 32 chunks...
# Batch 615/1761 – embedding 32 chunks...
# Batch 616/1761 – embedding 32 chunks...
# Batch 617/1761 – embedding 32 chunks...
# Batch 618/1761 – embedding 32 chunks...
# Batch 619/1761 – embedding 32 chunks...
# Batch 620/1761 – embedding 32 chunks...
# Batch 621/1761 – embedding 32 chunks...
# Batch 622/1761 – embedding 32 chunks...
# Batch 623/1761 – embedding 32 chunks...
# Batch 624/1761 – embedding 32 chunks...
# Batch 625/1761 – embedding 32 chunks...
# Batch 626/1761 – embedding 32 chunks...
# Batch 627/1761 – embedding 32 chunks...
# Batch 628/1761 – embedding 32 chunks...
# Batch 629/1761 – embedding 32 chunks...
# Batch 630/1761 – embedding 32 chunks...
# Batch 631/1761 – embedding 32 chunks...
# Batch 632/1761 – embedding 32 chunks...
# Batch 633/1761 – embedding 32 chunks...
# Batch 634/1761 – embedding 32 chunks...
# Batch 635/1761 – embedding 32 chunks...
# Batch 636/1761 – embedding 32 chunks...
# Batch 637/1761 – embedding 32 chunks...
# Batch 638/1761 – embedding 32 chunks...
# Batch 639/1761 – embedding 32 chunks...
# Batch 640/1761 – embedding 32 chunks...
# Batch 641/1761 – embedding 32 chunks...
# Batch 642/1761 – embedding 32 chunks...
# Batch 643/1761 – embedding 32 chunks...
# Batch 644/1761 – embedding 32 chunks...
# Batch 645/1761 – embedding 32 chunks...
# Batch 646/1761 – embedding 32 chunks...
# Batch 647/1761 – embedding 32 chunks...
# Batch 648/1761 – embedding 32 chunks...
# Batch 649/1761 – embedding 32 chunks...
# Batch 650/1761 – embedding 32 chunks...
# Batch 651/1761 – embedding 32 chunks...
# Batch 652/1761 – embedding 32 chunks...
# Batch 653/1761 – embedding 32 chunks...
# Batch 654/1761 – embedding 32 chunks...
# Batch 655/1761 – embedding 32 chunks...
# Batch 656/1761 – embedding 32 chunks...
# Batch 657/1761 – embedding 32 chunks...
# Batch 658/1761 – embedding 32 chunks...
# Batch 659/1761 – embedding 32 chunks...
# Batch 660/1761 – embedding 32 chunks...
# Batch 661/1761 – embedding 32 chunks...
# Batch 662/1761 – embedding 32 chunks...
# Batch 663/1761 – embedding 32 chunks...
# Batch 664/1761 – embedding 32 chunks...
# Batch 665/1761 – embedding 32 chunks...
# Batch 666/1761 – embedding 32 chunks...
# Batch 667/1761 – embedding 32 chunks...
# Batch 668/1761 – embedding 32 chunks...
# Batch 669/1761 – embedding 32 chunks...
# Batch 670/1761 – embedding 32 chunks...
# Batch 671/1761 – embedding 32 chunks...
# Batch 672/1761 – embedding 32 chunks...
# Batch 673/1761 – embedding 32 chunks...
# Batch 674/1761 – embedding 32 chunks...
# Batch 675/1761 – embedding 32 chunks...
# Batch 676/1761 – embedding 32 chunks...
# Batch 677/1761 – embedding 32 chunks...
# Batch 678/1761 – embedding 32 chunks...
# Batch 679/1761 – embedding 32 chunks...
# Batch 680/1761 – embedding 32 chunks...
# Batch 681/1761 – embedding 32 chunks...
# Batch 682/1761 – embedding 32 chunks...
# Batch 683/1761 – embedding 32 chunks...
# Batch 684/1761 – embedding 32 chunks...
# Batch 685/1761 – embedding 32 chunks...
# Batch 686/1761 – embedding 32 chunks...
# Batch 687/1761 – embedding 32 chunks...
# Batch 688/1761 – embedding 32 chunks...
# Batch 689/1761 – embedding 32 chunks...
# Batch 690/1761 – embedding 32 chunks...
# Batch 691/1761 – embedding 32 chunks...
# Batch 692/1761 – embedding 32 chunks...
# Batch 693/1761 – embedding 32 chunks...
# Batch 694/1761 – embedding 32 chunks...
# Batch 695/1761 – embedding 32 chunks...
# Batch 696/1761 – embedding 32 chunks...
# Batch 697/1761 – embedding 32 chunks...
# Batch 698/1761 – embedding 32 chunks...
# Batch 699/1761 – embedding 32 chunks...
# Batch 700/1761 – embedding 32 chunks...
# Batch 701/1761 – embedding 32 chunks...
# Batch 702/1761 – embedding 32 chunks...
# Batch 703/1761 – embedding 32 chunks...
# Batch 704/1761 – embedding 32 chunks...
# Batch 705/1761 – embedding 32 chunks...
# Batch 706/1761 – embedding 32 chunks...
# Batch 707/1761 – embedding 32 chunks...
# Batch 708/1761 – embedding 32 chunks...
# Batch 709/1761 – embedding 32 chunks...
# Batch 710/1761 – embedding 32 chunks...
# Batch 711/1761 – embedding 32 chunks...
# Batch 712/1761 – embedding 32 chunks...
# Batch 713/1761 – embedding 32 chunks...
# Batch 714/1761 – embedding 32 chunks...
# Batch 715/1761 – embedding 32 chunks...
# Batch 716/1761 – embedding 32 chunks...
# Batch 717/1761 – embedding 32 chunks...
# Batch 718/1761 – embedding 32 chunks...
# Batch 719/1761 – embedding 32 chunks...
# Batch 720/1761 – embedding 32 chunks...
# Batch 721/1761 – embedding 32 chunks...
# Batch 722/1761 – embedding 32 chunks...
# Batch 723/1761 – embedding 32 chunks...
# Batch 724/1761 – embedding 32 chunks...
# Batch 725/1761 – embedding 32 chunks...
# Batch 726/1761 – embedding 32 chunks...
# Batch 727/1761 – embedding 32 chunks...
# Batch 728/1761 – embedding 32 chunks...
# Batch 729/1761 – embedding 32 chunks...
# Batch 730/1761 – embedding 32 chunks...
# Batch 731/1761 – embedding 32 chunks...
# Batch 732/1761 – embedding 32 chunks...
# Batch 733/1761 – embedding 32 chunks...
# Batch 734/1761 – embedding 32 chunks...
# Batch 735/1761 – embedding 32 chunks...
# Batch 736/1761 – embedding 32 chunks...
# Batch 737/1761 – embedding 32 chunks...
# Batch 738/1761 – embedding 32 chunks...
# Batch 739/1761 – embedding 32 chunks...
# Batch 740/1761 – embedding 32 chunks...
# Batch 741/1761 – embedding 32 chunks...
# Batch 742/1761 – embedding 32 chunks...
# Batch 743/1761 – embedding 32 chunks...
# Batch 744/1761 – embedding 32 chunks...
# Batch 745/1761 – embedding 32 chunks...
# Batch 746/1761 – embedding 32 chunks...
# Batch 747/1761 – embedding 32 chunks...
# Batch 748/1761 – embedding 32 chunks...
# Batch 749/1761 – embedding 32 chunks...
# Batch 750/1761 – embedding 32 chunks...
# Batch 751/1761 – embedding 32 chunks...
# Batch 752/1761 – embedding 32 chunks...
# Batch 753/1761 – embedding 32 chunks...
# Batch 754/1761 – embedding 32 chunks...
# Batch 755/1761 – embedding 32 chunks...
# Batch 756/1761 – embedding 32 chunks...
# Batch 757/1761 – embedding 32 chunks...
# Batch 758/1761 – embedding 32 chunks...
# Batch 759/1761 – embedding 32 chunks...
# Batch 760/1761 – embedding 32 chunks...
# Batch 761/1761 – embedding 32 chunks...
# Batch 762/1761 – embedding 32 chunks...
# Batch 763/1761 – embedding 32 chunks...
# Batch 764/1761 – embedding 32 chunks...
# Batch 765/1761 – embedding 32 chunks...
# Batch 766/1761 – embedding 32 chunks...
# Batch 767/1761 – embedding 32 chunks...
# Batch 768/1761 – embedding 32 chunks...
# Batch 769/1761 – embedding 32 chunks...
# Batch 770/1761 – embedding 32 chunks...
# Batch 771/1761 – embedding 32 chunks...
# Batch 772/1761 – embedding 32 chunks...
# Batch 773/1761 – embedding 32 chunks...
# Batch 774/1761 – embedding 32 chunks...
# Batch 775/1761 – embedding 32 chunks...
# Batch 776/1761 – embedding 32 chunks...
# Batch 777/1761 – embedding 32 chunks...
# Batch 778/1761 – embedding 32 chunks...
# Batch 779/1761 – embedding 32 chunks...
# Batch 780/1761 – embedding 32 chunks...
# Batch 781/1761 – embedding 32 chunks...
# Batch 782/1761 – embedding 32 chunks...
# Batch 783/1761 – embedding 32 chunks...
# Batch 784/1761 – embedding 32 chunks...
# Batch 785/1761 – embedding 32 chunks...
# Batch 786/1761 – embedding 32 chunks...
# Batch 787/1761 – embedding 32 chunks...
# Batch 788/1761 – embedding 32 chunks...
# Batch 789/1761 – embedding 32 chunks...
# Batch 790/1761 – embedding 32 chunks...
# Batch 791/1761 – embedding 32 chunks...
# Batch 792/1761 – embedding 32 chunks...
# Batch 793/1761 – embedding 32 chunks...
# Batch 794/1761 – embedding 32 chunks...
# Batch 795/1761 – embedding 32 chunks...
# Batch 796/1761 – embedding 32 chunks...
# Batch 797/1761 – embedding 32 chunks...
# Batch 798/1761 – embedding 32 chunks...
# Batch 799/1761 – embedding 32 chunks...
# Batch 800/1761 – embedding 32 chunks...
# Batch 801/1761 – embedding 32 chunks...
# Batch 802/1761 – embedding 32 chunks...
# Batch 803/1761 – embedding 32 chunks...
# Batch 804/1761 – embedding 32 chunks...
# Batch 805/1761 – embedding 32 chunks...
# Batch 806/1761 – embedding 32 chunks...
# Batch 807/1761 – embedding 32 chunks...
# Batch 808/1761 – embedding 32 chunks...
# Batch 809/1761 – embedding 32 chunks...
# Batch 810/1761 – embedding 32 chunks...
# Batch 811/1761 – embedding 32 chunks...
# Batch 812/1761 – embedding 32 chunks...
# Batch 813/1761 – embedding 32 chunks...
# Batch 814/1761 – embedding 32 chunks...
# Batch 815/1761 – embedding 32 chunks...
# Batch 816/1761 – embedding 32 chunks...
# Batch 817/1761 – embedding 32 chunks...
# Batch 818/1761 – embedding 32 chunks...
# Batch 819/1761 – embedding 32 chunks...
# Batch 820/1761 – embedding 32 chunks...
# Batch 821/1761 – embedding 32 chunks...
# Batch 822/1761 – embedding 32 chunks...
# Batch 823/1761 – embedding 32 chunks...
# Batch 824/1761 – embedding 32 chunks...
# Batch 825/1761 – embedding 32 chunks...
# Batch 826/1761 – embedding 32 chunks...
# Batch 827/1761 – embedding 32 chunks...
# Batch 828/1761 – embedding 32 chunks...
# Batch 829/1761 – embedding 32 chunks...
# Batch 830/1761 – embedding 32 chunks...
# Batch 831/1761 – embedding 32 chunks...
# Batch 832/1761 – embedding 32 chunks...
# Batch 833/1761 – embedding 32 chunks...
# Batch 834/1761 – embedding 32 chunks...
# Batch 835/1761 – embedding 32 chunks...
# Batch 836/1761 – embedding 32 chunks...
# Batch 837/1761 – embedding 32 chunks...
# Batch 838/1761 – embedding 32 chunks...
# Batch 839/1761 – embedding 32 chunks...
# Batch 840/1761 – embedding 32 chunks...
# Batch 841/1761 – embedding 32 chunks...
# Batch 842/1761 – embedding 32 chunks...
# Batch 843/1761 – embedding 32 chunks...
# Batch 844/1761 – embedding 32 chunks...
# Batch 845/1761 – embedding 32 chunks...
# Batch 846/1761 – embedding 32 chunks...
# Batch 847/1761 – embedding 32 chunks...
# Batch 848/1761 – embedding 32 chunks...
# Batch 849/1761 – embedding 32 chunks...
# Batch 850/1761 – embedding 32 chunks...
# Batch 851/1761 – embedding 32 chunks...
# Batch 852/1761 – embedding 32 chunks...
# Batch 853/1761 – embedding 32 chunks...
# Batch 854/1761 – embedding 32 chunks...
# Batch 855/1761 – embedding 32 chunks...
# Batch 856/1761 – embedding 32 chunks...
# Batch 857/1761 – embedding 32 chunks...
# Batch 858/1761 – embedding 32 chunks...
# Batch 859/1761 – embedding 32 chunks...
# Batch 860/1761 – embedding 32 chunks...
# Batch 861/1761 – embedding 32 chunks...
# Batch 862/1761 – embedding 32 chunks...
# Batch 863/1761 – embedding 32 chunks...
# Batch 864/1761 – embedding 32 chunks...
# Batch 865/1761 – embedding 32 chunks...
# Batch 866/1761 – embedding 32 chunks...
# Batch 867/1761 – embedding 32 chunks...
# Batch 868/1761 – embedding 32 chunks...
# Batch 869/1761 – embedding 32 chunks...
# Batch 870/1761 – embedding 32 chunks...
# Batch 871/1761 – embedding 32 chunks...
# Batch 872/1761 – embedding 32 chunks...
# Batch 873/1761 – embedding 32 chunks...
# Batch 874/1761 – embedding 32 chunks...
# Batch 875/1761 – embedding 32 chunks...
# Batch 876/1761 – embedding 32 chunks...
# Batch 877/1761 – embedding 32 chunks...
# Batch 878/1761 – embedding 32 chunks...
# Batch 879/1761 – embedding 32 chunks...
# Batch 880/1761 – embedding 32 chunks...
# Batch 881/1761 – embedding 32 chunks...
# Batch 882/1761 – embedding 32 chunks...
# Batch 883/1761 – embedding 32 chunks...
# Batch 884/1761 – embedding 32 chunks...
# Batch 885/1761 – embedding 32 chunks...
# Batch 886/1761 – embedding 32 chunks...
# Batch 887/1761 – embedding 32 chunks...
# Batch 888/1761 – embedding 32 chunks...
# Batch 889/1761 – embedding 32 chunks...
# Batch 890/1761 – embedding 32 chunks...
# Batch 891/1761 – embedding 32 chunks...
# Batch 892/1761 – embedding 32 chunks...
# Batch 893/1761 – embedding 32 chunks...
# Batch 894/1761 – embedding 32 chunks...
# Batch 895/1761 – embedding 32 chunks...
# Batch 896/1761 – embedding 32 chunks...
# Batch 897/1761 – embedding 32 chunks...
# Batch 898/1761 – embedding 32 chunks...
# Batch 899/1761 – embedding 32 chunks...
# Batch 900/1761 – embedding 32 chunks...
# Batch 901/1761 – embedding 32 chunks...
# Batch 902/1761 – embedding 32 chunks...
# Batch 903/1761 – embedding 32 chunks...
# Batch 904/1761 – embedding 32 chunks...
# Batch 905/1761 – embedding 32 chunks...
# Batch 906/1761 – embedding 32 chunks...
# Batch 907/1761 – embedding 32 chunks...
# Batch 908/1761 – embedding 32 chunks...
# Batch 909/1761 – embedding 32 chunks...
# Batch 910/1761 – embedding 32 chunks...
# Batch 911/1761 – embedding 32 chunks...
# Batch 912/1761 – embedding 32 chunks...
# Batch 913/1761 – embedding 32 chunks...
# Batch 914/1761 – embedding 32 chunks...
# Batch 915/1761 – embedding 32 chunks...
# Batch 916/1761 – embedding 32 chunks...
# Batch 917/1761 – embedding 32 chunks...
# Batch 918/1761 – embedding 32 chunks...
# Batch 919/1761 – embedding 32 chunks...
# Batch 920/1761 – embedding 32 chunks...
# Batch 921/1761 – embedding 32 chunks...
# Batch 922/1761 – embedding 32 chunks...
# Batch 923/1761 – embedding 32 chunks...
# Batch 924/1761 – embedding 32 chunks...
# Batch 925/1761 – embedding 32 chunks...
# Batch 926/1761 – embedding 32 chunks...
# Batch 927/1761 – embedding 32 chunks...
# Batch 928/1761 – embedding 32 chunks...
# Batch 929/1761 – embedding 32 chunks...
# Batch 930/1761 – embedding 32 chunks...
# Batch 931/1761 – embedding 32 chunks...
# Batch 932/1761 – embedding 32 chunks...
# Batch 933/1761 – embedding 32 chunks...
# Batch 934/1761 – embedding 32 chunks...
# Batch 935/1761 – embedding 32 chunks...
# Batch 936/1761 – embedding 32 chunks...
# Batch 937/1761 – embedding 32 chunks...
# Batch 938/1761 – embedding 32 chunks...
# Batch 939/1761 – embedding 32 chunks...
# Batch 940/1761 – embedding 32 chunks...
# Batch 941/1761 – embedding 32 chunks...
# Batch 942/1761 – embedding 32 chunks...
# Batch 943/1761 – embedding 32 chunks...
# Batch 944/1761 – embedding 32 chunks...
# Batch 945/1761 – embedding 32 chunks...
# Batch 946/1761 – embedding 32 chunks...
# Batch 947/1761 – embedding 32 chunks...
# Batch 948/1761 – embedding 32 chunks...
# Batch 949/1761 – embedding 32 chunks...
# Batch 950/1761 – embedding 32 chunks...
# Batch 951/1761 – embedding 32 chunks...
# Batch 952/1761 – embedding 32 chunks...
# Batch 953/1761 – embedding 32 chunks...
# Batch 954/1761 – embedding 32 chunks...
# Batch 955/1761 – embedding 32 chunks...
# Batch 956/1761 – embedding 32 chunks...
# Batch 957/1761 – embedding 32 chunks...
# Batch 958/1761 – embedding 32 chunks...
# Batch 959/1761 – embedding 32 chunks...
# Batch 960/1761 – embedding 32 chunks...
# Batch 961/1761 – embedding 32 chunks...
# Batch 962/1761 – embedding 32 chunks...
# Batch 963/1761 – embedding 32 chunks...
# Batch 964/1761 – embedding 32 chunks...
# Batch 965/1761 – embedding 32 chunks...
# Batch 966/1761 – embedding 32 chunks...
# Batch 967/1761 – embedding 32 chunks...
# Batch 968/1761 – embedding 32 chunks...
# Batch 969/1761 – embedding 32 chunks...
# Batch 970/1761 – embedding 32 chunks...
# Batch 971/1761 – embedding 32 chunks...
# Batch 972/1761 – embedding 32 chunks...
# Batch 973/1761 – embedding 32 chunks...
# Batch 974/1761 – embedding 32 chunks...
# Batch 975/1761 – embedding 32 chunks...
# Batch 976/1761 – embedding 32 chunks...
# Batch 977/1761 – embedding 32 chunks...
# Batch 978/1761 – embedding 32 chunks...
# Batch 979/1761 – embedding 32 chunks...
# Batch 980/1761 – embedding 32 chunks...
# Batch 981/1761 – embedding 32 chunks...
# Batch 982/1761 – embedding 32 chunks...
# Batch 983/1761 – embedding 32 chunks...
# Batch 984/1761 – embedding 32 chunks...
# Batch 985/1761 – embedding 32 chunks...
# Batch 986/1761 – embedding 32 chunks...
# Batch 987/1761 – embedding 32 chunks...
# Batch 988/1761 – embedding 32 chunks...
# Batch 989/1761 – embedding 32 chunks...
# Batch 990/1761 – embedding 32 chunks...
# Batch 991/1761 – embedding 32 chunks...
# Batch 992/1761 – embedding 32 chunks...
# Batch 993/1761 – embedding 32 chunks...
# Batch 994/1761 – embedding 32 chunks...
# Batch 995/1761 – embedding 32 chunks...
# Batch 996/1761 – embedding 32 chunks...
# Batch 997/1761 – embedding 32 chunks...
# Batch 998/1761 – embedding 32 chunks...
# Batch 999/1761 – embedding 32 chunks...
# Batch 1000/1761 – embedding 32 chunks...
# Batch 1001/1761 – embedding 32 chunks...
# Batch 1002/1761 – embedding 32 chunks...
# Batch 1003/1761 – embedding 32 chunks...
# Batch 1004/1761 – embedding 32 chunks...
# Batch 1005/1761 – embedding 32 chunks...
# Batch 1006/1761 – embedding 32 chunks...
# Batch 1007/1761 – embedding 32 chunks...
# Batch 1008/1761 – embedding 32 chunks...
# Batch 1009/1761 – embedding 32 chunks...
# Batch 1010/1761 – embedding 32 chunks...
# Batch 1011/1761 – embedding 32 chunks...
# Batch 1012/1761 – embedding 32 chunks...
# Batch 1013/1761 – embedding 32 chunks...
# Batch 1014/1761 – embedding 32 chunks...
# Batch 1015/1761 – embedding 32 chunks...
# Batch 1016/1761 – embedding 32 chunks...
# Batch 1017/1761 – embedding 32 chunks...
# Batch 1018/1761 – embedding 32 chunks...
# Batch 1019/1761 – embedding 32 chunks...
# Batch 1020/1761 – embedding 32 chunks...
# Batch 1021/1761 – embedding 32 chunks...
# Batch 1022/1761 – embedding 32 chunks...
# Batch 1023/1761 – embedding 32 chunks...
# Batch 1024/1761 – embedding 32 chunks...
# Batch 1025/1761 – embedding 32 chunks...
# Batch 1026/1761 – embedding 32 chunks...
# Batch 1027/1761 – embedding 32 chunks...
# Batch 1028/1761 – embedding 32 chunks...
# Batch 1029/1761 – embedding 32 chunks...
# Batch 1030/1761 – embedding 32 chunks...
# Batch 1031/1761 – embedding 32 chunks...
# Batch 1032/1761 – embedding 32 chunks...
# Batch 1033/1761 – embedding 32 chunks...
# Batch 1034/1761 – embedding 32 chunks...
# Batch 1035/1761 – embedding 32 chunks...
# Batch 1036/1761 – embedding 32 chunks...
# Batch 1037/1761 – embedding 32 chunks...
# Batch 1038/1761 – embedding 32 chunks...
# Batch 1039/1761 – embedding 32 chunks...
# Batch 1040/1761 – embedding 32 chunks...
# Batch 1041/1761 – embedding 32 chunks...
# Batch 1042/1761 – embedding 32 chunks...
# Batch 1043/1761 – embedding 32 chunks...
# Batch 1044/1761 – embedding 32 chunks...
# Batch 1045/1761 – embedding 32 chunks...
# Batch 1046/1761 – embedding 32 chunks...
# Batch 1047/1761 – embedding 32 chunks...
# Batch 1048/1761 – embedding 32 chunks...
# Batch 1049/1761 – embedding 32 chunks...
# Batch 1050/1761 – embedding 32 chunks...
# Batch 1051/1761 – embedding 32 chunks...
# Batch 1052/1761 – embedding 32 chunks...
# Batch 1053/1761 – embedding 32 chunks...
# Batch 1054/1761 – embedding 32 chunks...
# Batch 1055/1761 – embedding 32 chunks...
# Batch 1056/1761 – embedding 32 chunks...
# Batch 1057/1761 – embedding 32 chunks...
# Batch 1058/1761 – embedding 32 chunks...
# Batch 1059/1761 – embedding 32 chunks...
# Batch 1060/1761 – embedding 32 chunks...
# Batch 1061/1761 – embedding 32 chunks...
# Batch 1062/1761 – embedding 32 chunks...
# Batch 1063/1761 – embedding 32 chunks...
# Batch 1064/1761 – embedding 32 chunks...
# Batch 1065/1761 – embedding 32 chunks...
# Batch 1066/1761 – embedding 32 chunks...
# Batch 1067/1761 – embedding 32 chunks...
# Batch 1068/1761 – embedding 32 chunks...
# Batch 1069/1761 – embedding 32 chunks...
# Batch 1070/1761 – embedding 32 chunks...
# Batch 1071/1761 – embedding 32 chunks...
# Batch 1072/1761 – embedding 32 chunks...
# Batch 1073/1761 – embedding 32 chunks...
# Batch 1074/1761 – embedding 32 chunks...
# Batch 1075/1761 – embedding 32 chunks...
# Batch 1076/1761 – embedding 32 chunks...
# Batch 1077/1761 – embedding 32 chunks...
# Batch 1078/1761 – embedding 32 chunks...
# Batch 1079/1761 – embedding 32 chunks...
# Batch 1080/1761 – embedding 32 chunks...
# Batch 1081/1761 – embedding 32 chunks...
# Batch 1082/1761 – embedding 32 chunks...
# Batch 1083/1761 – embedding 32 chunks...
# Batch 1084/1761 – embedding 32 chunks...
# Batch 1085/1761 – embedding 32 chunks...
# Batch 1086/1761 – embedding 32 chunks...
# Batch 1087/1761 – embedding 32 chunks...
# Batch 1088/1761 – embedding 32 chunks...
# Batch 1089/1761 – embedding 32 chunks...
# Batch 1090/1761 – embedding 32 chunks...
# Batch 1091/1761 – embedding 32 chunks...
# Batch 1092/1761 – embedding 32 chunks...
# Batch 1093/1761 – embedding 32 chunks...
# Batch 1094/1761 – embedding 32 chunks...
# Batch 1095/1761 – embedding 32 chunks...
# Batch 1096/1761 – embedding 32 chunks...
# Batch 1097/1761 – embedding 32 chunks...
# Batch 1098/1761 – embedding 32 chunks...
# Batch 1099/1761 – embedding 32 chunks...
# Batch 1100/1761 – embedding 32 chunks...
# Batch 1101/1761 – embedding 32 chunks...
# Batch 1102/1761 – embedding 32 chunks...
# Batch 1103/1761 – embedding 32 chunks...
# Batch 1104/1761 – embedding 32 chunks...
# Batch 1105/1761 – embedding 32 chunks...
# Batch 1106/1761 – embedding 32 chunks...
# Batch 1107/1761 – embedding 32 chunks...
# Batch 1108/1761 – embedding 32 chunks...
# Batch 1109/1761 – embedding 32 chunks...
# Batch 1110/1761 – embedding 32 chunks...
# Batch 1111/1761 – embedding 32 chunks...
# Batch 1112/1761 – embedding 32 chunks...
# Batch 1113/1761 – embedding 32 chunks...
# Batch 1114/1761 – embedding 32 chunks...
# Batch 1115/1761 – embedding 32 chunks...
# Batch 1116/1761 – embedding 32 chunks...
# Batch 1117/1761 – embedding 32 chunks...
# Batch 1118/1761 – embedding 32 chunks...
# Batch 1119/1761 – embedding 32 chunks...
# Batch 1120/1761 – embedding 32 chunks...
# Batch 1121/1761 – embedding 32 chunks...
# Batch 1122/1761 – embedding 32 chunks...
# Batch 1123/1761 – embedding 32 chunks...
# Batch 1124/1761 – embedding 32 chunks...
# Batch 1125/1761 – embedding 32 chunks...
# Batch 1126/1761 – embedding 32 chunks...
# Batch 1127/1761 – embedding 32 chunks...
# Batch 1128/1761 – embedding 32 chunks...
# Batch 1129/1761 – embedding 32 chunks...
# Batch 1130/1761 – embedding 32 chunks...
# Batch 1131/1761 – embedding 32 chunks...
# Batch 1132/1761 – embedding 32 chunks...
# Batch 1133/1761 – embedding 32 chunks...
# Batch 1134/1761 – embedding 32 chunks...
# Batch 1135/1761 – embedding 32 chunks...
# Batch 1136/1761 – embedding 32 chunks...
# Batch 1137/1761 – embedding 32 chunks...
# Batch 1138/1761 – embedding 32 chunks...
# Batch 1139/1761 – embedding 32 chunks...
# Batch 1140/1761 – embedding 32 chunks...
# Batch 1141/1761 – embedding 32 chunks...
# Batch 1142/1761 – embedding 32 chunks...
# Batch 1143/1761 – embedding 32 chunks...
# Batch 1144/1761 – embedding 32 chunks...
# Batch 1145/1761 – embedding 32 chunks...
# Batch 1146/1761 – embedding 32 chunks...
# Batch 1147/1761 – embedding 32 chunks...
# Batch 1148/1761 – embedding 32 chunks...
# Batch 1149/1761 – embedding 32 chunks...
# Batch 1150/1761 – embedding 32 chunks...
# Batch 1151/1761 – embedding 32 chunks...
# Batch 1152/1761 – embedding 32 chunks...
# Batch 1153/1761 – embedding 32 chunks...
# Batch 1154/1761 – embedding 32 chunks...
# Batch 1155/1761 – embedding 32 chunks...
# Batch 1156/1761 – embedding 32 chunks...
# Batch 1157/1761 – embedding 32 chunks...
# Batch 1158/1761 – embedding 32 chunks...
# Batch 1159/1761 – embedding 32 chunks...
# Batch 1160/1761 – embedding 32 chunks...
# Batch 1161/1761 – embedding 32 chunks...
# Batch 1162/1761 – embedding 32 chunks...
# Batch 1163/1761 – embedding 32 chunks...
# Batch 1164/1761 – embedding 32 chunks...
# Batch 1165/1761 – embedding 32 chunks...
# Batch 1166/1761 – embedding 32 chunks...
# Batch 1167/1761 – embedding 32 chunks...
# Batch 1168/1761 – embedding 32 chunks...
# Batch 1169/1761 – embedding 32 chunks...
# Batch 1170/1761 – embedding 32 chunks...
# Batch 1171/1761 – embedding 32 chunks...
# Batch 1172/1761 – embedding 32 chunks...
# Batch 1173/1761 – embedding 32 chunks...
# Batch 1174/1761 – embedding 32 chunks...
# Batch 1175/1761 – embedding 32 chunks...
# ...
# Batch 1375/1761 – embedding 32 chunks...
# Batch 1376/1761 – embedding 32 chunks...
# Batch 1377/1761 – embedding 32 chunks...
# Batch 1378/1761 – embedding 32 chunks...
# Batch 1379/1761 – embedding 32 chunks...
# Batch 1380/1761 – embedding 32 chunks...
# Batch 1381/1761 – embedding 32 chunks...
# Batch 1382/1761 – embedding 32 chunks...
# Batch 1383/1761 – embedding 32 chunks...
# Batch 1384/1761 – embedding 32 chunks...
# Batch 1385/1761 – embedding 32 chunks...
# Batch 1386/1761 – embedding 32 chunks...
# Batch 1387/1761 – embedding 32 chunks...
# Batch 1388/1761 – embedding 32 chunks...
# Batch 1389/1761 – embedding 32 chunks...
# Batch 1390/1761 – embedding 32 chunks...
# Batch 1391/1761 – embedding 32 chunks...
# Batch 1392/1761 – embedding 32 chunks...
# Batch 1393/1761 – embedding 32 chunks...
# Batch 1394/1761 – embedding 32 chunks...
# Batch 1395/1761 – embedding 32 chunks...
# Batch 1396/1761 – embedding 32 chunks...
# Batch 1397/1761 – embedding 32 chunks...
# Batch 1398/1761 – embedding 32 chunks...
# Batch 1399/1761 – embedding 32 chunks...
# Batch 1400/1761 – embedding 32 chunks...
# Batch 1401/1761 – embedding 32 chunks...
# Batch 1402/1761 – embedding 32 chunks...
# Batch 1403/1761 – embedding 32 chunks...
# Batch 1404/1761 – embedding 32 chunks...
# Batch 1405/1761 – embedding 32 chunks...
# Batch 1406/1761 – embedding 32 chunks...
# Batch 1407/1761 – embedding 32 chunks...
# Batch 1408/1761 – embedding 32 chunks...
# Batch 1409/1761 – embedding 32 chunks...
# Batch 1410/1761 – embedding 32 chunks...
# Batch 1411/1761 – embedding 32 chunks...
# Batch 1412/1761 – embedding 32 chunks...
# Batch 1413/1761 – embedding 32 chunks...
# Batch 1414/1761 – embedding 32 chunks...
# Batch 1415/1761 – embedding 32 chunks...
# Batch 1416/1761 – embedding 32 chunks...
# Batch 1417/1761 – embedding 32 chunks...
# Batch 1418/1761 – embedding 32 chunks...
# Batch 1419/1761 – embedding 32 chunks...
# Batch 1420/1761 – embedding 32 chunks...
# Batch 1421/1761 – embedding 32 chunks...
# Batch 1422/1761 – embedding 32 chunks...
# Batch 1423/1761 – embedding 32 chunks...
# Batch 1424/1761 – embedding 32 chunks...
# Batch 1425/1761 – embedding 32 chunks...
# Batch 1426/1761 – embedding 32 chunks...
# Batch 1427/1761 – embedding 32 chunks...
# Batch 1428/1761 – embedding 32 chunks...
# Batch 1429/1761 – embedding 32 chunks...
# Batch 1430/1761 – embedding 32 chunks...
# Batch 1431/1761 – embedding 32 chunks...
# Batch 1432/1761 – embedding 32 chunks...
# Batch 1433/1761 – embedding 32 chunks...
# Batch 1434/1761 – embedding 32 chunks...
# Batch 1435/1761 – embedding 32 chunks...
# Batch 1436/1761 – embedding 32 chunks...
# Batch 1437/1761 – embedding 32 chunks...
# Batch 1438/1761 – embedding 32 chunks...
# Batch 1439/1761 – embedding 32 chunks...
# Batch 1440/1761 – embedding 32 chunks...
# Batch 1441/1761 – embedding 32 chunks...
# Batch 1442/1761 – embedding 32 chunks...
# Batch 1443/1761 – embedding 32 chunks...
# Batch 1444/1761 – embedding 32 chunks...
# Batch 1445/1761 – embedding 32 chunks...
# Batch 1446/1761 – embedding 32 chunks...
# Batch 1447/1761 – embedding 32 chunks...
# Batch 1448/1761 – embedding 32 chunks...
# Batch 1449/1761 – embedding 32 chunks...
# Batch 1450/1761 – embedding 32 chunks...
# Batch 1451/1761 – embedding 32 chunks...
# Batch 1452/1761 – embedding 32 chunks...
# Batch 1453/1761 – embedding 32 chunks...
# Batch 1454/1761 – embedding 32 chunks...
# Batch 1455/1761 – embedding 32 chunks...
# Batch 1456/1761 – embedding 32 chunks...
# Batch 1457/1761 – embedding 32 chunks...
# Batch 1458/1761 – embedding 32 chunks...
# Batch 1459/1761 – embedding 32 chunks...
# Batch 1460/1761 – embedding 32 chunks...
# Batch 1461/1761 – embedding 32 chunks...
# Batch 1462/1761 – embedding 32 chunks...
# Batch 1463/1761 – embedding 32 chunks...
# Batch 1464/1761 – embedding 32 chunks...
# Batch 1465/1761 – embedding 32 chunks...
# Batch 1466/1761 – embedding 32 chunks...
# Batch 1467/1761 – embedding 32 chunks...
# Batch 1468/1761 – embedding 32 chunks...
# Batch 1469/1761 – embedding 32 chunks...
# Batch 1470/1761 – embedding 32 chunks...
# Batch 1471/1761 – embedding 32 chunks...
# Batch 1472/1761 – embedding 32 chunks...
# Batch 1473/1761 – embedding 32 chunks...
# Batch 1474/1761 – embedding 32 chunks...
# Batch 1475/1761 – embedding 32 chunks...
# Batch 1476/1761 – embedding 32 chunks...
# Batch 1477/1761 – embedding 32 chunks...
# Batch 1478/1761 – embedding 32 chunks...
# Batch 1479/1761 – embedding 32 chunks...
# Batch 1480/1761 – embedding 32 chunks...
# Batch 1481/1761 – embedding 32 chunks...
# Batch 1482/1761 – embedding 32 chunks...
# Batch 1483/1761 – embedding 32 chunks...
# Batch 1484/1761 – embedding 32 chunks...
# Batch 1485/1761 – embedding 32 chunks...
# Batch 1486/1761 – embedding 32 chunks...
# Batch 1487/1761 – embedding 32 chunks...
# Batch 1488/1761 – embedding 32 chunks...
# Batch 1489/1761 – embedding 32 chunks...
# Batch 1490/1761 – embedding 32 chunks...
# Batch 1491/1761 – embedding 32 chunks...
# Batch 1492/1761 – embedding 32 chunks...
# Batch 1493/1761 – embedding 32 chunks...
# Batch 1494/1761 – embedding 32 chunks...
# Batch 1495/1761 – embedding 32 chunks...
# Batch 1496/1761 – embedding 32 chunks...
# Batch 1497/1761 – embedding 32 chunks...
# Batch 1498/1761 – embedding 32 chunks...
# Batch 1499/1761 – embedding 32 chunks...
# Batch 1500/1761 – embedding 32 chunks...
# Batch 1501/1761 – embedding 32 chunks...
# Batch 1502/1761 – embedding 32 chunks...
# Batch 1503/1761 – embedding 32 chunks...
# Batch 1504/1761 – embedding 32 chunks...
# Batch 1505/1761 – embedding 32 chunks...
# Batch 1506/1761 – embedding 32 chunks...
# Batch 1507/1761 – embedding 32 chunks...
# Batch 1508/1761 – embedding 32 chunks...
# Batch 1509/1761 – embedding 32 chunks...
# Batch 1510/1761 – embedding 32 chunks...
# Batch 1511/1761 – embedding 32 chunks...
# Batch 1512/1761 – embedding 32 chunks...
# Batch 1513/1761 – embedding 32 chunks...
# Batch 1514/1761 – embedding 32 chunks...
# Batch 1515/1761 – embedding 32 chunks...
# Batch 1516/1761 – embedding 32 chunks...
# Batch 1517/1761 – embedding 32 chunks...
# Batch 1518/1761 – embedding 32 chunks...
# Batch 1519/1761 – embedding 32 chunks...
# Batch 1520/1761 – embedding 32 chunks...
# Batch 1521/1761 – embedding 32 chunks...
# Batch 1522/1761 – embedding 32 chunks...
# Batch 1523/1761 – embedding 32 chunks...
# Batch 1524/1761 – embedding 32 chunks...
# Batch 1525/1761 – embedding 32 chunks...
# Batch 1526/1761 – embedding 32 chunks...
# Batch 1527/1761 – embedding 32 chunks...
# Batch 1528/1761 – embedding 32 chunks...
# Batch 1529/1761 – embedding 32 chunks...
# Batch 1530/1761 – embedding 32 chunks...
# Batch 1531/1761 – embedding 32 chunks...
# Batch 1532/1761 – embedding 32 chunks...
# Batch 1533/1761 – embedding 32 chunks...
# Batch 1534/1761 – embedding 32 chunks...
# Batch 1535/1761 – embedding 32 chunks...
# Batch 1536/1761 – embedding 32 chunks...
# Batch 1537/1761 – embedding 32 chunks...
# Batch 1538/1761 – embedding 32 chunks...
# Batch 1539/1761 – embedding 32 chunks...
# Batch 1540/1761 – embedding 32 chunks...
# Batch 1541/1761 – embedding 32 chunks...
# Batch 1542/1761 – embedding 32 chunks...
# Batch 1543/1761 – embedding 32 chunks...
# Batch 1544/1761 – embedding 32 chunks...
# Batch 1545/1761 – embedding 32 chunks...
# Batch 1546/1761 – embedding 32 chunks...
# Batch 1547/1761 – embedding 32 chunks...
# Batch 1548/1761 – embedding 32 chunks...
# Batch 1549/1761 – embedding 32 chunks...
# Batch 1550/1761 – embedding 32 chunks...
# Batch 1551/1761 – embedding 32 chunks...
# Batch 1552/1761 – embedding 32 chunks...
# Batch 1553/1761 – embedding 32 chunks...
# Batch 1554/1761 – embedding 32 chunks...
# Batch 1555/1761 – embedding 32 chunks...
# Batch 1556/1761 – embedding 32 chunks...
# Batch 1557/1761 – embedding 32 chunks...
# Batch 1558/1761 – embedding 32 chunks...
# Batch 1559/1761 – embedding 32 chunks...
# Batch 1560/1761 – embedding 32 chunks...
# Batch 1561/1761 – embedding 32 chunks...
# Batch 1562/1761 – embedding 32 chunks...
# Batch 1563/1761 – embedding 32 chunks...
# Batch 1564/1761 – embedding 32 chunks...
# Batch 1565/1761 – embedding 32 chunks...
# Batch 1566/1761 – embedding 32 chunks...
# Batch 1567/1761 – embedding 32 chunks...
# Batch 1568/1761 – embedding 32 chunks...
# Batch 1569/1761 – embedding 32 chunks...
# Batch 1570/1761 – embedding 32 chunks...
# Batch 1571/1761 – embedding 32 chunks...
# Batch 1572/1761 – embedding 32 chunks...
# Batch 1573/1761 – embedding 32 chunks...
# Batch 1574/1761 – embedding 32 chunks...
# Batch 1575/1761 – embedding 32 chunks...
# Batch 1576/1761 – embedding 32 chunks...
# Batch 1577/1761 – embedding 32 chunks...
# Batch 1578/1761 – embedding 32 chunks...
# Batch 1579/1761 – embedding 32 chunks...
# Batch 1580/1761 – embedding 32 chunks...
# Batch 1581/1761 – embedding 32 chunks...
# Batch 1582/1761 – embedding 32 chunks...
# Batch 1583/1761 – embedding 32 chunks...
# Batch 1584/1761 – embedding 32 chunks...
# Batch 1585/1761 – embedding 32 chunks...
# Batch 1586/1761 – embedding 32 chunks...
# Batch 1587/1761 – embedding 32 chunks...
# Batch 1588/1761 – embedding 32 chunks...
# Batch 1589/1761 – embedding 32 chunks...
# Batch 1590/1761 – embedding 32 chunks...
# Batch 1591/1761 – embedding 32 chunks...
# Batch 1592/1761 – embedding 32 chunks...
# Batch 1593/1761 – embedding 32 chunks...
# Batch 1594/1761 – embedding 32 chunks...
# Batch 1595/1761 – embedding 32 chunks...
# Batch 1596/1761 – embedding 32 chunks...
# Batch 1597/1761 – embedding 32 chunks...
# Batch 1598/1761 – embedding 32 chunks...
# Batch 1599/1761 – embedding 32 chunks...
# Batch 1600/1761 – embedding 32 chunks...
# Batch 1601/1761 – embedding 32 chunks...
# Batch 1602/1761 – embedding 32 chunks...
# Batch 1603/1761 – embedding 32 chunks...
# Batch 1604/1761 – embedding 32 chunks...
# Batch 1605/1761 – embedding 32 chunks...
# Batch 1606/1761 – embedding 32 chunks...
# Batch 1607/1761 – embedding 32 chunks...
# Batch 1608/1761 – embedding 32 chunks...
# Batch 1609/1761 – embedding 32 chunks...
# Batch 1610/1761 – embedding 32 chunks...
# Batch 1611/1761 – embedding 32 chunks...
# Batch 1612/1761 – embedding 32 chunks...
# Batch 1613/1761 – embedding 32 chunks...
# Batch 1614/1761 – embedding 32 chunks...
# Batch 1615/1761 – embedding 32 chunks...
# Batch 1616/1761 – embedding 32 chunks...
# Batch 1617/1761 – embedding 32 chunks...
# Batch 1618/1761 – embedding 32 chunks...
# Batch 1619/1761 – embedding 32 chunks...
# Batch 1620/1761 – embedding 32 chunks...
# Batch 1621/1761 – embedding 32 chunks...
# Batch 1622/1761 – embedding 32 chunks...
# Batch 1623/1761 – embedding 32 chunks...
# Batch 1624/1761 – embedding 32 chunks...
# Batch 1625/1761 – embedding 32 chunks...
# Batch 1626/1761 – embedding 32 chunks...
# Batch 1627/1761 – embedding 32 chunks...
# Batch 1628/1761 – embedding 32 chunks...
# Batch 1629/1761 – embedding 32 chunks...
# Batch 1630/1761 – embedding 32 chunks...
# Batch 1631/1761 – embedding 32 chunks...
# Batch 1632/1761 – embedding 32 chunks...
# Batch 1633/1761 – embedding 32 chunks...
# Batch 1634/1761 – embedding 32 chunks...
# Batch 1635/1761 – embedding 32 chunks...
# Batch 1636/1761 – embedding 32 chunks...
# Batch 1637/1761 – embedding 32 chunks...
# Batch 1638/1761 – embedding 32 chunks...
# Batch 1639/1761 – embedding 32 chunks...
# Batch 1640/1761 – embedding 32 chunks...
# Batch 1641/1761 – embedding 32 chunks...
# Batch 1642/1761 – embedding 32 chunks...
# Batch 1643/1761 – embedding 32 chunks...
# Batch 1644/1761 – embedding 32 chunks...
# Batch 1645/1761 – embedding 32 chunks...
# Batch 1646/1761 – embedding 32 chunks...
# Batch 1647/1761 – embedding 32 chunks...
# Batch 1648/1761 – embedding 32 chunks...
# Batch 1649/1761 – embedding 32 chunks...
# Batch 1650/1761 – embedding 32 chunks...
# Batch 1651/1761 – embedding 32 chunks...
# Batch 1652/1761 – embedding 32 chunks...
# Batch 1653/1761 – embedding 32 chunks...
# Batch 1654/1761 – embedding 32 chunks...
# Batch 1655/1761 – embedding 32 chunks...
# Batch 1656/1761 – embedding 32 chunks...
# Batch 1657/1761 – embedding 32 chunks...
# Batch 1658/1761 – embedding 32 chunks...
# Batch 1659/1761 – embedding 32 chunks...
# Batch 1660/1761 – embedding 32 chunks...
# Batch 1661/1761 – embedding 32 chunks...
# Batch 1662/1761 – embedding 32 chunks...
# Batch 1663/1761 – embedding 32 chunks...
# Batch 1664/1761 – embedding 32 chunks...
# Batch 1665/1761 – embedding 32 chunks...
# Batch 1666/1761 – embedding 32 chunks...
# Batch 1667/1761 – embedding 32 chunks...
# Batch 1668/1761 – embedding 32 chunks...
# Batch 1669/1761 – embedding 32 chunks...
# Batch 1670/1761 – embedding 32 chunks...
# Batch 1671/1761 – embedding 32 chunks...
# Batch 1672/1761 – embedding 32 chunks...
# Batch 1673/1761 – embedding 32 chunks...
# Batch 1674/1761 – embedding 32 chunks...
# Batch 1675/1761 – embedding 32 chunks...
# Batch 1676/1761 – embedding 32 chunks...
# Batch 1677/1761 – embedding 32 chunks...
# Batch 1678/1761 – embedding 32 chunks...
# Batch 1679/1761 – embedding 32 chunks...
# Batch 1680/1761 – embedding 32 chunks...
# Batch 1681/1761 – embedding 32 chunks...
# Batch 1682/1761 – embedding 32 chunks...
# Batch 1683/1761 – embedding 32 chunks...
# Batch 1684/1761 – embedding 32 chunks...
# Batch 1685/1761 – embedding 32 chunks...
# Batch 1686/1761 – embedding 32 chunks...
# Batch 1687/1761 – embedding 32 chunks...
# Batch 1688/1761 – embedding 32 chunks...
# Batch 1689/1761 – embedding 32 chunks...
# Batch 1690/1761 – embedding 32 chunks...
# Batch 1691/1761 – embedding 32 chunks...
# Batch 1692/1761 – embedding 32 chunks...
# Batch 1693/1761 – embedding 32 chunks...
# Batch 1694/1761 – embedding 32 chunks...
# Batch 1695/1761 – embedding 32 chunks...
# Batch 1696/1761 – embedding 32 chunks...
# Batch 1697/1761 – embedding 32 chunks...
# Batch 1698/1761 – embedding 32 chunks...
# Batch 1699/1761 – embedding 32 chunks...
# Batch 1700/1761 – embedding 32 chunks...
# Batch 1701/1761 – embedding 32 chunks...
# Batch 1702/1761 – embedding 32 chunks...
# Batch 1703/1761 – embedding 32 chunks...
# Batch 1704/1761 – embedding 32 chunks...
# Batch 1705/1761 – embedding 32 chunks...
# Batch 1706/1761 – embedding 32 chunks...
# Batch 1707/1761 – embedding 32 chunks...
# Batch 1708/1761 – embedding 32 chunks...
# Batch 1709/1761 – embedding 32 chunks...
# Batch 1710/1761 – embedding 32 chunks...
# Batch 1711/1761 – embedding 32 chunks...
# Batch 1712/1761 – embedding 32 chunks...
# Batch 1713/1761 – embedding 32 chunks...
# Batch 1714/1761 – embedding 32 chunks...
# Batch 1715/1761 – embedding 32 chunks...
# Batch 1716/1761 – embedding 32 chunks...
# Batch 1717/1761 – embedding 32 chunks...
# Batch 1718/1761 – embedding 32 chunks...
# Batch 1719/1761 – embedding 32 chunks...
# Batch 1720/1761 – embedding 32 chunks...
# Batch 1721/1761 – embedding 32 chunks...
# Batch 1722/1761 – embedding 32 chunks...
# Batch 1723/1761 – embedding 32 chunks...
# Batch 1724/1761 – embedding 32 chunks...
# Batch 1725/1761 – embedding 32 chunks...
# Batch 1726/1761 – embedding 32 chunks...
# Batch 1727/1761 – embedding 32 chunks...
# Batch 1728/1761 – embedding 32 chunks...
# Batch 1729/1761 – embedding 32 chunks...
# Batch 1730/1761 – embedding 32 chunks...
# Batch 1731/1761 – embedding 32 chunks...
# Batch 1732/1761 – embedding 32 chunks...
# Batch 1733/1761 – embedding 32 chunks...
# Batch 1734/1761 – embedding 32 chunks...
# Batch 1735/1761 – embedding 32 chunks...
# Batch 1736/1761 – embedding 32 chunks...
# Batch 1737/1761 – embedding 32 chunks...
# Batch 1738/1761 – embedding 32 chunks...
# Batch 1739/1761 – embedding 32 chunks...
# Batch 1740/1761 – embedding 32 chunks...
# Batch 1741/1761 – embedding 32 chunks...
# Batch 1742/1761 – embedding 32 chunks...
# Batch 1743/1761 – embedding 32 chunks...
# Batch 1744/1761 – embedding 32 chunks...
# Batch 1745/1761 – embedding 32 chunks...
# Batch 1746/1761 – embedding 32 chunks...
# Batch 1747/1761 – embedding 32 chunks...
# Batch 1748/1761 – embedding 32 chunks...
# Batch 1749/1761 – embedding 32 chunks...
# Batch 1750/1761 – embedding 32 chunks...
# Batch 1751/1761 – embedding 32 chunks...
# Batch 1752/1761 – embedding 32 chunks...
# Batch 1753/1761 – embedding 32 chunks...
# Batch 1754/1761 – embedding 32 chunks...
# Batch 1755/1761 – embedding 32 chunks...
# Batch 1756/1761 – embedding 32 chunks...
# Batch 1757/1761 – embedding 32 chunks...
# Batch 1758/1761 – embedding 32 chunks...
# Batch 1759/1761 – embedding 32 chunks...
# Batch 1760/1761 – embedding 32 chunks...
# Batch 1761/1761 – embedding 27 chunks...
# Embedding pipeline completed.
# Vector index 'chunkEmbeddings' ensured on :OpinionChunk(embedding) with dim=1024.
